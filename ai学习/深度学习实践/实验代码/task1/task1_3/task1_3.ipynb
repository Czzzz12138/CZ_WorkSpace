# %% [markdown]
# # 任务1_3: Transformer  (MNIST)

# %% [markdown]
# ## 1) 安装与启动 Jupyter 内核（VS Code）
#
# 首次使用可在此单元安装依赖；运行后在 VS Code 右上角选择 Python 内核。

# %%
# 如已安装可跳过
# %pip install -U pip
# %pip install ipykernel notebook torch torchvision pillow pandas matplotlib

# 导入 sys 用于查看当前内核的 Python 路径
import sys
# 输出当前解释器路径，确认内核环境
print(sys.executable)
# 输出提示信息，确认单元执行
print("内核已就绪")
# Out:
# d:\anaconda\envs\DL\python.exe
# 内核已就绪

# %%
# 解决 Windows 下 OpenMP 重复加载导致的内核崩溃问题
# 导入 os 用于设置环境变量
import os
# 允许重复加载 OpenMP 库，避免特定环境崩溃
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
# 打印确认信息
print("KMP_DUPLICATE_LIB_OK set")
# Out:
# KMP_DUPLICATE_LIB_OK set

# %% [markdown]
# ## 2) 导入依赖并检查 PyTorch 版本

# %%
# 基础库：路径、正则、随机数
import os
import re
import random
# 深度学习与数据处理相关
import torch
import pandas as pd
import torch.nn as nn
import matplotlib.pyplot as plt
from PIL import Image
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader

# 打印 PyTorch 版本，确认环境
print("torch version:", torch.__version__)
# Out:
# torch version: 2.8.0+cpu

# %% [markdown]
# ## 3) 配置数据路径（基于当前工作目录）
#
# Notebook 中没有 __file__，这里使用当前工作目录并手动拼接数据路径。

# %%
# 若你的 Notebook 不在该目录运行，可手动指定项目根目录
# 这里用当前工作目录的上一级作为默认根目录
project_root = os.path.dirname(os.getcwd())
# 例如：project_root = r"d:/CZ_WorkSpace/ai学习/深度学习实践"

# 拼接训练与测试数据集路径
train_dir = os.path.join(project_root, "MNIST_kaggle", "trainingSet")
test_dir = os.path.join(project_root, "MNIST_kaggle", "testSet")

# 打印路径与是否存在，便于排查数据路径问题
print("cwd:", os.getcwd())
print("project_root:", project_root)
print("train_dir exists:", os.path.exists(train_dir), "train_dir:", train_dir)
print("test_dir exists:", os.path.exists(test_dir), "test_dir:", test_dir)
# Out:
# cwd: d:\CZ_WorkSpace\ai学习\深度学习实践\task1\task1_3
# project_root: d:\CZ_WorkSpace\ai学习\深度学习实践\task1
# train_dir exists: True train_dir: d:\CZ_WorkSpace\ai学习\深度学习实践\task1\MNIST_kaggle\trainingSet
# test_dir exists: True test_dir: d:\CZ_WorkSpace\ai学习\深度学习实践\task1\MNIST_kaggle\testSet

# %% [markdown]
# ## 4) 定义 MyDataset（有标签/无标签双模式）
#
# Transformer 输入为 [1, 28, 28]，后续在模型中做 Patch Embedding。

# %%
class MyDataset(Dataset):
    # 初始化数据集，支持有标签/无标签两种模式
    def __init__(self, data_dir, labeled=True):
        # 保存数据目录与标注标记
        self.data_dir = data_dir
        self.labeled = labeled
        # samples 保存 (路径, 标签) 或 路径
        self.samples = []
        # 定义统一的图像预处理流程
        self.transform = transforms.Compose([
            transforms.Grayscale(num_output_channels=1),
            transforms.Resize((28, 28)),
            transforms.ToTensor(),
        ])

        # 如果是训练集，读取子目录作为类别
        if self.labeled:
            # 获取所有类别目录名
            class_names = [d for d in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, d))]
            # 按数字顺序排序类别目录
            class_names = sorted(class_names, key=lambda x: int(x) if x.isdigit() else x)
            # 构建类别名到整数标签的映射
            self.class_to_idx = {name: int(name) for name in class_names}
            # 遍历每个类别目录收集样本
            for class_name in class_names:
                class_dir = os.path.join(data_dir, class_name)
                for file_name in os.listdir(class_dir):
                    # 只保留图片文件
                    if file_name.lower().endswith((".jpg", ".jpeg", ".png", ".bmp")):
                        file_path = os.path.join(class_dir, file_name)
                        label = self.class_to_idx[class_name]
                        self.samples.append((file_path, label))
        else:
            # 测试集无标签，仅保存图片路径
            self.class_to_idx = {}
            for file_name in os.listdir(data_dir):
                file_path = os.path.join(data_dir, file_name)
                # 只保留图片文件
                if os.path.isfile(file_path) and file_name.lower().endswith((".jpg", ".jpeg", ".png", ".bmp")):
                    self.samples.append(file_path)

    # 返回样本数量
    def __len__(self):
        return len(self.samples)

    # 获取单个样本
    def __getitem__(self, idx):
        # 根据是否有标签拆包
        if self.labeled:
            file_path, label = self.samples[idx]
        else:
            file_path = self.samples[idx]
            label = None

        # 读取图片并做预处理
        image = Image.open(file_path)
        image = self.transform(image)

        # 训练集返回 (图像张量, 标签)
        if self.labeled:
            return image, torch.tensor(label, dtype=torch.long)
        # 测试集返回 (图像张量, 文件路径)
        return image, file_path

# %% [markdown]
# ## 5) 构建 DataLoader 并检查 batch 形状

# %%
# 构建训练集 Dataset（有标签）
mydataset = MyDataset(data_dir=train_dir, labeled=True)
# 训练 DataLoader：打乱样本，提升训练随机性
mydataset_loader = DataLoader(mydataset, batch_size=64, shuffle=True)

# 构建测试集 Dataset（无标签）
test_dataset = MyDataset(data_dir=test_dir, labeled=False)
# 测试 DataLoader：不打乱，保持文件顺序
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# 打印样本数量，检查数据是否加载成功
print(f"Train samples: {len(mydataset)}")
print(f"Test samples: {len(test_dataset)}")

# 简单查看前两个 batch 的形状与标签示例
for batch_idx, (images, labels) in enumerate(mydataset_loader):
    print(f"Batch {batch_idx}: images={images.shape}, labels={labels.shape}")
    print("Label sample:", labels[:10].tolist())
    if batch_idx == 1:
        break
# Out:
# Train samples: 42000
# Test samples: 28000
# Batch 0: images=torch.Size([64, 1, 28, 28]), labels=torch.Size([64])
# Label sample: [9, 4, 0, 6, 4, 6, 8, 7, 7, 1]
# Batch 1: images=torch.Size([64, 1, 28, 28]), labels=torch.Size([64])
# Label sample: [9, 6, 7, 7, 8, 6, 1, 2, 3, 5]

# %% [markdown]
# ## 6) 定义 Transformer 网络 MyTransformer
#
# 采用 Patch Embedding + TransformerEncoder + 分类头。

# %%
class PatchEmbed(nn.Module):
    # 将图像划分为 patch，并映射到 embedding 维度
    def __init__(self, img_size=28, patch_size=4, in_chans=1, embed_dim=64):
        super().__init__()
        if img_size % patch_size != 0:
            raise ValueError("img_size must be divisible by patch_size")
        self.patch_size = patch_size
        self.num_patches = (img_size // patch_size) ** 2
        # 使用卷积实现 patch 划分与线性映射
        self.proj = nn.Conv2d(in_chans, embed_dim, kernel_size=patch_size, stride=patch_size)

    def forward(self, x):
        # [B, C, H, W] -> [B, embed_dim, H', W']
        x = self.proj(x)
        # 展平空间维度，得到 patch 序列 [B, num_patches, embed_dim]
        x = x.flatten(2).transpose(1, 2)
        return x


class MyTransformer(nn.Module):
    # 初始化 Transformer 模型
    def __init__(self, img_size=28, patch_size=4, embed_dim=64, num_heads=4, num_layers=2, mlp_ratio=2):
        super().__init__()
        # Patch Embedding
        self.patch_embed = PatchEmbed(img_size=img_size, patch_size=patch_size, in_chans=1, embed_dim=embed_dim)
        num_patches = self.patch_embed.num_patches
        # 位置编码（可学习）
        self.pos_embed = nn.Parameter(torch.zeros(1, num_patches, embed_dim))
        # Transformer 编码器层
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=embed_dim,
            nhead=num_heads,
            dim_feedforward=embed_dim * mlp_ratio,
            dropout=0.1,
            batch_first=True,
        )
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)
        # 分类头
        self.classifier = nn.Linear(embed_dim, 10)

    def forward(self, x):
        # 生成 patch token 序列
        x = self.patch_embed(x)
        # 加上位置编码
        x = x + self.pos_embed
        # Transformer 编码
        x = self.encoder(x)
        # 全局平均池化得到图像表示
        x = x.mean(dim=1)
        # 分类输出 logits
        x = self.classifier(x)
        return x

# %% [markdown]
# ## 7) 定义评估函数 evaluate 与单样本推理 single_sample_check

# %%
def evaluate(model, data_loader):
    # 若数据集为空或无标签，跳过评估
    if len(data_loader.dataset) == 0 or not data_loader.dataset.labeled:
        print("Warning: test set has no labels, skip accuracy evaluation.")
        return None

    # 切换到评估模式，关闭 dropout/bn 的训练行为
    model.eval()
    correct = 0
    total = 0
    # 评估阶段不需要梯度，节省显存与时间
    with torch.no_grad():
        for images, labels in data_loader:
            # 前向推理得到 logits
            outputs = model(images)
            # 取最大值所在类别作为预测结果
            preds = torch.argmax(outputs, dim=1)
            # 统计预测正确数量
            correct += (preds == labels).sum().item()
            # 统计样本总数
            total += labels.size(0)

    # 恢复训练模式，避免影响后续训练
    model.train()
    if total == 0:
        print("Warning: test set is empty, skip accuracy evaluation.")
        return None
    # 返回准确率
    return correct / total


def single_sample_check(model, dataset):
    # 若测试集为空，直接返回
    if len(dataset) == 0:
        print("Single image validation skipped: test dataset is empty.")
        return

    # 随机抽取一张图片做单样本推理
    sample_idx = random.randint(0, len(dataset) - 1)
    sample = dataset[sample_idx]
    if dataset.labeled:
        # 训练集/有标签模式
        image, label = sample
        image_path, _ = dataset.samples[sample_idx]
    else:
        # 测试集/无标签模式
        image, image_path = sample
        label = None

    # 推理前切换到评估模式
    model.eval()
    with torch.no_grad():
        # 为单张图片增加 batch 维度
        logits = model(image.unsqueeze(0))
        # 计算 softmax 概率用于置信度
        probs = torch.softmax(logits, dim=1)
        # 取最大概率的类别作为预测结果
        pred = torch.argmax(probs, dim=1).item()
        # 取预测类别的置信度
        confidence = probs[0, pred].item()
    # 恢复训练模式
    model.train()

    # 输出推理结果
    print("\nSingle Image Validation")
    print(f"Image: {image_path}")
    if label is not None:
        print(f"True Label: {label.item()}, Pred Label: {pred}, Confidence: {confidence:.4f}")
    else:
        print(f"Pred Label: {pred}, Confidence: {confidence:.4f} (no ground-truth label)")

# %% [markdown]
# ## 8) 定义损失函数与优化器

# %%
# 定义交叉熵损失（输入 logits，目标为类别索引）
loss_fn = nn.CrossEntropyLoss()
# 初始化 Transformer 模型
model = MyTransformer()
# 定义优化器（Adam）
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# 快速可用性检查：随机输入跑通前向与损失
_ = loss_fn(model(torch.randn(4, 1, 28, 28)), torch.randint(0, 10, (4,)))
print("model check ok")
# Out:
# model check ok

# %% [markdown]
# ## 9) 训练循环（含评估与模型保存）
#
# 模型和提交文件保存到 task1_3 目录下。

# %%
# 训练总轮数
epochs = 10
# 模型参数保存目录（相对当前工作目录）
checkpoint_dir = os.path.join(os.getcwd(), "checkpoints")
# 确保目录存在
os.makedirs(checkpoint_dir, exist_ok=True)

# 记录每个 epoch 的平均 loss
epoch_losses = []
# 记录每个 epoch 的准确率（若无标签则记录 None）
epoch_accs = []

# 开始训练循环
for epoch in range(epochs):
    # 设置为训练模式
    model.train()
    running_loss = 0.0
    sample_count = 0
    # 逐 batch 训练
    for batch_idx, (images, labels) in enumerate(mydataset_loader):
        # 前向推理得到 logits
        output = model(images)
        # 计算当前 batch 的损失
        loss = loss_fn(output, labels)

        # 清空梯度
        optimizer.zero_grad()
        # 反向传播计算梯度
        loss.backward()
        # 更新参数
        optimizer.step()

        # 累计 loss（按样本数加权）
        batch_size = labels.size(0)
        running_loss += loss.item() * batch_size
        sample_count += batch_size

        # 输出当前 batch 的 loss
        print(f"Epoch {epoch}, Batch {batch_idx}, Loss: {loss.item():.6f}")

    # 计算并记录该 epoch 的平均 loss
    epoch_loss = running_loss / max(sample_count, 1)
    epoch_losses.append(epoch_loss)

    # 在测试集上做一次评估（若有标签）
    test_acc = evaluate(model, test_loader)
    if test_acc is not None:
        epoch_accs.append(test_acc)
        print(f"Epoch {epoch}, Test Accuracy: {test_acc * 100:.2f}%")
    else:
        epoch_accs.append(None)

    # 保存该 epoch 的模型参数
    if epoch % 1 == 0:
        ckpt_path = os.path.join(checkpoint_dir, f"model_epoch_{epoch}.pth")
        torch.save(model.state_dict(), ckpt_path)
        print("Saved:", ckpt_path)
# Out:
# Epoch 0, Batch 0, Loss: 2.442468
# Epoch 0, Batch 1, Loss: 2.313513
# Epoch 0, Batch 2, Loss: 2.250959
# Epoch 0, Batch 3, Loss: 2.419289
# Epoch 0, Batch 4, Loss: 2.361580
# Epoch 0, Batch 5, Loss: 2.384667
# Epoch 0, Batch 6, Loss: 2.156953
# Epoch 0, Batch 7, Loss: 2.296406
# Epoch 0, Batch 8, Loss: 2.238029
# Epoch 0, Batch 9, Loss: 2.352197
# Epoch 0, Batch 10, Loss: 2.258392
# Epoch 0, Batch 11, Loss: 2.207642
# Epoch 0, Batch 12, Loss: 2.232247
# Epoch 0, Batch 13, Loss: 2.206021
# Epoch 0, Batch 14, Loss: 2.219352
# Epoch 0, Batch 15, Loss: 2.159674
# Epoch 0, Batch 16, Loss: 2.243257
# Epoch 0, Batch 17, Loss: 2.222726
# Epoch 0, Batch 18, Loss: 2.095264
# Epoch 0, Batch 19, Loss: 2.057265
# Epoch 0, Batch 20, Loss: 2.214052
# Epoch 0, Batch 21, Loss: 2.307927
# Epoch 0, Batch 22, Loss: 2.161069
# Epoch 0, Batch 23, Loss: 2.182587
# Epoch 0, Batch 24, Loss: 2.177037
# Epoch 0, Batch 25, Loss: 2.170782
# Epoch 0, Batch 26, Loss: 2.111810
# Epoch 0, Batch 27, Loss: 2.064085
# Epoch 0, Batch 28, Loss: 2.049813
# Epoch 0, Batch 29, Loss: 2.033973
# Epoch 0, Batch 30, Loss: 2.057626
# Epoch 0, Batch 31, Loss: 1.910672
# Epoch 0, Batch 32, Loss: 2.249975
# Epoch 0, Batch 33, Loss: 1.848925
# Epoch 0, Batch 34, Loss: 2.032515
# Epoch 0, Batch 35, Loss: 2.170148
# Epoch 0, Batch 36, Loss: 2.068227
# Epoch 0, Batch 37, Loss: 2.220111
# Epoch 0, Batch 38, Loss: 2.193329
# Epoch 0, Batch 39, Loss: 2.041730
# Epoch 0, Batch 40, Loss: 2.032011
# Epoch 0, Batch 41, Loss: 2.113193
# Epoch 0, Batch 42, Loss: 2.053195
# Epoch 0, Batch 43, Loss: 2.083856
# Epoch 0, Batch 44, Loss: 1.966582
# Epoch 0, Batch 45, Loss: 2.050797
# Epoch 0, Batch 46, Loss: 1.968703
# Epoch 0, Batch 47, Loss: 2.093244
# Epoch 0, Batch 48, Loss: 2.086831
# Epoch 0, Batch 49, Loss: 2.021219
# Epoch 0, Batch 50, Loss: 2.081468
# Epoch 0, Batch 51, Loss: 2.116502
# Epoch 0, Batch 52, Loss: 1.980894
# Epoch 0, Batch 53, Loss: 1.981894
# Epoch 0, Batch 54, Loss: 2.196780
# Epoch 0, Batch 55, Loss: 1.876062
# Epoch 0, Batch 56, Loss: 1.963330
# Epoch 0, Batch 57, Loss: 1.903264
# Epoch 0, Batch 58, Loss: 2.086263
# Epoch 0, Batch 59, Loss: 1.958688
# Epoch 0, Batch 60, Loss: 1.962880
# Epoch 0, Batch 61, Loss: 1.861857
# Epoch 0, Batch 62, Loss: 1.917418
# Epoch 0, Batch 63, Loss: 1.910968
# Epoch 0, Batch 64, Loss: 2.075742
# Epoch 0, Batch 65, Loss: 1.906654
# Epoch 0, Batch 66, Loss: 2.058863
# Epoch 0, Batch 67, Loss: 2.003917
# Epoch 0, Batch 68, Loss: 1.782613
# Epoch 0, Batch 69, Loss: 1.891078
# Epoch 0, Batch 70, Loss: 1.991217
# Epoch 0, Batch 71, Loss: 1.908358
# Epoch 0, Batch 72, Loss: 1.895652
# Epoch 0, Batch 73, Loss: 1.859209
# Epoch 0, Batch 74, Loss: 1.823030
# Epoch 0, Batch 75, Loss: 1.826320
# Epoch 0, Batch 76, Loss: 1.914147
# Epoch 0, Batch 77, Loss: 1.942541
# Epoch 0, Batch 78, Loss: 1.878968
# Epoch 0, Batch 79, Loss: 1.975655
# Epoch 0, Batch 80, Loss: 1.842753
# Epoch 0, Batch 81, Loss: 1.719057
# Epoch 0, Batch 82, Loss: 1.767325
# Epoch 0, Batch 83, Loss: 1.606549
# Epoch 0, Batch 84, Loss: 2.036444
# Epoch 0, Batch 85, Loss: 1.825678
# Epoch 0, Batch 86, Loss: 1.780368
# Epoch 0, Batch 87, Loss: 1.921028
# Epoch 0, Batch 88, Loss: 1.785108
# Epoch 0, Batch 89, Loss: 1.688687
# Epoch 0, Batch 90, Loss: 1.773708
# Epoch 0, Batch 91, Loss: 1.855198
# Epoch 0, Batch 92, Loss: 1.644316
# Epoch 0, Batch 93, Loss: 1.562883
# Epoch 0, Batch 94, Loss: 1.749439
# Epoch 0, Batch 95, Loss: 1.466184
# Epoch 0, Batch 96, Loss: 1.609059
# Epoch 0, Batch 97, Loss: 1.724770
# Epoch 0, Batch 98, Loss: 1.684296
# Epoch 0, Batch 99, Loss: 1.735613
# Epoch 0, Batch 100, Loss: 1.557024
# Epoch 0, Batch 101, Loss: 1.522191
# Epoch 0, Batch 102, Loss: 1.640478
# Epoch 0, Batch 103, Loss: 1.460034
# Epoch 0, Batch 104, Loss: 1.483476
# Epoch 0, Batch 105, Loss: 1.453297
# Epoch 0, Batch 106, Loss: 1.403212
# Epoch 0, Batch 107, Loss: 1.611782
# Epoch 0, Batch 108, Loss: 1.526205
# Epoch 0, Batch 109, Loss: 1.431971
# Epoch 0, Batch 110, Loss: 1.510953
# Epoch 0, Batch 111, Loss: 1.571292
# Epoch 0, Batch 112, Loss: 1.618808
# Epoch 0, Batch 113, Loss: 1.618865
# Epoch 0, Batch 114, Loss: 1.508203
# Epoch 0, Batch 115, Loss: 1.527358
# Epoch 0, Batch 116, Loss: 1.755427
# Epoch 0, Batch 117, Loss: 1.434519
# Epoch 0, Batch 118, Loss: 1.320802
# Epoch 0, Batch 119, Loss: 1.565479
# Epoch 0, Batch 120, Loss: 1.531025
# Epoch 0, Batch 121, Loss: 1.386735
# Epoch 0, Batch 122, Loss: 1.365749
# Epoch 0, Batch 123, Loss: 1.504458
# Epoch 0, Batch 124, Loss: 1.378084
# Epoch 0, Batch 125, Loss: 1.454116
# Epoch 0, Batch 126, Loss: 1.371280
# Epoch 0, Batch 127, Loss: 1.327976
# Epoch 0, Batch 128, Loss: 1.533182
# Epoch 0, Batch 129, Loss: 1.241765
# Epoch 0, Batch 130, Loss: 1.280031
# Epoch 0, Batch 131, Loss: 1.576684
# Epoch 0, Batch 132, Loss: 1.518066
# Epoch 0, Batch 133, Loss: 1.201524
# Epoch 0, Batch 134, Loss: 1.246587
# Epoch 0, Batch 135, Loss: 1.360174
# Epoch 0, Batch 136, Loss: 1.248468
# Epoch 0, Batch 137, Loss: 1.327319
# Epoch 0, Batch 138, Loss: 1.266755
# Epoch 0, Batch 139, Loss: 1.268539
# Epoch 0, Batch 140, Loss: 1.307194
# Epoch 0, Batch 141, Loss: 1.293543
# Epoch 0, Batch 142, Loss: 1.151930
# Epoch 0, Batch 143, Loss: 1.332254
# Epoch 0, Batch 144, Loss: 1.185735
# Epoch 0, Batch 145, Loss: 1.201908
# Epoch 0, Batch 146, Loss: 1.219479
# Epoch 0, Batch 147, Loss: 1.408386
# Epoch 0, Batch 148, Loss: 1.201137
# Epoch 0, Batch 149, Loss: 1.088502
# Epoch 0, Batch 150, Loss: 1.138677
# Epoch 0, Batch 151, Loss: 1.148872
# Epoch 0, Batch 152, Loss: 1.102834
# Epoch 0, Batch 153, Loss: 1.023838
# Epoch 0, Batch 154, Loss: 1.211994
# Epoch 0, Batch 155, Loss: 1.168416
# Epoch 0, Batch 156, Loss: 1.220953
# Epoch 0, Batch 157, Loss: 0.978117
# Epoch 0, Batch 158, Loss: 1.202538
# Epoch 0, Batch 159, Loss: 1.119968
# Epoch 0, Batch 160, Loss: 1.055866
# Epoch 0, Batch 161, Loss: 1.076231
# Epoch 0, Batch 162, Loss: 1.235780
# Epoch 0, Batch 163, Loss: 1.225765
# Epoch 0, Batch 164, Loss: 1.035422
# Epoch 0, Batch 165, Loss: 1.065385
# Epoch 0, Batch 166, Loss: 1.108664
# Epoch 0, Batch 167, Loss: 1.017173
# Epoch 0, Batch 168, Loss: 1.182943
# Epoch 0, Batch 169, Loss: 1.012881
# Epoch 0, Batch 170, Loss: 1.043538
# Epoch 0, Batch 171, Loss: 1.072357
# Epoch 0, Batch 172, Loss: 0.855246
# Epoch 0, Batch 173, Loss: 0.923960
# Epoch 0, Batch 174, Loss: 1.082698
# Epoch 0, Batch 175, Loss: 0.975748
# Epoch 0, Batch 176, Loss: 1.062651
# Epoch 0, Batch 177, Loss: 1.078793
# Epoch 0, Batch 178, Loss: 1.129594
# Epoch 0, Batch 179, Loss: 0.983930
# Epoch 0, Batch 180, Loss: 0.941827
# Epoch 0, Batch 181, Loss: 0.989857
# Epoch 0, Batch 182, Loss: 0.893468
# Epoch 0, Batch 183, Loss: 0.941657
# Epoch 0, Batch 184, Loss: 0.865059
# Epoch 0, Batch 185, Loss: 0.987354
# Epoch 0, Batch 186, Loss: 1.063380
# Epoch 0, Batch 187, Loss: 0.959300
# Epoch 0, Batch 188, Loss: 0.914069
# Epoch 0, Batch 189, Loss: 0.887699
# Epoch 0, Batch 190, Loss: 0.829600
# Epoch 0, Batch 191, Loss: 0.842009
# Epoch 0, Batch 192, Loss: 0.898296
# Epoch 0, Batch 193, Loss: 0.814378
# Epoch 0, Batch 194, Loss: 1.032291
# Epoch 0, Batch 195, Loss: 0.914154
# Epoch 0, Batch 196, Loss: 0.832164
# Epoch 0, Batch 197, Loss: 0.940849
# Epoch 0, Batch 198, Loss: 0.764117
# Epoch 0, Batch 199, Loss: 1.159343
# Epoch 0, Batch 200, Loss: 0.850968
# Epoch 0, Batch 201, Loss: 0.795416
# Epoch 0, Batch 202, Loss: 0.774830
# Epoch 0, Batch 203, Loss: 0.939236
# Epoch 0, Batch 204, Loss: 1.247792
# Epoch 0, Batch 205, Loss: 1.165744
# Epoch 0, Batch 206, Loss: 0.876407
# Epoch 0, Batch 207, Loss: 1.253692
# Epoch 0, Batch 208, Loss: 1.070073
# Epoch 0, Batch 209, Loss: 0.986365
# Epoch 0, Batch 210, Loss: 0.889661
# Epoch 0, Batch 211, Loss: 1.030326
# Epoch 0, Batch 212, Loss: 0.790868
# Epoch 0, Batch 213, Loss: 0.918400
# Epoch 0, Batch 214, Loss: 1.086514
# Epoch 0, Batch 215, Loss: 0.867473
# Epoch 0, Batch 216, Loss: 1.043171
# Epoch 0, Batch 217, Loss: 0.804203
# Epoch 0, Batch 218, Loss: 0.708780
# Epoch 0, Batch 219, Loss: 0.916474
# Epoch 0, Batch 220, Loss: 0.675450
# Epoch 0, Batch 221, Loss: 0.684482
# Epoch 0, Batch 222, Loss: 1.150944
# Epoch 0, Batch 223, Loss: 0.921881
# Epoch 0, Batch 224, Loss: 0.708864
# Epoch 0, Batch 225, Loss: 0.707479
# Epoch 0, Batch 226, Loss: 1.014412
# Epoch 0, Batch 227, Loss: 0.771506
# Epoch 0, Batch 228, Loss: 0.951634
# Epoch 0, Batch 229, Loss: 1.098087
# Epoch 0, Batch 230, Loss: 0.823921
# Epoch 0, Batch 231, Loss: 0.848972
# Epoch 0, Batch 232, Loss: 0.874635
# Epoch 0, Batch 233, Loss: 0.695258
# Epoch 0, Batch 234, Loss: 0.756834
# Epoch 0, Batch 235, Loss: 0.829416
# Epoch 0, Batch 236, Loss: 1.042311
# Epoch 0, Batch 237, Loss: 0.762226
# Epoch 0, Batch 238, Loss: 0.762000
# Epoch 0, Batch 239, Loss: 0.978145
# Epoch 0, Batch 240, Loss: 0.849165
# Epoch 0, Batch 241, Loss: 0.828431
# Epoch 0, Batch 242, Loss: 1.113421
# Epoch 0, Batch 243, Loss: 0.747246
# Epoch 0, Batch 244, Loss: 0.755256
# Epoch 0, Batch 245, Loss: 1.003825
# Epoch 0, Batch 246, Loss: 0.773056
# Epoch 0, Batch 247, Loss: 0.756724
# Epoch 0, Batch 248, Loss: 0.892921
# Epoch 0, Batch 249, Loss: 0.833129
# Epoch 0, Batch 250, Loss: 0.805563
# Epoch 0, Batch 251, Loss: 0.701941
# Epoch 0, Batch 252, Loss: 0.468045
# Epoch 0, Batch 253, Loss: 0.580248
# Epoch 0, Batch 254, Loss: 0.820206
# Epoch 0, Batch 255, Loss: 0.716970
# Epoch 0, Batch 256, Loss: 1.038994
# Epoch 0, Batch 257, Loss: 0.743847
# Epoch 0, Batch 258, Loss: 0.932182
# Epoch 0, Batch 259, Loss: 0.811818
# Epoch 0, Batch 260, Loss: 0.811812
# Epoch 0, Batch 261, Loss: 0.706167
# Epoch 0, Batch 262, Loss: 0.753732
# Epoch 0, Batch 263, Loss: 0.636967
# Epoch 0, Batch 264, Loss: 0.850529
# Epoch 0, Batch 265, Loss: 0.848536
# Epoch 0, Batch 266, Loss: 0.611978
# Epoch 0, Batch 267, Loss: 0.758066
# Epoch 0, Batch 268, Loss: 0.675134
# Epoch 0, Batch 269, Loss: 0.679821
# Epoch 0, Batch 270, Loss: 0.647760
# Epoch 0, Batch 271, Loss: 0.708260
# Epoch 0, Batch 272, Loss: 0.932849
# Epoch 0, Batch 273, Loss: 0.899621
# Epoch 0, Batch 274, Loss: 0.619756
# Epoch 0, Batch 275, Loss: 0.757866
# Epoch 0, Batch 276, Loss: 0.884458
# Epoch 0, Batch 277, Loss: 0.643647
# Epoch 0, Batch 278, Loss: 0.739364
# Epoch 0, Batch 279, Loss: 0.722082
# Epoch 0, Batch 280, Loss: 0.559154
# Epoch 0, Batch 281, Loss: 0.784797
# Epoch 0, Batch 282, Loss: 0.943690
# Epoch 0, Batch 283, Loss: 0.643947
# Epoch 0, Batch 284, Loss: 0.546395
# Epoch 0, Batch 285, Loss: 0.672736
# Epoch 0, Batch 286, Loss: 0.783442
# Epoch 0, Batch 287, Loss: 0.545807
# Epoch 0, Batch 288, Loss: 0.946779
# Epoch 0, Batch 289, Loss: 0.665055
# Epoch 0, Batch 290, Loss: 0.595794
# Epoch 0, Batch 291, Loss: 0.734441
# Epoch 0, Batch 292, Loss: 0.876852
# Epoch 0, Batch 293, Loss: 0.586999
# Epoch 0, Batch 294, Loss: 0.523322
# Epoch 0, Batch 295, Loss: 0.680952
# Epoch 0, Batch 296, Loss: 0.576652
# Epoch 0, Batch 297, Loss: 0.836872
# Epoch 0, Batch 298, Loss: 0.824778
# Epoch 0, Batch 299, Loss: 0.681758
# Epoch 0, Batch 300, Loss: 0.826355
# Epoch 0, Batch 301, Loss: 0.662341
# Epoch 0, Batch 302, Loss: 0.511774
# Epoch 0, Batch 303, Loss: 0.690711
# Epoch 0, Batch 304, Loss: 0.515548
# Epoch 0, Batch 305, Loss: 0.731475
# Epoch 0, Batch 306, Loss: 0.624886
# Epoch 0, Batch 307, Loss: 0.663005
# Epoch 0, Batch 308, Loss: 0.594142
# Epoch 0, Batch 309, Loss: 0.817028
# Epoch 0, Batch 310, Loss: 0.713074
# Epoch 0, Batch 311, Loss: 0.887261
# Epoch 0, Batch 312, Loss: 0.723646
# Epoch 0, Batch 313, Loss: 0.426506
# Epoch 0, Batch 314, Loss: 0.677570
# Epoch 0, Batch 315, Loss: 0.612265
# Epoch 0, Batch 316, Loss: 0.583792
# Epoch 0, Batch 317, Loss: 0.645012
# Epoch 0, Batch 318, Loss: 0.648467
# Epoch 0, Batch 319, Loss: 0.807108
# Epoch 0, Batch 320, Loss: 0.729526
# Epoch 0, Batch 321, Loss: 0.778660
# Epoch 0, Batch 322, Loss: 0.670841
# Epoch 0, Batch 323, Loss: 0.726075
# Epoch 0, Batch 324, Loss: 0.564710
# Epoch 0, Batch 325, Loss: 0.748516
# Epoch 0, Batch 326, Loss: 0.717760
# Epoch 0, Batch 327, Loss: 0.651656
# Epoch 0, Batch 328, Loss: 0.610169
# Epoch 0, Batch 329, Loss: 0.495219
# Epoch 0, Batch 330, Loss: 0.341898
# Epoch 0, Batch 331, Loss: 0.495396
# Epoch 0, Batch 332, Loss: 0.788801
# Epoch 0, Batch 333, Loss: 0.597440
# Epoch 0, Batch 334, Loss: 0.664130
# Epoch 0, Batch 335, Loss: 0.703716
# Epoch 0, Batch 336, Loss: 0.574672
# Epoch 0, Batch 337, Loss: 0.470233
# Epoch 0, Batch 338, Loss: 0.787400
# Epoch 0, Batch 339, Loss: 0.457068
# Epoch 0, Batch 340, Loss: 0.595049
# Epoch 0, Batch 341, Loss: 0.696035
# Epoch 0, Batch 342, Loss: 0.545845
# Epoch 0, Batch 343, Loss: 0.632542
# Epoch 0, Batch 344, Loss: 0.513825
# Epoch 0, Batch 345, Loss: 0.610741
# Epoch 0, Batch 346, Loss: 0.566429
# Epoch 0, Batch 347, Loss: 0.907027
# Epoch 0, Batch 348, Loss: 0.508578
# Epoch 0, Batch 349, Loss: 0.554890
# Epoch 0, Batch 350, Loss: 0.655950
# Epoch 0, Batch 351, Loss: 0.738967
# Epoch 0, Batch 352, Loss: 0.554242
# Epoch 0, Batch 353, Loss: 0.684595
# Epoch 0, Batch 354, Loss: 0.706905
# Epoch 0, Batch 355, Loss: 0.448727
# Epoch 0, Batch 356, Loss: 0.655524
# Epoch 0, Batch 357, Loss: 0.526373
# Epoch 0, Batch 358, Loss: 0.728107
# Epoch 0, Batch 359, Loss: 0.530706
# Epoch 0, Batch 360, Loss: 0.764383
# Epoch 0, Batch 361, Loss: 0.543908
# Epoch 0, Batch 362, Loss: 0.733552
# Epoch 0, Batch 363, Loss: 0.693266
# Epoch 0, Batch 364, Loss: 0.448428
# Epoch 0, Batch 365, Loss: 0.575811
# Epoch 0, Batch 366, Loss: 0.415916
# Epoch 0, Batch 367, Loss: 0.505162
# Epoch 0, Batch 368, Loss: 0.379249
# Epoch 0, Batch 369, Loss: 0.476956
# Epoch 0, Batch 370, Loss: 0.635718
# Epoch 0, Batch 371, Loss: 0.425950
# Epoch 0, Batch 372, Loss: 0.635679
# Epoch 0, Batch 373, Loss: 0.656157
# Epoch 0, Batch 374, Loss: 0.601137
# Epoch 0, Batch 375, Loss: 0.296309
# Epoch 0, Batch 376, Loss: 0.428207
# Epoch 0, Batch 377, Loss: 0.751585
# Epoch 0, Batch 378, Loss: 0.548702
# Epoch 0, Batch 379, Loss: 0.399546
# Epoch 0, Batch 380, Loss: 0.548843
# Epoch 0, Batch 381, Loss: 0.769140
# Epoch 0, Batch 382, Loss: 0.424796
# Epoch 0, Batch 383, Loss: 0.569707
# Epoch 0, Batch 384, Loss: 0.433750
# Epoch 0, Batch 385, Loss: 0.557202
# Epoch 0, Batch 386, Loss: 0.558691
# Epoch 0, Batch 387, Loss: 0.419997
# Epoch 0, Batch 388, Loss: 0.494451
# Epoch 0, Batch 389, Loss: 0.359808
# Epoch 0, Batch 390, Loss: 0.776096
# Epoch 0, Batch 391, Loss: 0.570919
# Epoch 0, Batch 392, Loss: 0.359509
# Epoch 0, Batch 393, Loss: 0.411595
# Epoch 0, Batch 394, Loss: 0.415116
# Epoch 0, Batch 395, Loss: 0.503501
# Epoch 0, Batch 396, Loss: 0.477814
# Epoch 0, Batch 397, Loss: 0.289901
# Epoch 0, Batch 398, Loss: 0.663347
# Epoch 0, Batch 399, Loss: 0.758616
# Epoch 0, Batch 400, Loss: 0.596660
# Epoch 0, Batch 401, Loss: 0.397304
# Epoch 0, Batch 402, Loss: 0.612165
# Epoch 0, Batch 403, Loss: 0.565590
# Epoch 0, Batch 404, Loss: 0.505310
# Epoch 0, Batch 405, Loss: 0.466641
# Epoch 0, Batch 406, Loss: 0.643368
# Epoch 0, Batch 407, Loss: 0.593009
# Epoch 0, Batch 408, Loss: 0.471545
# Epoch 0, Batch 409, Loss: 0.677043
# Epoch 0, Batch 410, Loss: 0.579591
# Epoch 0, Batch 411, Loss: 0.463325
# Epoch 0, Batch 412, Loss: 0.585011
# Epoch 0, Batch 413, Loss: 0.359632
# Epoch 0, Batch 414, Loss: 0.518024
# Epoch 0, Batch 415, Loss: 0.409574
# Epoch 0, Batch 416, Loss: 0.528842
# Epoch 0, Batch 417, Loss: 0.444100
# Epoch 0, Batch 418, Loss: 0.490582
# Epoch 0, Batch 419, Loss: 0.507982
# Epoch 0, Batch 420, Loss: 0.732392
# Epoch 0, Batch 421, Loss: 0.550255
# Epoch 0, Batch 422, Loss: 0.579610
# Epoch 0, Batch 423, Loss: 0.686576
# Epoch 0, Batch 424, Loss: 0.559800
# Epoch 0, Batch 425, Loss: 0.525593
# Epoch 0, Batch 426, Loss: 0.543577
# Epoch 0, Batch 427, Loss: 0.442159
# Epoch 0, Batch 428, Loss: 0.699300
# Epoch 0, Batch 429, Loss: 0.523352
# Epoch 0, Batch 430, Loss: 0.455612
# Epoch 0, Batch 431, Loss: 0.836862
# Epoch 0, Batch 432, Loss: 0.539395
# Epoch 0, Batch 433, Loss: 0.554706
# Epoch 0, Batch 434, Loss: 0.292876
# Epoch 0, Batch 435, Loss: 0.352494
# Epoch 0, Batch 436, Loss: 0.830610
# Epoch 0, Batch 437, Loss: 0.542465
# Epoch 0, Batch 438, Loss: 0.424007
# Epoch 0, Batch 439, Loss: 0.369411
# Epoch 0, Batch 440, Loss: 0.391518
# Epoch 0, Batch 441, Loss: 0.614909
# Epoch 0, Batch 442, Loss: 0.618679
# Epoch 0, Batch 443, Loss: 0.600059
# Epoch 0, Batch 444, Loss: 0.310326
# Epoch 0, Batch 445, Loss: 0.383260
# Epoch 0, Batch 446, Loss: 0.653962
# Epoch 0, Batch 447, Loss: 0.523165
# Epoch 0, Batch 448, Loss: 0.469791
# Epoch 0, Batch 449, Loss: 0.398480
# Epoch 0, Batch 450, Loss: 0.541158
# Epoch 0, Batch 451, Loss: 0.474388
# Epoch 0, Batch 452, Loss: 0.327667
# Epoch 0, Batch 453, Loss: 0.545363
# Epoch 0, Batch 454, Loss: 0.339700
# Epoch 0, Batch 455, Loss: 0.567467
# Epoch 0, Batch 456, Loss: 0.382117
# Epoch 0, Batch 457, Loss: 0.442984
# Epoch 0, Batch 458, Loss: 0.495666
# Epoch 0, Batch 459, Loss: 0.491709
# Epoch 0, Batch 460, Loss: 0.455905
# Epoch 0, Batch 461, Loss: 0.423292
# Epoch 0, Batch 462, Loss: 0.444189
# Epoch 0, Batch 463, Loss: 0.382797
# Epoch 0, Batch 464, Loss: 0.383200
# Epoch 0, Batch 465, Loss: 0.463679
# Epoch 0, Batch 466, Loss: 0.390619
# Epoch 0, Batch 467, Loss: 0.380095
# Epoch 0, Batch 468, Loss: 0.323790
# Epoch 0, Batch 469, Loss: 0.606084
# Epoch 0, Batch 470, Loss: 0.640930
# Epoch 0, Batch 471, Loss: 0.522615
# Epoch 0, Batch 472, Loss: 0.381770
# Epoch 0, Batch 473, Loss: 0.479179
# Epoch 0, Batch 474, Loss: 0.418718
# Epoch 0, Batch 475, Loss: 0.491636
# Epoch 0, Batch 476, Loss: 0.442002
# Epoch 0, Batch 477, Loss: 0.375739
# Epoch 0, Batch 478, Loss: 0.597060
# Epoch 0, Batch 479, Loss: 0.547797
# Epoch 0, Batch 480, Loss: 0.378995
# Epoch 0, Batch 481, Loss: 0.576791
# Epoch 0, Batch 482, Loss: 0.553743
# Epoch 0, Batch 483, Loss: 0.554708
# Epoch 0, Batch 484, Loss: 0.652761
# Epoch 0, Batch 485, Loss: 0.409923
# Epoch 0, Batch 486, Loss: 0.638692
# Epoch 0, Batch 487, Loss: 0.292506
# Epoch 0, Batch 488, Loss: 0.508623
# Epoch 0, Batch 489, Loss: 0.647440
# Epoch 0, Batch 490, Loss: 0.408883
# Epoch 0, Batch 491, Loss: 0.583023
# Epoch 0, Batch 492, Loss: 0.302453
# Epoch 0, Batch 493, Loss: 0.288424
# Epoch 0, Batch 494, Loss: 0.541318
# Epoch 0, Batch 495, Loss: 0.525666
# Epoch 0, Batch 496, Loss: 0.615012
# Epoch 0, Batch 497, Loss: 0.543848
# Epoch 0, Batch 498, Loss: 0.462067
# Epoch 0, Batch 499, Loss: 0.405028
# Epoch 0, Batch 500, Loss: 0.484168
# Epoch 0, Batch 501, Loss: 0.262395
# Epoch 0, Batch 502, Loss: 0.679577
# Epoch 0, Batch 503, Loss: 0.739340
# Epoch 0, Batch 504, Loss: 0.553373
# Epoch 0, Batch 505, Loss: 0.603456
# Epoch 0, Batch 506, Loss: 0.573857
# Epoch 0, Batch 507, Loss: 0.371389
# Epoch 0, Batch 508, Loss: 0.561898
# Epoch 0, Batch 509, Loss: 0.436636
# Epoch 0, Batch 510, Loss: 0.598529
# Epoch 0, Batch 511, Loss: 0.578349
# Epoch 0, Batch 512, Loss: 0.318208
# Epoch 0, Batch 513, Loss: 0.280206
# Epoch 0, Batch 514, Loss: 0.479224
# Epoch 0, Batch 515, Loss: 0.357433
# Epoch 0, Batch 516, Loss: 0.442555
# Epoch 0, Batch 517, Loss: 0.321307
# Epoch 0, Batch 518, Loss: 0.420006
# Epoch 0, Batch 519, Loss: 0.510689
# Epoch 0, Batch 520, Loss: 0.449024
# Epoch 0, Batch 521, Loss: 0.332225
# Epoch 0, Batch 522, Loss: 0.414241
# Epoch 0, Batch 523, Loss: 0.254407
# Epoch 0, Batch 524, Loss: 0.673459
# Epoch 0, Batch 525, Loss: 0.279258
# Epoch 0, Batch 526, Loss: 0.519862
# Epoch 0, Batch 527, Loss: 0.370762
# Epoch 0, Batch 528, Loss: 0.389250
# Epoch 0, Batch 529, Loss: 0.372299
# Epoch 0, Batch 530, Loss: 0.536207
# Epoch 0, Batch 531, Loss: 0.374474
# Epoch 0, Batch 532, Loss: 0.469873
# Epoch 0, Batch 533, Loss: 0.391246
# Epoch 0, Batch 534, Loss: 0.393777
# Epoch 0, Batch 535, Loss: 0.194638
# Epoch 0, Batch 536, Loss: 0.462559
# Epoch 0, Batch 537, Loss: 0.514239
# Epoch 0, Batch 538, Loss: 0.451430
# Epoch 0, Batch 539, Loss: 0.389044
# Epoch 0, Batch 540, Loss: 0.396565
# Epoch 0, Batch 541, Loss: 0.565937
# Epoch 0, Batch 542, Loss: 0.466171
# Epoch 0, Batch 543, Loss: 0.508129
# Epoch 0, Batch 544, Loss: 0.416437
# Epoch 0, Batch 545, Loss: 0.636692
# Epoch 0, Batch 546, Loss: 0.516454
# Epoch 0, Batch 547, Loss: 0.449738
# Epoch 0, Batch 548, Loss: 0.531816
# Epoch 0, Batch 549, Loss: 0.396570
# Epoch 0, Batch 550, Loss: 0.404446
# Epoch 0, Batch 551, Loss: 0.363668
# Epoch 0, Batch 552, Loss: 0.570187
# Epoch 0, Batch 553, Loss: 0.529443
# Epoch 0, Batch 554, Loss: 0.245069
# Epoch 0, Batch 555, Loss: 0.693402
# Epoch 0, Batch 556, Loss: 0.390369
# Epoch 0, Batch 557, Loss: 0.390243
# Epoch 0, Batch 558, Loss: 0.509125
# Epoch 0, Batch 559, Loss: 0.257746
# Epoch 0, Batch 560, Loss: 0.460604
# Epoch 0, Batch 561, Loss: 0.444147
# Epoch 0, Batch 562, Loss: 0.295714
# Epoch 0, Batch 563, Loss: 0.282084
# Epoch 0, Batch 564, Loss: 0.484582
# Epoch 0, Batch 565, Loss: 0.343607
# Epoch 0, Batch 566, Loss: 0.450833
# Epoch 0, Batch 567, Loss: 0.554671
# Epoch 0, Batch 568, Loss: 0.613491
# Epoch 0, Batch 569, Loss: 0.350472
# Epoch 0, Batch 570, Loss: 0.633432
# Epoch 0, Batch 571, Loss: 0.364018
# Epoch 0, Batch 572, Loss: 0.318161
# Epoch 0, Batch 573, Loss: 0.412558
# Epoch 0, Batch 574, Loss: 0.401630
# Epoch 0, Batch 575, Loss: 0.452198
# Epoch 0, Batch 576, Loss: 0.392388
# Epoch 0, Batch 577, Loss: 0.461903
# Epoch 0, Batch 578, Loss: 0.255842
# Epoch 0, Batch 579, Loss: 0.339819
# Epoch 0, Batch 580, Loss: 0.330828
# Epoch 0, Batch 581, Loss: 0.296665
# Epoch 0, Batch 582, Loss: 0.645315
# Epoch 0, Batch 583, Loss: 0.611912
# Epoch 0, Batch 584, Loss: 0.354280
# Epoch 0, Batch 585, Loss: 0.563400
# Epoch 0, Batch 586, Loss: 0.228035
# Epoch 0, Batch 587, Loss: 0.407722
# Epoch 0, Batch 588, Loss: 0.190998
# Epoch 0, Batch 589, Loss: 0.488605
# Epoch 0, Batch 590, Loss: 0.377763
# Epoch 0, Batch 591, Loss: 0.326175
# Epoch 0, Batch 592, Loss: 0.530443
# Epoch 0, Batch 593, Loss: 0.565124
# Epoch 0, Batch 594, Loss: 0.439371
# Epoch 0, Batch 595, Loss: 0.504432
# Epoch 0, Batch 596, Loss: 0.331510
# Epoch 0, Batch 597, Loss: 0.202311
# Epoch 0, Batch 598, Loss: 0.506607
# Epoch 0, Batch 599, Loss: 0.410162
# Epoch 0, Batch 600, Loss: 0.332298
# Epoch 0, Batch 601, Loss: 0.242525
# Epoch 0, Batch 602, Loss: 0.405210
# Epoch 0, Batch 603, Loss: 0.347644
# Epoch 0, Batch 604, Loss: 0.388811
# Epoch 0, Batch 605, Loss: 0.362942
# Epoch 0, Batch 606, Loss: 0.513800
# Epoch 0, Batch 607, Loss: 0.225137
# Epoch 0, Batch 608, Loss: 0.461321
# Epoch 0, Batch 609, Loss: 0.608178
# Epoch 0, Batch 610, Loss: 0.422823
# Epoch 0, Batch 611, Loss: 0.362713
# Epoch 0, Batch 612, Loss: 0.492065
# Epoch 0, Batch 613, Loss: 0.293008
# Epoch 0, Batch 614, Loss: 0.342976
# Epoch 0, Batch 615, Loss: 0.508540
# Epoch 0, Batch 616, Loss: 0.480420
# Epoch 0, Batch 617, Loss: 0.452550
# Epoch 0, Batch 618, Loss: 0.318046
# Epoch 0, Batch 619, Loss: 0.324584
# Epoch 0, Batch 620, Loss: 0.317513
# Epoch 0, Batch 621, Loss: 0.315506
# Epoch 0, Batch 622, Loss: 0.284307
# Epoch 0, Batch 623, Loss: 0.513834
# Epoch 0, Batch 624, Loss: 0.326329
# Epoch 0, Batch 625, Loss: 0.522775
# Epoch 0, Batch 626, Loss: 0.297784
# Epoch 0, Batch 627, Loss: 0.527747
# Epoch 0, Batch 628, Loss: 0.479396
# Epoch 0, Batch 629, Loss: 0.491231
# Epoch 0, Batch 630, Loss: 0.221042
# Epoch 0, Batch 631, Loss: 0.372774
# Epoch 0, Batch 632, Loss: 0.443653
# Epoch 0, Batch 633, Loss: 0.463226
# Epoch 0, Batch 634, Loss: 0.535738
# Epoch 0, Batch 635, Loss: 0.361715
# Epoch 0, Batch 636, Loss: 0.313149
# Epoch 0, Batch 637, Loss: 0.592359
# Epoch 0, Batch 638, Loss: 0.544773
# Epoch 0, Batch 639, Loss: 0.231865
# Epoch 0, Batch 640, Loss: 0.400044
# Epoch 0, Batch 641, Loss: 0.454808
# Epoch 0, Batch 642, Loss: 0.372536
# Epoch 0, Batch 643, Loss: 0.595009
# Epoch 0, Batch 644, Loss: 0.511572
# Epoch 0, Batch 645, Loss: 0.223319
# Epoch 0, Batch 646, Loss: 0.534698
# Epoch 0, Batch 647, Loss: 0.391895
# Epoch 0, Batch 648, Loss: 0.375167
# Epoch 0, Batch 649, Loss: 0.353408
# Epoch 0, Batch 650, Loss: 0.218191
# Epoch 0, Batch 651, Loss: 0.625100
# Epoch 0, Batch 652, Loss: 0.253603
# Epoch 0, Batch 653, Loss: 0.380963
# Epoch 0, Batch 654, Loss: 0.439338
# Epoch 0, Batch 655, Loss: 0.479974
# Epoch 0, Batch 656, Loss: 0.414505
# Warning: test set has no labels, skip accuracy evaluation.
# Saved: d:\CZ_WorkSpace\ai学习\深度学习实践\task1\task1_3\checkpoints\model_epoch_0.pth
# Epoch 1, Batch 0, Loss: 0.447816
# Epoch 1, Batch 1, Loss: 0.193690
# Epoch 1, Batch 2, Loss: 0.328974
# Epoch 1, Batch 3, Loss: 0.358807
# Epoch 1, Batch 4, Loss: 0.444189
# Epoch 1, Batch 5, Loss: 0.305746
# Epoch 1, Batch 6, Loss: 0.492337
# Epoch 1, Batch 7, Loss: 0.438509
# Epoch 1, Batch 8, Loss: 0.483019
# Epoch 1, Batch 9, Loss: 0.310305
# Epoch 1, Batch 10, Loss: 0.326432
# Epoch 1, Batch 11, Loss: 0.352389
# Epoch 1, Batch 12, Loss: 0.358192
# Epoch 1, Batch 13, Loss: 0.348582
# Epoch 1, Batch 14, Loss: 0.522947
# Epoch 1, Batch 15, Loss: 0.556593
# Epoch 1, Batch 16, Loss: 0.385436
# Epoch 1, Batch 17, Loss: 0.253689
# Epoch 1, Batch 18, Loss: 0.384741
# Epoch 1, Batch 19, Loss: 0.415650
# Epoch 1, Batch 20, Loss: 0.368966
# Epoch 1, Batch 21, Loss: 0.246521
# Epoch 1, Batch 22, Loss: 0.191413
# Epoch 1, Batch 23, Loss: 0.212605
# Epoch 1, Batch 24, Loss: 0.405041
# Epoch 1, Batch 25, Loss: 0.453309
# Epoch 1, Batch 26, Loss: 0.328151
# Epoch 1, Batch 27, Loss: 0.327338
# Epoch 1, Batch 28, Loss: 0.194070
# Epoch 1, Batch 29, Loss: 0.481813
# Epoch 1, Batch 30, Loss: 0.369445
# Epoch 1, Batch 31, Loss: 0.300366
# Epoch 1, Batch 32, Loss: 0.435147
# Epoch 1, Batch 33, Loss: 0.493939
# Epoch 1, Batch 34, Loss: 0.480773
# Epoch 1, Batch 35, Loss: 0.260024
# Epoch 1, Batch 36, Loss: 0.380878
# Epoch 1, Batch 37, Loss: 0.406780
# Epoch 1, Batch 38, Loss: 0.456002
# Epoch 1, Batch 39, Loss: 0.462948
# Epoch 1, Batch 40, Loss: 0.503602
# Epoch 1, Batch 41, Loss: 0.432539
# Epoch 1, Batch 42, Loss: 0.335092
# Epoch 1, Batch 43, Loss: 0.399908
# Epoch 1, Batch 44, Loss: 0.319131
# Epoch 1, Batch 45, Loss: 0.215565
# Epoch 1, Batch 46, Loss: 0.324541
# Epoch 1, Batch 47, Loss: 0.246715
# Epoch 1, Batch 48, Loss: 0.398231
# Epoch 1, Batch 49, Loss: 0.342822
# Epoch 1, Batch 50, Loss: 0.366904
# Epoch 1, Batch 51, Loss: 0.366530
# Epoch 1, Batch 52, Loss: 0.384994
# Epoch 1, Batch 53, Loss: 0.331710
# Epoch 1, Batch 54, Loss: 0.250137
# Epoch 1, Batch 55, Loss: 0.256016
# Epoch 1, Batch 56, Loss: 0.429564
# Epoch 1, Batch 57, Loss: 0.421055
# Epoch 1, Batch 58, Loss: 0.289735
# Epoch 1, Batch 59, Loss: 0.450004
# Epoch 1, Batch 60, Loss: 0.190871
# Epoch 1, Batch 61, Loss: 0.488601
# Epoch 1, Batch 62, Loss: 0.424527
# Epoch 1, Batch 63, Loss: 0.572277
# Epoch 1, Batch 64, Loss: 0.291822
# Epoch 1, Batch 65, Loss: 0.341811
# Epoch 1, Batch 66, Loss: 0.208154
# Epoch 1, Batch 67, Loss: 0.436899
# Epoch 1, Batch 68, Loss: 0.343950
# Epoch 1, Batch 69, Loss: 0.460736
# Epoch 1, Batch 70, Loss: 0.473113
# Epoch 1, Batch 71, Loss: 0.252032
# Epoch 1, Batch 72, Loss: 0.339750
# Epoch 1, Batch 73, Loss: 0.467869
# Epoch 1, Batch 74, Loss: 0.376834
# Epoch 1, Batch 75, Loss: 0.373781
# Epoch 1, Batch 76, Loss: 0.239360
# Epoch 1, Batch 77, Loss: 0.382190
# Epoch 1, Batch 78, Loss: 0.214428
# Epoch 1, Batch 79, Loss: 0.326604
# Epoch 1, Batch 80, Loss: 0.354547
# Epoch 1, Batch 81, Loss: 0.427929
# Epoch 1, Batch 82, Loss: 0.316854
# Epoch 1, Batch 83, Loss: 0.619153
# Epoch 1, Batch 84, Loss: 0.266000
# Epoch 1, Batch 85, Loss: 0.439673
# Epoch 1, Batch 86, Loss: 0.382149
# Epoch 1, Batch 87, Loss: 0.223897
# Epoch 1, Batch 88, Loss: 0.362580
# Epoch 1, Batch 89, Loss: 0.267229
# Epoch 1, Batch 90, Loss: 0.506252
# Epoch 1, Batch 91, Loss: 0.383895
# Epoch 1, Batch 92, Loss: 0.264591
# Epoch 1, Batch 93, Loss: 0.253377
# Epoch 1, Batch 94, Loss: 0.174096
# Epoch 1, Batch 95, Loss: 0.386025
# Epoch 1, Batch 96, Loss: 0.270748
# Epoch 1, Batch 97, Loss: 0.209079
# Epoch 1, Batch 98, Loss: 0.360451
# Epoch 1, Batch 99, Loss: 0.278812
# Epoch 1, Batch 100, Loss: 0.276101
# Epoch 1, Batch 101, Loss: 0.235576
# Epoch 1, Batch 102, Loss: 0.299172
# Epoch 1, Batch 103, Loss: 0.467031
# Epoch 1, Batch 104, Loss: 0.243099
# Epoch 1, Batch 105, Loss: 0.308394
# Epoch 1, Batch 106, Loss: 0.285367
# Epoch 1, Batch 107, Loss: 0.194766
# Epoch 1, Batch 108, Loss: 0.223390
# Epoch 1, Batch 109, Loss: 0.426031
# Epoch 1, Batch 110, Loss: 0.470786
# Epoch 1, Batch 111, Loss: 0.233965
# Epoch 1, Batch 112, Loss: 0.379657
# Epoch 1, Batch 113, Loss: 0.273991
# Epoch 1, Batch 114, Loss: 0.235052
# Epoch 1, Batch 115, Loss: 0.537241
# Epoch 1, Batch 116, Loss: 0.359516
# Epoch 1, Batch 117, Loss: 0.405442
# Epoch 1, Batch 118, Loss: 0.312474
# Epoch 1, Batch 119, Loss: 0.330197
# Epoch 1, Batch 120, Loss: 0.327023
# Epoch 1, Batch 121, Loss: 0.452367
# Epoch 1, Batch 122, Loss: 0.339700
# Epoch 1, Batch 123, Loss: 0.324804
# Epoch 1, Batch 124, Loss: 0.253756
# Epoch 1, Batch 125, Loss: 0.249433
# Epoch 1, Batch 126, Loss: 0.344487
# Epoch 1, Batch 127, Loss: 0.383896
# Epoch 1, Batch 128, Loss: 0.247768
# Epoch 1, Batch 129, Loss: 0.494719
# Epoch 1, Batch 130, Loss: 0.472737
# Epoch 1, Batch 131, Loss: 0.359511
# Epoch 1, Batch 132, Loss: 0.245888
# Epoch 1, Batch 133, Loss: 0.513935
# Epoch 1, Batch 134, Loss: 0.431511
# Epoch 1, Batch 135, Loss: 0.224370
# Epoch 1, Batch 136, Loss: 0.299330
# Epoch 1, Batch 137, Loss: 0.432214
# Epoch 1, Batch 138, Loss: 0.559116
# Epoch 1, Batch 139, Loss: 0.326279
# Epoch 1, Batch 140, Loss: 0.336836
# Epoch 1, Batch 141, Loss: 0.209517
# Epoch 1, Batch 142, Loss: 0.237787
# Epoch 1, Batch 143, Loss: 0.328912
# Epoch 1, Batch 144, Loss: 0.515818
# Epoch 1, Batch 145, Loss: 0.235739
# Epoch 1, Batch 146, Loss: 0.485216
# Epoch 1, Batch 147, Loss: 0.261026
# Epoch 1, Batch 148, Loss: 0.312278
# Epoch 1, Batch 149, Loss: 0.348797
# Epoch 1, Batch 150, Loss: 0.264214
# Epoch 1, Batch 151, Loss: 0.199679
# Epoch 1, Batch 152, Loss: 0.377962
# Epoch 1, Batch 153, Loss: 0.241077
# Epoch 1, Batch 154, Loss: 0.186143
# Epoch 1, Batch 155, Loss: 0.357980
# Epoch 1, Batch 156, Loss: 0.366038
# Epoch 1, Batch 157, Loss: 0.172257
# Epoch 1, Batch 158, Loss: 0.238154
# Epoch 1, Batch 159, Loss: 0.338015
# Epoch 1, Batch 160, Loss: 0.222447
# Epoch 1, Batch 161, Loss: 0.439903
# Epoch 1, Batch 162, Loss: 0.347636
# Epoch 1, Batch 163, Loss: 0.583530
# Epoch 1, Batch 164, Loss: 0.263903
# Epoch 1, Batch 165, Loss: 0.233153
# Epoch 1, Batch 166, Loss: 0.211709
# Epoch 1, Batch 167, Loss: 0.512932
# Epoch 1, Batch 168, Loss: 0.378703
# Epoch 1, Batch 169, Loss: 0.187562
# Epoch 1, Batch 170, Loss: 0.274748
# Epoch 1, Batch 171, Loss: 0.281946
# Epoch 1, Batch 172, Loss: 0.214658
# Epoch 1, Batch 173, Loss: 0.363589
# Epoch 1, Batch 174, Loss: 0.461322
# Epoch 1, Batch 175, Loss: 0.348785
# Epoch 1, Batch 176, Loss: 0.249264
# Epoch 1, Batch 177, Loss: 0.220770
# Epoch 1, Batch 178, Loss: 0.491560
# Epoch 1, Batch 179, Loss: 0.378655
# Epoch 1, Batch 180, Loss: 0.204404
# Epoch 1, Batch 181, Loss: 0.182477
# Epoch 1, Batch 182, Loss: 0.246473
# Epoch 1, Batch 183, Loss: 0.310447
# Epoch 1, Batch 184, Loss: 0.273117
# Epoch 1, Batch 185, Loss: 0.338628
# Epoch 1, Batch 186, Loss: 0.269639
# Epoch 1, Batch 187, Loss: 0.435471
# Epoch 1, Batch 188, Loss: 0.461458
# Epoch 1, Batch 189, Loss: 0.366194
# Epoch 1, Batch 190, Loss: 0.311338
# Epoch 1, Batch 191, Loss: 0.304845
# Epoch 1, Batch 192, Loss: 0.332264
# Epoch 1, Batch 193, Loss: 0.290644
# Epoch 1, Batch 194, Loss: 0.214791
# Epoch 1, Batch 195, Loss: 0.402117
# Epoch 1, Batch 196, Loss: 0.246329
# Epoch 1, Batch 197, Loss: 0.305444
# Epoch 1, Batch 198, Loss: 0.515171
# Epoch 1, Batch 199, Loss: 0.360157
# Epoch 1, Batch 200, Loss: 0.242804
# Epoch 1, Batch 201, Loss: 0.361865
# Epoch 1, Batch 202, Loss: 0.186164
# Epoch 1, Batch 203, Loss: 0.287930
# Epoch 1, Batch 204, Loss: 0.350194
# Epoch 1, Batch 205, Loss: 0.184308
# Epoch 1, Batch 206, Loss: 0.387264
# Epoch 1, Batch 207, Loss: 0.214937
# Epoch 1, Batch 208, Loss: 0.378995
# Epoch 1, Batch 209, Loss: 0.220040
# Epoch 1, Batch 210, Loss: 0.271379
# Epoch 1, Batch 211, Loss: 0.358899
# Epoch 1, Batch 212, Loss: 0.258703
# Epoch 1, Batch 213, Loss: 0.431102
# Epoch 1, Batch 214, Loss: 0.253505
# Epoch 1, Batch 215, Loss: 0.132462
# Epoch 1, Batch 216, Loss: 0.356437
# Epoch 1, Batch 217, Loss: 0.254073
# Epoch 1, Batch 218, Loss: 0.147505
# Epoch 1, Batch 219, Loss: 0.323061
# Epoch 1, Batch 220, Loss: 0.388105
# Epoch 1, Batch 221, Loss: 0.281417
# Epoch 1, Batch 222, Loss: 0.440327
# Epoch 1, Batch 223, Loss: 0.276163
# Epoch 1, Batch 224, Loss: 0.314381
# Epoch 1, Batch 225, Loss: 0.137833
# Epoch 1, Batch 226, Loss: 0.307580
# Epoch 1, Batch 227, Loss: 0.296190
# Epoch 1, Batch 228, Loss: 0.330032
# Epoch 1, Batch 229, Loss: 0.266778
# Epoch 1, Batch 230, Loss: 0.358977
# Epoch 1, Batch 231, Loss: 0.522077
# Epoch 1, Batch 232, Loss: 0.114369
# Epoch 1, Batch 233, Loss: 0.435595
# Epoch 1, Batch 234, Loss: 0.165659
# Epoch 1, Batch 235, Loss: 0.221043
# Epoch 1, Batch 236, Loss: 0.301449
# Epoch 1, Batch 237, Loss: 0.402763
# Epoch 1, Batch 238, Loss: 0.258461
# Epoch 1, Batch 239, Loss: 0.297265
# Epoch 1, Batch 240, Loss: 0.264327
# Epoch 1, Batch 241, Loss: 0.238578
# Epoch 1, Batch 242, Loss: 0.368827
# Epoch 1, Batch 243, Loss: 0.318655
# Epoch 1, Batch 244, Loss: 0.325835
# Epoch 1, Batch 245, Loss: 0.298747
# Epoch 1, Batch 246, Loss: 0.310512
# Epoch 1, Batch 247, Loss: 0.454570
# Epoch 1, Batch 248, Loss: 0.260535
# Epoch 1, Batch 249, Loss: 0.143526
# Epoch 1, Batch 250, Loss: 0.336964
# Epoch 1, Batch 251, Loss: 0.378901
# Epoch 1, Batch 252, Loss: 0.240873
# Epoch 1, Batch 253, Loss: 0.138082
# Epoch 1, Batch 254, Loss: 0.217203
# Epoch 1, Batch 255, Loss: 0.255576
# Epoch 1, Batch 256, Loss: 0.224028
# Epoch 1, Batch 257, Loss: 0.348207
# Epoch 1, Batch 258, Loss: 0.384171
# Epoch 1, Batch 259, Loss: 0.261604
# Epoch 1, Batch 260, Loss: 0.252821
# Epoch 1, Batch 261, Loss: 0.365377
# Epoch 1, Batch 262, Loss: 0.191044
# Epoch 1, Batch 263, Loss: 0.350615
# Epoch 1, Batch 264, Loss: 0.218431
# Epoch 1, Batch 265, Loss: 0.241595
# Epoch 1, Batch 266, Loss: 0.201873
# Epoch 1, Batch 267, Loss: 0.152307
# Epoch 1, Batch 268, Loss: 0.447010
# Epoch 1, Batch 269, Loss: 0.242596
# Epoch 1, Batch 270, Loss: 0.309471
# Epoch 1, Batch 271, Loss: 0.346687
# Epoch 1, Batch 272, Loss: 0.223210
# Epoch 1, Batch 273, Loss: 0.278587
# Epoch 1, Batch 274, Loss: 0.253906
# Epoch 1, Batch 275, Loss: 0.208290
# Epoch 1, Batch 276, Loss: 0.429622
# Epoch 1, Batch 277, Loss: 0.200565
# Epoch 1, Batch 278, Loss: 0.318333
# Epoch 1, Batch 279, Loss: 0.380953
# Epoch 1, Batch 280, Loss: 0.353100
# Epoch 1, Batch 281, Loss: 0.191846
# Epoch 1, Batch 282, Loss: 0.160453
# Epoch 1, Batch 283, Loss: 0.310330
# Epoch 1, Batch 284, Loss: 0.284440
# Epoch 1, Batch 285, Loss: 0.279793
# Epoch 1, Batch 286, Loss: 0.281145
# Epoch 1, Batch 287, Loss: 0.351961
# Epoch 1, Batch 288, Loss: 0.421858
# Epoch 1, Batch 289, Loss: 0.264592
# Epoch 1, Batch 290, Loss: 0.169982
# Epoch 1, Batch 291, Loss: 0.312030
# Epoch 1, Batch 292, Loss: 0.136542
# Epoch 1, Batch 293, Loss: 0.312684
# Epoch 1, Batch 294, Loss: 0.180237
# Epoch 1, Batch 295, Loss: 0.247330
# Epoch 1, Batch 296, Loss: 0.266876
# Epoch 1, Batch 297, Loss: 0.445081
# Epoch 1, Batch 298, Loss: 0.278385
# Epoch 1, Batch 299, Loss: 0.271892
# Epoch 1, Batch 300, Loss: 0.192657
# Epoch 1, Batch 301, Loss: 0.536328
# Epoch 1, Batch 302, Loss: 0.170676
# Epoch 1, Batch 303, Loss: 0.258168
# Epoch 1, Batch 304, Loss: 0.173950
# Epoch 1, Batch 305, Loss: 0.266275
# Epoch 1, Batch 306, Loss: 0.414769
# Epoch 1, Batch 307, Loss: 0.291926
# Epoch 1, Batch 308, Loss: 0.293389
# Epoch 1, Batch 309, Loss: 0.329076
# Epoch 1, Batch 310, Loss: 0.422948
# Epoch 1, Batch 311, Loss: 0.201823
# Epoch 1, Batch 312, Loss: 0.164777
# Epoch 1, Batch 313, Loss: 0.280450
# Epoch 1, Batch 314, Loss: 0.312642
# Epoch 1, Batch 315, Loss: 0.218127
# Epoch 1, Batch 316, Loss: 0.356579
# Epoch 1, Batch 317, Loss: 0.382815
# Epoch 1, Batch 318, Loss: 0.298721
# Epoch 1, Batch 319, Loss: 0.224069
# Epoch 1, Batch 320, Loss: 0.211997
# Epoch 1, Batch 321, Loss: 0.236821
# Epoch 1, Batch 322, Loss: 0.224047
# Epoch 1, Batch 323, Loss: 0.279922
# Epoch 1, Batch 324, Loss: 0.481656
# Epoch 1, Batch 325, Loss: 0.238127
# Epoch 1, Batch 326, Loss: 0.447094
# Epoch 1, Batch 327, Loss: 0.263488
# Epoch 1, Batch 328, Loss: 0.177605
# Epoch 1, Batch 329, Loss: 0.170303
# Epoch 1, Batch 330, Loss: 0.277403
# Epoch 1, Batch 331, Loss: 0.257770
# Epoch 1, Batch 332, Loss: 0.109884
# Epoch 1, Batch 333, Loss: 0.180791
# Epoch 1, Batch 334, Loss: 0.383468
# Epoch 1, Batch 335, Loss: 0.432095
# Epoch 1, Batch 336, Loss: 0.199774
# Epoch 1, Batch 337, Loss: 0.318226
# Epoch 1, Batch 338, Loss: 0.152997
# Epoch 1, Batch 339, Loss: 0.256860
# Epoch 1, Batch 340, Loss: 0.133910
# Epoch 1, Batch 341, Loss: 0.182840
# Epoch 1, Batch 342, Loss: 0.285336
# Epoch 1, Batch 343, Loss: 0.360947
# Epoch 1, Batch 344, Loss: 0.288201
# Epoch 1, Batch 345, Loss: 0.525568
# Epoch 1, Batch 346, Loss: 0.366892
# Epoch 1, Batch 347, Loss: 0.194992
# Epoch 1, Batch 348, Loss: 0.255787
# Epoch 1, Batch 349, Loss: 0.298609
# Epoch 1, Batch 350, Loss: 0.214209
# Epoch 1, Batch 351, Loss: 0.299664
# Epoch 1, Batch 352, Loss: 0.186033
# Epoch 1, Batch 353, Loss: 0.191432
# Epoch 1, Batch 354, Loss: 0.438257
# Epoch 1, Batch 355, Loss: 0.409532
# Epoch 1, Batch 356, Loss: 0.388008
# Epoch 1, Batch 357, Loss: 0.175887
# Epoch 1, Batch 358, Loss: 0.218306
# Epoch 1, Batch 359, Loss: 0.574947
# Epoch 1, Batch 360, Loss: 0.491973
# Epoch 1, Batch 361, Loss: 0.292693
# Epoch 1, Batch 362, Loss: 0.499424
# Epoch 1, Batch 363, Loss: 0.331884
# Epoch 1, Batch 364, Loss: 0.267927
# Epoch 1, Batch 365, Loss: 0.402680
# Epoch 1, Batch 366, Loss: 0.318721
# Epoch 1, Batch 367, Loss: 0.277640
# Epoch 1, Batch 368, Loss: 0.224608
# Epoch 1, Batch 369, Loss: 0.277913
# Epoch 1, Batch 370, Loss: 0.197362
# Epoch 1, Batch 371, Loss: 0.329423
# Epoch 1, Batch 372, Loss: 0.185692
# Epoch 1, Batch 373, Loss: 0.125620
# Epoch 1, Batch 374, Loss: 0.332013
# Epoch 1, Batch 375, Loss: 0.286472
# Epoch 1, Batch 376, Loss: 0.337941
# Epoch 1, Batch 377, Loss: 0.178619
# Epoch 1, Batch 378, Loss: 0.121616
# Epoch 1, Batch 379, Loss: 0.327880
# Epoch 1, Batch 380, Loss: 0.191470
# Epoch 1, Batch 381, Loss: 0.356350
# Epoch 1, Batch 382, Loss: 0.157613
# Epoch 1, Batch 383, Loss: 0.240128
# Epoch 1, Batch 384, Loss: 0.284464
# Epoch 1, Batch 385, Loss: 0.252903
# Epoch 1, Batch 386, Loss: 0.350241
# Epoch 1, Batch 387, Loss: 0.372802
# Epoch 1, Batch 388, Loss: 0.167521
# Epoch 1, Batch 389, Loss: 0.265682
# Epoch 1, Batch 390, Loss: 0.294111
# Epoch 1, Batch 391, Loss: 0.325042
# Epoch 1, Batch 392, Loss: 0.206901
# Epoch 1, Batch 393, Loss: 0.096765
# Epoch 1, Batch 394, Loss: 0.268967
# Epoch 1, Batch 395, Loss: 0.338796
# Epoch 1, Batch 396, Loss: 0.140124
# Epoch 1, Batch 397, Loss: 0.241522
# Epoch 1, Batch 398, Loss: 0.365808
# Epoch 1, Batch 399, Loss: 0.269824
# Epoch 1, Batch 400, Loss: 0.292919
# Epoch 1, Batch 401, Loss: 0.185952
# Epoch 1, Batch 402, Loss: 0.427612
# Epoch 1, Batch 403, Loss: 0.417226
# Epoch 1, Batch 404, Loss: 0.287021
# Epoch 1, Batch 405, Loss: 0.141069
# Epoch 1, Batch 406, Loss: 0.270779
# Epoch 1, Batch 407, Loss: 0.158001
# Epoch 1, Batch 408, Loss: 0.103397
# Epoch 1, Batch 409, Loss: 0.432748
# Epoch 1, Batch 410, Loss: 0.265427
# Epoch 1, Batch 411, Loss: 0.384955
# Epoch 1, Batch 412, Loss: 0.155310
# Epoch 1, Batch 413, Loss: 0.331388
# Epoch 1, Batch 414, Loss: 0.309478
# Epoch 1, Batch 415, Loss: 0.249532
# Epoch 1, Batch 416, Loss: 0.354079
# Epoch 1, Batch 417, Loss: 0.397581
# Epoch 1, Batch 418, Loss: 0.266939
# Epoch 1, Batch 419, Loss: 0.314109
# Epoch 1, Batch 420, Loss: 0.363963
# Epoch 1, Batch 421, Loss: 0.420331
# Epoch 1, Batch 422, Loss: 0.328209
# Epoch 1, Batch 423, Loss: 0.192006
# Epoch 1, Batch 424, Loss: 0.457516
# Epoch 1, Batch 425, Loss: 0.249491
# Epoch 1, Batch 426, Loss: 0.276329
# Epoch 1, Batch 427, Loss: 0.162481
# Epoch 1, Batch 428, Loss: 0.307642
# Epoch 1, Batch 429, Loss: 0.379355
# Epoch 1, Batch 430, Loss: 0.239030
# Epoch 1, Batch 431, Loss: 0.237769
# Epoch 1, Batch 432, Loss: 0.203645
# Epoch 1, Batch 433, Loss: 0.178762
# Epoch 1, Batch 434, Loss: 0.230687
# Epoch 1, Batch 435, Loss: 0.283779
# Epoch 1, Batch 436, Loss: 0.172381
# Epoch 1, Batch 437, Loss: 0.256442
# Epoch 1, Batch 438, Loss: 0.243271
# Epoch 1, Batch 439, Loss: 0.270182
# Epoch 1, Batch 440, Loss: 0.327626
# Epoch 1, Batch 441, Loss: 0.353272
# Epoch 1, Batch 442, Loss: 0.370460
# Epoch 1, Batch 443, Loss: 0.229489
# Epoch 1, Batch 444, Loss: 0.191256
# Epoch 1, Batch 445, Loss: 0.568461
# Epoch 1, Batch 446, Loss: 0.297266
# Epoch 1, Batch 447, Loss: 0.205925
# Epoch 1, Batch 448, Loss: 0.297752
# Epoch 1, Batch 449, Loss: 0.292301
# Epoch 1, Batch 450, Loss: 0.302307
# Epoch 1, Batch 451, Loss: 0.610340
# Epoch 1, Batch 452, Loss: 0.316684
# Epoch 1, Batch 453, Loss: 0.226688
# Epoch 1, Batch 454, Loss: 0.267934
# Epoch 1, Batch 455, Loss: 0.175666
# Epoch 1, Batch 456, Loss: 0.390565
# Epoch 1, Batch 457, Loss: 0.396524
# Epoch 1, Batch 458, Loss: 0.165768
# Epoch 1, Batch 459, Loss: 0.278250
# Epoch 1, Batch 460, Loss: 0.262482
# Epoch 1, Batch 461, Loss: 0.314747
# Epoch 1, Batch 462, Loss: 0.334501
# Epoch 1, Batch 463, Loss: 0.113242
# Epoch 1, Batch 464, Loss: 0.257482
# Epoch 1, Batch 465, Loss: 0.523713
# Epoch 1, Batch 466, Loss: 0.352787
# Epoch 1, Batch 467, Loss: 0.436318
# Epoch 1, Batch 468, Loss: 0.261557
# Epoch 1, Batch 469, Loss: 0.238372
# Epoch 1, Batch 470, Loss: 0.276768
# Epoch 1, Batch 471, Loss: 0.279779
# Epoch 1, Batch 472, Loss: 0.127475
# Epoch 1, Batch 473, Loss: 0.314974
# Epoch 1, Batch 474, Loss: 0.420809
# Epoch 1, Batch 475, Loss: 0.342850
# Epoch 1, Batch 476, Loss: 0.232895
# Epoch 1, Batch 477, Loss: 0.243707
# Epoch 1, Batch 478, Loss: 0.342156
# Epoch 1, Batch 479, Loss: 0.322466
# Epoch 1, Batch 480, Loss: 0.251288
# Epoch 1, Batch 481, Loss: 0.489530
# Epoch 1, Batch 482, Loss: 0.353711
# Epoch 1, Batch 483, Loss: 0.178477
# Epoch 1, Batch 484, Loss: 0.090054
# Epoch 1, Batch 485, Loss: 0.174505
# Epoch 1, Batch 486, Loss: 0.224688
# Epoch 1, Batch 487, Loss: 0.262661
# Epoch 1, Batch 488, Loss: 0.202801
# Epoch 1, Batch 489, Loss: 0.160072
# Epoch 1, Batch 490, Loss: 0.255782
# Epoch 1, Batch 491, Loss: 0.173819
# Epoch 1, Batch 492, Loss: 0.172317
# Epoch 1, Batch 493, Loss: 0.437142
# Epoch 1, Batch 494, Loss: 0.272353
# Epoch 1, Batch 495, Loss: 0.269917
# Epoch 1, Batch 496, Loss: 0.487394
# Epoch 1, Batch 497, Loss: 0.411856
# Epoch 1, Batch 498, Loss: 0.233862
# Epoch 1, Batch 499, Loss: 0.140885
# Epoch 1, Batch 500, Loss: 0.388902
# Epoch 1, Batch 501, Loss: 0.224556
# Epoch 1, Batch 502, Loss: 0.419295
# Epoch 1, Batch 503, Loss: 0.273675
# Epoch 1, Batch 504, Loss: 0.259477
# Epoch 1, Batch 505, Loss: 0.242720
# Epoch 1, Batch 506, Loss: 0.241173
# Epoch 1, Batch 507, Loss: 0.315668
# Epoch 1, Batch 508, Loss: 0.334925
# Epoch 1, Batch 509, Loss: 0.176625
# Epoch 1, Batch 510, Loss: 0.196439
# Epoch 1, Batch 511, Loss: 0.214819
# Epoch 1, Batch 512, Loss: 0.220514
# Epoch 1, Batch 513, Loss: 0.372824
# Epoch 1, Batch 514, Loss: 0.322419
# Epoch 1, Batch 515, Loss: 0.255753
# Epoch 1, Batch 516, Loss: 0.178741
# Epoch 1, Batch 517, Loss: 0.349689
# Epoch 1, Batch 518, Loss: 0.192675
# Epoch 1, Batch 519, Loss: 0.211466
# Epoch 1, Batch 520, Loss: 0.280641
# Epoch 1, Batch 521, Loss: 0.267793
# Epoch 1, Batch 522, Loss: 0.572474
# Epoch 1, Batch 523, Loss: 0.151335
# Epoch 1, Batch 524, Loss: 0.101893
# Epoch 1, Batch 525, Loss: 0.114124
# Epoch 1, Batch 526, Loss: 0.290455
# Epoch 1, Batch 527, Loss: 0.205930
# Epoch 1, Batch 528, Loss: 0.253759
# Epoch 1, Batch 529, Loss: 0.226961
# Epoch 1, Batch 530, Loss: 0.202622
# Epoch 1, Batch 531, Loss: 0.271423
# Epoch 1, Batch 532, Loss: 0.416263
# Epoch 1, Batch 533, Loss: 0.353738
# Epoch 1, Batch 534, Loss: 0.169140
# Epoch 1, Batch 535, Loss: 0.238615
# Epoch 1, Batch 536, Loss: 0.304441
# Epoch 1, Batch 537, Loss: 0.128383
# Epoch 1, Batch 538, Loss: 0.072092
# Epoch 1, Batch 539, Loss: 0.307995
# Epoch 1, Batch 540, Loss: 0.128862
# Epoch 1, Batch 541, Loss: 0.207270
# Epoch 1, Batch 542, Loss: 0.197314
# Epoch 1, Batch 543, Loss: 0.242949
# Epoch 1, Batch 544, Loss: 0.321822
# Epoch 1, Batch 545, Loss: 0.402718
# Epoch 1, Batch 546, Loss: 0.086056
# Epoch 1, Batch 547, Loss: 0.250360
# Epoch 1, Batch 548, Loss: 0.316400
# Epoch 1, Batch 549, Loss: 0.280931
# Epoch 1, Batch 550, Loss: 0.347170
# Epoch 1, Batch 551, Loss: 0.239223
# Epoch 1, Batch 552, Loss: 0.242178
# Epoch 1, Batch 553, Loss: 0.208967
# Epoch 1, Batch 554, Loss: 0.380216
# Epoch 1, Batch 555, Loss: 0.231137
# Epoch 1, Batch 556, Loss: 0.253227
# Epoch 1, Batch 557, Loss: 0.302699
# Epoch 1, Batch 558, Loss: 0.316433
# Epoch 1, Batch 559, Loss: 0.250277
# Epoch 1, Batch 560, Loss: 0.166237
# Epoch 1, Batch 561, Loss: 0.381433
# Epoch 1, Batch 562, Loss: 0.292757
# Epoch 1, Batch 563, Loss: 0.165040
# Epoch 1, Batch 564, Loss: 0.334700
# Epoch 1, Batch 565, Loss: 0.164207
# Epoch 1, Batch 566, Loss: 0.172950
# Epoch 1, Batch 567, Loss: 0.370632
# Epoch 1, Batch 568, Loss: 0.173790
# Epoch 1, Batch 569, Loss: 0.181436
# Epoch 1, Batch 570, Loss: 0.183191
# Epoch 1, Batch 571, Loss: 0.383576
# Epoch 1, Batch 572, Loss: 0.297178
# Epoch 1, Batch 573, Loss: 0.253479
# Epoch 1, Batch 574, Loss: 0.318191
# Epoch 1, Batch 575, Loss: 0.271611
# Epoch 1, Batch 576, Loss: 0.283544
# Epoch 1, Batch 577, Loss: 0.352568
# Epoch 1, Batch 578, Loss: 0.166465
# Epoch 1, Batch 579, Loss: 0.122743
# Epoch 1, Batch 580, Loss: 0.258949
# Epoch 1, Batch 581, Loss: 0.158245
# Epoch 1, Batch 582, Loss: 0.263827
# Epoch 1, Batch 583, Loss: 0.129404
# Epoch 1, Batch 584, Loss: 0.389865
# Epoch 1, Batch 585, Loss: 0.145235
# Epoch 1, Batch 586, Loss: 0.118640
# Epoch 1, Batch 587, Loss: 0.517520
# Epoch 1, Batch 588, Loss: 0.171123
# Epoch 1, Batch 589, Loss: 0.294343
# Epoch 1, Batch 590, Loss: 0.297710
# Epoch 1, Batch 591, Loss: 0.451415
# Epoch 1, Batch 592, Loss: 0.320005
# Epoch 1, Batch 593, Loss: 0.478419
# Epoch 1, Batch 594, Loss: 0.224226
# Epoch 1, Batch 595, Loss: 0.339239
# Epoch 1, Batch 596, Loss: 0.270465
# Epoch 1, Batch 597, Loss: 0.173463
# Epoch 1, Batch 598, Loss: 0.234919
# Epoch 1, Batch 599, Loss: 0.175624
# Epoch 1, Batch 600, Loss: 0.225302
# Epoch 1, Batch 601, Loss: 0.205547
# Epoch 1, Batch 602, Loss: 0.230700
# Epoch 1, Batch 603, Loss: 0.249216
# Epoch 1, Batch 604, Loss: 0.162578
# Epoch 1, Batch 605, Loss: 0.202156
# Epoch 1, Batch 606, Loss: 0.169102
# Epoch 1, Batch 607, Loss: 0.269301
# Epoch 1, Batch 608, Loss: 0.202880
# Epoch 1, Batch 609, Loss: 0.274600
# Epoch 1, Batch 610, Loss: 0.291900
# Epoch 1, Batch 611, Loss: 0.172434
# Epoch 1, Batch 612, Loss: 0.100400
# Epoch 1, Batch 613, Loss: 0.307877
# Epoch 1, Batch 614, Loss: 0.301994
# Epoch 1, Batch 615, Loss: 0.349986
# Epoch 1, Batch 616, Loss: 0.213515
# Epoch 1, Batch 617, Loss: 0.144660
# Epoch 1, Batch 618, Loss: 0.213771
# Epoch 1, Batch 619, Loss: 0.129076
# Epoch 1, Batch 620, Loss: 0.341530
# Epoch 1, Batch 621, Loss: 0.362905
# Epoch 1, Batch 622, Loss: 0.181675
# Epoch 1, Batch 623, Loss: 0.205163
# Epoch 1, Batch 624, Loss: 0.100052
# Epoch 1, Batch 625, Loss: 0.357204
# Epoch 1, Batch 626, Loss: 0.227637
# Epoch 1, Batch 627, Loss: 0.246770
# Epoch 1, Batch 628, Loss: 0.479203
# Epoch 1, Batch 629, Loss: 0.175205
# Epoch 1, Batch 630, Loss: 0.295623
# Epoch 1, Batch 631, Loss: 0.201659
# Epoch 1, Batch 632, Loss: 0.370784
# Epoch 1, Batch 633, Loss: 0.152253
# Epoch 1, Batch 634, Loss: 0.231700
# Epoch 1, Batch 635, Loss: 0.258289
# Epoch 1, Batch 636, Loss: 0.191502
# Epoch 1, Batch 637, Loss: 0.156016
# Epoch 1, Batch 638, Loss: 0.186791
# Epoch 1, Batch 639, Loss: 0.206869
# Epoch 1, Batch 640, Loss: 0.273548
# Epoch 1, Batch 641, Loss: 0.406984
# Epoch 1, Batch 642, Loss: 0.173544
# Epoch 1, Batch 643, Loss: 0.198699
# Epoch 1, Batch 644, Loss: 0.199261
# Epoch 1, Batch 645, Loss: 0.453225
# Epoch 1, Batch 646, Loss: 0.296564
# Epoch 1, Batch 647, Loss: 0.223658
# Epoch 1, Batch 648, Loss: 0.448247
# Epoch 1, Batch 649, Loss: 0.128863
# Epoch 1, Batch 650, Loss: 0.331130
# Epoch 1, Batch 651, Loss: 0.267930
# Epoch 1, Batch 652, Loss: 0.187336
# Epoch 1, Batch 653, Loss: 0.521581
# Epoch 1, Batch 654, Loss: 0.111454
# Epoch 1, Batch 655, Loss: 0.084281
# Epoch 1, Batch 656, Loss: 0.475330
# Warning: test set has no labels, skip accuracy evaluation.
# Saved: d:\CZ_WorkSpace\ai学习\深度学习实践\task1\task1_3\checkpoints\model_epoch_1.pth
# Epoch 2, Batch 0, Loss: 0.446875
# Epoch 2, Batch 1, Loss: 0.237743
# Epoch 2, Batch 2, Loss: 0.111149
# Epoch 2, Batch 3, Loss: 0.561146
# Epoch 2, Batch 4, Loss: 0.390512
# Epoch 2, Batch 5, Loss: 0.275652
# Epoch 2, Batch 6, Loss: 0.196739
# Epoch 2, Batch 7, Loss: 0.412707
# Epoch 2, Batch 8, Loss: 0.498151
# Epoch 2, Batch 9, Loss: 0.272161
# Epoch 2, Batch 10, Loss: 0.351209
# Epoch 2, Batch 11, Loss: 0.204332
# Epoch 2, Batch 12, Loss: 0.324353
# Epoch 2, Batch 13, Loss: 0.271653
# Epoch 2, Batch 14, Loss: 0.243840
# Epoch 2, Batch 15, Loss: 0.163612
# Epoch 2, Batch 16, Loss: 0.115207
# Epoch 2, Batch 17, Loss: 0.170308
# Epoch 2, Batch 18, Loss: 0.189005
# Epoch 2, Batch 19, Loss: 0.051365
# Epoch 2, Batch 20, Loss: 0.325170
# Epoch 2, Batch 21, Loss: 0.164044
# Epoch 2, Batch 22, Loss: 0.264904
# Epoch 2, Batch 23, Loss: 0.086343
# Epoch 2, Batch 24, Loss: 0.176203
# Epoch 2, Batch 25, Loss: 0.220404
# Epoch 2, Batch 26, Loss: 0.231938
# Epoch 2, Batch 27, Loss: 0.171614
# Epoch 2, Batch 28, Loss: 0.173518
# Epoch 2, Batch 29, Loss: 0.153152
# Epoch 2, Batch 30, Loss: 0.262434
# Epoch 2, Batch 31, Loss: 0.195939
# Epoch 2, Batch 32, Loss: 0.340729
# Epoch 2, Batch 33, Loss: 0.168143
# Epoch 2, Batch 34, Loss: 0.183652
# Epoch 2, Batch 35, Loss: 0.344654
# Epoch 2, Batch 36, Loss: 0.451923
# Epoch 2, Batch 37, Loss: 0.275885
# Epoch 2, Batch 38, Loss: 0.174850
# Epoch 2, Batch 39, Loss: 0.272927
# Epoch 2, Batch 40, Loss: 0.086897
# Epoch 2, Batch 41, Loss: 0.216299
# Epoch 2, Batch 42, Loss: 0.183409
# Epoch 2, Batch 43, Loss: 0.117798
# Epoch 2, Batch 44, Loss: 0.229295
# Epoch 2, Batch 45, Loss: 0.354702
# Epoch 2, Batch 46, Loss: 0.188467
# Epoch 2, Batch 47, Loss: 0.312652
# Epoch 2, Batch 48, Loss: 0.093227
# Epoch 2, Batch 49, Loss: 0.297009
# Epoch 2, Batch 50, Loss: 0.176905
# Epoch 2, Batch 51, Loss: 0.140500
# Epoch 2, Batch 52, Loss: 0.169009
# Epoch 2, Batch 53, Loss: 0.301640
# Epoch 2, Batch 54, Loss: 0.162553
# Epoch 2, Batch 55, Loss: 0.254772
# Epoch 2, Batch 56, Loss: 0.188984
# ...
# Epoch 9, Batch 204, Loss: 0.006327
# Epoch 9, Batch 205, Loss: 0.040683
# Epoch 9, Batch 206, Loss: 0.016830
# Epoch 9, Batch 207, Loss: 0.074621
# Epoch 9, Batch 208, Loss: 0.094082
# Epoch 9, Batch 209, Loss: 0.074906
# Epoch 9, Batch 210, Loss: 0.065217
# Epoch 9, Batch 211, Loss: 0.047866
# Epoch 9, Batch 212, Loss: 0.024253
# Epoch 9, Batch 213, Loss: 0.073271
# Epoch 9, Batch 214, Loss: 0.043336
# Epoch 9, Batch 215, Loss: 0.042235
# Epoch 9, Batch 216, Loss: 0.020803
# Epoch 9, Batch 217, Loss: 0.010902
# Epoch 9, Batch 218, Loss: 0.122310
# Epoch 9, Batch 219, Loss: 0.040067
# Epoch 9, Batch 220, Loss: 0.043645
# Epoch 9, Batch 221, Loss: 0.128884
# Epoch 9, Batch 222, Loss: 0.053303
# Epoch 9, Batch 223, Loss: 0.044702
# Epoch 9, Batch 224, Loss: 0.091958
# Epoch 9, Batch 225, Loss: 0.054289
# Epoch 9, Batch 226, Loss: 0.032089
# Epoch 9, Batch 227, Loss: 0.007266
# Epoch 9, Batch 228, Loss: 0.048811
# Epoch 9, Batch 229, Loss: 0.213722
# Epoch 9, Batch 230, Loss: 0.050006
# Epoch 9, Batch 231, Loss: 0.049204
# Epoch 9, Batch 232, Loss: 0.023939
# Epoch 9, Batch 233, Loss: 0.112704
# Epoch 9, Batch 234, Loss: 0.018976
# Epoch 9, Batch 235, Loss: 0.082068
# Epoch 9, Batch 236, Loss: 0.103749
# Epoch 9, Batch 237, Loss: 0.004470
# Epoch 9, Batch 238, Loss: 0.071024
# Epoch 9, Batch 239, Loss: 0.105993
# Epoch 9, Batch 240, Loss: 0.100875
# Epoch 9, Batch 241, Loss: 0.095902
# Epoch 9, Batch 242, Loss: 0.092529
# Epoch 9, Batch 243, Loss: 0.036882
# Epoch 9, Batch 244, Loss: 0.075509
# Epoch 9, Batch 245, Loss: 0.038895
# Epoch 9, Batch 246, Loss: 0.046509
# Epoch 9, Batch 247, Loss: 0.051183
# Epoch 9, Batch 248, Loss: 0.039977
# Epoch 9, Batch 249, Loss: 0.064052
# Epoch 9, Batch 250, Loss: 0.094717
# Epoch 9, Batch 251, Loss: 0.040447
# Epoch 9, Batch 252, Loss: 0.084356
# Epoch 9, Batch 253, Loss: 0.040310
# Epoch 9, Batch 254, Loss: 0.211485
# Epoch 9, Batch 255, Loss: 0.023822
# Epoch 9, Batch 256, Loss: 0.072411
# Epoch 9, Batch 257, Loss: 0.047264
# Epoch 9, Batch 258, Loss: 0.128508
# Epoch 9, Batch 259, Loss: 0.120220
# Epoch 9, Batch 260, Loss: 0.059632
# Epoch 9, Batch 261, Loss: 0.045193
# Epoch 9, Batch 262, Loss: 0.065019
# Epoch 9, Batch 263, Loss: 0.074872
# Epoch 9, Batch 264, Loss: 0.010460
# Epoch 9, Batch 265, Loss: 0.162451
# Epoch 9, Batch 266, Loss: 0.069659
# Epoch 9, Batch 267, Loss: 0.031934
# Epoch 9, Batch 268, Loss: 0.134996
# Epoch 9, Batch 269, Loss: 0.295759
# Epoch 9, Batch 270, Loss: 0.049957
# Epoch 9, Batch 271, Loss: 0.086337
# Epoch 9, Batch 272, Loss: 0.031153
# Epoch 9, Batch 273, Loss: 0.070392
# Epoch 9, Batch 274, Loss: 0.084439
# Epoch 9, Batch 275, Loss: 0.075145
# Epoch 9, Batch 276, Loss: 0.080781
# Epoch 9, Batch 277, Loss: 0.057858
# Epoch 9, Batch 278, Loss: 0.062348
# Epoch 9, Batch 279, Loss: 0.044874
# Epoch 9, Batch 280, Loss: 0.120362
# Epoch 9, Batch 281, Loss: 0.072218
# Epoch 9, Batch 282, Loss: 0.054892
# Epoch 9, Batch 283, Loss: 0.048505
# Epoch 9, Batch 284, Loss: 0.140600
# Epoch 9, Batch 285, Loss: 0.025128
# Epoch 9, Batch 286, Loss: 0.026619
# Epoch 9, Batch 287, Loss: 0.064083
# Epoch 9, Batch 288, Loss: 0.171287
# Epoch 9, Batch 289, Loss: 0.055951
# Epoch 9, Batch 290, Loss: 0.112946
# Epoch 9, Batch 291, Loss: 0.034658
# Epoch 9, Batch 292, Loss: 0.071779
# Epoch 9, Batch 293, Loss: 0.056745
# Epoch 9, Batch 294, Loss: 0.037016
# Epoch 9, Batch 295, Loss: 0.077813
# Epoch 9, Batch 296, Loss: 0.145823
# Epoch 9, Batch 297, Loss: 0.050484
# Epoch 9, Batch 298, Loss: 0.025450
# Epoch 9, Batch 299, Loss: 0.141008
# Epoch 9, Batch 300, Loss: 0.180392
# Epoch 9, Batch 301, Loss: 0.092183
# Epoch 9, Batch 302, Loss: 0.036095
# Epoch 9, Batch 303, Loss: 0.088329
# Epoch 9, Batch 304, Loss: 0.040874
# Epoch 9, Batch 305, Loss: 0.028606
# Epoch 9, Batch 306, Loss: 0.146312
# Epoch 9, Batch 307, Loss: 0.030890
# Epoch 9, Batch 308, Loss: 0.117226
# Epoch 9, Batch 309, Loss: 0.096951
# Epoch 9, Batch 310, Loss: 0.040862
# Epoch 9, Batch 311, Loss: 0.038473
# Epoch 9, Batch 312, Loss: 0.031530
# Epoch 9, Batch 313, Loss: 0.130223
# Epoch 9, Batch 314, Loss: 0.049901
# Epoch 9, Batch 315, Loss: 0.060914
# Epoch 9, Batch 316, Loss: 0.067624
# Epoch 9, Batch 317, Loss: 0.021307
# Epoch 9, Batch 318, Loss: 0.024553
# Epoch 9, Batch 319, Loss: 0.022246
# Epoch 9, Batch 320, Loss: 0.183190
# Epoch 9, Batch 321, Loss: 0.187865
# Epoch 9, Batch 322, Loss: 0.010240
# Epoch 9, Batch 323, Loss: 0.031281
# Epoch 9, Batch 324, Loss: 0.275391
# Epoch 9, Batch 325, Loss: 0.093666
# Epoch 9, Batch 326, Loss: 0.164367
# Epoch 9, Batch 327, Loss: 0.166158
# Epoch 9, Batch 328, Loss: 0.052594
# Epoch 9, Batch 329, Loss: 0.043204
# Epoch 9, Batch 330, Loss: 0.055578
# Epoch 9, Batch 331, Loss: 0.061282
# Epoch 9, Batch 332, Loss: 0.012608
# Epoch 9, Batch 333, Loss: 0.175924
# Epoch 9, Batch 334, Loss: 0.118535
# Epoch 9, Batch 335, Loss: 0.021609
# Epoch 9, Batch 336, Loss: 0.033618
# Epoch 9, Batch 337, Loss: 0.030517
# Epoch 9, Batch 338, Loss: 0.167568
# Epoch 9, Batch 339, Loss: 0.061020
# Epoch 9, Batch 340, Loss: 0.039219
# Epoch 9, Batch 341, Loss: 0.047216
# Epoch 9, Batch 342, Loss: 0.024977
# Epoch 9, Batch 343, Loss: 0.042460
# Epoch 9, Batch 344, Loss: 0.052065
# Epoch 9, Batch 345, Loss: 0.140473
# Epoch 9, Batch 346, Loss: 0.045342
# Epoch 9, Batch 347, Loss: 0.049645
# Epoch 9, Batch 348, Loss: 0.172808
# Epoch 9, Batch 349, Loss: 0.054920
# Epoch 9, Batch 350, Loss: 0.061050
# Epoch 9, Batch 351, Loss: 0.022121
# Epoch 9, Batch 352, Loss: 0.129296
# Epoch 9, Batch 353, Loss: 0.058809
# Epoch 9, Batch 354, Loss: 0.025978
# Epoch 9, Batch 355, Loss: 0.056206
# Epoch 9, Batch 356, Loss: 0.016325
# Epoch 9, Batch 357, Loss: 0.022017
# Epoch 9, Batch 358, Loss: 0.080993
# Epoch 9, Batch 359, Loss: 0.082590
# Epoch 9, Batch 360, Loss: 0.020751
# Epoch 9, Batch 361, Loss: 0.101092
# Epoch 9, Batch 362, Loss: 0.067174
# Epoch 9, Batch 363, Loss: 0.024918
# Epoch 9, Batch 364, Loss: 0.013260
# Epoch 9, Batch 365, Loss: 0.040700
# Epoch 9, Batch 366, Loss: 0.017835
# Epoch 9, Batch 367, Loss: 0.044012
# Epoch 9, Batch 368, Loss: 0.025386
# Epoch 9, Batch 369, Loss: 0.179307
# Epoch 9, Batch 370, Loss: 0.044893
# Epoch 9, Batch 371, Loss: 0.030550
# Epoch 9, Batch 372, Loss: 0.033593
# Epoch 9, Batch 373, Loss: 0.062365
# Epoch 9, Batch 374, Loss: 0.064669
# Epoch 9, Batch 375, Loss: 0.045409
# Epoch 9, Batch 376, Loss: 0.032447
# Epoch 9, Batch 377, Loss: 0.086538
# Epoch 9, Batch 378, Loss: 0.085087
# Epoch 9, Batch 379, Loss: 0.130324
# Epoch 9, Batch 380, Loss: 0.004053
# Epoch 9, Batch 381, Loss: 0.135807
# Epoch 9, Batch 382, Loss: 0.186099
# Epoch 9, Batch 383, Loss: 0.236769
# Epoch 9, Batch 384, Loss: 0.168439
# Epoch 9, Batch 385, Loss: 0.101036
# Epoch 9, Batch 386, Loss: 0.017812
# Epoch 9, Batch 387, Loss: 0.019410
# Epoch 9, Batch 388, Loss: 0.136699
# Epoch 9, Batch 389, Loss: 0.117125
# Epoch 9, Batch 390, Loss: 0.079290
# Epoch 9, Batch 391, Loss: 0.076805
# Epoch 9, Batch 392, Loss: 0.024772
# Epoch 9, Batch 393, Loss: 0.037944
# Epoch 9, Batch 394, Loss: 0.043733
# Epoch 9, Batch 395, Loss: 0.147385
# Epoch 9, Batch 396, Loss: 0.043608
# Epoch 9, Batch 397, Loss: 0.063705
# Epoch 9, Batch 398, Loss: 0.097979
# Epoch 9, Batch 399, Loss: 0.095006
# Epoch 9, Batch 400, Loss: 0.057223
# Epoch 9, Batch 401, Loss: 0.012815
# Epoch 9, Batch 402, Loss: 0.016076
# Epoch 9, Batch 403, Loss: 0.057991
# Epoch 9, Batch 404, Loss: 0.017963
# Epoch 9, Batch 405, Loss: 0.048911
# Epoch 9, Batch 406, Loss: 0.097946
# Epoch 9, Batch 407, Loss: 0.070534
# Epoch 9, Batch 408, Loss: 0.071966
# Epoch 9, Batch 409, Loss: 0.064648
# Epoch 9, Batch 410, Loss: 0.175477
# Epoch 9, Batch 411, Loss: 0.240215
# Epoch 9, Batch 412, Loss: 0.014136
# Epoch 9, Batch 413, Loss: 0.029514
# Epoch 9, Batch 414, Loss: 0.079850
# Epoch 9, Batch 415, Loss: 0.103636
# Epoch 9, Batch 416, Loss: 0.108325
# Epoch 9, Batch 417, Loss: 0.102896
# Epoch 9, Batch 418, Loss: 0.040346
# Epoch 9, Batch 419, Loss: 0.100661
# Epoch 9, Batch 420, Loss: 0.056033
# Epoch 9, Batch 421, Loss: 0.034565
# Epoch 9, Batch 422, Loss: 0.055119
# Epoch 9, Batch 423, Loss: 0.051578
# Epoch 9, Batch 424, Loss: 0.016123
# Epoch 9, Batch 425, Loss: 0.235352
# Epoch 9, Batch 426, Loss: 0.093725
# Epoch 9, Batch 427, Loss: 0.129814
# Epoch 9, Batch 428, Loss: 0.009967
# Epoch 9, Batch 429, Loss: 0.022366
# Epoch 9, Batch 430, Loss: 0.071088
# Epoch 9, Batch 431, Loss: 0.071343
# Epoch 9, Batch 432, Loss: 0.091254
# Epoch 9, Batch 433, Loss: 0.028753
# Epoch 9, Batch 434, Loss: 0.027822
# Epoch 9, Batch 435, Loss: 0.022957
# Epoch 9, Batch 436, Loss: 0.091588
# Epoch 9, Batch 437, Loss: 0.036373
# Epoch 9, Batch 438, Loss: 0.021370
# Epoch 9, Batch 439, Loss: 0.005569
# Epoch 9, Batch 440, Loss: 0.107605
# Epoch 9, Batch 441, Loss: 0.136256
# Epoch 9, Batch 442, Loss: 0.173943
# Epoch 9, Batch 443, Loss: 0.054452
# Epoch 9, Batch 444, Loss: 0.118917
# Epoch 9, Batch 445, Loss: 0.024221
# Epoch 9, Batch 446, Loss: 0.019403
# Epoch 9, Batch 447, Loss: 0.017560
# Epoch 9, Batch 448, Loss: 0.219425
# Epoch 9, Batch 449, Loss: 0.054936
# Epoch 9, Batch 450, Loss: 0.044228
# Epoch 9, Batch 451, Loss: 0.161672
# Epoch 9, Batch 452, Loss: 0.012996
# Epoch 9, Batch 453, Loss: 0.079201
# Epoch 9, Batch 454, Loss: 0.049555
# Epoch 9, Batch 455, Loss: 0.120689
# Epoch 9, Batch 456, Loss: 0.063428
# Epoch 9, Batch 457, Loss: 0.087141
# Epoch 9, Batch 458, Loss: 0.089827
# Epoch 9, Batch 459, Loss: 0.153910
# Epoch 9, Batch 460, Loss: 0.033902
# Epoch 9, Batch 461, Loss: 0.056029
# Epoch 9, Batch 462, Loss: 0.090378
# Epoch 9, Batch 463, Loss: 0.035243
# Epoch 9, Batch 464, Loss: 0.056327
# Epoch 9, Batch 465, Loss: 0.192256
# Epoch 9, Batch 466, Loss: 0.076471
# Epoch 9, Batch 467, Loss: 0.028838
# Epoch 9, Batch 468, Loss: 0.037032
# Epoch 9, Batch 469, Loss: 0.018681
# Epoch 9, Batch 470, Loss: 0.036498
# Epoch 9, Batch 471, Loss: 0.168088
# Epoch 9, Batch 472, Loss: 0.127525
# Epoch 9, Batch 473, Loss: 0.040652
# Epoch 9, Batch 474, Loss: 0.026294
# Epoch 9, Batch 475, Loss: 0.084112
# Epoch 9, Batch 476, Loss: 0.040294
# Epoch 9, Batch 477, Loss: 0.006077
# Epoch 9, Batch 478, Loss: 0.070607
# Epoch 9, Batch 479, Loss: 0.082292
# Epoch 9, Batch 480, Loss: 0.086223
# Epoch 9, Batch 481, Loss: 0.108632
# Epoch 9, Batch 482, Loss: 0.069736
# Epoch 9, Batch 483, Loss: 0.057875
# Epoch 9, Batch 484, Loss: 0.011710
# Epoch 9, Batch 485, Loss: 0.060393
# Epoch 9, Batch 486, Loss: 0.072249
# Epoch 9, Batch 487, Loss: 0.046551
# Epoch 9, Batch 488, Loss: 0.081587
# Epoch 9, Batch 489, Loss: 0.062093
# Epoch 9, Batch 490, Loss: 0.013329
# Epoch 9, Batch 491, Loss: 0.006285
# Epoch 9, Batch 492, Loss: 0.033264
# Epoch 9, Batch 493, Loss: 0.067791
# Epoch 9, Batch 494, Loss: 0.048956
# Epoch 9, Batch 495, Loss: 0.029451
# Epoch 9, Batch 496, Loss: 0.233090
# Epoch 9, Batch 497, Loss: 0.058583
# Epoch 9, Batch 498, Loss: 0.023178
# Epoch 9, Batch 499, Loss: 0.009142
# Epoch 9, Batch 500, Loss: 0.101489
# Epoch 9, Batch 501, Loss: 0.042415
# Epoch 9, Batch 502, Loss: 0.164598
# Epoch 9, Batch 503, Loss: 0.031755
# Epoch 9, Batch 504, Loss: 0.161957
# Epoch 9, Batch 505, Loss: 0.138381
# Epoch 9, Batch 506, Loss: 0.082466
# Epoch 9, Batch 507, Loss: 0.056439
# Epoch 9, Batch 508, Loss: 0.043117
# Epoch 9, Batch 509, Loss: 0.060178
# Epoch 9, Batch 510, Loss: 0.130757
# Epoch 9, Batch 511, Loss: 0.033762
# Epoch 9, Batch 512, Loss: 0.232119
# Epoch 9, Batch 513, Loss: 0.045936
# Epoch 9, Batch 514, Loss: 0.083566
# Epoch 9, Batch 515, Loss: 0.064315
# Epoch 9, Batch 516, Loss: 0.098226
# Epoch 9, Batch 517, Loss: 0.043238
# Epoch 9, Batch 518, Loss: 0.057540
# Epoch 9, Batch 519, Loss: 0.071055
# Epoch 9, Batch 520, Loss: 0.121162
# Epoch 9, Batch 521, Loss: 0.137168
# Epoch 9, Batch 522, Loss: 0.060677
# Epoch 9, Batch 523, Loss: 0.092909
# Epoch 9, Batch 524, Loss: 0.022805
# Epoch 9, Batch 525, Loss: 0.047324
# Epoch 9, Batch 526, Loss: 0.063230
# Epoch 9, Batch 527, Loss: 0.062478
# Epoch 9, Batch 528, Loss: 0.180577
# Epoch 9, Batch 529, Loss: 0.174522
# Epoch 9, Batch 530, Loss: 0.093340
# Epoch 9, Batch 531, Loss: 0.175138
# Epoch 9, Batch 532, Loss: 0.007263
# Epoch 9, Batch 533, Loss: 0.038869
# Epoch 9, Batch 534, Loss: 0.097729
# Epoch 9, Batch 535, Loss: 0.115771
# Epoch 9, Batch 536, Loss: 0.015255
# Epoch 9, Batch 537, Loss: 0.035625
# Epoch 9, Batch 538, Loss: 0.079900
# Epoch 9, Batch 539, Loss: 0.198718
# Epoch 9, Batch 540, Loss: 0.073631
# Epoch 9, Batch 541, Loss: 0.144472
# Epoch 9, Batch 542, Loss: 0.163789
# Epoch 9, Batch 543, Loss: 0.057225
# Epoch 9, Batch 544, Loss: 0.126404
# Epoch 9, Batch 545, Loss: 0.139672
# Epoch 9, Batch 546, Loss: 0.060984
# Epoch 9, Batch 547, Loss: 0.041545
# Epoch 9, Batch 548, Loss: 0.117106
# Epoch 9, Batch 549, Loss: 0.061603
# Epoch 9, Batch 550, Loss: 0.124036
# Epoch 9, Batch 551, Loss: 0.065089
# Epoch 9, Batch 552, Loss: 0.057715
# Epoch 9, Batch 553, Loss: 0.077253
# Epoch 9, Batch 554, Loss: 0.173541
# Epoch 9, Batch 555, Loss: 0.256713
# Epoch 9, Batch 556, Loss: 0.049536
# Epoch 9, Batch 557, Loss: 0.157930
# Epoch 9, Batch 558, Loss: 0.030403
# Epoch 9, Batch 559, Loss: 0.088569
# Epoch 9, Batch 560, Loss: 0.038528
# Epoch 9, Batch 561, Loss: 0.033763
# Epoch 9, Batch 562, Loss: 0.023077
# Epoch 9, Batch 563, Loss: 0.085600
# Epoch 9, Batch 564, Loss: 0.047564
# Epoch 9, Batch 565, Loss: 0.069227
# Epoch 9, Batch 566, Loss: 0.119399
# Epoch 9, Batch 567, Loss: 0.288525
# Epoch 9, Batch 568, Loss: 0.089844
# Epoch 9, Batch 569, Loss: 0.066374
# Epoch 9, Batch 570, Loss: 0.084571
# Epoch 9, Batch 571, Loss: 0.026403
# Epoch 9, Batch 572, Loss: 0.013052
# Epoch 9, Batch 573, Loss: 0.070540
# Epoch 9, Batch 574, Loss: 0.032472
# Epoch 9, Batch 575, Loss: 0.086205
# Epoch 9, Batch 576, Loss: 0.075189
# Epoch 9, Batch 577, Loss: 0.044440
# Epoch 9, Batch 578, Loss: 0.059950
# Epoch 9, Batch 579, Loss: 0.113381
# Epoch 9, Batch 580, Loss: 0.075102
# Epoch 9, Batch 581, Loss: 0.189704
# Epoch 9, Batch 582, Loss: 0.034865
# Epoch 9, Batch 583, Loss: 0.131122
# Epoch 9, Batch 584, Loss: 0.064241
# Epoch 9, Batch 585, Loss: 0.099408
# Epoch 9, Batch 586, Loss: 0.061411
# Epoch 9, Batch 587, Loss: 0.123439
# Epoch 9, Batch 588, Loss: 0.013850
# Epoch 9, Batch 589, Loss: 0.050668
# Epoch 9, Batch 590, Loss: 0.100091
# Epoch 9, Batch 591, Loss: 0.094951
# Epoch 9, Batch 592, Loss: 0.135630
# Epoch 9, Batch 593, Loss: 0.189337
# Epoch 9, Batch 594, Loss: 0.014495
# Epoch 9, Batch 595, Loss: 0.047665
# Epoch 9, Batch 596, Loss: 0.120954
# Epoch 9, Batch 597, Loss: 0.148132
# Epoch 9, Batch 598, Loss: 0.028264
# Epoch 9, Batch 599, Loss: 0.029937
# Epoch 9, Batch 600, Loss: 0.033771
# Epoch 9, Batch 601, Loss: 0.009079
# Epoch 9, Batch 602, Loss: 0.092634
# Epoch 9, Batch 603, Loss: 0.026434
# Epoch 9, Batch 604, Loss: 0.049433
# Epoch 9, Batch 605, Loss: 0.116852
# Epoch 9, Batch 606, Loss: 0.028992
# Epoch 9, Batch 607, Loss: 0.055154
# Epoch 9, Batch 608, Loss: 0.182207
# Epoch 9, Batch 609, Loss: 0.124376
# Epoch 9, Batch 610, Loss: 0.102534
# Epoch 9, Batch 611, Loss: 0.024051
# Epoch 9, Batch 612, Loss: 0.044344
# Epoch 9, Batch 613, Loss: 0.097465
# Epoch 9, Batch 614, Loss: 0.116907
# Epoch 9, Batch 615, Loss: 0.089607
# Epoch 9, Batch 616, Loss: 0.193561
# Epoch 9, Batch 617, Loss: 0.084498
# Epoch 9, Batch 618, Loss: 0.066001
# Epoch 9, Batch 619, Loss: 0.056258
# Epoch 9, Batch 620, Loss: 0.097498
# Epoch 9, Batch 621, Loss: 0.027960
# Epoch 9, Batch 622, Loss: 0.024151
# Epoch 9, Batch 623, Loss: 0.074022
# Epoch 9, Batch 624, Loss: 0.082493
# Epoch 9, Batch 625, Loss: 0.030497
# Epoch 9, Batch 626, Loss: 0.020094
# Epoch 9, Batch 627, Loss: 0.051339
# Epoch 9, Batch 628, Loss: 0.040265
# Epoch 9, Batch 629, Loss: 0.009364
# Epoch 9, Batch 630, Loss: 0.073155
# Epoch 9, Batch 631, Loss: 0.016005
# Epoch 9, Batch 632, Loss: 0.021775
# Epoch 9, Batch 633, Loss: 0.092396
# Epoch 9, Batch 634, Loss: 0.070173
# Epoch 9, Batch 635, Loss: 0.035050
# Epoch 9, Batch 636, Loss: 0.151761
# Epoch 9, Batch 637, Loss: 0.017373
# Epoch 9, Batch 638, Loss: 0.042186
# Epoch 9, Batch 639, Loss: 0.143281
# Epoch 9, Batch 640, Loss: 0.045501
# Epoch 9, Batch 641, Loss: 0.060634
# Epoch 9, Batch 642, Loss: 0.060172
# Epoch 9, Batch 643, Loss: 0.106949
# Epoch 9, Batch 644, Loss: 0.017976
# Epoch 9, Batch 645, Loss: 0.022728
# Epoch 9, Batch 646, Loss: 0.048111
# Epoch 9, Batch 647, Loss: 0.151214
# Epoch 9, Batch 648, Loss: 0.097898
# Epoch 9, Batch 649, Loss: 0.128069
# Epoch 9, Batch 650, Loss: 0.015702
# Epoch 9, Batch 651, Loss: 0.061771
# Epoch 9, Batch 652, Loss: 0.094106
# Epoch 9, Batch 653, Loss: 0.142056
# Epoch 9, Batch 654, Loss: 0.101111
# Epoch 9, Batch 655, Loss: 0.070136
# Epoch 9, Batch 656, Loss: 0.223739
# Warning: test set has no labels, skip accuracy evaluation.
# Saved: d:\CZ_WorkSpace\ai学习\深度学习实践\task1\task1_3\checkpoints\model_epoch_9.pth

# %%
# 9.1) 训练曲线可视化
# 构造 epoch 轴
epochs_axis = list(range(1, len(epoch_losses) + 1))

# 创建画布
plt.figure(figsize=(10, 4))
# 左图：训练损失
plt.subplot(1, 2, 1)
plt.plot(epochs_axis, epoch_losses, marker="o")
plt.title("Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True, linestyle="--", alpha=0.4)

# 右图：验证准确率（若有）
#plt.subplot(1, 2, 2)
valid_acc = [a for a in epoch_accs if a is not None]
valid_epochs = [i + 1 for i, a in enumerate(epoch_accs) if a is not None]
if valid_acc:
    plt.plot(valid_epochs, valid_acc, marker="o", color="green")
    plt.ylim(0, 1)
plt.title("Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.grid(True, linestyle="--", alpha=0.4)

# 调整布局并显示
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10) 训练后单图验证与可选模型加载推理

# %%
# 训练后随机抽样做一次单图验证
single_sample_check(model, test_dataset)

# 可选：加载某个 checkpoint 后再做单图推理
# model2 = MyTransformer()
# model2.load_state_dict(torch.load(os.path.join(checkpoint_dir, "model_epoch_8.pth"), map_location="cpu"))
# single_sample_check(model2, test_dataset)
# Out:
# Single Image Validation
# Image: d:\CZ_WorkSpace\ai学习\深度学习实践\task1\MNIST_kaggle\testSet\img_313.jpg
# Pred Label: 9, Confidence: 0.9951 (no ground-truth label)

# %%
# 11) 加载模型参数并对测试集推理（导出 Kaggle 提交文件）
# 引入 DataLoader 以便批量推理
from torch.utils.data import DataLoader

# TODO: 修改为你要加载的权重文件路径
ckpt_path = os.path.join(checkpoint_dir, "model_epoch_8.pth")

# 初始化模型并加载权重
infer_model = MyTransformer()
infer_model.load_state_dict(torch.load(ckpt_path, map_location="cpu"))
infer_model.eval()

# 构建推理 DataLoader（无标签）
infer_loader = DataLoader(test_dataset, batch_size=128, shuffle=False)
pred_records = []
with torch.no_grad():
    for images, file_paths in infer_loader:
        # 前向推理得到 logits
        logits = infer_model(images)
        # 取最大值所在类别作为预测结果
        preds = torch.argmax(logits, dim=1).cpu().numpy().tolist()
        for path, pred in zip(file_paths, preds):
            # 从文件名中解析 ImageId
            base = os.path.basename(path)
            match = re.search(r"\d+", base)
            if match is None:
                raise ValueError(f"Cannot parse image id from filename: {base}")
            image_id = int(match.group())
            pred_records.append((image_id, pred))

# 按 ImageId 升序排序，符合 Kaggle 提交格式
pred_records.sort(key=lambda x: x[0])
submit_df = pd.DataFrame(pred_records, columns=["ImageId", "Label"])

# 保存提交文件到当前工作目录
submit_path = os.path.join(os.getcwd(), "kaggle_submit_transformer.csv")
submit_df.to_csv(submit_path, index=False)
print(f"Saved submission file: {submit_path}")
print(submit_df.head())
# Out:
# Saved submission file: d:\CZ_WorkSpace\ai学习\深度学习实践\task1\task1_3\kaggle_submit_transformer.csv
#    ImageId  Label
# 0        1      2
# 1        2      0
# 2        3      9
# 3        4      9
# 4        5      3
