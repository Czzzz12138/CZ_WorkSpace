# %% [markdown]
# # 任务1_2: 卷积神经网络 (CNN)
#
# 参考 task1_1.ipynb 的流程，构建 CNN 网络结构。

# %% [markdown]
# ## 1) 安装与启动 Jupyter 内核（VS Code）
#
# 首次使用可在此单元安装依赖；运行后在 VS Code 右上角选择 Python 内核。

# %%
# 如已安装可跳过
# %pip install -U pip
# %pip install ipykernel notebook torch torchvision pillow pandas matplotlib

# 导入 sys 用于查看当前内核的 Python 路径
import sys
# 输出当前解释器路径，确认内核环境
print(sys.executable)
# 输出提示信息，确认单元执行
print("内核已就绪")
# Out:
# d:\anaconda\envs\DL\python.exe
# 内核已就绪

# %%
# 解决 Windows 下 OpenMP 重复加载导致的内核崩溃问题
# 导入 os 用于设置环境变量
import os
# 允许重复加载 OpenMP 库，避免特定环境崩溃
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
# 打印确认信息
print("KMP_DUPLICATE_LIB_OK set")
# Out:
# KMP_DUPLICATE_LIB_OK set

# %% [markdown]
# ## 2) 导入依赖并检查 PyTorch 版本

# %%
# 基础库：路径、正则、随机数
import os
import re
import random
# 深度学习与数据处理相关
import torch
import pandas as pd
import torch.nn as nn
import matplotlib.pyplot as plt
from PIL import Image
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader

# 打印 PyTorch 版本，确认环境
print("torch version:", torch.__version__)
# Out:
# torch version: 2.8.0+cpu

# %% [markdown]
# ## 3) 配置数据路径（基于当前工作目录）
#
# Notebook 中没有 __file__，这里使用当前工作目录并手动拼接数据路径。

# %%
# 若你的 Notebook 不在该目录运行，可手动指定项目根目录
# 这里用当前工作目录的上一级作为默认根目录
project_root = os.path.dirname(os.getcwd())
# 例如：project_root = r"d:/CZ_WorkSpace/ai学习/深度学习实践"

# 拼接训练与测试数据集路径
train_dir = os.path.join(project_root, "MNIST_kaggle", "trainingSet")
test_dir = os.path.join(project_root, "MNIST_kaggle", "testSet")

# 打印路径与是否存在，便于排查数据路径问题
print("cwd:", os.getcwd())
print("project_root:", project_root)
print("train_dir exists:", os.path.exists(train_dir), "train_dir:", train_dir)
print("test_dir exists:", os.path.exists(test_dir), "test_dir:", test_dir)
# Out:
# cwd: d:\CZ_WorkSpace\ai学习\深度学习实践\task1\task1_2
# project_root: d:\CZ_WorkSpace\ai学习\深度学习实践\task1
# train_dir exists: True train_dir: d:\CZ_WorkSpace\ai学习\深度学习实践\task1\MNIST_kaggle\trainingSet
# test_dir exists: True test_dir: d:\CZ_WorkSpace\ai学习\深度学习实践\task1\MNIST_kaggle\testSet

# %% [markdown]
# ## 4) 定义 MyDataset（有标签/无标签双模式）
#
# CNN 输入为 [1, 28, 28]，这里不再展平成 784。

# %%
class MyDataset(Dataset):
    # 初始化数据集，支持有标签/无标签两种模式
    def __init__(self, data_dir, labeled=True):
        # 保存数据目录与标注标记
        self.data_dir = data_dir
        self.labeled = labeled
        # samples 保存 (路径, 标签) 或 路径
        self.samples = []
        # 定义统一的图像预处理流程
        self.transform = transforms.Compose([
            transforms.Grayscale(num_output_channels=1),
            transforms.Resize((28, 28)),
            transforms.ToTensor(),
        ])

        # 如果是训练集，读取子目录作为类别
        if self.labeled:
            # 获取所有类别目录名
            class_names = [d for d in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, d))]
            # 按数字顺序排序类别目录
            class_names = sorted(class_names, key=lambda x: int(x) if x.isdigit() else x)
            # 构建类别名到整数标签的映射
            self.class_to_idx = {name: int(name) for name in class_names}
            # 遍历每个类别目录收集样本
            for class_name in class_names:
                class_dir = os.path.join(data_dir, class_name)
                for file_name in os.listdir(class_dir):
                    # 只保留图片文件
                    if file_name.lower().endswith((".jpg", ".jpeg", ".png", ".bmp")):
                        file_path = os.path.join(class_dir, file_name)
                        label = self.class_to_idx[class_name]
                        self.samples.append((file_path, label))
        else:
            # 测试集无标签，仅保存图片路径
            self.class_to_idx = {}
            for file_name in os.listdir(data_dir):
                file_path = os.path.join(data_dir, file_name)
                # 只保留图片文件
                if os.path.isfile(file_path) and file_name.lower().endswith((".jpg", ".jpeg", ".png", ".bmp")):
                    self.samples.append(file_path)

    # 返回样本数量
    def __len__(self):
        return len(self.samples)

    # 获取单个样本
    def __getitem__(self, idx):
        # 根据是否有标签拆包
        if self.labeled:
            file_path, label = self.samples[idx]
        else:
            file_path = self.samples[idx]
            label = None

        # 读取图片并做预处理
        image = Image.open(file_path)
        image = self.transform(image)

        # 训练集返回 (图像张量, 标签)
        if self.labeled:
            return image, torch.tensor(label, dtype=torch.long)
        # 测试集返回 (图像张量, 文件路径)
        return image, file_path

# %% [markdown]
# ## 5) 构建 DataLoader 并检查 batch 形状

# %%
# 构建训练集 Dataset（有标签）
mydataset = MyDataset(data_dir=train_dir, labeled=True)
# 训练 DataLoader：打乱样本，提升训练随机性
mydataset_loader = DataLoader(mydataset, batch_size=64, shuffle=True)

# 构建测试集 Dataset（无标签）
test_dataset = MyDataset(data_dir=test_dir, labeled=False)
# 测试 DataLoader：不打乱，保持文件顺序
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# 打印样本数量，检查数据是否加载成功
print(f"Train samples: {len(mydataset)}")
print(f"Test samples: {len(test_dataset)}")

# 简单查看前两个 batch 的形状与标签示例
for batch_idx, (images, labels) in enumerate(mydataset_loader):
    print(f"Batch {batch_idx}: images={images.shape}, labels={labels.shape}")
    print("Label sample:", labels[:10].tolist())
    if batch_idx == 1:
        break
# Out:
# Train samples: 42000
# Test samples: 28000
# Batch 0: images=torch.Size([64, 1, 28, 28]), labels=torch.Size([64])
# Label sample: [6, 0, 3, 3, 5, 4, 1, 9, 7, 6]
# Batch 1: images=torch.Size([64, 1, 28, 28]), labels=torch.Size([64])
# Label sample: [1, 0, 1, 6, 3, 9, 8, 6, 7, 9]

# %% [markdown]
# ## 6) 定义卷积神经网络 MyCNN
#
# 结构：Conv(1->16) -> ReLU -> MaxPool -> Conv(16->32) -> ReLU -> MaxPool -> FC。

# %%
class MyCNN(nn.Module):
    # 初始化 CNN 网络结构
    def __init__(self):
        super(MyCNN, self).__init__()
        # 卷积特征提取部分
        self.features = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=3, padding=1),#
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(16, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
        )
        # 分类器：展平后接全连接层输出 logits
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(32 * 7 * 7, 128),
            nn.ReLU(),
            nn.Linear(128, 10),
        )

    # 前向传播逻辑
    def forward(self, x):
        # 提取卷积特征
        x = self.features(x)
        # 通过分类器得到最终输出
        x = self.classifier(x)
        return x

# %% [markdown]
# ## 7) 定义评估函数 evaluate 与单样本推理 single_sample_check

# %%
def evaluate(model, data_loader):
    # 若数据集为空或无标签，跳过评估
    if len(data_loader.dataset) == 0 or not data_loader.dataset.labeled:
        print("Warning: test set has no labels, skip accuracy evaluation.")
        return None

    # 切换到评估模式，关闭 dropout/bn 的训练行为
    model.eval()
    correct = 0
    total = 0
    # 评估阶段不需要梯度，节省显存与时间
    with torch.no_grad():
        for images, labels in data_loader:
            # 前向推理得到 logits
            outputs = model(images)
            # 取最大值所在类别作为预测结果
            preds = torch.argmax(outputs, dim=1)
            # 统计预测正确数量
            correct += (preds == labels).sum().item()
            # 统计样本总数
            total += labels.size(0)

    # 恢复训练模式，避免影响后续训练
    model.train()
    if total == 0:
        print("Warning: test set is empty, skip accuracy evaluation.")
        return None
    # 返回准确率
    return correct / total


def single_sample_check(model, dataset):
    # 若测试集为空，直接返回
    if len(dataset) == 0:
        print("Single image validation skipped: test dataset is empty.")
        return

    # 随机抽取一张图片做单样本推理
    sample_idx = random.randint(0, len(dataset) - 1)
    sample = dataset[sample_idx]
    if dataset.labeled:
        # 训练集/有标签模式
        image, label = sample
        image_path, _ = dataset.samples[sample_idx]
    else:
        # 测试集/无标签模式
        image, image_path = sample
        label = None

    # 推理前切换到评估模式
    model.eval()
    with torch.no_grad():
        # 为单张图片增加 batch 维度
        logits = model(image.unsqueeze(0))
        # 计算 softmax 概率用于置信度
        probs = torch.softmax(logits, dim=1)
        # 取最大概率的类别作为预测结果
        pred = torch.argmax(probs, dim=1).item()
        # 取预测类别的置信度
        confidence = probs[0, pred].item()
    # 恢复训练模式
    model.train()

    # 输出推理结果
    print("\nSingle Image Validation")
    print(f"Image: {image_path}")
    if label is not None:
        print(f"True Label: {label.item()}, Pred Label: {pred}, Confidence: {confidence:.4f}")
    else:
        print(f"Pred Label: {pred}, Confidence: {confidence:.4f} (no ground-truth label)")

# %% [markdown]
# ## 8) 定义损失函数与优化器

# %%
# 定义交叉熵损失（输入 logits，目标为类别索引）
loss_fn = nn.CrossEntropyLoss()
# 初始化 CNN 模型
model = MyCNN()
# 定义优化器（Adam）
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# 快速可用性检查：随机输入跑通前向与损失
_ = loss_fn(model(torch.randn(4, 1, 28, 28)), torch.randint(0, 10, (4,)))
print("model check ok")
# Out:
# model check ok

# %% [markdown]
# ## 9) 训练循环（含评估与模型保存）
#
# 模型和提交文件保存到 task1_2 目录下。

# %%
# 训练总轮数
epochs = 10
# 模型参数保存目录（相对当前工作目录）
checkpoint_dir = os.path.join(os.getcwd(), "checkpoints")
# 确保目录存在
os.makedirs(checkpoint_dir, exist_ok=True)

# 记录每个 epoch 的平均 loss
epoch_losses = []
# 记录每个 epoch 的准确率（若无标签则记录 None）
epoch_accs = []

# 开始训练循环
for epoch in range(epochs):
    # 设置为训练模式
    model.train()
    running_loss = 0.0
    sample_count = 0
    # 逐 batch 训练
    for batch_idx, (images, labels) in enumerate(mydataset_loader):
        # 前向推理得到 logits
        output = model(images)
        # 计算当前 batch 的损失
        loss = loss_fn(output, labels)

        # 清空梯度
        optimizer.zero_grad()
        # 反向传播计算梯度
        loss.backward()
        # 更新参数
        optimizer.step()

        # 累计 loss（按样本数加权）
        batch_size = labels.size(0)
        running_loss += loss.item() * batch_size
        sample_count += batch_size

        # 输出当前 batch 的 loss
        print(f"Epoch {epoch}, Batch {batch_idx}, Loss: {loss.item():.6f}")

    # 计算并记录该 epoch 的平均 loss
    epoch_loss = running_loss / max(sample_count, 1)
    epoch_losses.append(epoch_loss)

    # 在测试集上做一次评估（若有标签）
    test_acc = evaluate(model, test_loader)
    if test_acc is not None:
        epoch_accs.append(test_acc)
        print(f"Epoch {epoch}, Test Accuracy: {test_acc * 100:.2f}%")
    else:
        epoch_accs.append(None)

    # 保存该 epoch 的模型参数
    if epoch % 1 == 0:
        ckpt_path = os.path.join(checkpoint_dir, f"model_epoch_{epoch}.pth")
        torch.save(model.state_dict(), ckpt_path)
        print("Saved:", ckpt_path)
# Out:
# Epoch 0, Batch 0, Loss: 2.300032
# Epoch 0, Batch 1, Loss: 2.281977
# Epoch 0, Batch 2, Loss: 2.329375
# Epoch 0, Batch 3, Loss: 2.267167
# Epoch 0, Batch 4, Loss: 2.267009
# Epoch 0, Batch 5, Loss: 2.194599
# Epoch 0, Batch 6, Loss: 2.234555
# Epoch 0, Batch 7, Loss: 2.225582
# Epoch 0, Batch 8, Loss: 2.208209
# Epoch 0, Batch 9, Loss: 2.145916
# Epoch 0, Batch 10, Loss: 2.113258
# Epoch 0, Batch 11, Loss: 2.123006
# Epoch 0, Batch 12, Loss: 2.039119
# Epoch 0, Batch 13, Loss: 2.057364
# Epoch 0, Batch 14, Loss: 1.948332
# Epoch 0, Batch 15, Loss: 1.883313
# Epoch 0, Batch 16, Loss: 1.819091
# Epoch 0, Batch 17, Loss: 1.840171
# Epoch 0, Batch 18, Loss: 1.772254
# Epoch 0, Batch 19, Loss: 1.648682
# Epoch 0, Batch 20, Loss: 1.583730
# Epoch 0, Batch 21, Loss: 1.623439
# Epoch 0, Batch 22, Loss: 1.511744
# Epoch 0, Batch 23, Loss: 1.377695
# Epoch 0, Batch 24, Loss: 1.259452
# Epoch 0, Batch 25, Loss: 1.375113
# Epoch 0, Batch 26, Loss: 1.201292
# Epoch 0, Batch 27, Loss: 1.241904
# Epoch 0, Batch 28, Loss: 1.087093
# Epoch 0, Batch 29, Loss: 0.925404
# Epoch 0, Batch 30, Loss: 0.996162
# Epoch 0, Batch 31, Loss: 0.873910
# Epoch 0, Batch 32, Loss: 0.848207
# Epoch 0, Batch 33, Loss: 0.941669
# Epoch 0, Batch 34, Loss: 0.895583
# Epoch 0, Batch 35, Loss: 0.794163
# Epoch 0, Batch 36, Loss: 0.808519
# Epoch 0, Batch 37, Loss: 0.617944
# Epoch 0, Batch 38, Loss: 0.617451
# Epoch 0, Batch 39, Loss: 0.651006
# Epoch 0, Batch 40, Loss: 0.657578
# Epoch 0, Batch 41, Loss: 0.832301
# Epoch 0, Batch 42, Loss: 0.656952
# Epoch 0, Batch 43, Loss: 0.462750
# Epoch 0, Batch 44, Loss: 0.912299
# Epoch 0, Batch 45, Loss: 0.569560
# Epoch 0, Batch 46, Loss: 0.490422
# Epoch 0, Batch 47, Loss: 0.462625
# Epoch 0, Batch 48, Loss: 0.452563
# Epoch 0, Batch 49, Loss: 0.402226
# Epoch 0, Batch 50, Loss: 0.616003
# Epoch 0, Batch 51, Loss: 0.394284
# Epoch 0, Batch 52, Loss: 0.483012
# Epoch 0, Batch 53, Loss: 0.628694
# Epoch 0, Batch 54, Loss: 0.548226
# Epoch 0, Batch 55, Loss: 0.724245
# Epoch 0, Batch 56, Loss: 0.429464
# Epoch 0, Batch 57, Loss: 0.576526
# Epoch 0, Batch 58, Loss: 0.726889
# Epoch 0, Batch 59, Loss: 0.665131
# Epoch 0, Batch 60, Loss: 0.725390
# Epoch 0, Batch 61, Loss: 0.584834
# Epoch 0, Batch 62, Loss: 0.447721
# Epoch 0, Batch 63, Loss: 0.534017
# Epoch 0, Batch 64, Loss: 0.575213
# Epoch 0, Batch 65, Loss: 0.568266
# Epoch 0, Batch 66, Loss: 0.562705
# Epoch 0, Batch 67, Loss: 0.600944
# Epoch 0, Batch 68, Loss: 0.248323
# Epoch 0, Batch 69, Loss: 0.532729
# Epoch 0, Batch 70, Loss: 0.336707
# Epoch 0, Batch 71, Loss: 0.577063
# Epoch 0, Batch 72, Loss: 0.742085
# Epoch 0, Batch 73, Loss: 0.564867
# Epoch 0, Batch 74, Loss: 0.232681
# Epoch 0, Batch 75, Loss: 0.406183
# Epoch 0, Batch 76, Loss: 0.512823
# Epoch 0, Batch 77, Loss: 0.365093
# Epoch 0, Batch 78, Loss: 0.311158
# Epoch 0, Batch 79, Loss: 0.601962
# Epoch 0, Batch 80, Loss: 0.386237
# Epoch 0, Batch 81, Loss: 0.338336
# Epoch 0, Batch 82, Loss: 0.443099
# Epoch 0, Batch 83, Loss: 0.316497
# Epoch 0, Batch 84, Loss: 0.456420
# Epoch 0, Batch 85, Loss: 0.486679
# Epoch 0, Batch 86, Loss: 0.438281
# Epoch 0, Batch 87, Loss: 0.280459
# Epoch 0, Batch 88, Loss: 0.407873
# Epoch 0, Batch 89, Loss: 0.426471
# Epoch 0, Batch 90, Loss: 0.570018
# Epoch 0, Batch 91, Loss: 0.476604
# Epoch 0, Batch 92, Loss: 0.409547
# Epoch 0, Batch 93, Loss: 0.268308
# Epoch 0, Batch 94, Loss: 0.728170
# Epoch 0, Batch 95, Loss: 0.203735
# Epoch 0, Batch 96, Loss: 0.503272
# Epoch 0, Batch 97, Loss: 0.415982
# Epoch 0, Batch 98, Loss: 0.453050
# Epoch 0, Batch 99, Loss: 0.500416
# Epoch 0, Batch 100, Loss: 0.409970
# Epoch 0, Batch 101, Loss: 0.390571
# Epoch 0, Batch 102, Loss: 0.368568
# Epoch 0, Batch 103, Loss: 0.371104
# Epoch 0, Batch 104, Loss: 0.475027
# Epoch 0, Batch 105, Loss: 0.305496
# Epoch 0, Batch 106, Loss: 0.151932
# Epoch 0, Batch 107, Loss: 0.474004
# Epoch 0, Batch 108, Loss: 0.155129
# Epoch 0, Batch 109, Loss: 0.379692
# Epoch 0, Batch 110, Loss: 0.388468
# Epoch 0, Batch 111, Loss: 0.338589
# Epoch 0, Batch 112, Loss: 0.492127
# Epoch 0, Batch 113, Loss: 0.454297
# Epoch 0, Batch 114, Loss: 0.282317
# Epoch 0, Batch 115, Loss: 0.680014
# Epoch 0, Batch 116, Loss: 0.271255
# Epoch 0, Batch 117, Loss: 0.265655
# Epoch 0, Batch 118, Loss: 0.431752
# Epoch 0, Batch 119, Loss: 0.435929
# Epoch 0, Batch 120, Loss: 0.283799
# Epoch 0, Batch 121, Loss: 0.533226
# Epoch 0, Batch 122, Loss: 0.314473
# Epoch 0, Batch 123, Loss: 0.263172
# Epoch 0, Batch 124, Loss: 0.245227
# Epoch 0, Batch 125, Loss: 0.577687
# Epoch 0, Batch 126, Loss: 0.302016
# Epoch 0, Batch 127, Loss: 0.276179
# Epoch 0, Batch 128, Loss: 0.280600
# Epoch 0, Batch 129, Loss: 0.160754
# Epoch 0, Batch 130, Loss: 0.212496
# Epoch 0, Batch 131, Loss: 0.359947
# Epoch 0, Batch 132, Loss: 0.425969
# Epoch 0, Batch 133, Loss: 0.367172
# Epoch 0, Batch 134, Loss: 0.197054
# Epoch 0, Batch 135, Loss: 0.386749
# Epoch 0, Batch 136, Loss: 0.302599
# Epoch 0, Batch 137, Loss: 0.451035
# Epoch 0, Batch 138, Loss: 0.281013
# Epoch 0, Batch 139, Loss: 0.231229
# Epoch 0, Batch 140, Loss: 0.135938
# Epoch 0, Batch 141, Loss: 0.276324
# Epoch 0, Batch 142, Loss: 0.389058
# Epoch 0, Batch 143, Loss: 0.327344
# Epoch 0, Batch 144, Loss: 0.351432
# Epoch 0, Batch 145, Loss: 0.363762
# Epoch 0, Batch 146, Loss: 0.419150
# Epoch 0, Batch 147, Loss: 0.509501
# Epoch 0, Batch 148, Loss: 0.480153
# Epoch 0, Batch 149, Loss: 0.438713
# Epoch 0, Batch 150, Loss: 0.267858
# Epoch 0, Batch 151, Loss: 0.464572
# Epoch 0, Batch 152, Loss: 0.544685
# Epoch 0, Batch 153, Loss: 0.392936
# Epoch 0, Batch 154, Loss: 0.125593
# Epoch 0, Batch 155, Loss: 0.207137
# Epoch 0, Batch 156, Loss: 0.184786
# Epoch 0, Batch 157, Loss: 0.494086
# Epoch 0, Batch 158, Loss: 0.206559
# Epoch 0, Batch 159, Loss: 0.443464
# Epoch 0, Batch 160, Loss: 0.248671
# Epoch 0, Batch 161, Loss: 0.327233
# Epoch 0, Batch 162, Loss: 0.296431
# Epoch 0, Batch 163, Loss: 0.321758
# Epoch 0, Batch 164, Loss: 0.350947
# Epoch 0, Batch 165, Loss: 0.329958
# Epoch 0, Batch 166, Loss: 0.299591
# Epoch 0, Batch 167, Loss: 0.287158
# Epoch 0, Batch 168, Loss: 0.482925
# Epoch 0, Batch 169, Loss: 0.343591
# Epoch 0, Batch 170, Loss: 0.204053
# Epoch 0, Batch 171, Loss: 0.481697
# Epoch 0, Batch 172, Loss: 0.332909
# Epoch 0, Batch 173, Loss: 0.301220
# Epoch 0, Batch 174, Loss: 0.309344
# Epoch 0, Batch 175, Loss: 0.215204
# Epoch 0, Batch 176, Loss: 0.420302
# Epoch 0, Batch 177, Loss: 0.340718
# Epoch 0, Batch 178, Loss: 0.173461
# Epoch 0, Batch 179, Loss: 0.325710
# Epoch 0, Batch 180, Loss: 0.213268
# Epoch 0, Batch 181, Loss: 0.228340
# Epoch 0, Batch 182, Loss: 0.237436
# Epoch 0, Batch 183, Loss: 0.249839
# Epoch 0, Batch 184, Loss: 0.243528
# Epoch 0, Batch 185, Loss: 0.333417
# Epoch 0, Batch 186, Loss: 0.561905
# Epoch 0, Batch 187, Loss: 0.344394
# Epoch 0, Batch 188, Loss: 0.317679
# Epoch 0, Batch 189, Loss: 0.279737
# Epoch 0, Batch 190, Loss: 0.232711
# Epoch 0, Batch 191, Loss: 0.252799
# Epoch 0, Batch 192, Loss: 0.095609
# Epoch 0, Batch 193, Loss: 0.180575
# Epoch 0, Batch 194, Loss: 0.270121
# Epoch 0, Batch 195, Loss: 0.206687
# Epoch 0, Batch 196, Loss: 0.300349
# Epoch 0, Batch 197, Loss: 0.197429
# Epoch 0, Batch 198, Loss: 0.309779
# Epoch 0, Batch 199, Loss: 0.191174
# Epoch 0, Batch 200, Loss: 0.128919
# Epoch 0, Batch 201, Loss: 0.177823
# Epoch 0, Batch 202, Loss: 0.094160
# Epoch 0, Batch 203, Loss: 0.433668
# Epoch 0, Batch 204, Loss: 0.235000
# Epoch 0, Batch 205, Loss: 0.371234
# Epoch 0, Batch 206, Loss: 0.257709
# Epoch 0, Batch 207, Loss: 0.236435
# Epoch 0, Batch 208, Loss: 0.145949
# Epoch 0, Batch 209, Loss: 0.255211
# Epoch 0, Batch 210, Loss: 0.161489
# Epoch 0, Batch 211, Loss: 0.233486
# Epoch 0, Batch 212, Loss: 0.111125
# Epoch 0, Batch 213, Loss: 0.377723
# Epoch 0, Batch 214, Loss: 0.302282
# Epoch 0, Batch 215, Loss: 0.170925
# Epoch 0, Batch 216, Loss: 0.264534
# Epoch 0, Batch 217, Loss: 0.133544
# Epoch 0, Batch 218, Loss: 0.325520
# Epoch 0, Batch 219, Loss: 0.180263
# Epoch 0, Batch 220, Loss: 0.125959
# Epoch 0, Batch 221, Loss: 0.173229
# Epoch 0, Batch 222, Loss: 0.186696
# Epoch 0, Batch 223, Loss: 0.171054
# Epoch 0, Batch 224, Loss: 0.254552
# Epoch 0, Batch 225, Loss: 0.219025
# Epoch 0, Batch 226, Loss: 0.079381
# Epoch 0, Batch 227, Loss: 0.146156
# Epoch 0, Batch 228, Loss: 0.180592
# Epoch 0, Batch 229, Loss: 0.302448
# Epoch 0, Batch 230, Loss: 0.206059
# Epoch 0, Batch 231, Loss: 0.344151
# Epoch 0, Batch 232, Loss: 0.160147
# Epoch 0, Batch 233, Loss: 0.260762
# Epoch 0, Batch 234, Loss: 0.173804
# Epoch 0, Batch 235, Loss: 0.169357
# Epoch 0, Batch 236, Loss: 0.245703
# Epoch 0, Batch 237, Loss: 0.125022
# Epoch 0, Batch 238, Loss: 0.187685
# Epoch 0, Batch 239, Loss: 0.130449
# Epoch 0, Batch 240, Loss: 0.398227
# Epoch 0, Batch 241, Loss: 0.174454
# Epoch 0, Batch 242, Loss: 0.155832
# Epoch 0, Batch 243, Loss: 0.302601
# Epoch 0, Batch 244, Loss: 0.108673
# Epoch 0, Batch 245, Loss: 0.192966
# Epoch 0, Batch 246, Loss: 0.209029
# Epoch 0, Batch 247, Loss: 0.282116
# Epoch 0, Batch 248, Loss: 0.173942
# Epoch 0, Batch 249, Loss: 0.144024
# Epoch 0, Batch 250, Loss: 0.325506
# Epoch 0, Batch 251, Loss: 0.158880
# Epoch 0, Batch 252, Loss: 0.186719
# Epoch 0, Batch 253, Loss: 0.201650
# Epoch 0, Batch 254, Loss: 0.084535
# Epoch 0, Batch 255, Loss: 0.281493
# Epoch 0, Batch 256, Loss: 0.188358
# Epoch 0, Batch 257, Loss: 0.294329
# Epoch 0, Batch 258, Loss: 0.075318
# Epoch 0, Batch 259, Loss: 0.235367
# Epoch 0, Batch 260, Loss: 0.283696
# Epoch 0, Batch 261, Loss: 0.446677
# Epoch 0, Batch 262, Loss: 0.148522
# Epoch 0, Batch 263, Loss: 0.185787
# Epoch 0, Batch 264, Loss: 0.184853
# Epoch 0, Batch 265, Loss: 0.067451
# Epoch 0, Batch 266, Loss: 0.136766
# Epoch 0, Batch 267, Loss: 0.136158
# Epoch 0, Batch 268, Loss: 0.253756
# Epoch 0, Batch 269, Loss: 0.144035
# Epoch 0, Batch 270, Loss: 0.174365
# Epoch 0, Batch 271, Loss: 0.177794
# Epoch 0, Batch 272, Loss: 0.179099
# Epoch 0, Batch 273, Loss: 0.206807
# Epoch 0, Batch 274, Loss: 0.433401
# Epoch 0, Batch 275, Loss: 0.201835
# Epoch 0, Batch 276, Loss: 0.082648
# Epoch 0, Batch 277, Loss: 0.221616
# Epoch 0, Batch 278, Loss: 0.261492
# Epoch 0, Batch 279, Loss: 0.193206
# Epoch 0, Batch 280, Loss: 0.196591
# Epoch 0, Batch 281, Loss: 0.241346
# Epoch 0, Batch 282, Loss: 0.119585
# Epoch 0, Batch 283, Loss: 0.197111
# Epoch 0, Batch 284, Loss: 0.156904
# Epoch 0, Batch 285, Loss: 0.131927
# Epoch 0, Batch 286, Loss: 0.143106
# Epoch 0, Batch 287, Loss: 0.337773
# Epoch 0, Batch 288, Loss: 0.277538
# Epoch 0, Batch 289, Loss: 0.303455
# Epoch 0, Batch 290, Loss: 0.131648
# Epoch 0, Batch 291, Loss: 0.315452
# Epoch 0, Batch 292, Loss: 0.129769
# Epoch 0, Batch 293, Loss: 0.127535
# Epoch 0, Batch 294, Loss: 0.127615
# Epoch 0, Batch 295, Loss: 0.099229
# Epoch 0, Batch 296, Loss: 0.093580
# Epoch 0, Batch 297, Loss: 0.133568
# Epoch 0, Batch 298, Loss: 0.279097
# Epoch 0, Batch 299, Loss: 0.269722
# Epoch 0, Batch 300, Loss: 0.140409
# Epoch 0, Batch 301, Loss: 0.227274
# Epoch 0, Batch 302, Loss: 0.187537
# Epoch 0, Batch 303, Loss: 0.110862
# Epoch 0, Batch 304, Loss: 0.212331
# Epoch 0, Batch 305, Loss: 0.277356
# Epoch 0, Batch 306, Loss: 0.202104
# Epoch 0, Batch 307, Loss: 0.134225
# Epoch 0, Batch 308, Loss: 0.233903
# Epoch 0, Batch 309, Loss: 0.092315
# Epoch 0, Batch 310, Loss: 0.211300
# Epoch 0, Batch 311, Loss: 0.158793
# Epoch 0, Batch 312, Loss: 0.158049
# Epoch 0, Batch 313, Loss: 0.184769
# Epoch 0, Batch 314, Loss: 0.130743
# Epoch 0, Batch 315, Loss: 0.164391
# Epoch 0, Batch 316, Loss: 0.075490
# Epoch 0, Batch 317, Loss: 0.058188
# Epoch 0, Batch 318, Loss: 0.073946
# Epoch 0, Batch 319, Loss: 0.162221
# Epoch 0, Batch 320, Loss: 0.123174
# Epoch 0, Batch 321, Loss: 0.139235
# Epoch 0, Batch 322, Loss: 0.165524
# Epoch 0, Batch 323, Loss: 0.072970
# Epoch 0, Batch 324, Loss: 0.107149
# Epoch 0, Batch 325, Loss: 0.129702
# Epoch 0, Batch 326, Loss: 0.100104
# Epoch 0, Batch 327, Loss: 0.233534
# Epoch 0, Batch 328, Loss: 0.169118
# Epoch 0, Batch 329, Loss: 0.093374
# Epoch 0, Batch 330, Loss: 0.168740
# Epoch 0, Batch 331, Loss: 0.222826
# Epoch 0, Batch 332, Loss: 0.136647
# Epoch 0, Batch 333, Loss: 0.129970
# Epoch 0, Batch 334, Loss: 0.046663
# Epoch 0, Batch 335, Loss: 0.122468
# Epoch 0, Batch 336, Loss: 0.136988
# Epoch 0, Batch 337, Loss: 0.163865
# Epoch 0, Batch 338, Loss: 0.277365
# Epoch 0, Batch 339, Loss: 0.093045
# Epoch 0, Batch 340, Loss: 0.231758
# Epoch 0, Batch 341, Loss: 0.061688
# Epoch 0, Batch 342, Loss: 0.149839
# Epoch 0, Batch 343, Loss: 0.256898
# Epoch 0, Batch 344, Loss: 0.043604
# Epoch 0, Batch 345, Loss: 0.054649
# Epoch 0, Batch 346, Loss: 0.091438
# Epoch 0, Batch 347, Loss: 0.118310
# Epoch 0, Batch 348, Loss: 0.233524
# Epoch 0, Batch 349, Loss: 0.122960
# Epoch 0, Batch 350, Loss: 0.081344
# Epoch 0, Batch 351, Loss: 0.108927
# Epoch 0, Batch 352, Loss: 0.361064
# Epoch 0, Batch 353, Loss: 0.214064
# Epoch 0, Batch 354, Loss: 0.160678
# Epoch 0, Batch 355, Loss: 0.090918
# Epoch 0, Batch 356, Loss: 0.087365
# Epoch 0, Batch 357, Loss: 0.127681
# Epoch 0, Batch 358, Loss: 0.181762
# Epoch 0, Batch 359, Loss: 0.189425
# Epoch 0, Batch 360, Loss: 0.136442
# Epoch 0, Batch 361, Loss: 0.076822
# Epoch 0, Batch 362, Loss: 0.176466
# Epoch 0, Batch 363, Loss: 0.160800
# Epoch 0, Batch 364, Loss: 0.161145
# Epoch 0, Batch 365, Loss: 0.065133
# Epoch 0, Batch 366, Loss: 0.203064
# Epoch 0, Batch 367, Loss: 0.152045
# Epoch 0, Batch 368, Loss: 0.079453
# Epoch 0, Batch 369, Loss: 0.104321
# Epoch 0, Batch 370, Loss: 0.276728
# Epoch 0, Batch 371, Loss: 0.152450
# Epoch 0, Batch 372, Loss: 0.163102
# Epoch 0, Batch 373, Loss: 0.153269
# Epoch 0, Batch 374, Loss: 0.398441
# Epoch 0, Batch 375, Loss: 0.112299
# Epoch 0, Batch 376, Loss: 0.194738
# Epoch 0, Batch 377, Loss: 0.246679
# Epoch 0, Batch 378, Loss: 0.166789
# Epoch 0, Batch 379, Loss: 0.293121
# Epoch 0, Batch 380, Loss: 0.143946
# Epoch 0, Batch 381, Loss: 0.422437
# Epoch 0, Batch 382, Loss: 0.099501
# Epoch 0, Batch 383, Loss: 0.103753
# Epoch 0, Batch 384, Loss: 0.202511
# Epoch 0, Batch 385, Loss: 0.137854
# Epoch 0, Batch 386, Loss: 0.065995
# Epoch 0, Batch 387, Loss: 0.124390
# Epoch 0, Batch 388, Loss: 0.080574
# Epoch 0, Batch 389, Loss: 0.100547
# Epoch 0, Batch 390, Loss: 0.108917
# Epoch 0, Batch 391, Loss: 0.103560
# Epoch 0, Batch 392, Loss: 0.062508
# Epoch 0, Batch 393, Loss: 0.137218
# Epoch 0, Batch 394, Loss: 0.101580
# Epoch 0, Batch 395, Loss: 0.040808
# Epoch 0, Batch 396, Loss: 0.077712
# Epoch 0, Batch 397, Loss: 0.097967
# Epoch 0, Batch 398, Loss: 0.056970
# Epoch 0, Batch 399, Loss: 0.095055
# Epoch 0, Batch 400, Loss: 0.094449
# Epoch 0, Batch 401, Loss: 0.120581
# Epoch 0, Batch 402, Loss: 0.110047
# Epoch 0, Batch 403, Loss: 0.148528
# Epoch 0, Batch 404, Loss: 0.036384
# Epoch 0, Batch 405, Loss: 0.461055
# Epoch 0, Batch 406, Loss: 0.191948
# Epoch 0, Batch 407, Loss: 0.068241
# Epoch 0, Batch 408, Loss: 0.354858
# Epoch 0, Batch 409, Loss: 0.082471
# Epoch 0, Batch 410, Loss: 0.045853
# Epoch 0, Batch 411, Loss: 0.101645
# Epoch 0, Batch 412, Loss: 0.069673
# Epoch 0, Batch 413, Loss: 0.092472
# Epoch 0, Batch 414, Loss: 0.099071
# Epoch 0, Batch 415, Loss: 0.114774
# Epoch 0, Batch 416, Loss: 0.027504
# Epoch 0, Batch 417, Loss: 0.035156
# Epoch 0, Batch 418, Loss: 0.145735
# Epoch 0, Batch 419, Loss: 0.063235
# Epoch 0, Batch 420, Loss: 0.142828
# Epoch 0, Batch 421, Loss: 0.244260
# Epoch 0, Batch 422, Loss: 0.153618
# Epoch 0, Batch 423, Loss: 0.095594
# Epoch 0, Batch 424, Loss: 0.287542
# Epoch 0, Batch 425, Loss: 0.071911
# Epoch 0, Batch 426, Loss: 0.101178
# Epoch 0, Batch 427, Loss: 0.196655
# Epoch 0, Batch 428, Loss: 0.091750
# Epoch 0, Batch 429, Loss: 0.051679
# Epoch 0, Batch 430, Loss: 0.244400
# Epoch 0, Batch 431, Loss: 0.189408
# Epoch 0, Batch 432, Loss: 0.387132
# Epoch 0, Batch 433, Loss: 0.127301
# Epoch 0, Batch 434, Loss: 0.097898
# Epoch 0, Batch 435, Loss: 0.163617
# Epoch 0, Batch 436, Loss: 0.178104
# Epoch 0, Batch 437, Loss: 0.126556
# Epoch 0, Batch 438, Loss: 0.287421
# Epoch 0, Batch 439, Loss: 0.183185
# Epoch 0, Batch 440, Loss: 0.125597
# Epoch 0, Batch 441, Loss: 0.054505
# Epoch 0, Batch 442, Loss: 0.451271
# Epoch 0, Batch 443, Loss: 0.272320
# Epoch 0, Batch 444, Loss: 0.096329
# Epoch 0, Batch 445, Loss: 0.155814
# Epoch 0, Batch 446, Loss: 0.166894
# Epoch 0, Batch 447, Loss: 0.212336
# Epoch 0, Batch 448, Loss: 0.119844
# Epoch 0, Batch 449, Loss: 0.133248
# Epoch 0, Batch 450, Loss: 0.099315
# Epoch 0, Batch 451, Loss: 0.146331
# Epoch 0, Batch 452, Loss: 0.221015
# Epoch 0, Batch 453, Loss: 0.112822
# Epoch 0, Batch 454, Loss: 0.151657
# Epoch 0, Batch 455, Loss: 0.135996
# Epoch 0, Batch 456, Loss: 0.241773
# Epoch 0, Batch 457, Loss: 0.105256
# Epoch 0, Batch 458, Loss: 0.071453
# Epoch 0, Batch 459, Loss: 0.194890
# Epoch 0, Batch 460, Loss: 0.138670
# Epoch 0, Batch 461, Loss: 0.149911
# Epoch 0, Batch 462, Loss: 0.080507
# Epoch 0, Batch 463, Loss: 0.127373
# Epoch 0, Batch 464, Loss: 0.121669
# Epoch 0, Batch 465, Loss: 0.244688
# Epoch 0, Batch 466, Loss: 0.164347
# Epoch 0, Batch 467, Loss: 0.108152
# Epoch 0, Batch 468, Loss: 0.164150
# Epoch 0, Batch 469, Loss: 0.106926
# Epoch 0, Batch 470, Loss: 0.092320
# Epoch 0, Batch 471, Loss: 0.096415
# Epoch 0, Batch 472, Loss: 0.170973
# Epoch 0, Batch 473, Loss: 0.098446
# Epoch 0, Batch 474, Loss: 0.107234
# Epoch 0, Batch 475, Loss: 0.128366
# Epoch 0, Batch 476, Loss: 0.048084
# Epoch 0, Batch 477, Loss: 0.131811
# Epoch 0, Batch 478, Loss: 0.038394
# Epoch 0, Batch 479, Loss: 0.176803
# Epoch 0, Batch 480, Loss: 0.072335
# Epoch 0, Batch 481, Loss: 0.068682
# Epoch 0, Batch 482, Loss: 0.275986
# Epoch 0, Batch 483, Loss: 0.126545
# Epoch 0, Batch 484, Loss: 0.294442
# Epoch 0, Batch 485, Loss: 0.163832
# Epoch 0, Batch 486, Loss: 0.130720
# Epoch 0, Batch 487, Loss: 0.081377
# Epoch 0, Batch 488, Loss: 0.048068
# Epoch 0, Batch 489, Loss: 0.065521
# Epoch 0, Batch 490, Loss: 0.057940
# Epoch 0, Batch 491, Loss: 0.061044
# Epoch 0, Batch 492, Loss: 0.093796
# Epoch 0, Batch 493, Loss: 0.138117
# Epoch 0, Batch 494, Loss: 0.171991
# Epoch 0, Batch 495, Loss: 0.176492
# Epoch 0, Batch 496, Loss: 0.077843
# Epoch 0, Batch 497, Loss: 0.078297
# Epoch 0, Batch 498, Loss: 0.093883
# Epoch 0, Batch 499, Loss: 0.057517
# Epoch 0, Batch 500, Loss: 0.117415
# Epoch 0, Batch 501, Loss: 0.131305
# Epoch 0, Batch 502, Loss: 0.191819
# Epoch 0, Batch 503, Loss: 0.057277
# Epoch 0, Batch 504, Loss: 0.208937
# Epoch 0, Batch 505, Loss: 0.145265
# Epoch 0, Batch 506, Loss: 0.115418
# Epoch 0, Batch 507, Loss: 0.075889
# Epoch 0, Batch 508, Loss: 0.111301
# Epoch 0, Batch 509, Loss: 0.072331
# Epoch 0, Batch 510, Loss: 0.053493
# Epoch 0, Batch 511, Loss: 0.032393
# Epoch 0, Batch 512, Loss: 0.091691
# Epoch 0, Batch 513, Loss: 0.117491
# Epoch 0, Batch 514, Loss: 0.032976
# Epoch 0, Batch 515, Loss: 0.127522
# Epoch 0, Batch 516, Loss: 0.193369
# Epoch 0, Batch 517, Loss: 0.044317
# Epoch 0, Batch 518, Loss: 0.256601
# Epoch 0, Batch 519, Loss: 0.097058
# Epoch 0, Batch 520, Loss: 0.011131
# Epoch 0, Batch 521, Loss: 0.043859
# Epoch 0, Batch 522, Loss: 0.116293
# Epoch 0, Batch 523, Loss: 0.083834
# Epoch 0, Batch 524, Loss: 0.075200
# Epoch 0, Batch 525, Loss: 0.090482
# Epoch 0, Batch 526, Loss: 0.102863
# Epoch 0, Batch 527, Loss: 0.081350
# Epoch 0, Batch 528, Loss: 0.159090
# Epoch 0, Batch 529, Loss: 0.268368
# Epoch 0, Batch 530, Loss: 0.021121
# Epoch 0, Batch 531, Loss: 0.082195
# Epoch 0, Batch 532, Loss: 0.115761
# Epoch 0, Batch 533, Loss: 0.143335
# Epoch 0, Batch 534, Loss: 0.150062
# Epoch 0, Batch 535, Loss: 0.258439
# Epoch 0, Batch 536, Loss: 0.132014
# Epoch 0, Batch 537, Loss: 0.181147
# Epoch 0, Batch 538, Loss: 0.060207
# Epoch 0, Batch 539, Loss: 0.046501
# Epoch 0, Batch 540, Loss: 0.200649
# Epoch 0, Batch 541, Loss: 0.067347
# Epoch 0, Batch 542, Loss: 0.039938
# Epoch 0, Batch 543, Loss: 0.113734
# Epoch 0, Batch 544, Loss: 0.124997
# Epoch 0, Batch 545, Loss: 0.038906
# Epoch 0, Batch 546, Loss: 0.077398
# Epoch 0, Batch 547, Loss: 0.046063
# Epoch 0, Batch 548, Loss: 0.092636
# Epoch 0, Batch 549, Loss: 0.146838
# Epoch 0, Batch 550, Loss: 0.027995
# Epoch 0, Batch 551, Loss: 0.083275
# Epoch 0, Batch 552, Loss: 0.148439
# Epoch 0, Batch 553, Loss: 0.074717
# Epoch 0, Batch 554, Loss: 0.191405
# Epoch 0, Batch 555, Loss: 0.111174
# Epoch 0, Batch 556, Loss: 0.286518
# Epoch 0, Batch 557, Loss: 0.058028
# Epoch 0, Batch 558, Loss: 0.140605
# Epoch 0, Batch 559, Loss: 0.120499
# Epoch 0, Batch 560, Loss: 0.120514
# Epoch 0, Batch 561, Loss: 0.142356
# Epoch 0, Batch 562, Loss: 0.121995
# Epoch 0, Batch 563, Loss: 0.265553
# Epoch 0, Batch 564, Loss: 0.115939
# Epoch 0, Batch 565, Loss: 0.068963
# Epoch 0, Batch 566, Loss: 0.066645
# Epoch 0, Batch 567, Loss: 0.198010
# Epoch 0, Batch 568, Loss: 0.232808
# Epoch 0, Batch 569, Loss: 0.155295
# Epoch 0, Batch 570, Loss: 0.215277
# Epoch 0, Batch 571, Loss: 0.135404
# Epoch 0, Batch 572, Loss: 0.102493
# Epoch 0, Batch 573, Loss: 0.109461
# Epoch 0, Batch 574, Loss: 0.081040
# Epoch 0, Batch 575, Loss: 0.109474
# Epoch 0, Batch 576, Loss: 0.102436
# Epoch 0, Batch 577, Loss: 0.186039
# Epoch 0, Batch 578, Loss: 0.072633
# Epoch 0, Batch 579, Loss: 0.086253
# Epoch 0, Batch 580, Loss: 0.135146
# Epoch 0, Batch 581, Loss: 0.140245
# Epoch 0, Batch 582, Loss: 0.122564
# Epoch 0, Batch 583, Loss: 0.076231
# Epoch 0, Batch 584, Loss: 0.097957
# Epoch 0, Batch 585, Loss: 0.079832
# Epoch 0, Batch 586, Loss: 0.077532
# Epoch 0, Batch 587, Loss: 0.095746
# Epoch 0, Batch 588, Loss: 0.076906
# Epoch 0, Batch 589, Loss: 0.127065
# Epoch 0, Batch 590, Loss: 0.197133
# Epoch 0, Batch 591, Loss: 0.065084
# Epoch 0, Batch 592, Loss: 0.117602
# Epoch 0, Batch 593, Loss: 0.037027
# Epoch 0, Batch 594, Loss: 0.085917
# Epoch 0, Batch 595, Loss: 0.046021
# Epoch 0, Batch 596, Loss: 0.171165
# Epoch 0, Batch 597, Loss: 0.028404
# Epoch 0, Batch 598, Loss: 0.076094
# Epoch 0, Batch 599, Loss: 0.104598
# Epoch 0, Batch 600, Loss: 0.135619
# Epoch 0, Batch 601, Loss: 0.276641
# Epoch 0, Batch 602, Loss: 0.038075
# Epoch 0, Batch 603, Loss: 0.091697
# Epoch 0, Batch 604, Loss: 0.076002
# Epoch 0, Batch 605, Loss: 0.064845
# Epoch 0, Batch 606, Loss: 0.161177
# Epoch 0, Batch 607, Loss: 0.012489
# Epoch 0, Batch 608, Loss: 0.160709
# Epoch 0, Batch 609, Loss: 0.194719
# Epoch 0, Batch 610, Loss: 0.222613
# Epoch 0, Batch 611, Loss: 0.060221
# Epoch 0, Batch 612, Loss: 0.117174
# Epoch 0, Batch 613, Loss: 0.047829
# Epoch 0, Batch 614, Loss: 0.027944
# Epoch 0, Batch 615, Loss: 0.092571
# Epoch 0, Batch 616, Loss: 0.027619
# Epoch 0, Batch 617, Loss: 0.293499
# Epoch 0, Batch 618, Loss: 0.061909
# Epoch 0, Batch 619, Loss: 0.074998
# Epoch 0, Batch 620, Loss: 0.124571
# Epoch 0, Batch 621, Loss: 0.017895
# Epoch 0, Batch 622, Loss: 0.052939
# Epoch 0, Batch 623, Loss: 0.033321
# Epoch 0, Batch 624, Loss: 0.238438
# Epoch 0, Batch 625, Loss: 0.156742
# Epoch 0, Batch 626, Loss: 0.168493
# Epoch 0, Batch 627, Loss: 0.052660
# Epoch 0, Batch 628, Loss: 0.188352
# Epoch 0, Batch 629, Loss: 0.054835
# Epoch 0, Batch 630, Loss: 0.029763
# Epoch 0, Batch 631, Loss: 0.281638
# Epoch 0, Batch 632, Loss: 0.084875
# Epoch 0, Batch 633, Loss: 0.076902
# Epoch 0, Batch 634, Loss: 0.196739
# Epoch 0, Batch 635, Loss: 0.013641
# Epoch 0, Batch 636, Loss: 0.037179
# Epoch 0, Batch 637, Loss: 0.007123
# Epoch 0, Batch 638, Loss: 0.114880
# Epoch 0, Batch 639, Loss: 0.187560
# Epoch 0, Batch 640, Loss: 0.221379
# Epoch 0, Batch 641, Loss: 0.046863
# Epoch 0, Batch 642, Loss: 0.229122
# Epoch 0, Batch 643, Loss: 0.089098
# Epoch 0, Batch 644, Loss: 0.106842
# Epoch 0, Batch 645, Loss: 0.031083
# Epoch 0, Batch 646, Loss: 0.097967
# Epoch 0, Batch 647, Loss: 0.036097
# Epoch 0, Batch 648, Loss: 0.187371
# Epoch 0, Batch 649, Loss: 0.060593
# Epoch 0, Batch 650, Loss: 0.109028
# Epoch 0, Batch 651, Loss: 0.095980
# Epoch 0, Batch 652, Loss: 0.062242
# Epoch 0, Batch 653, Loss: 0.123526
# Epoch 0, Batch 654, Loss: 0.046174
# Epoch 0, Batch 655, Loss: 0.138396
# Epoch 0, Batch 656, Loss: 0.046045
# Warning: test set has no labels, skip accuracy evaluation.
# Saved: d:\CZ_WorkSpace\ai学习\深度学习实践\task1\task1_2\checkpoints\model_epoch_0.pth
# Epoch 1, Batch 0, Loss: 0.041539
# Epoch 1, Batch 1, Loss: 0.090719
# Epoch 1, Batch 2, Loss: 0.094951
# Epoch 1, Batch 3, Loss: 0.086339
# Epoch 1, Batch 4, Loss: 0.063190
# Epoch 1, Batch 5, Loss: 0.135377
# Epoch 1, Batch 6, Loss: 0.155366
# Epoch 1, Batch 7, Loss: 0.032951
# Epoch 1, Batch 8, Loss: 0.298537
# Epoch 1, Batch 9, Loss: 0.035535
# Epoch 1, Batch 10, Loss: 0.066039
# Epoch 1, Batch 11, Loss: 0.126623
# Epoch 1, Batch 12, Loss: 0.113384
# Epoch 1, Batch 13, Loss: 0.204119
# Epoch 1, Batch 14, Loss: 0.128896
# Epoch 1, Batch 15, Loss: 0.129819
# Epoch 1, Batch 16, Loss: 0.093832
# Epoch 1, Batch 17, Loss: 0.035162
# Epoch 1, Batch 18, Loss: 0.193459
# Epoch 1, Batch 19, Loss: 0.131335
# Epoch 1, Batch 20, Loss: 0.049171
# Epoch 1, Batch 21, Loss: 0.105080
# Epoch 1, Batch 22, Loss: 0.201171
# Epoch 1, Batch 23, Loss: 0.030265
# Epoch 1, Batch 24, Loss: 0.094046
# Epoch 1, Batch 25, Loss: 0.033154
# Epoch 1, Batch 26, Loss: 0.021437
# Epoch 1, Batch 27, Loss: 0.092823
# Epoch 1, Batch 28, Loss: 0.063144
# Epoch 1, Batch 29, Loss: 0.037626
# Epoch 1, Batch 30, Loss: 0.044555
# Epoch 1, Batch 31, Loss: 0.081244
# Epoch 1, Batch 32, Loss: 0.107452
# Epoch 1, Batch 33, Loss: 0.081865
# Epoch 1, Batch 34, Loss: 0.122477
# Epoch 1, Batch 35, Loss: 0.092023
# Epoch 1, Batch 36, Loss: 0.102474
# Epoch 1, Batch 37, Loss: 0.134752
# Epoch 1, Batch 38, Loss: 0.157073
# Epoch 1, Batch 39, Loss: 0.027498
# Epoch 1, Batch 40, Loss: 0.062628
# Epoch 1, Batch 41, Loss: 0.250782
# Epoch 1, Batch 42, Loss: 0.112107
# Epoch 1, Batch 43, Loss: 0.049577
# Epoch 1, Batch 44, Loss: 0.189350
# Epoch 1, Batch 45, Loss: 0.125016
# Epoch 1, Batch 46, Loss: 0.048092
# Epoch 1, Batch 47, Loss: 0.056250
# Epoch 1, Batch 48, Loss: 0.145705
# Epoch 1, Batch 49, Loss: 0.024713
# Epoch 1, Batch 50, Loss: 0.072064
# Epoch 1, Batch 51, Loss: 0.109659
# Epoch 1, Batch 52, Loss: 0.067578
# Epoch 1, Batch 53, Loss: 0.238490
# Epoch 1, Batch 54, Loss: 0.095150
# Epoch 1, Batch 55, Loss: 0.034833
# Epoch 1, Batch 56, Loss: 0.027624
# Epoch 1, Batch 57, Loss: 0.113803
# Epoch 1, Batch 58, Loss: 0.061460
# Epoch 1, Batch 59, Loss: 0.132697
# Epoch 1, Batch 60, Loss: 0.113854
# Epoch 1, Batch 61, Loss: 0.069196
# Epoch 1, Batch 62, Loss: 0.110953
# Epoch 1, Batch 63, Loss: 0.082877
# Epoch 1, Batch 64, Loss: 0.038888
# Epoch 1, Batch 65, Loss: 0.033832
# Epoch 1, Batch 66, Loss: 0.140463
# Epoch 1, Batch 67, Loss: 0.031510
# Epoch 1, Batch 68, Loss: 0.035886
# Epoch 1, Batch 69, Loss: 0.102370
# Epoch 1, Batch 70, Loss: 0.150119
# Epoch 1, Batch 71, Loss: 0.119854
# Epoch 1, Batch 72, Loss: 0.087800
# Epoch 1, Batch 73, Loss: 0.058450
# Epoch 1, Batch 74, Loss: 0.034734
# Epoch 1, Batch 75, Loss: 0.015388
# Epoch 1, Batch 76, Loss: 0.077498
# Epoch 1, Batch 77, Loss: 0.090795
# Epoch 1, Batch 78, Loss: 0.124384
# Epoch 1, Batch 79, Loss: 0.046386
# Epoch 1, Batch 80, Loss: 0.045361
# Epoch 1, Batch 81, Loss: 0.065679
# Epoch 1, Batch 82, Loss: 0.094636
# Epoch 1, Batch 83, Loss: 0.229508
# Epoch 1, Batch 84, Loss: 0.038781
# Epoch 1, Batch 85, Loss: 0.073877
# Epoch 1, Batch 86, Loss: 0.101015
# Epoch 1, Batch 87, Loss: 0.025172
# Epoch 1, Batch 88, Loss: 0.120427
# Epoch 1, Batch 89, Loss: 0.029337
# Epoch 1, Batch 90, Loss: 0.035798
# Epoch 1, Batch 91, Loss: 0.026958
# Epoch 1, Batch 92, Loss: 0.124724
# Epoch 1, Batch 93, Loss: 0.052288
# Epoch 1, Batch 94, Loss: 0.019837
# Epoch 1, Batch 95, Loss: 0.032768
# Epoch 1, Batch 96, Loss: 0.054434
# Epoch 1, Batch 97, Loss: 0.020422
# Epoch 1, Batch 98, Loss: 0.015570
# Epoch 1, Batch 99, Loss: 0.031752
# Epoch 1, Batch 100, Loss: 0.084358
# Epoch 1, Batch 101, Loss: 0.103389
# Epoch 1, Batch 102, Loss: 0.029457
# Epoch 1, Batch 103, Loss: 0.177767
# Epoch 1, Batch 104, Loss: 0.040961
# Epoch 1, Batch 105, Loss: 0.146138
# Epoch 1, Batch 106, Loss: 0.052275
# Epoch 1, Batch 107, Loss: 0.110067
# Epoch 1, Batch 108, Loss: 0.144885
# Epoch 1, Batch 109, Loss: 0.030764
# Epoch 1, Batch 110, Loss: 0.214165
# Epoch 1, Batch 111, Loss: 0.022745
# Epoch 1, Batch 112, Loss: 0.194178
# Epoch 1, Batch 113, Loss: 0.034594
# Epoch 1, Batch 114, Loss: 0.033630
# Epoch 1, Batch 115, Loss: 0.105268
# Epoch 1, Batch 116, Loss: 0.024052
# Epoch 1, Batch 117, Loss: 0.036809
# Epoch 1, Batch 118, Loss: 0.152964
# Epoch 1, Batch 119, Loss: 0.035987
# Epoch 1, Batch 120, Loss: 0.146207
# Epoch 1, Batch 121, Loss: 0.032547
# Epoch 1, Batch 122, Loss: 0.051479
# Epoch 1, Batch 123, Loss: 0.156601
# Epoch 1, Batch 124, Loss: 0.041996
# Epoch 1, Batch 125, Loss: 0.071871
# Epoch 1, Batch 126, Loss: 0.025211
# Epoch 1, Batch 127, Loss: 0.175053
# Epoch 1, Batch 128, Loss: 0.103949
# Epoch 1, Batch 129, Loss: 0.131880
# Epoch 1, Batch 130, Loss: 0.071485
# Epoch 1, Batch 131, Loss: 0.109471
# Epoch 1, Batch 132, Loss: 0.130177
# Epoch 1, Batch 133, Loss: 0.195499
# Epoch 1, Batch 134, Loss: 0.043439
# Epoch 1, Batch 135, Loss: 0.034884
# Epoch 1, Batch 136, Loss: 0.039062
# Epoch 1, Batch 137, Loss: 0.062237
# Epoch 1, Batch 138, Loss: 0.028991
# Epoch 1, Batch 139, Loss: 0.028126
# Epoch 1, Batch 140, Loss: 0.025645
# Epoch 1, Batch 141, Loss: 0.101980
# Epoch 1, Batch 142, Loss: 0.027581
# Epoch 1, Batch 143, Loss: 0.127255
# Epoch 1, Batch 144, Loss: 0.074840
# Epoch 1, Batch 145, Loss: 0.081484
# Epoch 1, Batch 146, Loss: 0.052276
# Epoch 1, Batch 147, Loss: 0.012983
# Epoch 1, Batch 148, Loss: 0.061289
# Epoch 1, Batch 149, Loss: 0.081866
# Epoch 1, Batch 150, Loss: 0.068608
# Epoch 1, Batch 151, Loss: 0.076702
# Epoch 1, Batch 152, Loss: 0.035781
# Epoch 1, Batch 153, Loss: 0.101055
# Epoch 1, Batch 154, Loss: 0.049366
# Epoch 1, Batch 155, Loss: 0.045733
# Epoch 1, Batch 156, Loss: 0.025456
# Epoch 1, Batch 157, Loss: 0.022803
# Epoch 1, Batch 158, Loss: 0.015962
# Epoch 1, Batch 159, Loss: 0.025496
# Epoch 1, Batch 160, Loss: 0.019014
# Epoch 1, Batch 161, Loss: 0.007174
# Epoch 1, Batch 162, Loss: 0.172480
# Epoch 1, Batch 163, Loss: 0.031746
# Epoch 1, Batch 164, Loss: 0.067311
# Epoch 1, Batch 165, Loss: 0.041489
# Epoch 1, Batch 166, Loss: 0.231100
# Epoch 1, Batch 167, Loss: 0.071647
# Epoch 1, Batch 168, Loss: 0.202733
# Epoch 1, Batch 169, Loss: 0.174982
# Epoch 1, Batch 170, Loss: 0.068168
# Epoch 1, Batch 171, Loss: 0.317344
# Epoch 1, Batch 172, Loss: 0.054658
# Epoch 1, Batch 173, Loss: 0.025959
# Epoch 1, Batch 174, Loss: 0.122488
# Epoch 1, Batch 175, Loss: 0.044272
# Epoch 1, Batch 176, Loss: 0.059207
# Epoch 1, Batch 177, Loss: 0.088801
# Epoch 1, Batch 178, Loss: 0.113932
# Epoch 1, Batch 179, Loss: 0.097642
# Epoch 1, Batch 180, Loss: 0.088524
# Epoch 1, Batch 181, Loss: 0.159861
# Epoch 1, Batch 182, Loss: 0.156514
# Epoch 1, Batch 183, Loss: 0.107207
# Epoch 1, Batch 184, Loss: 0.174727
# Epoch 1, Batch 185, Loss: 0.038420
# Epoch 1, Batch 186, Loss: 0.010699
# Epoch 1, Batch 187, Loss: 0.079885
# Epoch 1, Batch 188, Loss: 0.089670
# Epoch 1, Batch 189, Loss: 0.174129
# Epoch 1, Batch 190, Loss: 0.039802
# Epoch 1, Batch 191, Loss: 0.032580
# Epoch 1, Batch 192, Loss: 0.015142
# Epoch 1, Batch 193, Loss: 0.059026
# Epoch 1, Batch 194, Loss: 0.046725
# Epoch 1, Batch 195, Loss: 0.079732
# Epoch 1, Batch 196, Loss: 0.030158
# Epoch 1, Batch 197, Loss: 0.053606
# Epoch 1, Batch 198, Loss: 0.120306
# Epoch 1, Batch 199, Loss: 0.017159
# Epoch 1, Batch 200, Loss: 0.041265
# Epoch 1, Batch 201, Loss: 0.041594
# Epoch 1, Batch 202, Loss: 0.092956
# Epoch 1, Batch 203, Loss: 0.200278
# Epoch 1, Batch 204, Loss: 0.084523
# Epoch 1, Batch 205, Loss: 0.024580
# Epoch 1, Batch 206, Loss: 0.089800
# Epoch 1, Batch 207, Loss: 0.124957
# Epoch 1, Batch 208, Loss: 0.028285
# Epoch 1, Batch 209, Loss: 0.028266
# Epoch 1, Batch 210, Loss: 0.082838
# Epoch 1, Batch 211, Loss: 0.062808
# Epoch 1, Batch 212, Loss: 0.041715
# Epoch 1, Batch 213, Loss: 0.049687
# Epoch 1, Batch 214, Loss: 0.103643
# Epoch 1, Batch 215, Loss: 0.115803
# Epoch 1, Batch 216, Loss: 0.046196
# Epoch 1, Batch 217, Loss: 0.232874
# Epoch 1, Batch 218, Loss: 0.098172
# Epoch 1, Batch 219, Loss: 0.017461
# Epoch 1, Batch 220, Loss: 0.045084
# Epoch 1, Batch 221, Loss: 0.080888
# Epoch 1, Batch 222, Loss: 0.112554
# Epoch 1, Batch 223, Loss: 0.040693
# Epoch 1, Batch 224, Loss: 0.076919
# Epoch 1, Batch 225, Loss: 0.071887
# Epoch 1, Batch 226, Loss: 0.020570
# Epoch 1, Batch 227, Loss: 0.030653
# Epoch 1, Batch 228, Loss: 0.089894
# Epoch 1, Batch 229, Loss: 0.148631
# Epoch 1, Batch 230, Loss: 0.162016
# Epoch 1, Batch 231, Loss: 0.066632
# Epoch 1, Batch 232, Loss: 0.112636
# Epoch 1, Batch 233, Loss: 0.046743
# Epoch 1, Batch 234, Loss: 0.165099
# Epoch 1, Batch 235, Loss: 0.099363
# Epoch 1, Batch 236, Loss: 0.108298
# Epoch 1, Batch 237, Loss: 0.140738
# Epoch 1, Batch 238, Loss: 0.050979
# Epoch 1, Batch 239, Loss: 0.049645
# Epoch 1, Batch 240, Loss: 0.041168
# Epoch 1, Batch 241, Loss: 0.094199
# Epoch 1, Batch 242, Loss: 0.086963
# Epoch 1, Batch 243, Loss: 0.034465
# Epoch 1, Batch 244, Loss: 0.105913
# Epoch 1, Batch 245, Loss: 0.044835
# Epoch 1, Batch 246, Loss: 0.125366
# Epoch 1, Batch 247, Loss: 0.083804
# Epoch 1, Batch 248, Loss: 0.018492
# Epoch 1, Batch 249, Loss: 0.037604
# Epoch 1, Batch 250, Loss: 0.076361
# Epoch 1, Batch 251, Loss: 0.134232
# Epoch 1, Batch 252, Loss: 0.198037
# Epoch 1, Batch 253, Loss: 0.068555
# Epoch 1, Batch 254, Loss: 0.166896
# Epoch 1, Batch 255, Loss: 0.075924
# Epoch 1, Batch 256, Loss: 0.011924
# Epoch 1, Batch 257, Loss: 0.028234
# Epoch 1, Batch 258, Loss: 0.150797
# Epoch 1, Batch 259, Loss: 0.017299
# Epoch 1, Batch 260, Loss: 0.253502
# Epoch 1, Batch 261, Loss: 0.046664
# Epoch 1, Batch 262, Loss: 0.076451
# Epoch 1, Batch 263, Loss: 0.171262
# Epoch 1, Batch 264, Loss: 0.125168
# Epoch 1, Batch 265, Loss: 0.150096
# Epoch 1, Batch 266, Loss: 0.041790
# Epoch 1, Batch 267, Loss: 0.088620
# Epoch 1, Batch 268, Loss: 0.048279
# Epoch 1, Batch 269, Loss: 0.144412
# Epoch 1, Batch 270, Loss: 0.086654
# Epoch 1, Batch 271, Loss: 0.053191
# Epoch 1, Batch 272, Loss: 0.066714
# Epoch 1, Batch 273, Loss: 0.078047
# Epoch 1, Batch 274, Loss: 0.026725
# Epoch 1, Batch 275, Loss: 0.034589
# Epoch 1, Batch 276, Loss: 0.039607
# Epoch 1, Batch 277, Loss: 0.083580
# Epoch 1, Batch 278, Loss: 0.066165
# Epoch 1, Batch 279, Loss: 0.097106
# Epoch 1, Batch 280, Loss: 0.078271
# Epoch 1, Batch 281, Loss: 0.040305
# Epoch 1, Batch 282, Loss: 0.118048
# Epoch 1, Batch 283, Loss: 0.091722
# Epoch 1, Batch 284, Loss: 0.043271
# Epoch 1, Batch 285, Loss: 0.071315
# Epoch 1, Batch 286, Loss: 0.153507
# Epoch 1, Batch 287, Loss: 0.284937
# Epoch 1, Batch 288, Loss: 0.041648
# Epoch 1, Batch 289, Loss: 0.043265
# Epoch 1, Batch 290, Loss: 0.074088
# Epoch 1, Batch 291, Loss: 0.083305
# Epoch 1, Batch 292, Loss: 0.131332
# Epoch 1, Batch 293, Loss: 0.061595
# Epoch 1, Batch 294, Loss: 0.122116
# Epoch 1, Batch 295, Loss: 0.078365
# Epoch 1, Batch 296, Loss: 0.046654
# Epoch 1, Batch 297, Loss: 0.021431
# Epoch 1, Batch 298, Loss: 0.124735
# Epoch 1, Batch 299, Loss: 0.031996
# Epoch 1, Batch 300, Loss: 0.076115
# Epoch 1, Batch 301, Loss: 0.067370
# Epoch 1, Batch 302, Loss: 0.044146
# Epoch 1, Batch 303, Loss: 0.042237
# Epoch 1, Batch 304, Loss: 0.131176
# Epoch 1, Batch 305, Loss: 0.040937
# Epoch 1, Batch 306, Loss: 0.079520
# Epoch 1, Batch 307, Loss: 0.047303
# Epoch 1, Batch 308, Loss: 0.088513
# Epoch 1, Batch 309, Loss: 0.018999
# Epoch 1, Batch 310, Loss: 0.034231
# Epoch 1, Batch 311, Loss: 0.045000
# Epoch 1, Batch 312, Loss: 0.037486
# Epoch 1, Batch 313, Loss: 0.017336
# Epoch 1, Batch 314, Loss: 0.083908
# Epoch 1, Batch 315, Loss: 0.022738
# Epoch 1, Batch 316, Loss: 0.032474
# Epoch 1, Batch 317, Loss: 0.178306
# Epoch 1, Batch 318, Loss: 0.093890
# Epoch 1, Batch 319, Loss: 0.088212
# Epoch 1, Batch 320, Loss: 0.062456
# Epoch 1, Batch 321, Loss: 0.049223
# Epoch 1, Batch 322, Loss: 0.076562
# Epoch 1, Batch 323, Loss: 0.061651
# Epoch 1, Batch 324, Loss: 0.060477
# Epoch 1, Batch 325, Loss: 0.068449
# Epoch 1, Batch 326, Loss: 0.051708
# Epoch 1, Batch 327, Loss: 0.078996
# Epoch 1, Batch 328, Loss: 0.042593
# Epoch 1, Batch 329, Loss: 0.146046
# Epoch 1, Batch 330, Loss: 0.069720
# Epoch 1, Batch 331, Loss: 0.029917
# Epoch 1, Batch 332, Loss: 0.010919
# Epoch 1, Batch 333, Loss: 0.051277
# Epoch 1, Batch 334, Loss: 0.040101
# Epoch 1, Batch 335, Loss: 0.064627
# Epoch 1, Batch 336, Loss: 0.237089
# Epoch 1, Batch 337, Loss: 0.074699
# Epoch 1, Batch 338, Loss: 0.074738
# Epoch 1, Batch 339, Loss: 0.079241
# Epoch 1, Batch 340, Loss: 0.068617
# Epoch 1, Batch 341, Loss: 0.136638
# Epoch 1, Batch 342, Loss: 0.027352
# Epoch 1, Batch 343, Loss: 0.103162
# Epoch 1, Batch 344, Loss: 0.102245
# Epoch 1, Batch 345, Loss: 0.019976
# Epoch 1, Batch 346, Loss: 0.049491
# Epoch 1, Batch 347, Loss: 0.062845
# Epoch 1, Batch 348, Loss: 0.128371
# Epoch 1, Batch 349, Loss: 0.074384
# Epoch 1, Batch 350, Loss: 0.060290
# Epoch 1, Batch 351, Loss: 0.096788
# Epoch 1, Batch 352, Loss: 0.147345
# Epoch 1, Batch 353, Loss: 0.087683
# Epoch 1, Batch 354, Loss: 0.050385
# Epoch 1, Batch 355, Loss: 0.011960
# Epoch 1, Batch 356, Loss: 0.013012
# Epoch 1, Batch 357, Loss: 0.156746
# Epoch 1, Batch 358, Loss: 0.037718
# Epoch 1, Batch 359, Loss: 0.038034
# Epoch 1, Batch 360, Loss: 0.043283
# Epoch 1, Batch 361, Loss: 0.021328
# Epoch 1, Batch 362, Loss: 0.045233
# Epoch 1, Batch 363, Loss: 0.129774
# Epoch 1, Batch 364, Loss: 0.088428
# Epoch 1, Batch 365, Loss: 0.044114
# Epoch 1, Batch 366, Loss: 0.116341
# Epoch 1, Batch 367, Loss: 0.102176
# Epoch 1, Batch 368, Loss: 0.025851
# Epoch 1, Batch 369, Loss: 0.056834
# Epoch 1, Batch 370, Loss: 0.050589
# Epoch 1, Batch 371, Loss: 0.030400
# Epoch 1, Batch 372, Loss: 0.036893
# Epoch 1, Batch 373, Loss: 0.073306
# Epoch 1, Batch 374, Loss: 0.034417
# Epoch 1, Batch 375, Loss: 0.035751
# Epoch 1, Batch 376, Loss: 0.004610
# Epoch 1, Batch 377, Loss: 0.010446
# Epoch 1, Batch 378, Loss: 0.028660
# Epoch 1, Batch 379, Loss: 0.051345
# Epoch 1, Batch 380, Loss: 0.059475
# Epoch 1, Batch 381, Loss: 0.046357
# Epoch 1, Batch 382, Loss: 0.045791
# Epoch 1, Batch 383, Loss: 0.044606
# Epoch 1, Batch 384, Loss: 0.144334
# Epoch 1, Batch 385, Loss: 0.027372
# Epoch 1, Batch 386, Loss: 0.016830
# Epoch 1, Batch 387, Loss: 0.037125
# Epoch 1, Batch 388, Loss: 0.024074
# Epoch 1, Batch 389, Loss: 0.046763
# Epoch 1, Batch 390, Loss: 0.010424
# Epoch 1, Batch 391, Loss: 0.031436
# Epoch 1, Batch 392, Loss: 0.182959
# Epoch 1, Batch 393, Loss: 0.055310
# Epoch 1, Batch 394, Loss: 0.134061
# Epoch 1, Batch 395, Loss: 0.104179
# Epoch 1, Batch 396, Loss: 0.029327
# Epoch 1, Batch 397, Loss: 0.077410
# Epoch 1, Batch 398, Loss: 0.127866
# Epoch 1, Batch 399, Loss: 0.091745
# Epoch 1, Batch 400, Loss: 0.090872
# Epoch 1, Batch 401, Loss: 0.066942
# Epoch 1, Batch 402, Loss: 0.218794
# Epoch 1, Batch 403, Loss: 0.063344
# Epoch 1, Batch 404, Loss: 0.077464
# Epoch 1, Batch 405, Loss: 0.121108
# Epoch 1, Batch 406, Loss: 0.053541
# Epoch 1, Batch 407, Loss: 0.039994
# Epoch 1, Batch 408, Loss: 0.111468
# Epoch 1, Batch 409, Loss: 0.070397
# Epoch 1, Batch 410, Loss: 0.019789
# Epoch 1, Batch 411, Loss: 0.082501
# Epoch 1, Batch 412, Loss: 0.152970
# Epoch 1, Batch 413, Loss: 0.052949
# Epoch 1, Batch 414, Loss: 0.058157
# Epoch 1, Batch 415, Loss: 0.083947
# Epoch 1, Batch 416, Loss: 0.041904
# Epoch 1, Batch 417, Loss: 0.097137
# Epoch 1, Batch 418, Loss: 0.042364
# Epoch 1, Batch 419, Loss: 0.099516
# Epoch 1, Batch 420, Loss: 0.099969
# Epoch 1, Batch 421, Loss: 0.053169
# Epoch 1, Batch 422, Loss: 0.013446
# Epoch 1, Batch 423, Loss: 0.178031
# Epoch 1, Batch 424, Loss: 0.062373
# Epoch 1, Batch 425, Loss: 0.026158
# Epoch 1, Batch 426, Loss: 0.079889
# Epoch 1, Batch 427, Loss: 0.080586
# Epoch 1, Batch 428, Loss: 0.083720
# Epoch 1, Batch 429, Loss: 0.150935
# Epoch 1, Batch 430, Loss: 0.110077
# Epoch 1, Batch 431, Loss: 0.012508
# Epoch 1, Batch 432, Loss: 0.016281
# Epoch 1, Batch 433, Loss: 0.155207
# Epoch 1, Batch 434, Loss: 0.028364
# Epoch 1, Batch 435, Loss: 0.059170
# Epoch 1, Batch 436, Loss: 0.073485
# Epoch 1, Batch 437, Loss: 0.033822
# Epoch 1, Batch 438, Loss: 0.053013
# Epoch 1, Batch 439, Loss: 0.056641
# Epoch 1, Batch 440, Loss: 0.086137
# Epoch 1, Batch 441, Loss: 0.101170
# Epoch 1, Batch 442, Loss: 0.034899
# Epoch 1, Batch 443, Loss: 0.036555
# Epoch 1, Batch 444, Loss: 0.048475
# Epoch 1, Batch 445, Loss: 0.018667
# Epoch 1, Batch 446, Loss: 0.048781
# Epoch 1, Batch 447, Loss: 0.073437
# Epoch 1, Batch 448, Loss: 0.070732
# Epoch 1, Batch 449, Loss: 0.050745
# Epoch 1, Batch 450, Loss: 0.073534
# Epoch 1, Batch 451, Loss: 0.036031
# Epoch 1, Batch 452, Loss: 0.015699
# Epoch 1, Batch 453, Loss: 0.027985
# Epoch 1, Batch 454, Loss: 0.081234
# Epoch 1, Batch 455, Loss: 0.043363
# Epoch 1, Batch 456, Loss: 0.045702
# Epoch 1, Batch 457, Loss: 0.019445
# Epoch 1, Batch 458, Loss: 0.018027
# Epoch 1, Batch 459, Loss: 0.038274
# Epoch 1, Batch 460, Loss: 0.062653
# Epoch 1, Batch 461, Loss: 0.054637
# Epoch 1, Batch 462, Loss: 0.077466
# Epoch 1, Batch 463, Loss: 0.007023
# Epoch 1, Batch 464, Loss: 0.143539
# Epoch 1, Batch 465, Loss: 0.080374
# Epoch 1, Batch 466, Loss: 0.035710
# Epoch 1, Batch 467, Loss: 0.085727
# Epoch 1, Batch 468, Loss: 0.073431
# Epoch 1, Batch 469, Loss: 0.092324
# Epoch 1, Batch 470, Loss: 0.044979
# Epoch 1, Batch 471, Loss: 0.090533
# Epoch 1, Batch 472, Loss: 0.013148
# Epoch 1, Batch 473, Loss: 0.078357
# Epoch 1, Batch 474, Loss: 0.095885
# Epoch 1, Batch 475, Loss: 0.066814
# Epoch 1, Batch 476, Loss: 0.063074
# Epoch 1, Batch 477, Loss: 0.007767
# Epoch 1, Batch 478, Loss: 0.138610
# Epoch 1, Batch 479, Loss: 0.074561
# Epoch 1, Batch 480, Loss: 0.160593
# Epoch 1, Batch 481, Loss: 0.031237
# Epoch 1, Batch 482, Loss: 0.044022
# Epoch 1, Batch 483, Loss: 0.052958
# Epoch 1, Batch 484, Loss: 0.145724
# Epoch 1, Batch 485, Loss: 0.011254
# Epoch 1, Batch 486, Loss: 0.042492
# Epoch 1, Batch 487, Loss: 0.015717
# Epoch 1, Batch 488, Loss: 0.010297
# Epoch 1, Batch 489, Loss: 0.050534
# Epoch 1, Batch 490, Loss: 0.014895
# Epoch 1, Batch 491, Loss: 0.097357
# Epoch 1, Batch 492, Loss: 0.084883
# Epoch 1, Batch 493, Loss: 0.034534
# Epoch 1, Batch 494, Loss: 0.081290
# Epoch 1, Batch 495, Loss: 0.013216
# Epoch 1, Batch 496, Loss: 0.082499
# Epoch 1, Batch 497, Loss: 0.047200
# Epoch 1, Batch 498, Loss: 0.056553
# Epoch 1, Batch 499, Loss: 0.015513
# Epoch 1, Batch 500, Loss: 0.044722
# Epoch 1, Batch 501, Loss: 0.082046
# Epoch 1, Batch 502, Loss: 0.067551
# Epoch 1, Batch 503, Loss: 0.107047
# Epoch 1, Batch 504, Loss: 0.026077
# Epoch 1, Batch 505, Loss: 0.051959
# Epoch 1, Batch 506, Loss: 0.118949
# Epoch 1, Batch 507, Loss: 0.003274
# Epoch 1, Batch 508, Loss: 0.010848
# Epoch 1, Batch 509, Loss: 0.098276
# Epoch 1, Batch 510, Loss: 0.017996
# Epoch 1, Batch 511, Loss: 0.030768
# Epoch 1, Batch 512, Loss: 0.042159
# Epoch 1, Batch 513, Loss: 0.066278
# Epoch 1, Batch 514, Loss: 0.078581
# Epoch 1, Batch 515, Loss: 0.050691
# Epoch 1, Batch 516, Loss: 0.037557
# Epoch 1, Batch 517, Loss: 0.060776
# Epoch 1, Batch 518, Loss: 0.138645
# Epoch 1, Batch 519, Loss: 0.114247
# Epoch 1, Batch 520, Loss: 0.036433
# Epoch 1, Batch 521, Loss: 0.018886
# Epoch 1, Batch 522, Loss: 0.012621
# Epoch 1, Batch 523, Loss: 0.209060
# Epoch 1, Batch 524, Loss: 0.047604
# Epoch 1, Batch 525, Loss: 0.154026
# Epoch 1, Batch 526, Loss: 0.032097
# Epoch 1, Batch 527, Loss: 0.048744
# Epoch 1, Batch 528, Loss: 0.029076
# Epoch 1, Batch 529, Loss: 0.056709
# Epoch 1, Batch 530, Loss: 0.067583
# Epoch 1, Batch 531, Loss: 0.373592
# Epoch 1, Batch 532, Loss: 0.038837
# Epoch 1, Batch 533, Loss: 0.013644
# Epoch 1, Batch 534, Loss: 0.018612
# Epoch 1, Batch 535, Loss: 0.141857
# Epoch 1, Batch 536, Loss: 0.021709
# Epoch 1, Batch 537, Loss: 0.112736
# Epoch 1, Batch 538, Loss: 0.016636
# Epoch 1, Batch 539, Loss: 0.005724
# Epoch 1, Batch 540, Loss: 0.020246
# Epoch 1, Batch 541, Loss: 0.124599
# Epoch 1, Batch 542, Loss: 0.125726
# Epoch 1, Batch 543, Loss: 0.033259
# Epoch 1, Batch 544, Loss: 0.044190
# Epoch 1, Batch 545, Loss: 0.056845
# Epoch 1, Batch 546, Loss: 0.055130
# Epoch 1, Batch 547, Loss: 0.033048
# Epoch 1, Batch 548, Loss: 0.040954
# Epoch 1, Batch 549, Loss: 0.028566
# Epoch 1, Batch 550, Loss: 0.018897
# Epoch 1, Batch 551, Loss: 0.071400
# Epoch 1, Batch 552, Loss: 0.049523
# Epoch 1, Batch 553, Loss: 0.014157
# Epoch 1, Batch 554, Loss: 0.025683
# Epoch 1, Batch 555, Loss: 0.005702
# Epoch 1, Batch 556, Loss: 0.010948
# Epoch 1, Batch 557, Loss: 0.028861
# Epoch 1, Batch 558, Loss: 0.088428
# Epoch 1, Batch 559, Loss: 0.092391
# Epoch 1, Batch 560, Loss: 0.051544
# Epoch 1, Batch 561, Loss: 0.098944
# Epoch 1, Batch 562, Loss: 0.087652
# Epoch 1, Batch 563, Loss: 0.074156
# Epoch 1, Batch 564, Loss: 0.019693
# Epoch 1, Batch 565, Loss: 0.224968
# Epoch 1, Batch 566, Loss: 0.010980
# Epoch 1, Batch 567, Loss: 0.029210
# Epoch 1, Batch 568, Loss: 0.074949
# Epoch 1, Batch 569, Loss: 0.014316
# Epoch 1, Batch 570, Loss: 0.135531
# Epoch 1, Batch 571, Loss: 0.151573
# Epoch 1, Batch 572, Loss: 0.047376
# Epoch 1, Batch 573, Loss: 0.038585
# Epoch 1, Batch 574, Loss: 0.020744
# Epoch 1, Batch 575, Loss: 0.133302
# Epoch 1, Batch 576, Loss: 0.038948
# Epoch 1, Batch 577, Loss: 0.098584
# Epoch 1, Batch 578, Loss: 0.011525
# Epoch 1, Batch 579, Loss: 0.076644
# Epoch 1, Batch 580, Loss: 0.024627
# Epoch 1, Batch 581, Loss: 0.046165
# Epoch 1, Batch 582, Loss: 0.199272
# Epoch 1, Batch 583, Loss: 0.048081
# Epoch 1, Batch 584, Loss: 0.095707
# Epoch 1, Batch 585, Loss: 0.054552
# Epoch 1, Batch 586, Loss: 0.056234
# Epoch 1, Batch 587, Loss: 0.008418
# Epoch 1, Batch 588, Loss: 0.037254
# Epoch 1, Batch 589, Loss: 0.014853
# Epoch 1, Batch 590, Loss: 0.073515
# Epoch 1, Batch 591, Loss: 0.114499
# Epoch 1, Batch 592, Loss: 0.077350
# Epoch 1, Batch 593, Loss: 0.059167
# Epoch 1, Batch 594, Loss: 0.133611
# Epoch 1, Batch 595, Loss: 0.150712
# Epoch 1, Batch 596, Loss: 0.044122
# Epoch 1, Batch 597, Loss: 0.031043
# Epoch 1, Batch 598, Loss: 0.082254
# Epoch 1, Batch 599, Loss: 0.103680
# Epoch 1, Batch 600, Loss: 0.044693
# Epoch 1, Batch 601, Loss: 0.080057
# Epoch 1, Batch 602, Loss: 0.015028
# Epoch 1, Batch 603, Loss: 0.129483
# Epoch 1, Batch 604, Loss: 0.283397
# Epoch 1, Batch 605, Loss: 0.076642
# Epoch 1, Batch 606, Loss: 0.085843
# Epoch 1, Batch 607, Loss: 0.029792
# Epoch 1, Batch 608, Loss: 0.130556
# Epoch 1, Batch 609, Loss: 0.125300
# Epoch 1, Batch 610, Loss: 0.015146
# Epoch 1, Batch 611, Loss: 0.057240
# Epoch 1, Batch 612, Loss: 0.036685
# Epoch 1, Batch 613, Loss: 0.061250
# Epoch 1, Batch 614, Loss: 0.100845
# Epoch 1, Batch 615, Loss: 0.037472
# Epoch 1, Batch 616, Loss: 0.024841
# Epoch 1, Batch 617, Loss: 0.059107
# Epoch 1, Batch 618, Loss: 0.022660
# Epoch 1, Batch 619, Loss: 0.032421
# Epoch 1, Batch 620, Loss: 0.015200
# Epoch 1, Batch 621, Loss: 0.157671
# Epoch 1, Batch 622, Loss: 0.055331
# Epoch 1, Batch 623, Loss: 0.082041
# Epoch 1, Batch 624, Loss: 0.079047
# Epoch 1, Batch 625, Loss: 0.022817
# Epoch 1, Batch 626, Loss: 0.107287
# Epoch 1, Batch 627, Loss: 0.016172
# Epoch 1, Batch 628, Loss: 0.176659
# Epoch 1, Batch 629, Loss: 0.015852
# Epoch 1, Batch 630, Loss: 0.160284
# Epoch 1, Batch 631, Loss: 0.063102
# Epoch 1, Batch 632, Loss: 0.083338
# Epoch 1, Batch 633, Loss: 0.066888
# Epoch 1, Batch 634, Loss: 0.073662
# Epoch 1, Batch 635, Loss: 0.045870
# Epoch 1, Batch 636, Loss: 0.030547
# Epoch 1, Batch 637, Loss: 0.039199
# Epoch 1, Batch 638, Loss: 0.105651
# Epoch 1, Batch 639, Loss: 0.268399
# Epoch 1, Batch 640, Loss: 0.082861
# Epoch 1, Batch 641, Loss: 0.067082
# Epoch 1, Batch 642, Loss: 0.059928
# Epoch 1, Batch 643, Loss: 0.057228
# Epoch 1, Batch 644, Loss: 0.031473
# Epoch 1, Batch 645, Loss: 0.025943
# Epoch 1, Batch 646, Loss: 0.035275
# Epoch 1, Batch 647, Loss: 0.126515
# Epoch 1, Batch 648, Loss: 0.027273
# Epoch 1, Batch 649, Loss: 0.041900
# Epoch 1, Batch 650, Loss: 0.145450
# Epoch 1, Batch 651, Loss: 0.081889
# Epoch 1, Batch 652, Loss: 0.011276
# Epoch 1, Batch 653, Loss: 0.080702
# Epoch 1, Batch 654, Loss: 0.140809
# Epoch 1, Batch 655, Loss: 0.009545
# Epoch 1, Batch 656, Loss: 0.028682
# Warning: test set has no labels, skip accuracy evaluation.
# Saved: d:\CZ_WorkSpace\ai学习\深度学习实践\task1\task1_2\checkpoints\model_epoch_1.pth
# Epoch 2, Batch 0, Loss: 0.056766
# Epoch 2, Batch 1, Loss: 0.058542
# Epoch 2, Batch 2, Loss: 0.113429
# Epoch 2, Batch 3, Loss: 0.048807
# Epoch 2, Batch 4, Loss: 0.043520
# Epoch 2, Batch 5, Loss: 0.006054
# Epoch 2, Batch 6, Loss: 0.006400
# Epoch 2, Batch 7, Loss: 0.092503
# Epoch 2, Batch 8, Loss: 0.101655
# Epoch 2, Batch 9, Loss: 0.074579
# Epoch 2, Batch 10, Loss: 0.031991
# Epoch 2, Batch 11, Loss: 0.065590
# Epoch 2, Batch 12, Loss: 0.120809
# Epoch 2, Batch 13, Loss: 0.063778
# Epoch 2, Batch 14, Loss: 0.060106
# Epoch 2, Batch 15, Loss: 0.033796
# Epoch 2, Batch 16, Loss: 0.046293
# Epoch 2, Batch 17, Loss: 0.055799
# Epoch 2, Batch 18, Loss: 0.082645
# Epoch 2, Batch 19, Loss: 0.016828
# Epoch 2, Batch 20, Loss: 0.035880
# Epoch 2, Batch 21, Loss: 0.060724
# Epoch 2, Batch 22, Loss: 0.060371
# Epoch 2, Batch 23, Loss: 0.092718
# Epoch 2, Batch 24, Loss: 0.068264
# Epoch 2, Batch 25, Loss: 0.023113
# Epoch 2, Batch 26, Loss: 0.089268
# Epoch 2, Batch 27, Loss: 0.051855
# Epoch 2, Batch 28, Loss: 0.013905
# Epoch 2, Batch 29, Loss: 0.049634
# Epoch 2, Batch 30, Loss: 0.043124
# Epoch 2, Batch 31, Loss: 0.023990
# Epoch 2, Batch 32, Loss: 0.005545
# Epoch 2, Batch 33, Loss: 0.090886
# Epoch 2, Batch 34, Loss: 0.011951
# Epoch 2, Batch 35, Loss: 0.053247
# Epoch 2, Batch 36, Loss: 0.061149
# Epoch 2, Batch 37, Loss: 0.044158
# Epoch 2, Batch 38, Loss: 0.015851
# Epoch 2, Batch 39, Loss: 0.033783
# Epoch 2, Batch 40, Loss: 0.017619
# Epoch 2, Batch 41, Loss: 0.031758
# Epoch 2, Batch 42, Loss: 0.159869
# Epoch 2, Batch 43, Loss: 0.027345
# Epoch 2, Batch 44, Loss: 0.014169
# Epoch 2, Batch 45, Loss: 0.014248
# Epoch 2, Batch 46, Loss: 0.007392
# Epoch 2, Batch 47, Loss: 0.074844
# Epoch 2, Batch 48, Loss: 0.054361
# Epoch 2, Batch 49, Loss: 0.020123
# Epoch 2, Batch 50, Loss: 0.038636
# Epoch 2, Batch 51, Loss: 0.063605
# Epoch 2, Batch 52, Loss: 0.117442
# Epoch 2, Batch 53, Loss: 0.056807
# Epoch 2, Batch 54, Loss: 0.018621
# Epoch 2, Batch 55, Loss: 0.097867
# Epoch 2, Batch 56, Loss: 0.041108
# ...
# Epoch 9, Batch 204, Loss: 0.006483
# Epoch 9, Batch 205, Loss: 0.000490
# Epoch 9, Batch 206, Loss: 0.031275
# Epoch 9, Batch 207, Loss: 0.087488
# Epoch 9, Batch 208, Loss: 0.001302
# Epoch 9, Batch 209, Loss: 0.003016
# Epoch 9, Batch 210, Loss: 0.011669
# Epoch 9, Batch 211, Loss: 0.024772
# Epoch 9, Batch 212, Loss: 0.021392
# Epoch 9, Batch 213, Loss: 0.001438
# Epoch 9, Batch 214, Loss: 0.030936
# Epoch 9, Batch 215, Loss: 0.074421
# Epoch 9, Batch 216, Loss: 0.000686
# Epoch 9, Batch 217, Loss: 0.002285
# Epoch 9, Batch 218, Loss: 0.000680
# Epoch 9, Batch 219, Loss: 0.000281
# Epoch 9, Batch 220, Loss: 0.003794
# Epoch 9, Batch 221, Loss: 0.022133
# Epoch 9, Batch 222, Loss: 0.017302
# Epoch 9, Batch 223, Loss: 0.001262
# Epoch 9, Batch 224, Loss: 0.026703
# Epoch 9, Batch 225, Loss: 0.063162
# Epoch 9, Batch 226, Loss: 0.003177
# Epoch 9, Batch 227, Loss: 0.038022
# Epoch 9, Batch 228, Loss: 0.017764
# Epoch 9, Batch 229, Loss: 0.045950
# Epoch 9, Batch 230, Loss: 0.020699
# Epoch 9, Batch 231, Loss: 0.010520
# Epoch 9, Batch 232, Loss: 0.007924
# Epoch 9, Batch 233, Loss: 0.006787
# Epoch 9, Batch 234, Loss: 0.004086
# Epoch 9, Batch 235, Loss: 0.000274
# Epoch 9, Batch 236, Loss: 0.129754
# Epoch 9, Batch 237, Loss: 0.000241
# Epoch 9, Batch 238, Loss: 0.001029
# Epoch 9, Batch 239, Loss: 0.005029
# Epoch 9, Batch 240, Loss: 0.002635
# Epoch 9, Batch 241, Loss: 0.000719
# Epoch 9, Batch 242, Loss: 0.019355
# Epoch 9, Batch 243, Loss: 0.156784
# Epoch 9, Batch 244, Loss: 0.012328
# Epoch 9, Batch 245, Loss: 0.002833
# Epoch 9, Batch 246, Loss: 0.018184
# Epoch 9, Batch 247, Loss: 0.015306
# Epoch 9, Batch 248, Loss: 0.017517
# Epoch 9, Batch 249, Loss: 0.001475
# Epoch 9, Batch 250, Loss: 0.006641
# Epoch 9, Batch 251, Loss: 0.002572
# Epoch 9, Batch 252, Loss: 0.052339
# Epoch 9, Batch 253, Loss: 0.001022
# Epoch 9, Batch 254, Loss: 0.001310
# Epoch 9, Batch 255, Loss: 0.001193
# Epoch 9, Batch 256, Loss: 0.003419
# Epoch 9, Batch 257, Loss: 0.044279
# Epoch 9, Batch 258, Loss: 0.007123
# Epoch 9, Batch 259, Loss: 0.000662
# Epoch 9, Batch 260, Loss: 0.010382
# Epoch 9, Batch 261, Loss: 0.008286
# Epoch 9, Batch 262, Loss: 0.008188
# Epoch 9, Batch 263, Loss: 0.001305
# Epoch 9, Batch 264, Loss: 0.006786
# Epoch 9, Batch 265, Loss: 0.004117
# Epoch 9, Batch 266, Loss: 0.007203
# Epoch 9, Batch 267, Loss: 0.002975
# Epoch 9, Batch 268, Loss: 0.002272
# Epoch 9, Batch 269, Loss: 0.002698
# Epoch 9, Batch 270, Loss: 0.027066
# Epoch 9, Batch 271, Loss: 0.002662
# Epoch 9, Batch 272, Loss: 0.000752
# Epoch 9, Batch 273, Loss: 0.002064
# Epoch 9, Batch 274, Loss: 0.018631
# Epoch 9, Batch 275, Loss: 0.000579
# Epoch 9, Batch 276, Loss: 0.088571
# Epoch 9, Batch 277, Loss: 0.001235
# Epoch 9, Batch 278, Loss: 0.000698
# Epoch 9, Batch 279, Loss: 0.031096
# Epoch 9, Batch 280, Loss: 0.016154
# Epoch 9, Batch 281, Loss: 0.000843
# Epoch 9, Batch 282, Loss: 0.000640
# Epoch 9, Batch 283, Loss: 0.019106
# Epoch 9, Batch 284, Loss: 0.001992
# Epoch 9, Batch 285, Loss: 0.003434
# Epoch 9, Batch 286, Loss: 0.000461
# Epoch 9, Batch 287, Loss: 0.019844
# Epoch 9, Batch 288, Loss: 0.000326
# Epoch 9, Batch 289, Loss: 0.000548
# Epoch 9, Batch 290, Loss: 0.003941
# Epoch 9, Batch 291, Loss: 0.006881
# Epoch 9, Batch 292, Loss: 0.005369
# Epoch 9, Batch 293, Loss: 0.000190
# Epoch 9, Batch 294, Loss: 0.005232
# Epoch 9, Batch 295, Loss: 0.007597
# Epoch 9, Batch 296, Loss: 0.001981
# Epoch 9, Batch 297, Loss: 0.002224
# Epoch 9, Batch 298, Loss: 0.000926
# Epoch 9, Batch 299, Loss: 0.020827
# Epoch 9, Batch 300, Loss: 0.003030
# Epoch 9, Batch 301, Loss: 0.003821
# Epoch 9, Batch 302, Loss: 0.108617
# Epoch 9, Batch 303, Loss: 0.001380
# Epoch 9, Batch 304, Loss: 0.002440
# Epoch 9, Batch 305, Loss: 0.001439
# Epoch 9, Batch 306, Loss: 0.064450
# Epoch 9, Batch 307, Loss: 0.005356
# Epoch 9, Batch 308, Loss: 0.005218
# Epoch 9, Batch 309, Loss: 0.001271
# Epoch 9, Batch 310, Loss: 0.005670
# Epoch 9, Batch 311, Loss: 0.000467
# Epoch 9, Batch 312, Loss: 0.003170
# Epoch 9, Batch 313, Loss: 0.002735
# Epoch 9, Batch 314, Loss: 0.033779
# Epoch 9, Batch 315, Loss: 0.025907
# Epoch 9, Batch 316, Loss: 0.000304
# Epoch 9, Batch 317, Loss: 0.001721
# Epoch 9, Batch 318, Loss: 0.001043
# Epoch 9, Batch 319, Loss: 0.001686
# Epoch 9, Batch 320, Loss: 0.002947
# Epoch 9, Batch 321, Loss: 0.002087
# Epoch 9, Batch 322, Loss: 0.001284
# Epoch 9, Batch 323, Loss: 0.004101
# Epoch 9, Batch 324, Loss: 0.005569
# Epoch 9, Batch 325, Loss: 0.003508
# Epoch 9, Batch 326, Loss: 0.056809
# Epoch 9, Batch 327, Loss: 0.006800
# Epoch 9, Batch 328, Loss: 0.001977
# Epoch 9, Batch 329, Loss: 0.002889
# Epoch 9, Batch 330, Loss: 0.015109
# Epoch 9, Batch 331, Loss: 0.011711
# Epoch 9, Batch 332, Loss: 0.094235
# Epoch 9, Batch 333, Loss: 0.020067
# Epoch 9, Batch 334, Loss: 0.004565
# Epoch 9, Batch 335, Loss: 0.000535
# Epoch 9, Batch 336, Loss: 0.004813
# Epoch 9, Batch 337, Loss: 0.003410
# Epoch 9, Batch 338, Loss: 0.008059
# Epoch 9, Batch 339, Loss: 0.001716
# Epoch 9, Batch 340, Loss: 0.002956
# Epoch 9, Batch 341, Loss: 0.005628
# Epoch 9, Batch 342, Loss: 0.016649
# Epoch 9, Batch 343, Loss: 0.008809
# Epoch 9, Batch 344, Loss: 0.001454
# Epoch 9, Batch 345, Loss: 0.009264
# Epoch 9, Batch 346, Loss: 0.000309
# Epoch 9, Batch 347, Loss: 0.075738
# Epoch 9, Batch 348, Loss: 0.009195
# Epoch 9, Batch 349, Loss: 0.015336
# Epoch 9, Batch 350, Loss: 0.000999
# Epoch 9, Batch 351, Loss: 0.004657
# Epoch 9, Batch 352, Loss: 0.001488
# Epoch 9, Batch 353, Loss: 0.001005
# Epoch 9, Batch 354, Loss: 0.002556
# Epoch 9, Batch 355, Loss: 0.000669
# Epoch 9, Batch 356, Loss: 0.003803
# Epoch 9, Batch 357, Loss: 0.007144
# Epoch 9, Batch 358, Loss: 0.004691
# Epoch 9, Batch 359, Loss: 0.003035
# Epoch 9, Batch 360, Loss: 0.004983
# Epoch 9, Batch 361, Loss: 0.001566
# Epoch 9, Batch 362, Loss: 0.050640
# Epoch 9, Batch 363, Loss: 0.004919
# Epoch 9, Batch 364, Loss: 0.026161
# Epoch 9, Batch 365, Loss: 0.001163
# Epoch 9, Batch 366, Loss: 0.002086
# Epoch 9, Batch 367, Loss: 0.000679
# Epoch 9, Batch 368, Loss: 0.002044
# Epoch 9, Batch 369, Loss: 0.029971
# Epoch 9, Batch 370, Loss: 0.000593
# Epoch 9, Batch 371, Loss: 0.008559
# Epoch 9, Batch 372, Loss: 0.005211
# Epoch 9, Batch 373, Loss: 0.002727
# Epoch 9, Batch 374, Loss: 0.005183
# Epoch 9, Batch 375, Loss: 0.003528
# Epoch 9, Batch 376, Loss: 0.003706
# Epoch 9, Batch 377, Loss: 0.013307
# Epoch 9, Batch 378, Loss: 0.025311
# Epoch 9, Batch 379, Loss: 0.006677
# Epoch 9, Batch 380, Loss: 0.002741
# Epoch 9, Batch 381, Loss: 0.010858
# Epoch 9, Batch 382, Loss: 0.010953
# Epoch 9, Batch 383, Loss: 0.004549
# Epoch 9, Batch 384, Loss: 0.006172
# Epoch 9, Batch 385, Loss: 0.001490
# Epoch 9, Batch 386, Loss: 0.003161
# Epoch 9, Batch 387, Loss: 0.002352
# Epoch 9, Batch 388, Loss: 0.001856
# Epoch 9, Batch 389, Loss: 0.013371
# Epoch 9, Batch 390, Loss: 0.001655
# Epoch 9, Batch 391, Loss: 0.004198
# Epoch 9, Batch 392, Loss: 0.008715
# Epoch 9, Batch 393, Loss: 0.002574
# Epoch 9, Batch 394, Loss: 0.003256
# Epoch 9, Batch 395, Loss: 0.009567
# Epoch 9, Batch 396, Loss: 0.001220
# Epoch 9, Batch 397, Loss: 0.002927
# Epoch 9, Batch 398, Loss: 0.001336
# Epoch 9, Batch 399, Loss: 0.005186
# Epoch 9, Batch 400, Loss: 0.012260
# Epoch 9, Batch 401, Loss: 0.000885
# Epoch 9, Batch 402, Loss: 0.025629
# Epoch 9, Batch 403, Loss: 0.001436
# Epoch 9, Batch 404, Loss: 0.030924
# Epoch 9, Batch 405, Loss: 0.000754
# Epoch 9, Batch 406, Loss: 0.033730
# Epoch 9, Batch 407, Loss: 0.003976
# Epoch 9, Batch 408, Loss: 0.067245
# Epoch 9, Batch 409, Loss: 0.013882
# Epoch 9, Batch 410, Loss: 0.008962
# Epoch 9, Batch 411, Loss: 0.007232
# Epoch 9, Batch 412, Loss: 0.008803
# Epoch 9, Batch 413, Loss: 0.004461
# Epoch 9, Batch 414, Loss: 0.000622
# Epoch 9, Batch 415, Loss: 0.001675
# Epoch 9, Batch 416, Loss: 0.009272
# Epoch 9, Batch 417, Loss: 0.008621
# Epoch 9, Batch 418, Loss: 0.001392
# Epoch 9, Batch 419, Loss: 0.030848
# Epoch 9, Batch 420, Loss: 0.030832
# Epoch 9, Batch 421, Loss: 0.053647
# Epoch 9, Batch 422, Loss: 0.028821
# Epoch 9, Batch 423, Loss: 0.006433
# Epoch 9, Batch 424, Loss: 0.001450
# Epoch 9, Batch 425, Loss: 0.003738
# Epoch 9, Batch 426, Loss: 0.000713
# Epoch 9, Batch 427, Loss: 0.006768
# Epoch 9, Batch 428, Loss: 0.050840
# Epoch 9, Batch 429, Loss: 0.000564
# Epoch 9, Batch 430, Loss: 0.000389
# Epoch 9, Batch 431, Loss: 0.001339
# Epoch 9, Batch 432, Loss: 0.003415
# Epoch 9, Batch 433, Loss: 0.009465
# Epoch 9, Batch 434, Loss: 0.189714
# Epoch 9, Batch 435, Loss: 0.013512
# Epoch 9, Batch 436, Loss: 0.001673
# Epoch 9, Batch 437, Loss: 0.022007
# Epoch 9, Batch 438, Loss: 0.001124
# Epoch 9, Batch 439, Loss: 0.000824
# Epoch 9, Batch 440, Loss: 0.000356
# Epoch 9, Batch 441, Loss: 0.000675
# Epoch 9, Batch 442, Loss: 0.000720
# Epoch 9, Batch 443, Loss: 0.002093
# Epoch 9, Batch 444, Loss: 0.005583
# Epoch 9, Batch 445, Loss: 0.000393
# Epoch 9, Batch 446, Loss: 0.000420
# Epoch 9, Batch 447, Loss: 0.009633
# Epoch 9, Batch 448, Loss: 0.021993
# Epoch 9, Batch 449, Loss: 0.005371
# Epoch 9, Batch 450, Loss: 0.008655
# Epoch 9, Batch 451, Loss: 0.060061
# Epoch 9, Batch 452, Loss: 0.005729
# Epoch 9, Batch 453, Loss: 0.021658
# Epoch 9, Batch 454, Loss: 0.003774
# Epoch 9, Batch 455, Loss: 0.007083
# Epoch 9, Batch 456, Loss: 0.000529
# Epoch 9, Batch 457, Loss: 0.002281
# Epoch 9, Batch 458, Loss: 0.024944
# Epoch 9, Batch 459, Loss: 0.001132
# Epoch 9, Batch 460, Loss: 0.003824
# Epoch 9, Batch 461, Loss: 0.011914
# Epoch 9, Batch 462, Loss: 0.022609
# Epoch 9, Batch 463, Loss: 0.006156
# Epoch 9, Batch 464, Loss: 0.002838
# Epoch 9, Batch 465, Loss: 0.000522
# Epoch 9, Batch 466, Loss: 0.001448
# Epoch 9, Batch 467, Loss: 0.008173
# Epoch 9, Batch 468, Loss: 0.006011
# Epoch 9, Batch 469, Loss: 0.006046
# Epoch 9, Batch 470, Loss: 0.044784
# Epoch 9, Batch 471, Loss: 0.004316
# Epoch 9, Batch 472, Loss: 0.013956
# Epoch 9, Batch 473, Loss: 0.002085
# Epoch 9, Batch 474, Loss: 0.006258
# Epoch 9, Batch 475, Loss: 0.003062
# Epoch 9, Batch 476, Loss: 0.000262
# Epoch 9, Batch 477, Loss: 0.004136
# Epoch 9, Batch 478, Loss: 0.000215
# Epoch 9, Batch 479, Loss: 0.006694
# Epoch 9, Batch 480, Loss: 0.000223
# Epoch 9, Batch 481, Loss: 0.004093
# Epoch 9, Batch 482, Loss: 0.040536
# Epoch 9, Batch 483, Loss: 0.003815
# Epoch 9, Batch 484, Loss: 0.018286
# Epoch 9, Batch 485, Loss: 0.001833
# Epoch 9, Batch 486, Loss: 0.016822
# Epoch 9, Batch 487, Loss: 0.002711
# Epoch 9, Batch 488, Loss: 0.024782
# Epoch 9, Batch 489, Loss: 0.001141
# Epoch 9, Batch 490, Loss: 0.001005
# Epoch 9, Batch 491, Loss: 0.002081
# Epoch 9, Batch 492, Loss: 0.000332
# Epoch 9, Batch 493, Loss: 0.005926
# Epoch 9, Batch 494, Loss: 0.004488
# Epoch 9, Batch 495, Loss: 0.000573
# Epoch 9, Batch 496, Loss: 0.001363
# Epoch 9, Batch 497, Loss: 0.020032
# Epoch 9, Batch 498, Loss: 0.009107
# Epoch 9, Batch 499, Loss: 0.003513
# Epoch 9, Batch 500, Loss: 0.011531
# Epoch 9, Batch 501, Loss: 0.001203
# Epoch 9, Batch 502, Loss: 0.001505
# Epoch 9, Batch 503, Loss: 0.002451
# Epoch 9, Batch 504, Loss: 0.001144
# Epoch 9, Batch 505, Loss: 0.001259
# Epoch 9, Batch 506, Loss: 0.006635
# Epoch 9, Batch 507, Loss: 0.002624
# Epoch 9, Batch 508, Loss: 0.008228
# Epoch 9, Batch 509, Loss: 0.000293
# Epoch 9, Batch 510, Loss: 0.003215
# Epoch 9, Batch 511, Loss: 0.006525
# Epoch 9, Batch 512, Loss: 0.005408
# Epoch 9, Batch 513, Loss: 0.002955
# Epoch 9, Batch 514, Loss: 0.001127
# Epoch 9, Batch 515, Loss: 0.006297
# Epoch 9, Batch 516, Loss: 0.002367
# Epoch 9, Batch 517, Loss: 0.045135
# Epoch 9, Batch 518, Loss: 0.000552
# Epoch 9, Batch 519, Loss: 0.002948
# Epoch 9, Batch 520, Loss: 0.000461
# Epoch 9, Batch 521, Loss: 0.013491
# Epoch 9, Batch 522, Loss: 0.002170
# Epoch 9, Batch 523, Loss: 0.003593
# Epoch 9, Batch 524, Loss: 0.079097
# Epoch 9, Batch 525, Loss: 0.013151
# Epoch 9, Batch 526, Loss: 0.012737
# Epoch 9, Batch 527, Loss: 0.004968
# Epoch 9, Batch 528, Loss: 0.008146
# Epoch 9, Batch 529, Loss: 0.003400
# Epoch 9, Batch 530, Loss: 0.003150
# Epoch 9, Batch 531, Loss: 0.009750
# Epoch 9, Batch 532, Loss: 0.000150
# Epoch 9, Batch 533, Loss: 0.009586
# Epoch 9, Batch 534, Loss: 0.000616
# Epoch 9, Batch 535, Loss: 0.000511
# Epoch 9, Batch 536, Loss: 0.000351
# Epoch 9, Batch 537, Loss: 0.000467
# Epoch 9, Batch 538, Loss: 0.008884
# Epoch 9, Batch 539, Loss: 0.000666
# Epoch 9, Batch 540, Loss: 0.000228
# Epoch 9, Batch 541, Loss: 0.024665
# Epoch 9, Batch 542, Loss: 0.005246
# Epoch 9, Batch 543, Loss: 0.000046
# Epoch 9, Batch 544, Loss: 0.001620
# Epoch 9, Batch 545, Loss: 0.009604
# Epoch 9, Batch 546, Loss: 0.028106
# Epoch 9, Batch 547, Loss: 0.001380
# Epoch 9, Batch 548, Loss: 0.000380
# Epoch 9, Batch 549, Loss: 0.000295
# Epoch 9, Batch 550, Loss: 0.037158
# Epoch 9, Batch 551, Loss: 0.005149
# Epoch 9, Batch 552, Loss: 0.003359
# Epoch 9, Batch 553, Loss: 0.067796
# Epoch 9, Batch 554, Loss: 0.098905
# Epoch 9, Batch 555, Loss: 0.011654
# Epoch 9, Batch 556, Loss: 0.000986
# Epoch 9, Batch 557, Loss: 0.010995
# Epoch 9, Batch 558, Loss: 0.003861
# Epoch 9, Batch 559, Loss: 0.009244
# Epoch 9, Batch 560, Loss: 0.021875
# Epoch 9, Batch 561, Loss: 0.000725
# Epoch 9, Batch 562, Loss: 0.000171
# Epoch 9, Batch 563, Loss: 0.000427
# Epoch 9, Batch 564, Loss: 0.004566
# Epoch 9, Batch 565, Loss: 0.046902
# Epoch 9, Batch 566, Loss: 0.000703
# Epoch 9, Batch 567, Loss: 0.000850
# Epoch 9, Batch 568, Loss: 0.004616
# Epoch 9, Batch 569, Loss: 0.007438
# Epoch 9, Batch 570, Loss: 0.002287
# Epoch 9, Batch 571, Loss: 0.001176
# Epoch 9, Batch 572, Loss: 0.000368
# Epoch 9, Batch 573, Loss: 0.000046
# Epoch 9, Batch 574, Loss: 0.042620
# Epoch 9, Batch 575, Loss: 0.030262
# Epoch 9, Batch 576, Loss: 0.000292
# Epoch 9, Batch 577, Loss: 0.012241
# Epoch 9, Batch 578, Loss: 0.000971
# Epoch 9, Batch 579, Loss: 0.001467
# Epoch 9, Batch 580, Loss: 0.089699
# Epoch 9, Batch 581, Loss: 0.001211
# Epoch 9, Batch 582, Loss: 0.000949
# Epoch 9, Batch 583, Loss: 0.002569
# Epoch 9, Batch 584, Loss: 0.024019
# Epoch 9, Batch 585, Loss: 0.003917
# Epoch 9, Batch 586, Loss: 0.015281
# Epoch 9, Batch 587, Loss: 0.008276
# Epoch 9, Batch 588, Loss: 0.078824
# Epoch 9, Batch 589, Loss: 0.007121
# Epoch 9, Batch 590, Loss: 0.000739
# Epoch 9, Batch 591, Loss: 0.048509
# Epoch 9, Batch 592, Loss: 0.001394
# Epoch 9, Batch 593, Loss: 0.008534
# Epoch 9, Batch 594, Loss: 0.001242
# Epoch 9, Batch 595, Loss: 0.008033
# Epoch 9, Batch 596, Loss: 0.035233
# Epoch 9, Batch 597, Loss: 0.000646
# Epoch 9, Batch 598, Loss: 0.046073
# Epoch 9, Batch 599, Loss: 0.002631
# Epoch 9, Batch 600, Loss: 0.000867
# Epoch 9, Batch 601, Loss: 0.001494
# Epoch 9, Batch 602, Loss: 0.003434
# Epoch 9, Batch 603, Loss: 0.012054
# Epoch 9, Batch 604, Loss: 0.002797
# Epoch 9, Batch 605, Loss: 0.009029
# Epoch 9, Batch 606, Loss: 0.016641
# Epoch 9, Batch 607, Loss: 0.015592
# Epoch 9, Batch 608, Loss: 0.000356
# Epoch 9, Batch 609, Loss: 0.000411
# Epoch 9, Batch 610, Loss: 0.010243
# Epoch 9, Batch 611, Loss: 0.014129
# Epoch 9, Batch 612, Loss: 0.004816
# Epoch 9, Batch 613, Loss: 0.017061
# Epoch 9, Batch 614, Loss: 0.002464
# Epoch 9, Batch 615, Loss: 0.008759
# Epoch 9, Batch 616, Loss: 0.001865
# Epoch 9, Batch 617, Loss: 0.000364
# Epoch 9, Batch 618, Loss: 0.000366
# Epoch 9, Batch 619, Loss: 0.002128
# Epoch 9, Batch 620, Loss: 0.000652
# Epoch 9, Batch 621, Loss: 0.001792
# Epoch 9, Batch 622, Loss: 0.010845
# Epoch 9, Batch 623, Loss: 0.005989
# Epoch 9, Batch 624, Loss: 0.015476
# Epoch 9, Batch 625, Loss: 0.010168
# Epoch 9, Batch 626, Loss: 0.000216
# Epoch 9, Batch 627, Loss: 0.000304
# Epoch 9, Batch 628, Loss: 0.014954
# Epoch 9, Batch 629, Loss: 0.039684
# Epoch 9, Batch 630, Loss: 0.000927
# Epoch 9, Batch 631, Loss: 0.000390
# Epoch 9, Batch 632, Loss: 0.002317
# Epoch 9, Batch 633, Loss: 0.014324
# Epoch 9, Batch 634, Loss: 0.006726
# Epoch 9, Batch 635, Loss: 0.023481
# Epoch 9, Batch 636, Loss: 0.000741
# Epoch 9, Batch 637, Loss: 0.002129
# Epoch 9, Batch 638, Loss: 0.024383
# Epoch 9, Batch 639, Loss: 0.005453
# Epoch 9, Batch 640, Loss: 0.000219
# Epoch 9, Batch 641, Loss: 0.016662
# Epoch 9, Batch 642, Loss: 0.001940
# Epoch 9, Batch 643, Loss: 0.000371
# Epoch 9, Batch 644, Loss: 0.011412
# Epoch 9, Batch 645, Loss: 0.021904
# Epoch 9, Batch 646, Loss: 0.001286
# Epoch 9, Batch 647, Loss: 0.002940
# Epoch 9, Batch 648, Loss: 0.000478
# Epoch 9, Batch 649, Loss: 0.003925
# Epoch 9, Batch 650, Loss: 0.000759
# Epoch 9, Batch 651, Loss: 0.003364
# Epoch 9, Batch 652, Loss: 0.011548
# Epoch 9, Batch 653, Loss: 0.000148
# Epoch 9, Batch 654, Loss: 0.001580
# Epoch 9, Batch 655, Loss: 0.000245
# Epoch 9, Batch 656, Loss: 0.009924
# Warning: test set has no labels, skip accuracy evaluation.
# Saved: d:\CZ_WorkSpace\ai学习\深度学习实践\task1\task1_2\checkpoints\model_epoch_9.pth

# %%
# 9.1) 训练曲线可视化
# 构造 epoch 轴
epochs_axis = list(range(1, len(epoch_losses) + 1))

# 创建画布
plt.figure(figsize=(10, 4))
# 左图：训练损失
plt.subplot(1, 2, 1)
plt.plot(epochs_axis, epoch_losses, marker="o")
plt.title("Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True, linestyle="--", alpha=0.4)

# 右图：验证准确率（若有）
#plt.subplot(1, 2, 2)
valid_acc = [a for a in epoch_accs if a is not None]
valid_epochs = [i + 1 for i, a in enumerate(epoch_accs) if a is not None]
if valid_acc:
    plt.plot(valid_epochs, valid_acc, marker="o", color="green")
    plt.ylim(0, 1)
plt.title("Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.grid(True, linestyle="--", alpha=0.4)

# 调整布局并显示
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10) 训练后单图验证与可选模型加载推理

# %%
# 训练后随机抽样做一次单图验证
single_sample_check(model, test_dataset)

# 可选：加载某个 checkpoint 后再做单图推理
# model2 = MyCNN()
# model2.load_state_dict(torch.load(os.path.join(checkpoint_dir, "model_epoch_8.pth"), map_location="cpu"))
# single_sample_check(model2, test_dataset)
# Out:
# Single Image Validation
# Image: d:\CZ_WorkSpace\ai学习\深度学习实践\task1\MNIST_kaggle\testSet\img_20366.jpg
# Pred Label: 2, Confidence: 0.9999 (no ground-truth label)

# %%
# 11) 加载模型参数并对测试集推理（导出 Kaggle 提交文件）
# 引入 DataLoader 以便批量推理
from torch.utils.data import DataLoader

# TODO: 修改为你要加载的权重文件路径
ckpt_path = os.path.join(checkpoint_dir, "model_epoch_8.pth")

# 初始化模型并加载权重
infer_model = MyCNN()
infer_model.load_state_dict(torch.load(ckpt_path, map_location="cpu"))
infer_model.eval()

# 构建推理 DataLoader（无标签）
infer_loader = DataLoader(test_dataset, batch_size=128, shuffle=False)
pred_records = []
with torch.no_grad():
    for images, file_paths in infer_loader:
        # 前向推理得到 logits
        logits = infer_model(images)
        # 取最大值所在类别作为预测结果
        preds = torch.argmax(logits, dim=1).cpu().numpy().tolist()
        for path, pred in zip(file_paths, preds):
            # 从文件名中解析 ImageId
            base = os.path.basename(path)
            match = re.search(r"\d+", base)
            if match is None:
                raise ValueError(f"Cannot parse image id from filename: {base}")
            image_id = int(match.group())
            pred_records.append((image_id, pred))

# 按 ImageId 升序排序，符合 Kaggle 提交格式
pred_records.sort(key=lambda x: x[0])
submit_df = pd.DataFrame(pred_records, columns=["ImageId", "Label"])

# 保存提交文件到当前工作目录
submit_path = os.path.join(os.getcwd(), "kaggle_submit_CNN.csv")
submit_df.to_csv(submit_path, index=False)
print(f"Saved submission file: {submit_path}")
print(submit_df.head())
# Out:
# Saved submission file: d:\CZ_WorkSpace\ai学习\深度学习实践\task1\task1_2\kaggle_submit_CNN.csv
#    ImageId  Label
# 0        1      2
# 1        2      0
# 2        3      9
# 3        4      9
# 4        5      3
