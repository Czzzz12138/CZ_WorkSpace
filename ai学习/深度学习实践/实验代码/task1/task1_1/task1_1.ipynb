# %% [markdown]
# # 任务1-1: 实现一个简单的全连接网络MLP，训练并评估 MNIST 数据集（MNIST_kaggle）
#
# 本 Notebook 将原始 PyTorch 脚本拆分为多个可独立执行的单元，便于调试、观察中间结果和分步训练。
# 任务1_1: 实现一个简单的全连接网络，训练并评估 MNIST 数据集（MNIST_kaggle）
# 这里的MNIST数据集不是标准版，区别于传统的MNIST（60000张训练图，10000张测试图），对于标准版MNIST，
# 可以直接使用 torchvision.datasets.MNIST 来加载和处理数据，但这里我们需要自己实现数据加载逻辑。
# 这里的是kaggle上提供的一个变体（比赛专用版），包含训练集和测试集两部分，且测试集（28000张）没有标签。
# 我们需要训练模型在训练集上，并在测试集上做预测，提交预测结果进行评测。

# %% [markdown]
# ## 1) 安装与启动 Jupyter 内核（VS Code）
#
# 首次使用可在此单元安装依赖；运行后在 VS Code 右上角选择 Python 内核（选择配置好的 DL 环境：python 3.9.25）。

# %%
# 如已安装可跳过
# %pip install -U pip
# %pip install ipykernel notebook torch torchvision pillow

import sys
print(sys.executable)
print("内核已就绪")
# Out:
# d:\anaconda\envs\DL\python.exe
# 内核已就绪

# %%
# 解决 Windows 下 OpenMP 重复加载导致的内核崩溃问题
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
print("KMP_DUPLICATE_LIB_OK set")
# Out:
# KMP_DUPLICATE_LIB_OK set

# %% [markdown]
# ## 2) 导入依赖并检查 PyTorch 版本
#
# 导入训练与数据处理所需模块，并确认当前 PyTorch 版本。

# %%
import os
import re
import random
import torch
import pandas as pd
import torch.nn as nn
import matplotlib.pyplot as plt
from PIL import Image
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader

print("torch version:", torch.__version__)
# Out:
# torch version: 2.8.0+cpu

# %% [markdown]
# ## 3) 配置数据路径（基于当前工作目录）

# %%
project_root = os.path.dirname(os.getcwd())   # 当前工作目录


train_dir = os.path.join(project_root, "MNIST_kaggle", "trainingSet")
test_dir = os.path.join(project_root, "MNIST_kaggle", "testSet")

print("cwd:", os.getcwd())
print("project_root:", project_root)
print("train_dir exists:", os.path.exists(train_dir), "train_dir:", train_dir)
print("test_dir exists:", os.path.exists(test_dir), "test_dir:", test_dir)
# Out:
# cwd: d:\CZ_WorkSpace\ai学习\深度学习实践\task1\task1_1
# project_root: d:\CZ_WorkSpace\ai学习\深度学习实践\task1
# train_dir exists: True train_dir: d:\CZ_WorkSpace\ai学习\深度学习实践\task1\MNIST_kaggle\trainingSet
# test_dir exists: True test_dir: d:\CZ_WorkSpace\ai学习\深度学习实践\task1\MNIST_kaggle\testSet

# %% [markdown]
# ## 4) 定义 MyDataset（有标签/无标签双模式）
#
# 保留原有数据集逻辑：灰度化、缩放、ToTensor、展平 784；支持训练集有标签和测试集无标签。

# %%
class MyDataset(Dataset):
    def __init__(self, data_dir, labeled=True):
        self.data_dir = data_dir
        self.labeled = labeled
        self.samples = []
        self.transform = transforms.Compose([
            transforms.Grayscale(num_output_channels=1),
            transforms.Resize((28, 28)),
            transforms.ToTensor(),
        ])

        if self.labeled:
            class_names = [d for d in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, d))]
            class_names = sorted(class_names, key=lambda x: int(x) if x.isdigit() else x)
            self.class_to_idx = {name: int(name) for name in class_names}
            for class_name in class_names:
                class_dir = os.path.join(data_dir, class_name)
                for file_name in os.listdir(class_dir):
                    if file_name.lower().endswith((".jpg", ".jpeg", ".png", ".bmp")):
                        file_path = os.path.join(class_dir, file_name)
                        label = self.class_to_idx[class_name]
                        self.samples.append((file_path, label))
        else:
            self.class_to_idx = {}
            for file_name in os.listdir(data_dir):
                file_path = os.path.join(data_dir, file_name)
                if os.path.isfile(file_path) and file_name.lower().endswith((".jpg", ".jpeg", ".png", ".bmp")):
                    self.samples.append(file_path)

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        if self.labeled:
            file_path, label = self.samples[idx]
        else:
            file_path = self.samples[idx]
            label = None

        image = Image.open(file_path)
        image = self.transform(image)
        image = image.view(-1)  # [1, 28, 28] -> [784]

        if self.labeled:
            return image, torch.tensor(label, dtype=torch.long)
        return image, file_path

# %% [markdown]
# ## 5) 构建 DataLoader 并检查 batch 形状
#
# 训练集使用 labeled=True，测试集按当前结构使用 labeled=False。

# %%
mydataset = MyDataset(data_dir=train_dir, labeled=True)
mydataset_loader = DataLoader(mydataset, batch_size=32, shuffle=True)

test_dataset = MyDataset(data_dir=test_dir, labeled=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

print(f"Train samples: {len(mydataset)}")
print(f"Test samples: {len(test_dataset)}")

for batch_idx, (images, labels) in enumerate(mydataset_loader):
    print(f"Batch {batch_idx}: images={images.shape}, labels={labels.shape}")
    print("Label sample:", labels[:10].tolist())
    if batch_idx == 1:
        break
# Out:
# Train samples: 42000
# Test samples: 28000
# Batch 0: images=torch.Size([32, 784]), labels=torch.Size([32])
# Label sample: [9, 4, 4, 3, 9, 7, 1, 3, 6, 6]
# Batch 1: images=torch.Size([32, 784]), labels=torch.Size([32])
# Label sample: [3, 0, 7, 3, 3, 1, 7, 7, 0, 4]

# %% [markdown]
# ## 6) 定义全连接网络 MyNetwork
#
# 网络结构为 784 -> 128 -> 10，输出 logits。

# %%
class MyNetwork(nn.Module):
    def __init__(self):
        super(MyNetwork, self).__init__()
        self.layer1 = nn.Linear(784, 128)
        self.act1 = nn.ReLU()
        self.layer2 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.act1(self.layer1(x))
        x = self.layer2(x)
        return x

# %% [markdown]
# ## 7) 定义评估函数 evaluate 与单样本推理 single_sample_check
#
# 测试集无标签时会跳过准确率；单样本推理输出预测类别与置信度。

# %%
def evaluate(model, data_loader):
    if len(data_loader.dataset) == 0 or not data_loader.dataset.labeled:
        print("Warning: test set has no labels, skip accuracy evaluation.")
        return None

    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in data_loader:
            outputs = model(images)
            preds = torch.argmax(outputs, dim=1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

    model.train()
    if total == 0:
        print("Warning: test set is empty, skip accuracy evaluation.")
        return None
    return correct / total


def single_sample_check(model, dataset):
    if len(dataset) == 0:
        print("Single image validation skipped: test dataset is empty.")
        return

    sample_idx = random.randint(0, len(dataset) - 1)
    sample = dataset[sample_idx]
    if dataset.labeled:
        image, label = sample
        image_path, _ = dataset.samples[sample_idx]
    else:
        image, image_path = sample
        label = None

    model.eval()
    with torch.no_grad():
        logits = model(image.unsqueeze(0))
        probs = torch.softmax(logits, dim=1)
        pred = torch.argmax(probs, dim=1).item()
        confidence = probs[0, pred].item()
    model.train()

    print("\nSingle Image Validation")
    print(f"Image: {image_path}")
    if label is not None:
        print(f"True Label: {label.item()}, Pred Label: {pred}, Confidence: {confidence:.4f}")
    else:
        print(f"Pred Label: {pred}, Confidence: {confidence:.4f} (no ground-truth label)")

# %% [markdown]
# ## 8) 定义损失函数与优化器
#
# 使用 CrossEntropyLoss 与 Adam(lr=0.001)，并做一次随机输入可用性检查。

# %%
loss_fn = nn.CrossEntropyLoss()
out = MyNetwork()
optimizer = torch.optim.Adam(out.parameters(), lr=0.001)

# 快速可用性检查
_ = loss_fn(out(torch.randn(32, 784)), torch.randint(0, 10, (32,)))
print("model check ok")
# Out:
# model check ok

# %% [markdown]
# ## 9) 编写训练循环（含测试评估与模型保存）
#
# 每个 epoch 执行训练；若测试集有标签则评估准确率；每 2 个 epoch 保存一次模型。

# %%
epochs = 10
os.makedirs("checkpoints", exist_ok=True)

epoch_losses = []
epoch_accs = []

for epoch in range(epochs):
    out.train()
    running_loss = 0.0
    sample_count = 0
    for batch_idx, (images, labels) in enumerate(mydataset_loader):
        output = out(images)
        loss = loss_fn(output, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        batch_size = labels.size(0)
        running_loss += loss.item() * batch_size
        sample_count += batch_size

        print(f"Epoch {epoch}, Batch {batch_idx}, Loss: {loss.item():.6f}")

    epoch_loss = running_loss / max(sample_count, 1)
    epoch_losses.append(epoch_loss)

    test_acc = evaluate(out, test_loader)
    if test_acc is not None:
        epoch_accs.append(test_acc)
        print(f"Epoch {epoch}, Test Accuracy: {test_acc * 100:.2f}%")
    else:
        epoch_accs.append(None)

    if epoch % 1 == 0:
        ckpt_path = os.path.join("checkpoints", f"model_epoch_{epoch}.pth")
        torch.save(out.state_dict(), ckpt_path)
        print("Saved:", ckpt_path)
# Out:
# Epoch 0, Batch 0, Loss: 2.307611
# Epoch 0, Batch 1, Loss: 2.280652
# Epoch 0, Batch 2, Loss: 2.255087
# Epoch 0, Batch 3, Loss: 2.233473
# Epoch 0, Batch 4, Loss: 2.184056
# Epoch 0, Batch 5, Loss: 2.176227
# Epoch 0, Batch 6, Loss: 2.102093
# Epoch 0, Batch 7, Loss: 2.053031
# Epoch 0, Batch 8, Loss: 2.032362
# Epoch 0, Batch 9, Loss: 1.971584
# Epoch 0, Batch 10, Loss: 2.037524
# Epoch 0, Batch 11, Loss: 1.876332
# Epoch 0, Batch 12, Loss: 1.855639
# Epoch 0, Batch 13, Loss: 1.865655
# Epoch 0, Batch 14, Loss: 1.803902
# Epoch 0, Batch 15, Loss: 1.795742
# Epoch 0, Batch 16, Loss: 1.704258
# Epoch 0, Batch 17, Loss: 1.706735
# Epoch 0, Batch 18, Loss: 1.630625
# Epoch 0, Batch 19, Loss: 1.703046
# Epoch 0, Batch 20, Loss: 1.602158
# Epoch 0, Batch 21, Loss: 1.574956
# Epoch 0, Batch 22, Loss: 1.520384
# Epoch 0, Batch 23, Loss: 1.426636
# Epoch 0, Batch 24, Loss: 1.373475
# Epoch 0, Batch 25, Loss: 1.287982
# Epoch 0, Batch 26, Loss: 1.350805
# Epoch 0, Batch 27, Loss: 1.246429
# Epoch 0, Batch 28, Loss: 1.450771
# Epoch 0, Batch 29, Loss: 1.024006
# Epoch 0, Batch 30, Loss: 1.209537
# Epoch 0, Batch 31, Loss: 1.150615
# Epoch 0, Batch 32, Loss: 0.998020
# Epoch 0, Batch 33, Loss: 1.094439
# Epoch 0, Batch 34, Loss: 0.984852
# Epoch 0, Batch 35, Loss: 0.877707
# Epoch 0, Batch 36, Loss: 1.030880
# Epoch 0, Batch 37, Loss: 1.228936
# Epoch 0, Batch 38, Loss: 1.269567
# Epoch 0, Batch 39, Loss: 1.075957
# Epoch 0, Batch 40, Loss: 1.082988
# Epoch 0, Batch 41, Loss: 0.834151
# Epoch 0, Batch 42, Loss: 1.033277
# Epoch 0, Batch 43, Loss: 1.102625
# Epoch 0, Batch 44, Loss: 0.895704
# Epoch 0, Batch 45, Loss: 0.752002
# Epoch 0, Batch 46, Loss: 0.968085
# Epoch 0, Batch 47, Loss: 0.702436
# Epoch 0, Batch 48, Loss: 1.028220
# Epoch 0, Batch 49, Loss: 0.748751
# Epoch 0, Batch 50, Loss: 0.744642
# Epoch 0, Batch 51, Loss: 0.993453
# Epoch 0, Batch 52, Loss: 1.052600
# Epoch 0, Batch 53, Loss: 0.824447
# Epoch 0, Batch 54, Loss: 0.729152
# Epoch 0, Batch 55, Loss: 0.927484
# Epoch 0, Batch 56, Loss: 0.785641
# Epoch 0, Batch 57, Loss: 0.662473
# Epoch 0, Batch 58, Loss: 0.655934
# Epoch 0, Batch 59, Loss: 0.821488
# Epoch 0, Batch 60, Loss: 0.351022
# Epoch 0, Batch 61, Loss: 0.588093
# Epoch 0, Batch 62, Loss: 0.647189
# Epoch 0, Batch 63, Loss: 0.627357
# Epoch 0, Batch 64, Loss: 0.630368
# Epoch 0, Batch 65, Loss: 0.505269
# Epoch 0, Batch 66, Loss: 0.670782
# Epoch 0, Batch 67, Loss: 0.748269
# Epoch 0, Batch 68, Loss: 0.810963
# Epoch 0, Batch 69, Loss: 0.729606
# Epoch 0, Batch 70, Loss: 0.822262
# Epoch 0, Batch 71, Loss: 0.571775
# Epoch 0, Batch 72, Loss: 0.667697
# Epoch 0, Batch 73, Loss: 0.567137
# Epoch 0, Batch 74, Loss: 0.738343
# Epoch 0, Batch 75, Loss: 0.564901
# Epoch 0, Batch 76, Loss: 0.453072
# Epoch 0, Batch 77, Loss: 0.639061
# Epoch 0, Batch 78, Loss: 0.693273
# Epoch 0, Batch 79, Loss: 0.688162
# Epoch 0, Batch 80, Loss: 0.392451
# Epoch 0, Batch 81, Loss: 0.632254
# Epoch 0, Batch 82, Loss: 0.526295
# Epoch 0, Batch 83, Loss: 0.526989
# Epoch 0, Batch 84, Loss: 0.749763
# Epoch 0, Batch 85, Loss: 0.664140
# Epoch 0, Batch 86, Loss: 0.448204
# Epoch 0, Batch 87, Loss: 0.557429
# Epoch 0, Batch 88, Loss: 0.471858
# Epoch 0, Batch 89, Loss: 0.694998
# Epoch 0, Batch 90, Loss: 0.566607
# Epoch 0, Batch 91, Loss: 0.899768
# Epoch 0, Batch 92, Loss: 0.736549
# Epoch 0, Batch 93, Loss: 0.555115
# Epoch 0, Batch 94, Loss: 0.635352
# Epoch 0, Batch 95, Loss: 0.537106
# Epoch 0, Batch 96, Loss: 0.453445
# Epoch 0, Batch 97, Loss: 0.808213
# Epoch 0, Batch 98, Loss: 0.945621
# Epoch 0, Batch 99, Loss: 0.445589
# Epoch 0, Batch 100, Loss: 0.616260
# Epoch 0, Batch 101, Loss: 0.460778
# Epoch 0, Batch 102, Loss: 0.701859
# Epoch 0, Batch 103, Loss: 0.565308
# Epoch 0, Batch 104, Loss: 0.519896
# Epoch 0, Batch 105, Loss: 0.724105
# Epoch 0, Batch 106, Loss: 0.601483
# Epoch 0, Batch 107, Loss: 0.519964
# Epoch 0, Batch 108, Loss: 0.709534
# Epoch 0, Batch 109, Loss: 0.342109
# Epoch 0, Batch 110, Loss: 0.560971
# Epoch 0, Batch 111, Loss: 0.288173
# Epoch 0, Batch 112, Loss: 0.682131
# Epoch 0, Batch 113, Loss: 0.583535
# Epoch 0, Batch 114, Loss: 0.544683
# Epoch 0, Batch 115, Loss: 0.608065
# Epoch 0, Batch 116, Loss: 0.474801
# Epoch 0, Batch 117, Loss: 0.400783
# Epoch 0, Batch 118, Loss: 0.330768
# Epoch 0, Batch 119, Loss: 0.447638
# Epoch 0, Batch 120, Loss: 0.529568
# Epoch 0, Batch 121, Loss: 0.319614
# Epoch 0, Batch 122, Loss: 0.709550
# Epoch 0, Batch 123, Loss: 0.658458
# Epoch 0, Batch 124, Loss: 0.395998
# Epoch 0, Batch 125, Loss: 0.445194
# Epoch 0, Batch 126, Loss: 0.555197
# Epoch 0, Batch 127, Loss: 0.467860
# Epoch 0, Batch 128, Loss: 0.692349
# Epoch 0, Batch 129, Loss: 0.618958
# Epoch 0, Batch 130, Loss: 0.404405
# Epoch 0, Batch 131, Loss: 0.292118
# Epoch 0, Batch 132, Loss: 0.371281
# Epoch 0, Batch 133, Loss: 0.388775
# Epoch 0, Batch 134, Loss: 0.301408
# Epoch 0, Batch 135, Loss: 0.314125
# Epoch 0, Batch 136, Loss: 0.384716
# Epoch 0, Batch 137, Loss: 0.420231
# Epoch 0, Batch 138, Loss: 0.286296
# Epoch 0, Batch 139, Loss: 0.370227
# Epoch 0, Batch 140, Loss: 0.398943
# Epoch 0, Batch 141, Loss: 0.357818
# Epoch 0, Batch 142, Loss: 0.317149
# Epoch 0, Batch 143, Loss: 0.320797
# Epoch 0, Batch 144, Loss: 0.557508
# Epoch 0, Batch 145, Loss: 0.502536
# Epoch 0, Batch 146, Loss: 0.243951
# Epoch 0, Batch 147, Loss: 0.672557
# Epoch 0, Batch 148, Loss: 0.254771
# Epoch 0, Batch 149, Loss: 0.399069
# Epoch 0, Batch 150, Loss: 0.239865
# Epoch 0, Batch 151, Loss: 0.232596
# Epoch 0, Batch 152, Loss: 0.591648
# Epoch 0, Batch 153, Loss: 0.277064
# Epoch 0, Batch 154, Loss: 0.468711
# Epoch 0, Batch 155, Loss: 0.714544
# Epoch 0, Batch 156, Loss: 0.271979
# Epoch 0, Batch 157, Loss: 0.528084
# Epoch 0, Batch 158, Loss: 0.352488
# Epoch 0, Batch 159, Loss: 0.311327
# Epoch 0, Batch 160, Loss: 0.480620
# Epoch 0, Batch 161, Loss: 0.274298
# Epoch 0, Batch 162, Loss: 0.544000
# Epoch 0, Batch 163, Loss: 0.398300
# Epoch 0, Batch 164, Loss: 0.392060
# Epoch 0, Batch 165, Loss: 0.293314
# Epoch 0, Batch 166, Loss: 0.466303
# Epoch 0, Batch 167, Loss: 0.405045
# Epoch 0, Batch 168, Loss: 0.442845
# Epoch 0, Batch 169, Loss: 0.342231
# Epoch 0, Batch 170, Loss: 0.521192
# Epoch 0, Batch 171, Loss: 0.293062
# Epoch 0, Batch 172, Loss: 0.460262
# Epoch 0, Batch 173, Loss: 0.281677
# Epoch 0, Batch 174, Loss: 0.492620
# Epoch 0, Batch 175, Loss: 0.237796
# Epoch 0, Batch 176, Loss: 0.264891
# Epoch 0, Batch 177, Loss: 0.338454
# Epoch 0, Batch 178, Loss: 0.354436
# Epoch 0, Batch 179, Loss: 0.761302
# Epoch 0, Batch 180, Loss: 0.465728
# Epoch 0, Batch 181, Loss: 0.354430
# Epoch 0, Batch 182, Loss: 0.290455
# Epoch 0, Batch 183, Loss: 0.334846
# Epoch 0, Batch 184, Loss: 0.638052
# Epoch 0, Batch 185, Loss: 0.561547
# Epoch 0, Batch 186, Loss: 0.442965
# Epoch 0, Batch 187, Loss: 0.401896
# Epoch 0, Batch 188, Loss: 0.213590
# Epoch 0, Batch 189, Loss: 0.354268
# Epoch 0, Batch 190, Loss: 0.459021
# Epoch 0, Batch 191, Loss: 0.478866
# Epoch 0, Batch 192, Loss: 0.346604
# Epoch 0, Batch 193, Loss: 0.630514
# Epoch 0, Batch 194, Loss: 0.318739
# Epoch 0, Batch 195, Loss: 0.561584
# Epoch 0, Batch 196, Loss: 0.475819
# Epoch 0, Batch 197, Loss: 0.229166
# Epoch 0, Batch 198, Loss: 0.582343
# Epoch 0, Batch 199, Loss: 0.295508
# Epoch 0, Batch 200, Loss: 0.468177
# Epoch 0, Batch 201, Loss: 0.373996
# Epoch 0, Batch 202, Loss: 0.363304
# Epoch 0, Batch 203, Loss: 0.530688
# Epoch 0, Batch 204, Loss: 0.509655
# Epoch 0, Batch 205, Loss: 0.482467
# Epoch 0, Batch 206, Loss: 0.160804
# Epoch 0, Batch 207, Loss: 0.207607
# Epoch 0, Batch 208, Loss: 0.377553
# Epoch 0, Batch 209, Loss: 0.500497
# Epoch 0, Batch 210, Loss: 0.291088
# Epoch 0, Batch 211, Loss: 0.392975
# Epoch 0, Batch 212, Loss: 0.365296
# Epoch 0, Batch 213, Loss: 0.290080
# Epoch 0, Batch 214, Loss: 0.220111
# Epoch 0, Batch 215, Loss: 0.324770
# Epoch 0, Batch 216, Loss: 0.445536
# Epoch 0, Batch 217, Loss: 0.752125
# Epoch 0, Batch 218, Loss: 0.399340
# Epoch 0, Batch 219, Loss: 0.268756
# Epoch 0, Batch 220, Loss: 0.508329
# Epoch 0, Batch 221, Loss: 0.302721
# Epoch 0, Batch 222, Loss: 0.513114
# Epoch 0, Batch 223, Loss: 0.327391
# Epoch 0, Batch 224, Loss: 0.393497
# Epoch 0, Batch 225, Loss: 0.322630
# Epoch 0, Batch 226, Loss: 0.452177
# Epoch 0, Batch 227, Loss: 0.282039
# Epoch 0, Batch 228, Loss: 0.287995
# Epoch 0, Batch 229, Loss: 0.294583
# Epoch 0, Batch 230, Loss: 0.618325
# Epoch 0, Batch 231, Loss: 0.382766
# Epoch 0, Batch 232, Loss: 0.418472
# Epoch 0, Batch 233, Loss: 0.415986
# Epoch 0, Batch 234, Loss: 0.337769
# Epoch 0, Batch 235, Loss: 0.430610
# Epoch 0, Batch 236, Loss: 0.221171
# Epoch 0, Batch 237, Loss: 0.306068
# Epoch 0, Batch 238, Loss: 0.458970
# Epoch 0, Batch 239, Loss: 0.352619
# Epoch 0, Batch 240, Loss: 0.393341
# Epoch 0, Batch 241, Loss: 0.246300
# Epoch 0, Batch 242, Loss: 0.560729
# Epoch 0, Batch 243, Loss: 0.273949
# Epoch 0, Batch 244, Loss: 0.238103
# Epoch 0, Batch 245, Loss: 0.349410
# Epoch 0, Batch 246, Loss: 0.459611
# Epoch 0, Batch 247, Loss: 0.619821
# Epoch 0, Batch 248, Loss: 0.540423
# Epoch 0, Batch 249, Loss: 0.185789
# Epoch 0, Batch 250, Loss: 0.376997
# Epoch 0, Batch 251, Loss: 0.394028
# Epoch 0, Batch 252, Loss: 0.374849
# Epoch 0, Batch 253, Loss: 0.361001
# Epoch 0, Batch 254, Loss: 0.373759
# Epoch 0, Batch 255, Loss: 0.405156
# Epoch 0, Batch 256, Loss: 0.140811
# Epoch 0, Batch 257, Loss: 0.281238
# Epoch 0, Batch 258, Loss: 0.263998
# Epoch 0, Batch 259, Loss: 0.394982
# Epoch 0, Batch 260, Loss: 0.263703
# Epoch 0, Batch 261, Loss: 0.213011
# Epoch 0, Batch 262, Loss: 0.380526
# Epoch 0, Batch 263, Loss: 0.395298
# Epoch 0, Batch 264, Loss: 0.559432
# Epoch 0, Batch 265, Loss: 0.357092
# Epoch 0, Batch 266, Loss: 0.332466
# Epoch 0, Batch 267, Loss: 0.238807
# Epoch 0, Batch 268, Loss: 0.542705
# Epoch 0, Batch 269, Loss: 0.315405
# Epoch 0, Batch 270, Loss: 0.312709
# Epoch 0, Batch 271, Loss: 0.405521
# Epoch 0, Batch 272, Loss: 0.268006
# Epoch 0, Batch 273, Loss: 0.486080
# Epoch 0, Batch 274, Loss: 0.255011
# Epoch 0, Batch 275, Loss: 0.204626
# Epoch 0, Batch 276, Loss: 0.189614
# Epoch 0, Batch 277, Loss: 0.114053
# Epoch 0, Batch 278, Loss: 0.391279
# Epoch 0, Batch 279, Loss: 0.528914
# Epoch 0, Batch 280, Loss: 0.229567
# Epoch 0, Batch 281, Loss: 0.190584
# Epoch 0, Batch 282, Loss: 0.356670
# Epoch 0, Batch 283, Loss: 0.224121
# Epoch 0, Batch 284, Loss: 0.439183
# Epoch 0, Batch 285, Loss: 0.467154
# Epoch 0, Batch 286, Loss: 0.149574
# Epoch 0, Batch 287, Loss: 0.313656
# Epoch 0, Batch 288, Loss: 0.441582
# Epoch 0, Batch 289, Loss: 0.345579
# Epoch 0, Batch 290, Loss: 0.138130
# Epoch 0, Batch 291, Loss: 0.597396
# Epoch 0, Batch 292, Loss: 0.232049
# Epoch 0, Batch 293, Loss: 0.281456
# Epoch 0, Batch 294, Loss: 0.432684
# Epoch 0, Batch 295, Loss: 0.234319
# Epoch 0, Batch 296, Loss: 0.311572
# Epoch 0, Batch 297, Loss: 0.453601
# Epoch 0, Batch 298, Loss: 0.233405
# Epoch 0, Batch 299, Loss: 0.473435
# Epoch 0, Batch 300, Loss: 0.350800
# Epoch 0, Batch 301, Loss: 0.252049
# Epoch 0, Batch 302, Loss: 0.168253
# Epoch 0, Batch 303, Loss: 0.252703
# Epoch 0, Batch 304, Loss: 0.304435
# Epoch 0, Batch 305, Loss: 0.355038
# Epoch 0, Batch 306, Loss: 0.226748
# Epoch 0, Batch 307, Loss: 0.769959
# Epoch 0, Batch 308, Loss: 0.333698
# Epoch 0, Batch 309, Loss: 0.206317
# Epoch 0, Batch 310, Loss: 0.398161
# Epoch 0, Batch 311, Loss: 0.382305
# Epoch 0, Batch 312, Loss: 0.490264
# Epoch 0, Batch 313, Loss: 0.253593
# Epoch 0, Batch 314, Loss: 0.205168
# Epoch 0, Batch 315, Loss: 0.327384
# Epoch 0, Batch 316, Loss: 0.291505
# Epoch 0, Batch 317, Loss: 0.660921
# Epoch 0, Batch 318, Loss: 0.633527
# Epoch 0, Batch 319, Loss: 0.213360
# Epoch 0, Batch 320, Loss: 0.467942
# Epoch 0, Batch 321, Loss: 0.418072
# Epoch 0, Batch 322, Loss: 0.203569
# Epoch 0, Batch 323, Loss: 0.392507
# Epoch 0, Batch 324, Loss: 0.538409
# Epoch 0, Batch 325, Loss: 0.547176
# Epoch 0, Batch 326, Loss: 0.152668
# Epoch 0, Batch 327, Loss: 0.488240
# Epoch 0, Batch 328, Loss: 0.500642
# Epoch 0, Batch 329, Loss: 0.818629
# Epoch 0, Batch 330, Loss: 0.281855
# Epoch 0, Batch 331, Loss: 0.233543
# Epoch 0, Batch 332, Loss: 0.133541
# Epoch 0, Batch 333, Loss: 0.170608
# Epoch 0, Batch 334, Loss: 0.480429
# Epoch 0, Batch 335, Loss: 0.198436
# Epoch 0, Batch 336, Loss: 0.525717
# Epoch 0, Batch 337, Loss: 0.462723
# Epoch 0, Batch 338, Loss: 0.358101
# Epoch 0, Batch 339, Loss: 0.552895
# Epoch 0, Batch 340, Loss: 0.549108
# Epoch 0, Batch 341, Loss: 0.526458
# Epoch 0, Batch 342, Loss: 0.453181
# Epoch 0, Batch 343, Loss: 0.404132
# Epoch 0, Batch 344, Loss: 0.229302
# Epoch 0, Batch 345, Loss: 0.580312
# Epoch 0, Batch 346, Loss: 0.448556
# Epoch 0, Batch 347, Loss: 0.226841
# Epoch 0, Batch 348, Loss: 0.215666
# Epoch 0, Batch 349, Loss: 0.208827
# Epoch 0, Batch 350, Loss: 0.217618
# Epoch 0, Batch 351, Loss: 0.380355
# Epoch 0, Batch 352, Loss: 0.403042
# Epoch 0, Batch 353, Loss: 0.253136
# Epoch 0, Batch 354, Loss: 0.222318
# Epoch 0, Batch 355, Loss: 0.104660
# Epoch 0, Batch 356, Loss: 0.350099
# Epoch 0, Batch 357, Loss: 0.323350
# Epoch 0, Batch 358, Loss: 0.365635
# Epoch 0, Batch 359, Loss: 0.119184
# Epoch 0, Batch 360, Loss: 0.372111
# Epoch 0, Batch 361, Loss: 0.220243
# Epoch 0, Batch 362, Loss: 0.305424
# Epoch 0, Batch 363, Loss: 0.123304
# Epoch 0, Batch 364, Loss: 0.269967
# Epoch 0, Batch 365, Loss: 0.256462
# Epoch 0, Batch 366, Loss: 0.242315
# Epoch 0, Batch 367, Loss: 0.314497
# Epoch 0, Batch 368, Loss: 0.298086
# Epoch 0, Batch 369, Loss: 0.533871
# Epoch 0, Batch 370, Loss: 0.350028
# Epoch 0, Batch 371, Loss: 0.213661
# Epoch 0, Batch 372, Loss: 0.484695
# Epoch 0, Batch 373, Loss: 0.322993
# Epoch 0, Batch 374, Loss: 0.309322
# Epoch 0, Batch 375, Loss: 0.137085
# Epoch 0, Batch 376, Loss: 0.320133
# Epoch 0, Batch 377, Loss: 0.138604
# Epoch 0, Batch 378, Loss: 0.214208
# Epoch 0, Batch 379, Loss: 0.347887
# Epoch 0, Batch 380, Loss: 0.445868
# Epoch 0, Batch 381, Loss: 0.225115
# Epoch 0, Batch 382, Loss: 0.218540
# Epoch 0, Batch 383, Loss: 0.413950
# Epoch 0, Batch 384, Loss: 0.108734
# Epoch 0, Batch 385, Loss: 0.230118
# Epoch 0, Batch 386, Loss: 0.259297
# Epoch 0, Batch 387, Loss: 0.433054
# Epoch 0, Batch 388, Loss: 0.211844
# Epoch 0, Batch 389, Loss: 0.519073
# Epoch 0, Batch 390, Loss: 0.160537
# Epoch 0, Batch 391, Loss: 0.325976
# Epoch 0, Batch 392, Loss: 0.149062
# Epoch 0, Batch 393, Loss: 0.344648
# Epoch 0, Batch 394, Loss: 0.320067
# Epoch 0, Batch 395, Loss: 0.267825
# Epoch 0, Batch 396, Loss: 0.501597
# Epoch 0, Batch 397, Loss: 0.271223
# Epoch 0, Batch 398, Loss: 0.199141
# Epoch 0, Batch 399, Loss: 0.319103
# Epoch 0, Batch 400, Loss: 0.316263
# Epoch 0, Batch 401, Loss: 0.403673
# Epoch 0, Batch 402, Loss: 0.312044
# Epoch 0, Batch 403, Loss: 0.563669
# Epoch 0, Batch 404, Loss: 0.373202
# Epoch 0, Batch 405, Loss: 0.347868
# Epoch 0, Batch 406, Loss: 0.214560
# Epoch 0, Batch 407, Loss: 0.222364
# Epoch 0, Batch 408, Loss: 0.139007
# Epoch 0, Batch 409, Loss: 0.166522
# Epoch 0, Batch 410, Loss: 0.099860
# Epoch 0, Batch 411, Loss: 0.208372
# Epoch 0, Batch 412, Loss: 0.189167
# Epoch 0, Batch 413, Loss: 0.340536
# Epoch 0, Batch 414, Loss: 0.287367
# Epoch 0, Batch 415, Loss: 0.532918
# Epoch 0, Batch 416, Loss: 0.513044
# Epoch 0, Batch 417, Loss: 0.130690
# Epoch 0, Batch 418, Loss: 0.330850
# Epoch 0, Batch 419, Loss: 0.177882
# Epoch 0, Batch 420, Loss: 0.458013
# Epoch 0, Batch 421, Loss: 0.415271
# Epoch 0, Batch 422, Loss: 0.325347
# Epoch 0, Batch 423, Loss: 0.277717
# Epoch 0, Batch 424, Loss: 0.166788
# Epoch 0, Batch 425, Loss: 0.198119
# Epoch 0, Batch 426, Loss: 0.424486
# Epoch 0, Batch 427, Loss: 0.091381
# Epoch 0, Batch 428, Loss: 0.175205
# Epoch 0, Batch 429, Loss: 0.184051
# Epoch 0, Batch 430, Loss: 0.600643
# Epoch 0, Batch 431, Loss: 0.342946
# Epoch 0, Batch 432, Loss: 0.301786
# Epoch 0, Batch 433, Loss: 0.317107
# Epoch 0, Batch 434, Loss: 0.240093
# Epoch 0, Batch 435, Loss: 0.212616
# Epoch 0, Batch 436, Loss: 0.122173
# Epoch 0, Batch 437, Loss: 0.180633
# Epoch 0, Batch 438, Loss: 0.246795
# Epoch 0, Batch 439, Loss: 0.387212
# Epoch 0, Batch 440, Loss: 0.278836
# Epoch 0, Batch 441, Loss: 0.276853
# Epoch 0, Batch 442, Loss: 0.397625
# Epoch 0, Batch 443, Loss: 0.525174
# Epoch 0, Batch 444, Loss: 0.208872
# Epoch 0, Batch 445, Loss: 0.253633
# Epoch 0, Batch 446, Loss: 0.404094
# Epoch 0, Batch 447, Loss: 0.424173
# Epoch 0, Batch 448, Loss: 0.197296
# Epoch 0, Batch 449, Loss: 0.300987
# Epoch 0, Batch 450, Loss: 0.248773
# Epoch 0, Batch 451, Loss: 0.371391
# Epoch 0, Batch 452, Loss: 0.224413
# Epoch 0, Batch 453, Loss: 0.208563
# Epoch 0, Batch 454, Loss: 0.179587
# Epoch 0, Batch 455, Loss: 0.500640
# Epoch 0, Batch 456, Loss: 0.402856
# Epoch 0, Batch 457, Loss: 0.510352
# Epoch 0, Batch 458, Loss: 0.203663
# Epoch 0, Batch 459, Loss: 0.177246
# Epoch 0, Batch 460, Loss: 0.363232
# Epoch 0, Batch 461, Loss: 0.279068
# Epoch 0, Batch 462, Loss: 0.105293
# Epoch 0, Batch 463, Loss: 0.375811
# Epoch 0, Batch 464, Loss: 0.313569
# Epoch 0, Batch 465, Loss: 0.189693
# Epoch 0, Batch 466, Loss: 0.595730
# Epoch 0, Batch 467, Loss: 0.219651
# Epoch 0, Batch 468, Loss: 0.439289
# Epoch 0, Batch 469, Loss: 0.241820
# Epoch 0, Batch 470, Loss: 0.140833
# Epoch 0, Batch 471, Loss: 0.316153
# Epoch 0, Batch 472, Loss: 0.287865
# Epoch 0, Batch 473, Loss: 0.365106
# Epoch 0, Batch 474, Loss: 0.273832
# Epoch 0, Batch 475, Loss: 0.186950
# Epoch 0, Batch 476, Loss: 0.075023
# Epoch 0, Batch 477, Loss: 0.364688
# Epoch 0, Batch 478, Loss: 0.118065
# Epoch 0, Batch 479, Loss: 0.121217
# Epoch 0, Batch 480, Loss: 0.321391
# Epoch 0, Batch 481, Loss: 0.348331
# Epoch 0, Batch 482, Loss: 0.472297
# Epoch 0, Batch 483, Loss: 0.182924
# Epoch 0, Batch 484, Loss: 0.385110
# Epoch 0, Batch 485, Loss: 0.379480
# Epoch 0, Batch 486, Loss: 0.083573
# Epoch 0, Batch 487, Loss: 0.283296
# Epoch 0, Batch 488, Loss: 0.318497
# Epoch 0, Batch 489, Loss: 0.093820
# Epoch 0, Batch 490, Loss: 0.211151
# Epoch 0, Batch 491, Loss: 0.217960
# Epoch 0, Batch 492, Loss: 0.111573
# Epoch 0, Batch 493, Loss: 0.196193
# Epoch 0, Batch 494, Loss: 0.409878
# Epoch 0, Batch 495, Loss: 0.233489
# Epoch 0, Batch 496, Loss: 0.133517
# Epoch 0, Batch 497, Loss: 0.336061
# Epoch 0, Batch 498, Loss: 0.195337
# Epoch 0, Batch 499, Loss: 0.464156
# Epoch 0, Batch 500, Loss: 0.377026
# Epoch 0, Batch 501, Loss: 0.092711
# Epoch 0, Batch 502, Loss: 0.261805
# Epoch 0, Batch 503, Loss: 0.372936
# Epoch 0, Batch 504, Loss: 0.251968
# Epoch 0, Batch 505, Loss: 0.695655
# Epoch 0, Batch 506, Loss: 0.166198
# Epoch 0, Batch 507, Loss: 0.213493
# Epoch 0, Batch 508, Loss: 0.390598
# Epoch 0, Batch 509, Loss: 0.537070
# Epoch 0, Batch 510, Loss: 0.779231
# Epoch 0, Batch 511, Loss: 0.133833
# Epoch 0, Batch 512, Loss: 0.294449
# Epoch 0, Batch 513, Loss: 0.270665
# Epoch 0, Batch 514, Loss: 0.120082
# Epoch 0, Batch 515, Loss: 0.351220
# Epoch 0, Batch 516, Loss: 0.531935
# Epoch 0, Batch 517, Loss: 0.256108
# Epoch 0, Batch 518, Loss: 0.078070
# Epoch 0, Batch 519, Loss: 0.256467
# Epoch 0, Batch 520, Loss: 0.229344
# Epoch 0, Batch 521, Loss: 0.219244
# Epoch 0, Batch 522, Loss: 0.336132
# Epoch 0, Batch 523, Loss: 0.345505
# Epoch 0, Batch 524, Loss: 0.366791
# Epoch 0, Batch 525, Loss: 0.384353
# Epoch 0, Batch 526, Loss: 0.123734
# Epoch 0, Batch 527, Loss: 0.271570
# Epoch 0, Batch 528, Loss: 0.308963
# Epoch 0, Batch 529, Loss: 0.457327
# Epoch 0, Batch 530, Loss: 0.265524
# Epoch 0, Batch 531, Loss: 0.168033
# Epoch 0, Batch 532, Loss: 0.380324
# Epoch 0, Batch 533, Loss: 0.459502
# Epoch 0, Batch 534, Loss: 0.246432
# Epoch 0, Batch 535, Loss: 0.580151
# Epoch 0, Batch 536, Loss: 0.402284
# Epoch 0, Batch 537, Loss: 0.300760
# Epoch 0, Batch 538, Loss: 0.170036
# Epoch 0, Batch 539, Loss: 0.361164
# Epoch 0, Batch 540, Loss: 0.272517
# Epoch 0, Batch 541, Loss: 0.212625
# Epoch 0, Batch 542, Loss: 0.418938
# Epoch 0, Batch 543, Loss: 0.269677
# Epoch 0, Batch 544, Loss: 0.367829
# Epoch 0, Batch 545, Loss: 0.291127
# Epoch 0, Batch 546, Loss: 0.458375
# Epoch 0, Batch 547, Loss: 0.274995
# Epoch 0, Batch 548, Loss: 0.198762
# Epoch 0, Batch 549, Loss: 0.276052
# Epoch 0, Batch 550, Loss: 0.192036
# Epoch 0, Batch 551, Loss: 0.378652
# Epoch 0, Batch 552, Loss: 0.499601
# Epoch 0, Batch 553, Loss: 0.470020
# Epoch 0, Batch 554, Loss: 0.291165
# Epoch 0, Batch 555, Loss: 0.344050
# Epoch 0, Batch 556, Loss: 0.507090
# Epoch 0, Batch 557, Loss: 0.210910
# Epoch 0, Batch 558, Loss: 0.169215
# Epoch 0, Batch 559, Loss: 0.109101
# Epoch 0, Batch 560, Loss: 0.418797
# Epoch 0, Batch 561, Loss: 0.099442
# Epoch 0, Batch 562, Loss: 0.237802
# Epoch 0, Batch 563, Loss: 0.584344
# Epoch 0, Batch 564, Loss: 0.201877
# Epoch 0, Batch 565, Loss: 0.532535
# Epoch 0, Batch 566, Loss: 0.218463
# Epoch 0, Batch 567, Loss: 0.991494
# Epoch 0, Batch 568, Loss: 0.392067
# Epoch 0, Batch 569, Loss: 0.447303
# Epoch 0, Batch 570, Loss: 0.376364
# Epoch 0, Batch 571, Loss: 0.279622
# Epoch 0, Batch 572, Loss: 0.250365
# Epoch 0, Batch 573, Loss: 0.672279
# Epoch 0, Batch 574, Loss: 0.283393
# Epoch 0, Batch 575, Loss: 0.347040
# Epoch 0, Batch 576, Loss: 0.430463
# Epoch 0, Batch 577, Loss: 0.297438
# Epoch 0, Batch 578, Loss: 0.399812
# Epoch 0, Batch 579, Loss: 0.557438
# Epoch 0, Batch 580, Loss: 0.250290
# Epoch 0, Batch 581, Loss: 0.322921
# Epoch 0, Batch 582, Loss: 0.392181
# Epoch 0, Batch 583, Loss: 0.289512
# Epoch 0, Batch 584, Loss: 0.254433
# Epoch 0, Batch 585, Loss: 0.212733
# Epoch 0, Batch 586, Loss: 0.355956
# Epoch 0, Batch 587, Loss: 0.269134
# Epoch 0, Batch 588, Loss: 0.115525
# Epoch 0, Batch 589, Loss: 0.282803
# Epoch 0, Batch 590, Loss: 0.172435
# Epoch 0, Batch 591, Loss: 0.190490
# Epoch 0, Batch 592, Loss: 0.593005
# Epoch 0, Batch 593, Loss: 0.223280
# Epoch 0, Batch 594, Loss: 0.207336
# Epoch 0, Batch 595, Loss: 0.155118
# Epoch 0, Batch 596, Loss: 0.220612
# Epoch 0, Batch 597, Loss: 0.354875
# Epoch 0, Batch 598, Loss: 0.278263
# Epoch 0, Batch 599, Loss: 0.213944
# Epoch 0, Batch 600, Loss: 0.098380
# Epoch 0, Batch 601, Loss: 0.109415
# Epoch 0, Batch 602, Loss: 0.133477
# Epoch 0, Batch 603, Loss: 0.403790
# Epoch 0, Batch 604, Loss: 0.056050
# Epoch 0, Batch 605, Loss: 0.152595
# Epoch 0, Batch 606, Loss: 0.423423
# Epoch 0, Batch 607, Loss: 0.150061
# Epoch 0, Batch 608, Loss: 0.259177
# Epoch 0, Batch 609, Loss: 0.234294
# Epoch 0, Batch 610, Loss: 0.357871
# Epoch 0, Batch 611, Loss: 0.218096
# Epoch 0, Batch 612, Loss: 0.219774
# Epoch 0, Batch 613, Loss: 0.246175
# Epoch 0, Batch 614, Loss: 0.346489
# Epoch 0, Batch 615, Loss: 0.293727
# Epoch 0, Batch 616, Loss: 0.162388
# Epoch 0, Batch 617, Loss: 0.189772
# Epoch 0, Batch 618, Loss: 0.124585
# Epoch 0, Batch 619, Loss: 0.086893
# Epoch 0, Batch 620, Loss: 0.148091
# Epoch 0, Batch 621, Loss: 0.356080
# Epoch 0, Batch 622, Loss: 0.328301
# Epoch 0, Batch 623, Loss: 0.260350
# Epoch 0, Batch 624, Loss: 0.210360
# Epoch 0, Batch 625, Loss: 0.203175
# Epoch 0, Batch 626, Loss: 0.489501
# Epoch 0, Batch 627, Loss: 0.197439
# Epoch 0, Batch 628, Loss: 0.277698
# Epoch 0, Batch 629, Loss: 0.233435
# Epoch 0, Batch 630, Loss: 0.240122
# Epoch 0, Batch 631, Loss: 0.196965
# Epoch 0, Batch 632, Loss: 0.193501
# Epoch 0, Batch 633, Loss: 0.304086
# Epoch 0, Batch 634, Loss: 0.186114
# Epoch 0, Batch 635, Loss: 0.322464
# Epoch 0, Batch 636, Loss: 0.164432
# Epoch 0, Batch 637, Loss: 0.296913
# Epoch 0, Batch 638, Loss: 0.457440
# Epoch 0, Batch 639, Loss: 0.088133
# Epoch 0, Batch 640, Loss: 0.164571
# Epoch 0, Batch 641, Loss: 0.189579
# Epoch 0, Batch 642, Loss: 0.053680
# Epoch 0, Batch 643, Loss: 0.209356
# Epoch 0, Batch 644, Loss: 0.386947
# Epoch 0, Batch 645, Loss: 0.405676
# Epoch 0, Batch 646, Loss: 0.351349
# Epoch 0, Batch 647, Loss: 0.472883
# Epoch 0, Batch 648, Loss: 0.058979
# Epoch 0, Batch 649, Loss: 0.561265
# Epoch 0, Batch 650, Loss: 0.166036
# Epoch 0, Batch 651, Loss: 0.361232
# Epoch 0, Batch 652, Loss: 0.182618
# Epoch 0, Batch 653, Loss: 0.575193
# Epoch 0, Batch 654, Loss: 0.184059
# Epoch 0, Batch 655, Loss: 0.168515
# Epoch 0, Batch 656, Loss: 0.368686
# Epoch 0, Batch 657, Loss: 0.369550
# Epoch 0, Batch 658, Loss: 0.149777
# Epoch 0, Batch 659, Loss: 0.382171
# Epoch 0, Batch 660, Loss: 0.111823
# Epoch 0, Batch 661, Loss: 0.114993
# Epoch 0, Batch 662, Loss: 0.321246
# Epoch 0, Batch 663, Loss: 0.396137
# Epoch 0, Batch 664, Loss: 0.237992
# Epoch 0, Batch 665, Loss: 0.402973
# Epoch 0, Batch 666, Loss: 0.287939
# Epoch 0, Batch 667, Loss: 0.215408
# Epoch 0, Batch 668, Loss: 0.130828
# Epoch 0, Batch 669, Loss: 0.188610
# Epoch 0, Batch 670, Loss: 0.150788
# Epoch 0, Batch 671, Loss: 0.173491
# Epoch 0, Batch 672, Loss: 0.433771
# Epoch 0, Batch 673, Loss: 0.215016
# Epoch 0, Batch 674, Loss: 0.178699
# Epoch 0, Batch 675, Loss: 0.185885
# Epoch 0, Batch 676, Loss: 0.309275
# Epoch 0, Batch 677, Loss: 0.166967
# Epoch 0, Batch 678, Loss: 0.374577
# Epoch 0, Batch 679, Loss: 0.173675
# Epoch 0, Batch 680, Loss: 0.360649
# Epoch 0, Batch 681, Loss: 0.479843
# Epoch 0, Batch 682, Loss: 0.300261
# Epoch 0, Batch 683, Loss: 0.299651
# Epoch 0, Batch 684, Loss: 0.109464
# Epoch 0, Batch 685, Loss: 0.381673
# Epoch 0, Batch 686, Loss: 0.254458
# Epoch 0, Batch 687, Loss: 0.219806
# Epoch 0, Batch 688, Loss: 0.389388
# Epoch 0, Batch 689, Loss: 0.171659
# Epoch 0, Batch 690, Loss: 0.153448
# Epoch 0, Batch 691, Loss: 0.122415
# Epoch 0, Batch 692, Loss: 0.188923
# Epoch 0, Batch 693, Loss: 0.230583
# Epoch 0, Batch 694, Loss: 0.217475
# Epoch 0, Batch 695, Loss: 0.288677
# Epoch 0, Batch 696, Loss: 0.227500
# Epoch 0, Batch 697, Loss: 0.152133
# Epoch 0, Batch 698, Loss: 0.210865
# Epoch 0, Batch 699, Loss: 0.207150
# Epoch 0, Batch 700, Loss: 0.203896
# Epoch 0, Batch 701, Loss: 0.246070
# Epoch 0, Batch 702, Loss: 0.187098
# Epoch 0, Batch 703, Loss: 0.199669
# Epoch 0, Batch 704, Loss: 0.126876
# Epoch 0, Batch 705, Loss: 0.228712
# Epoch 0, Batch 706, Loss: 0.264281
# Epoch 0, Batch 707, Loss: 0.186976
# Epoch 0, Batch 708, Loss: 0.329690
# Epoch 0, Batch 709, Loss: 0.199175
# Epoch 0, Batch 710, Loss: 0.464396
# Epoch 0, Batch 711, Loss: 0.233758
# Epoch 0, Batch 712, Loss: 0.189594
# Epoch 0, Batch 713, Loss: 0.117955
# Epoch 0, Batch 714, Loss: 0.090850
# Epoch 0, Batch 715, Loss: 0.153101
# Epoch 0, Batch 716, Loss: 0.165890
# Epoch 0, Batch 717, Loss: 0.059894
# Epoch 0, Batch 718, Loss: 0.310759
# Epoch 0, Batch 719, Loss: 0.188988
# Epoch 0, Batch 720, Loss: 0.347921
# Epoch 0, Batch 721, Loss: 0.370450
# Epoch 0, Batch 722, Loss: 0.117041
# Epoch 0, Batch 723, Loss: 0.092240
# Epoch 0, Batch 724, Loss: 0.165215
# Epoch 0, Batch 725, Loss: 0.108850
# Epoch 0, Batch 726, Loss: 0.317446
# Epoch 0, Batch 727, Loss: 0.301601
# Epoch 0, Batch 728, Loss: 0.444697
# Epoch 0, Batch 729, Loss: 0.450552
# Epoch 0, Batch 730, Loss: 0.463953
# Epoch 0, Batch 731, Loss: 0.205394
# Epoch 0, Batch 732, Loss: 0.310989
# Epoch 0, Batch 733, Loss: 0.106656
# Epoch 0, Batch 734, Loss: 0.067509
# Epoch 0, Batch 735, Loss: 0.075051
# Epoch 0, Batch 736, Loss: 0.337623
# Epoch 0, Batch 737, Loss: 0.193190
# Epoch 0, Batch 738, Loss: 0.261766
# Epoch 0, Batch 739, Loss: 0.134336
# Epoch 0, Batch 740, Loss: 0.391678
# Epoch 0, Batch 741, Loss: 0.147715
# Epoch 0, Batch 742, Loss: 0.172834
# Epoch 0, Batch 743, Loss: 0.448923
# Epoch 0, Batch 744, Loss: 0.292508
# Epoch 0, Batch 745, Loss: 0.100295
# Epoch 0, Batch 746, Loss: 0.391189
# Epoch 0, Batch 747, Loss: 0.649264
# Epoch 0, Batch 748, Loss: 0.194046
# Epoch 0, Batch 749, Loss: 0.312236
# Epoch 0, Batch 750, Loss: 0.120951
# Epoch 0, Batch 751, Loss: 0.130060
# Epoch 0, Batch 752, Loss: 0.142818
# Epoch 0, Batch 753, Loss: 0.198485
# Epoch 0, Batch 754, Loss: 0.105958
# Epoch 0, Batch 755, Loss: 0.171209
# Epoch 0, Batch 756, Loss: 0.121279
# Epoch 0, Batch 757, Loss: 0.332568
# Epoch 0, Batch 758, Loss: 0.194325
# Epoch 0, Batch 759, Loss: 0.357533
# Epoch 0, Batch 760, Loss: 0.263341
# Epoch 0, Batch 761, Loss: 0.157176
# Epoch 0, Batch 762, Loss: 0.274439
# Epoch 0, Batch 763, Loss: 0.158075
# Epoch 0, Batch 764, Loss: 0.133851
# Epoch 0, Batch 765, Loss: 0.402442
# Epoch 0, Batch 766, Loss: 0.277114
# Epoch 0, Batch 767, Loss: 0.146847
# Epoch 0, Batch 768, Loss: 0.206715
# Epoch 0, Batch 769, Loss: 0.174378
# Epoch 0, Batch 770, Loss: 0.640062
# Epoch 0, Batch 771, Loss: 0.178523
# Epoch 0, Batch 772, Loss: 0.143440
# Epoch 0, Batch 773, Loss: 0.211609
# Epoch 0, Batch 774, Loss: 0.118908
# Epoch 0, Batch 775, Loss: 0.081698
# Epoch 0, Batch 776, Loss: 0.269512
# Epoch 0, Batch 777, Loss: 0.153573
# Epoch 0, Batch 778, Loss: 0.269330
# Epoch 0, Batch 779, Loss: 0.195849
# Epoch 0, Batch 780, Loss: 0.200061
# Epoch 0, Batch 781, Loss: 0.155446
# Epoch 0, Batch 782, Loss: 0.168923
# Epoch 0, Batch 783, Loss: 0.429090
# Epoch 0, Batch 784, Loss: 0.123236
# Epoch 0, Batch 785, Loss: 0.179703
# Epoch 0, Batch 786, Loss: 0.520374
# Epoch 0, Batch 787, Loss: 0.122111
# Epoch 0, Batch 788, Loss: 0.243641
# Epoch 0, Batch 789, Loss: 0.139426
# Epoch 0, Batch 790, Loss: 0.381837
# Epoch 0, Batch 791, Loss: 0.116882
# Epoch 0, Batch 792, Loss: 0.189427
# Epoch 0, Batch 793, Loss: 0.127322
# Epoch 0, Batch 794, Loss: 0.281611
# Epoch 0, Batch 795, Loss: 0.521004
# Epoch 0, Batch 796, Loss: 0.323416
# Epoch 0, Batch 797, Loss: 0.215326
# Epoch 0, Batch 798, Loss: 0.218937
# Epoch 0, Batch 799, Loss: 0.308346
# Epoch 0, Batch 800, Loss: 0.195513
# Epoch 0, Batch 801, Loss: 0.197720
# Epoch 0, Batch 802, Loss: 0.145450
# Epoch 0, Batch 803, Loss: 0.219079
# Epoch 0, Batch 804, Loss: 0.184197
# Epoch 0, Batch 805, Loss: 0.181633
# Epoch 0, Batch 806, Loss: 0.138413
# Epoch 0, Batch 807, Loss: 0.321590
# Epoch 0, Batch 808, Loss: 0.097175
# Epoch 0, Batch 809, Loss: 0.223118
# Epoch 0, Batch 810, Loss: 0.282695
# Epoch 0, Batch 811, Loss: 0.194637
# Epoch 0, Batch 812, Loss: 0.217408
# Epoch 0, Batch 813, Loss: 0.238790
# Epoch 0, Batch 814, Loss: 0.358978
# Epoch 0, Batch 815, Loss: 0.122086
# Epoch 0, Batch 816, Loss: 0.237800
# Epoch 0, Batch 817, Loss: 0.248625
# Epoch 0, Batch 818, Loss: 0.312753
# Epoch 0, Batch 819, Loss: 0.163811
# Epoch 0, Batch 820, Loss: 0.224403
# Epoch 0, Batch 821, Loss: 0.490324
# Epoch 0, Batch 822, Loss: 0.196421
# Epoch 0, Batch 823, Loss: 0.499521
# Epoch 0, Batch 824, Loss: 0.483818
# Epoch 0, Batch 825, Loss: 0.162044
# Epoch 0, Batch 826, Loss: 0.408576
# Epoch 0, Batch 827, Loss: 0.195841
# Epoch 0, Batch 828, Loss: 0.138509
# Epoch 0, Batch 829, Loss: 0.093285
# Epoch 0, Batch 830, Loss: 0.209833
# Epoch 0, Batch 831, Loss: 0.317814
# Epoch 0, Batch 832, Loss: 0.213915
# Epoch 0, Batch 833, Loss: 0.119390
# Epoch 0, Batch 834, Loss: 0.208785
# Epoch 0, Batch 835, Loss: 0.199621
# Epoch 0, Batch 836, Loss: 0.331471
# Epoch 0, Batch 837, Loss: 0.260824
# Epoch 0, Batch 838, Loss: 0.101813
# Epoch 0, Batch 839, Loss: 0.411007
# Epoch 0, Batch 840, Loss: 0.147731
# Epoch 0, Batch 841, Loss: 0.513191
# Epoch 0, Batch 842, Loss: 0.283001
# Epoch 0, Batch 843, Loss: 0.227321
# Epoch 0, Batch 844, Loss: 0.321374
# Epoch 0, Batch 845, Loss: 0.093158
# Epoch 0, Batch 846, Loss: 0.454209
# Epoch 0, Batch 847, Loss: 0.397226
# Epoch 0, Batch 848, Loss: 0.311631
# Epoch 0, Batch 849, Loss: 0.389088
# Epoch 0, Batch 850, Loss: 0.266899
# Epoch 0, Batch 851, Loss: 0.296808
# Epoch 0, Batch 852, Loss: 0.075396
# Epoch 0, Batch 853, Loss: 0.511241
# Epoch 0, Batch 854, Loss: 0.155083
# Epoch 0, Batch 855, Loss: 0.277186
# Epoch 0, Batch 856, Loss: 0.110158
# Epoch 0, Batch 857, Loss: 0.333924
# Epoch 0, Batch 858, Loss: 0.080870
# Epoch 0, Batch 859, Loss: 0.086965
# Epoch 0, Batch 860, Loss: 0.106027
# Epoch 0, Batch 861, Loss: 0.350255
# Epoch 0, Batch 862, Loss: 0.271488
# Epoch 0, Batch 863, Loss: 0.407921
# Epoch 0, Batch 864, Loss: 0.148321
# Epoch 0, Batch 865, Loss: 0.357805
# Epoch 0, Batch 866, Loss: 0.134150
# Epoch 0, Batch 867, Loss: 0.209987
# Epoch 0, Batch 868, Loss: 0.273749
# Epoch 0, Batch 869, Loss: 0.133774
# Epoch 0, Batch 870, Loss: 0.131536
# Epoch 0, Batch 871, Loss: 0.321445
# Epoch 0, Batch 872, Loss: 0.182779
# Epoch 0, Batch 873, Loss: 0.244119
# Epoch 0, Batch 874, Loss: 0.201257
# Epoch 0, Batch 875, Loss: 0.118912
# Epoch 0, Batch 876, Loss: 0.044086
# Epoch 0, Batch 877, Loss: 0.183802
# Epoch 0, Batch 878, Loss: 0.133347
# Epoch 0, Batch 879, Loss: 0.143251
# Epoch 0, Batch 880, Loss: 0.293393
# Epoch 0, Batch 881, Loss: 0.378152
# Epoch 0, Batch 882, Loss: 0.332666
# Epoch 0, Batch 883, Loss: 0.172821
# Epoch 0, Batch 884, Loss: 0.355077
# Epoch 0, Batch 885, Loss: 0.089051
# Epoch 0, Batch 886, Loss: 0.239287
# Epoch 0, Batch 887, Loss: 0.265154
# Epoch 0, Batch 888, Loss: 0.101937
# Epoch 0, Batch 889, Loss: 0.277582
# Epoch 0, Batch 890, Loss: 0.127091
# Epoch 0, Batch 891, Loss: 0.152877
# Epoch 0, Batch 892, Loss: 0.333765
# Epoch 0, Batch 893, Loss: 0.192333
# Epoch 0, Batch 894, Loss: 0.077697
# Epoch 0, Batch 895, Loss: 0.245523
# Epoch 0, Batch 896, Loss: 0.213885
# Epoch 0, Batch 897, Loss: 0.327812
# Epoch 0, Batch 898, Loss: 0.183596
# Epoch 0, Batch 899, Loss: 0.284154
# Epoch 0, Batch 900, Loss: 0.047006
# Epoch 0, Batch 901, Loss: 0.451312
# Epoch 0, Batch 902, Loss: 0.288441
# Epoch 0, Batch 903, Loss: 0.098848
# Epoch 0, Batch 904, Loss: 0.147905
# Epoch 0, Batch 905, Loss: 0.280041
# Epoch 0, Batch 906, Loss: 0.059498
# Epoch 0, Batch 907, Loss: 0.172884
# Epoch 0, Batch 908, Loss: 0.129823
# Epoch 0, Batch 909, Loss: 0.369135
# Epoch 0, Batch 910, Loss: 0.429444
# Epoch 0, Batch 911, Loss: 0.279188
# Epoch 0, Batch 912, Loss: 0.353166
# Epoch 0, Batch 913, Loss: 0.074252
# Epoch 0, Batch 914, Loss: 0.419940
# Epoch 0, Batch 915, Loss: 0.261075
# Epoch 0, Batch 916, Loss: 0.131103
# Epoch 0, Batch 917, Loss: 0.132224
# Epoch 0, Batch 918, Loss: 0.133502
# Epoch 0, Batch 919, Loss: 0.213645
# Epoch 0, Batch 920, Loss: 0.160869
# Epoch 0, Batch 921, Loss: 0.080504
# Epoch 0, Batch 922, Loss: 0.286854
# Epoch 0, Batch 923, Loss: 0.194438
# Epoch 0, Batch 924, Loss: 0.097609
# Epoch 0, Batch 925, Loss: 0.090940
# Epoch 0, Batch 926, Loss: 0.231138
# Epoch 0, Batch 927, Loss: 0.336860
# Epoch 0, Batch 928, Loss: 0.084618
# Epoch 0, Batch 929, Loss: 0.353592
# Epoch 0, Batch 930, Loss: 0.076465
# Epoch 0, Batch 931, Loss: 0.158512
# Epoch 0, Batch 932, Loss: 0.238853
# Epoch 0, Batch 933, Loss: 0.157781
# Epoch 0, Batch 934, Loss: 0.300849
# Epoch 0, Batch 935, Loss: 0.462302
# Epoch 0, Batch 936, Loss: 0.528624
# Epoch 0, Batch 937, Loss: 0.142298
# Epoch 0, Batch 938, Loss: 0.089018
# Epoch 0, Batch 939, Loss: 0.235317
# Epoch 0, Batch 940, Loss: 0.236028
# Epoch 0, Batch 941, Loss: 0.183256
# Epoch 0, Batch 942, Loss: 0.282048
# Epoch 0, Batch 943, Loss: 0.164204
# Epoch 0, Batch 944, Loss: 0.079352
# Epoch 0, Batch 945, Loss: 0.191554
# Epoch 0, Batch 946, Loss: 0.322995
# Epoch 0, Batch 947, Loss: 0.472692
# Epoch 0, Batch 948, Loss: 0.094498
# Epoch 0, Batch 949, Loss: 0.289303
# Epoch 0, Batch 950, Loss: 0.200384
# Epoch 0, Batch 951, Loss: 0.363267
# Epoch 0, Batch 952, Loss: 0.132219
# Epoch 0, Batch 953, Loss: 0.344062
# Epoch 0, Batch 954, Loss: 0.162927
# Epoch 0, Batch 955, Loss: 0.368379
# Epoch 0, Batch 956, Loss: 0.172870
# Epoch 0, Batch 957, Loss: 0.572989
# Epoch 0, Batch 958, Loss: 0.095788
# Epoch 0, Batch 959, Loss: 0.408238
# Epoch 0, Batch 960, Loss: 0.360749
# Epoch 0, Batch 961, Loss: 0.264966
# Epoch 0, Batch 962, Loss: 0.078916
# Epoch 0, Batch 963, Loss: 0.296251
# Epoch 0, Batch 964, Loss: 0.130703
# Epoch 0, Batch 965, Loss: 0.432525
# Epoch 0, Batch 966, Loss: 0.232675
# Epoch 0, Batch 967, Loss: 0.053958
# Epoch 0, Batch 968, Loss: 0.161518
# Epoch 0, Batch 969, Loss: 0.215940
# Epoch 0, Batch 970, Loss: 0.101607
# Epoch 0, Batch 971, Loss: 0.304391
# Epoch 0, Batch 972, Loss: 0.099396
# Epoch 0, Batch 973, Loss: 0.138832
# Epoch 0, Batch 974, Loss: 0.261892
# Epoch 0, Batch 975, Loss: 0.137658
# Epoch 0, Batch 976, Loss: 0.523784
# Epoch 0, Batch 977, Loss: 0.239073
# Epoch 0, Batch 978, Loss: 0.216661
# Epoch 0, Batch 979, Loss: 0.146808
# Epoch 0, Batch 980, Loss: 0.104612
# Epoch 0, Batch 981, Loss: 0.533964
# Epoch 0, Batch 982, Loss: 0.396737
# Epoch 0, Batch 983, Loss: 0.126759
# Epoch 0, Batch 984, Loss: 0.291038
# Epoch 0, Batch 985, Loss: 0.473895
# Epoch 0, Batch 986, Loss: 0.147095
# Epoch 0, Batch 987, Loss: 0.102581
# Epoch 0, Batch 988, Loss: 0.096009
# Epoch 0, Batch 989, Loss: 0.067111
# Epoch 0, Batch 990, Loss: 0.097315
# Epoch 0, Batch 991, Loss: 0.415808
# Epoch 0, Batch 992, Loss: 0.259573
# Epoch 0, Batch 993, Loss: 0.138198
# Epoch 0, Batch 994, Loss: 0.181652
# Epoch 0, Batch 995, Loss: 0.286708
# Epoch 0, Batch 996, Loss: 0.147670
# Epoch 0, Batch 997, Loss: 0.365641
# Epoch 0, Batch 998, Loss: 0.145463
# Epoch 0, Batch 999, Loss: 0.166587
# Epoch 0, Batch 1000, Loss: 0.155845
# Epoch 0, Batch 1001, Loss: 0.185493
# Epoch 0, Batch 1002, Loss: 0.088574
# Epoch 0, Batch 1003, Loss: 0.162225
# Epoch 0, Batch 1004, Loss: 0.121931
# Epoch 0, Batch 1005, Loss: 0.155899
# Epoch 0, Batch 1006, Loss: 0.122864
# Epoch 0, Batch 1007, Loss: 0.230801
# Epoch 0, Batch 1008, Loss: 0.348283
# Epoch 0, Batch 1009, Loss: 0.137157
# Epoch 0, Batch 1010, Loss: 0.203447
# Epoch 0, Batch 1011, Loss: 0.285532
# Epoch 0, Batch 1012, Loss: 0.237808
# Epoch 0, Batch 1013, Loss: 0.245265
# Epoch 0, Batch 1014, Loss: 0.108539
# Epoch 0, Batch 1015, Loss: 0.241782
# Epoch 0, Batch 1016, Loss: 0.214863
# Epoch 0, Batch 1017, Loss: 0.338992
# Epoch 0, Batch 1018, Loss: 0.225017
# Epoch 0, Batch 1019, Loss: 0.140908
# Epoch 0, Batch 1020, Loss: 0.168685
# Epoch 0, Batch 1021, Loss: 0.174845
# Epoch 0, Batch 1022, Loss: 0.065573
# Epoch 0, Batch 1023, Loss: 0.248859
# Epoch 0, Batch 1024, Loss: 0.068369
# Epoch 0, Batch 1025, Loss: 0.214953
# Epoch 0, Batch 1026, Loss: 0.240886
# Epoch 0, Batch 1027, Loss: 0.125848
# Epoch 0, Batch 1028, Loss: 0.085239
# Epoch 0, Batch 1029, Loss: 0.396820
# Epoch 0, Batch 1030, Loss: 0.352832
# Epoch 0, Batch 1031, Loss: 0.169960
# Epoch 0, Batch 1032, Loss: 0.165532
# Epoch 0, Batch 1033, Loss: 0.266779
# Epoch 0, Batch 1034, Loss: 0.239531
# Epoch 0, Batch 1035, Loss: 0.162140
# Epoch 0, Batch 1036, Loss: 0.293253
# Epoch 0, Batch 1037, Loss: 0.087603
# Epoch 0, Batch 1038, Loss: 0.339853
# Epoch 0, Batch 1039, Loss: 0.070424
# Epoch 0, Batch 1040, Loss: 0.220078
# Epoch 0, Batch 1041, Loss: 0.281418
# Epoch 0, Batch 1042, Loss: 0.087478
# Epoch 0, Batch 1043, Loss: 0.157367
# Epoch 0, Batch 1044, Loss: 0.334960
# Epoch 0, Batch 1045, Loss: 0.203902
# Epoch 0, Batch 1046, Loss: 0.078808
# Epoch 0, Batch 1047, Loss: 0.213903
# Epoch 0, Batch 1048, Loss: 0.516209
# Epoch 0, Batch 1049, Loss: 0.171603
# Epoch 0, Batch 1050, Loss: 0.246495
# Epoch 0, Batch 1051, Loss: 0.392105
# Epoch 0, Batch 1052, Loss: 0.176855
# Epoch 0, Batch 1053, Loss: 0.158894
# Epoch 0, Batch 1054, Loss: 0.308663
# Epoch 0, Batch 1055, Loss: 0.253276
# Epoch 0, Batch 1056, Loss: 0.062702
# Epoch 0, Batch 1057, Loss: 0.080332
# Epoch 0, Batch 1058, Loss: 0.236874
# Epoch 0, Batch 1059, Loss: 0.477257
# Epoch 0, Batch 1060, Loss: 0.054672
# Epoch 0, Batch 1061, Loss: 0.196318
# Epoch 0, Batch 1062, Loss: 0.444191
# Epoch 0, Batch 1063, Loss: 0.737703
# Epoch 0, Batch 1064, Loss: 0.099873
# Epoch 0, Batch 1065, Loss: 0.103041
# Epoch 0, Batch 1066, Loss: 0.357281
# Epoch 0, Batch 1067, Loss: 0.178494
# Epoch 0, Batch 1068, Loss: 0.070544
# Epoch 0, Batch 1069, Loss: 0.173944
# Epoch 0, Batch 1070, Loss: 0.086017
# Epoch 0, Batch 1071, Loss: 0.149506
# Epoch 0, Batch 1072, Loss: 0.058612
# Epoch 0, Batch 1073, Loss: 0.105532
# Epoch 0, Batch 1074, Loss: 0.187898
# Epoch 0, Batch 1075, Loss: 0.394478
# Epoch 0, Batch 1076, Loss: 0.200698
# Epoch 0, Batch 1077, Loss: 0.220226
# Epoch 0, Batch 1078, Loss: 0.119454
# Epoch 0, Batch 1079, Loss: 0.338678
# Epoch 0, Batch 1080, Loss: 0.149442
# Epoch 0, Batch 1081, Loss: 0.346975
# Epoch 0, Batch 1082, Loss: 0.218343
# Epoch 0, Batch 1083, Loss: 0.122217
# Epoch 0, Batch 1084, Loss: 0.109245
# Epoch 0, Batch 1085, Loss: 0.139623
# Epoch 0, Batch 1086, Loss: 0.169452
# Epoch 0, Batch 1087, Loss: 0.143423
# Epoch 0, Batch 1088, Loss: 0.068728
# Epoch 0, Batch 1089, Loss: 0.150115
# Epoch 0, Batch 1090, Loss: 0.232100
# Epoch 0, Batch 1091, Loss: 0.128794
# Epoch 0, Batch 1092, Loss: 0.100273
# Epoch 0, Batch 1093, Loss: 0.153472
# Epoch 0, Batch 1094, Loss: 0.376593
# Epoch 0, Batch 1095, Loss: 0.128552
# Epoch 0, Batch 1096, Loss: 0.561983
# Epoch 0, Batch 1097, Loss: 0.194117
# Epoch 0, Batch 1098, Loss: 0.317807
# Epoch 0, Batch 1099, Loss: 0.198401
# Epoch 0, Batch 1100, Loss: 0.173578
# Epoch 0, Batch 1101, Loss: 0.090865
# Epoch 0, Batch 1102, Loss: 0.276801
# Epoch 0, Batch 1103, Loss: 0.177497
# Epoch 0, Batch 1104, Loss: 0.209367
# Epoch 0, Batch 1105, Loss: 0.235721
# Epoch 0, Batch 1106, Loss: 0.569627
# Epoch 0, Batch 1107, Loss: 0.097641
# Epoch 0, Batch 1108, Loss: 0.126159
# Epoch 0, Batch 1109, Loss: 0.111228
# Epoch 0, Batch 1110, Loss: 0.103006
# Epoch 0, Batch 1111, Loss: 0.182347
# Epoch 0, Batch 1112, Loss: 0.267633
# Epoch 0, Batch 1113, Loss: 0.114460
# Epoch 0, Batch 1114, Loss: 0.265238
# Epoch 0, Batch 1115, Loss: 0.129487
# Epoch 0, Batch 1116, Loss: 0.127565
# Epoch 0, Batch 1117, Loss: 0.115035
# Epoch 0, Batch 1118, Loss: 0.512994
# Epoch 0, Batch 1119, Loss: 0.183804
# Epoch 0, Batch 1120, Loss: 0.277334
# Epoch 0, Batch 1121, Loss: 0.399357
# Epoch 0, Batch 1122, Loss: 0.654236
# Epoch 0, Batch 1123, Loss: 0.273484
# Epoch 0, Batch 1124, Loss: 0.237284
# Epoch 0, Batch 1125, Loss: 0.401931
# Epoch 0, Batch 1126, Loss: 0.151368
# Epoch 0, Batch 1127, Loss: 0.079194
# Epoch 0, Batch 1128, Loss: 0.046163
# Epoch 0, Batch 1129, Loss: 0.143127
# Epoch 0, Batch 1130, Loss: 0.342376
# Epoch 0, Batch 1131, Loss: 0.143946
# Epoch 0, Batch 1132, Loss: 0.042387
# Epoch 0, Batch 1133, Loss: 0.125564
# Epoch 0, Batch 1134, Loss: 0.376793
# Epoch 0, Batch 1135, Loss: 0.047013
# Epoch 0, Batch 1136, Loss: 0.148263
# Epoch 0, Batch 1137, Loss: 0.168561
# Epoch 0, Batch 1138, Loss: 0.575891
# Epoch 0, Batch 1139, Loss: 0.220221
# Epoch 0, Batch 1140, Loss: 0.237454
# Epoch 0, Batch 1141, Loss: 0.207767
# Epoch 0, Batch 1142, Loss: 0.147182
# Epoch 0, Batch 1143, Loss: 0.178746
# Epoch 0, Batch 1144, Loss: 0.210125
# Epoch 0, Batch 1145, Loss: 0.242565
# Epoch 0, Batch 1146, Loss: 0.258292
# Epoch 0, Batch 1147, Loss: 0.134147
# Epoch 0, Batch 1148, Loss: 0.230890
# Epoch 0, Batch 1149, Loss: 0.251222
# Epoch 0, Batch 1150, Loss: 0.184194
# Epoch 0, Batch 1151, Loss: 0.051771
# Epoch 0, Batch 1152, Loss: 0.160492
# Epoch 0, Batch 1153, Loss: 0.138751
# Epoch 0, Batch 1154, Loss: 0.187155
# Epoch 0, Batch 1155, Loss: 0.452606
# Epoch 0, Batch 1156, Loss: 0.299313
# Epoch 0, Batch 1157, Loss: 0.319551
# Epoch 0, Batch 1158, Loss: 0.129721
# Epoch 0, Batch 1159, Loss: 0.176323
# Epoch 0, Batch 1160, Loss: 0.166923
# Epoch 0, Batch 1161, Loss: 0.180093
# Epoch 0, Batch 1162, Loss: 0.277546
# Epoch 0, Batch 1163, Loss: 0.125551
# Epoch 0, Batch 1164, Loss: 0.107116
# Epoch 0, Batch 1165, Loss: 0.057539
# Epoch 0, Batch 1166, Loss: 0.081028
# Epoch 0, Batch 1167, Loss: 0.248186
# Epoch 0, Batch 1168, Loss: 0.093795
# Epoch 0, Batch 1169, Loss: 0.141860
# Epoch 0, Batch 1170, Loss: 0.243328
# Epoch 0, Batch 1171, Loss: 0.222096
# Epoch 0, Batch 1172, Loss: 0.112417
# Epoch 0, Batch 1173, Loss: 0.187110
# Epoch 0, Batch 1174, Loss: 0.123172
# Epoch 0, Batch 1175, Loss: 0.166954
# Epoch 0, Batch 1176, Loss: 0.086271
# Epoch 0, Batch 1177, Loss: 0.083964
# Epoch 0, Batch 1178, Loss: 0.057328
# Epoch 0, Batch 1179, Loss: 0.156441
# Epoch 0, Batch 1180, Loss: 0.208594
# Epoch 0, Batch 1181, Loss: 0.095091
# Epoch 0, Batch 1182, Loss: 0.131274
# Epoch 0, Batch 1183, Loss: 0.232740
# Epoch 0, Batch 1184, Loss: 0.626553
# Epoch 0, Batch 1185, Loss: 0.140605
# Epoch 0, Batch 1186, Loss: 0.279650
# Epoch 0, Batch 1187, Loss: 0.181121
# Epoch 0, Batch 1188, Loss: 0.086462
# Epoch 0, Batch 1189, Loss: 0.349099
# Epoch 0, Batch 1190, Loss: 0.325011
# Epoch 0, Batch 1191, Loss: 0.220420
# Epoch 0, Batch 1192, Loss: 0.129575
# Epoch 0, Batch 1193, Loss: 0.214873
# Epoch 0, Batch 1194, Loss: 0.356430
# Epoch 0, Batch 1195, Loss: 0.262475
# Epoch 0, Batch 1196, Loss: 0.081664
# Epoch 0, Batch 1197, Loss: 0.064548
# Epoch 0, Batch 1198, Loss: 0.139360
# Epoch 0, Batch 1199, Loss: 0.150878
# Epoch 0, Batch 1200, Loss: 0.149858
# Epoch 0, Batch 1201, Loss: 0.165797
# Epoch 0, Batch 1202, Loss: 0.101349
# Epoch 0, Batch 1203, Loss: 0.032575
# Epoch 0, Batch 1204, Loss: 0.097407
# Epoch 0, Batch 1205, Loss: 0.309169
# Epoch 0, Batch 1206, Loss: 0.064207
# Epoch 0, Batch 1207, Loss: 0.277115
# Epoch 0, Batch 1208, Loss: 0.218165
# Epoch 0, Batch 1209, Loss: 0.268572
# Epoch 0, Batch 1210, Loss: 0.145787
# Epoch 0, Batch 1211, Loss: 0.053256
# Epoch 0, Batch 1212, Loss: 0.067172
# Epoch 0, Batch 1213, Loss: 0.441735
# Epoch 0, Batch 1214, Loss: 0.455086
# Epoch 0, Batch 1215, Loss: 0.172951
# Epoch 0, Batch 1216, Loss: 0.104381
# Epoch 0, Batch 1217, Loss: 0.104723
# Epoch 0, Batch 1218, Loss: 0.312999
# Epoch 0, Batch 1219, Loss: 0.150406
# Epoch 0, Batch 1220, Loss: 0.410428
# Epoch 0, Batch 1221, Loss: 0.134059
# Epoch 0, Batch 1222, Loss: 0.157717
# Epoch 0, Batch 1223, Loss: 0.261660
# Epoch 0, Batch 1224, Loss: 0.158502
# Epoch 0, Batch 1225, Loss: 0.055794
# Epoch 0, Batch 1226, Loss: 0.237023
# Epoch 0, Batch 1227, Loss: 0.171932
# Epoch 0, Batch 1228, Loss: 0.094714
# Epoch 0, Batch 1229, Loss: 0.033615
# Epoch 0, Batch 1230, Loss: 0.108704
# Epoch 0, Batch 1231, Loss: 0.132729
# Epoch 0, Batch 1232, Loss: 0.108590
# Epoch 0, Batch 1233, Loss: 0.263296
# Epoch 0, Batch 1234, Loss: 0.305700
# Epoch 0, Batch 1235, Loss: 0.104904
# Epoch 0, Batch 1236, Loss: 0.184111
# Epoch 0, Batch 1237, Loss: 0.171404
# Epoch 0, Batch 1238, Loss: 0.295965
# Epoch 0, Batch 1239, Loss: 0.483218
# Epoch 0, Batch 1240, Loss: 0.090493
# Epoch 0, Batch 1241, Loss: 0.063539
# Epoch 0, Batch 1242, Loss: 0.562642
# Epoch 0, Batch 1243, Loss: 0.098236
# Epoch 0, Batch 1244, Loss: 0.162780
# Epoch 0, Batch 1245, Loss: 0.035761
# Epoch 0, Batch 1246, Loss: 0.182820
# Epoch 0, Batch 1247, Loss: 0.221205
# Epoch 0, Batch 1248, Loss: 0.452805
# Epoch 0, Batch 1249, Loss: 0.181912
# Epoch 0, Batch 1250, Loss: 0.497697
# Epoch 0, Batch 1251, Loss: 0.142352
# Epoch 0, Batch 1252, Loss: 0.230378
# Epoch 0, Batch 1253, Loss: 0.409460
# Epoch 0, Batch 1254, Loss: 0.129362
# Epoch 0, Batch 1255, Loss: 0.181676
# Epoch 0, Batch 1256, Loss: 0.534288
# Epoch 0, Batch 1257, Loss: 0.258450
# Epoch 0, Batch 1258, Loss: 0.486485
# Epoch 0, Batch 1259, Loss: 0.201538
# Epoch 0, Batch 1260, Loss: 0.259868
# Epoch 0, Batch 1261, Loss: 0.031027
# Epoch 0, Batch 1262, Loss: 0.248673
# Epoch 0, Batch 1263, Loss: 0.202006
# Epoch 0, Batch 1264, Loss: 0.377882
# Epoch 0, Batch 1265, Loss: 0.457874
# Epoch 0, Batch 1266, Loss: 0.089528
# Epoch 0, Batch 1267, Loss: 0.161670
# Epoch 0, Batch 1268, Loss: 0.193804
# Epoch 0, Batch 1269, Loss: 0.098900
# Epoch 0, Batch 1270, Loss: 0.293020
# Epoch 0, Batch 1271, Loss: 0.330711
# Epoch 0, Batch 1272, Loss: 0.200171
# Epoch 0, Batch 1273, Loss: 0.529499
# Epoch 0, Batch 1274, Loss: 0.101331
# Epoch 0, Batch 1275, Loss: 0.154070
# Epoch 0, Batch 1276, Loss: 0.141473
# Epoch 0, Batch 1277, Loss: 0.076193
# Epoch 0, Batch 1278, Loss: 0.040572
# Epoch 0, Batch 1279, Loss: 0.212944
# Epoch 0, Batch 1280, Loss: 0.383118
# Epoch 0, Batch 1281, Loss: 0.169070
# Epoch 0, Batch 1282, Loss: 0.277710
# Epoch 0, Batch 1283, Loss: 0.231351
# Epoch 0, Batch 1284, Loss: 0.109680
# Epoch 0, Batch 1285, Loss: 0.263927
# Epoch 0, Batch 1286, Loss: 0.340909
# Epoch 0, Batch 1287, Loss: 0.290387
# Epoch 0, Batch 1288, Loss: 0.344216
# Epoch 0, Batch 1289, Loss: 0.115396
# Epoch 0, Batch 1290, Loss: 0.240206
# Epoch 0, Batch 1291, Loss: 0.279215
# Epoch 0, Batch 1292, Loss: 0.143186
# Epoch 0, Batch 1293, Loss: 0.311059
# Epoch 0, Batch 1294, Loss: 0.164878
# Epoch 0, Batch 1295, Loss: 0.084422
# Epoch 0, Batch 1296, Loss: 0.415481
# Epoch 0, Batch 1297, Loss: 0.063251
# Epoch 0, Batch 1298, Loss: 0.086563
# Epoch 0, Batch 1299, Loss: 0.307805
# Epoch 0, Batch 1300, Loss: 0.113145
# Epoch 0, Batch 1301, Loss: 0.278084
# Epoch 0, Batch 1302, Loss: 0.173657
# Epoch 0, Batch 1303, Loss: 0.107459
# Epoch 0, Batch 1304, Loss: 0.564650
# Epoch 0, Batch 1305, Loss: 0.112413
# Epoch 0, Batch 1306, Loss: 0.066284
# Epoch 0, Batch 1307, Loss: 0.061945
# Epoch 0, Batch 1308, Loss: 0.140670
# Epoch 0, Batch 1309, Loss: 0.052657
# Epoch 0, Batch 1310, Loss: 0.153293
# Epoch 0, Batch 1311, Loss: 0.167431
# Epoch 0, Batch 1312, Loss: 0.231569
# Warning: test set has no labels, skip accuracy evaluation.
# Saved: checkpoints\model_epoch_0.pth
# Epoch 1, Batch 0, Loss: 0.173067
# Epoch 1, Batch 1, Loss: 0.071151
# Epoch 1, Batch 2, Loss: 0.099333
# Epoch 1, Batch 3, Loss: 0.150467
# Epoch 1, Batch 4, Loss: 0.070274
# Epoch 1, Batch 5, Loss: 0.056366
# Epoch 1, Batch 6, Loss: 0.276754
# Epoch 1, Batch 7, Loss: 0.097434
# Epoch 1, Batch 8, Loss: 0.112960
# Epoch 1, Batch 9, Loss: 0.064849
# Epoch 1, Batch 10, Loss: 0.267258
# Epoch 1, Batch 11, Loss: 0.062696
# Epoch 1, Batch 12, Loss: 0.108033
# Epoch 1, Batch 13, Loss: 0.351246
# Epoch 1, Batch 14, Loss: 0.198263
# Epoch 1, Batch 15, Loss: 0.152954
# Epoch 1, Batch 16, Loss: 0.252605
# Epoch 1, Batch 17, Loss: 0.169802
# Epoch 1, Batch 18, Loss: 0.128278
# Epoch 1, Batch 19, Loss: 0.155720
# Epoch 1, Batch 20, Loss: 0.056386
# Epoch 1, Batch 21, Loss: 0.057575
# Epoch 1, Batch 22, Loss: 0.174920
# Epoch 1, Batch 23, Loss: 0.171051
# Epoch 1, Batch 24, Loss: 0.232447
# Epoch 1, Batch 25, Loss: 0.124328
# Epoch 1, Batch 26, Loss: 0.333045
# Epoch 1, Batch 27, Loss: 0.254337
# Epoch 1, Batch 28, Loss: 0.147099
# Epoch 1, Batch 29, Loss: 0.079920
# Epoch 1, Batch 30, Loss: 0.143056
# Epoch 1, Batch 31, Loss: 0.125751
# Epoch 1, Batch 32, Loss: 0.155911
# Epoch 1, Batch 33, Loss: 0.073548
# Epoch 1, Batch 34, Loss: 0.323100
# Epoch 1, Batch 35, Loss: 0.051562
# Epoch 1, Batch 36, Loss: 0.132637
# Epoch 1, Batch 37, Loss: 0.068696
# Epoch 1, Batch 38, Loss: 0.258557
# Epoch 1, Batch 39, Loss: 0.289186
# Epoch 1, Batch 40, Loss: 0.209955
# Epoch 1, Batch 41, Loss: 0.390655
# Epoch 1, Batch 42, Loss: 0.146841
# Epoch 1, Batch 43, Loss: 0.073094
# Epoch 1, Batch 44, Loss: 0.286291
# Epoch 1, Batch 45, Loss: 0.048364
# Epoch 1, Batch 46, Loss: 0.072342
# Epoch 1, Batch 47, Loss: 0.125102
# Epoch 1, Batch 48, Loss: 0.310579
# Epoch 1, Batch 49, Loss: 0.165757
# Epoch 1, Batch 50, Loss: 0.072874
# ...
# Epoch 9, Batch 868, Loss: 0.002690
# Epoch 9, Batch 869, Loss: 0.001424
# Epoch 9, Batch 870, Loss: 0.003668
# Epoch 9, Batch 871, Loss: 0.005546
# Epoch 9, Batch 872, Loss: 0.138322
# Epoch 9, Batch 873, Loss: 0.004768
# Epoch 9, Batch 874, Loss: 0.018592
# Epoch 9, Batch 875, Loss: 0.020001
# Epoch 9, Batch 876, Loss: 0.039577
# Epoch 9, Batch 877, Loss: 0.005572
# Epoch 9, Batch 878, Loss: 0.004679
# Epoch 9, Batch 879, Loss: 0.015315
# Epoch 9, Batch 880, Loss: 0.000856
# Epoch 9, Batch 881, Loss: 0.023219
# Epoch 9, Batch 882, Loss: 0.024603
# Epoch 9, Batch 883, Loss: 0.001534
# Epoch 9, Batch 884, Loss: 0.005696
# Epoch 9, Batch 885, Loss: 0.001088
# Epoch 9, Batch 886, Loss: 0.000361
# Epoch 9, Batch 887, Loss: 0.019288
# Epoch 9, Batch 888, Loss: 0.015415
# Epoch 9, Batch 889, Loss: 0.061305
# Epoch 9, Batch 890, Loss: 0.006715
# Epoch 9, Batch 891, Loss: 0.001129
# Epoch 9, Batch 892, Loss: 0.002821
# Epoch 9, Batch 893, Loss: 0.020414
# Epoch 9, Batch 894, Loss: 0.008545
# Epoch 9, Batch 895, Loss: 0.003757
# Epoch 9, Batch 896, Loss: 0.004496
# Epoch 9, Batch 897, Loss: 0.000479
# Epoch 9, Batch 898, Loss: 0.038154
# Epoch 9, Batch 899, Loss: 0.001489
# Epoch 9, Batch 900, Loss: 0.017202
# Epoch 9, Batch 901, Loss: 0.028575
# Epoch 9, Batch 902, Loss: 0.035268
# Epoch 9, Batch 903, Loss: 0.084756
# Epoch 9, Batch 904, Loss: 0.017892
# Epoch 9, Batch 905, Loss: 0.003057
# Epoch 9, Batch 906, Loss: 0.018319
# Epoch 9, Batch 907, Loss: 0.002305
# Epoch 9, Batch 908, Loss: 0.037324
# Epoch 9, Batch 909, Loss: 0.041732
# Epoch 9, Batch 910, Loss: 0.002364
# Epoch 9, Batch 911, Loss: 0.004592
# Epoch 9, Batch 912, Loss: 0.001871
# Epoch 9, Batch 913, Loss: 0.001004
# Epoch 9, Batch 914, Loss: 0.001163
# Epoch 9, Batch 915, Loss: 0.007395
# Epoch 9, Batch 916, Loss: 0.012100
# Epoch 9, Batch 917, Loss: 0.010077
# Epoch 9, Batch 918, Loss: 0.006968
# Epoch 9, Batch 919, Loss: 0.000593
# Epoch 9, Batch 920, Loss: 0.000943
# Epoch 9, Batch 921, Loss: 0.000844
# Epoch 9, Batch 922, Loss: 0.007051
# Epoch 9, Batch 923, Loss: 0.005238
# Epoch 9, Batch 924, Loss: 0.008690
# Epoch 9, Batch 925, Loss: 0.003274
# Epoch 9, Batch 926, Loss: 0.007190
# Epoch 9, Batch 927, Loss: 0.003938
# Epoch 9, Batch 928, Loss: 0.046178
# Epoch 9, Batch 929, Loss: 0.000955
# Epoch 9, Batch 930, Loss: 0.009415
# Epoch 9, Batch 931, Loss: 0.005764
# Epoch 9, Batch 932, Loss: 0.006134
# Epoch 9, Batch 933, Loss: 0.024419
# Epoch 9, Batch 934, Loss: 0.012785
# Epoch 9, Batch 935, Loss: 0.165550
# Epoch 9, Batch 936, Loss: 0.024420
# Epoch 9, Batch 937, Loss: 0.006643
# Epoch 9, Batch 938, Loss: 0.012562
# Epoch 9, Batch 939, Loss: 0.077837
# Epoch 9, Batch 940, Loss: 0.084459
# Epoch 9, Batch 941, Loss: 0.000906
# Epoch 9, Batch 942, Loss: 0.016776
# Epoch 9, Batch 943, Loss: 0.008619
# Epoch 9, Batch 944, Loss: 0.019457
# Epoch 9, Batch 945, Loss: 0.012264
# Epoch 9, Batch 946, Loss: 0.000623
# Epoch 9, Batch 947, Loss: 0.008402
# Epoch 9, Batch 948, Loss: 0.033668
# Epoch 9, Batch 949, Loss: 0.043031
# Epoch 9, Batch 950, Loss: 0.098561
# Epoch 9, Batch 951, Loss: 0.006335
# Epoch 9, Batch 952, Loss: 0.228693
# Epoch 9, Batch 953, Loss: 0.003504
# Epoch 9, Batch 954, Loss: 0.006188
# Epoch 9, Batch 955, Loss: 0.051990
# Epoch 9, Batch 956, Loss: 0.048301
# Epoch 9, Batch 957, Loss: 0.013531
# Epoch 9, Batch 958, Loss: 0.023450
# Epoch 9, Batch 959, Loss: 0.004803
# Epoch 9, Batch 960, Loss: 0.003830
# Epoch 9, Batch 961, Loss: 0.001303
# Epoch 9, Batch 962, Loss: 0.000370
# Epoch 9, Batch 963, Loss: 0.001873
# Epoch 9, Batch 964, Loss: 0.010886
# Epoch 9, Batch 965, Loss: 0.017620
# Epoch 9, Batch 966, Loss: 0.000793
# Epoch 9, Batch 967, Loss: 0.150418
# Epoch 9, Batch 968, Loss: 0.004793
# Epoch 9, Batch 969, Loss: 0.003391
# Epoch 9, Batch 970, Loss: 0.004771
# Epoch 9, Batch 971, Loss: 0.004522
# Epoch 9, Batch 972, Loss: 0.023529
# Epoch 9, Batch 973, Loss: 0.002153
# Epoch 9, Batch 974, Loss: 0.022503
# Epoch 9, Batch 975, Loss: 0.005004
# Epoch 9, Batch 976, Loss: 0.009639
# Epoch 9, Batch 977, Loss: 0.007022
# Epoch 9, Batch 978, Loss: 0.007755
# Epoch 9, Batch 979, Loss: 0.002872
# Epoch 9, Batch 980, Loss: 0.012053
# Epoch 9, Batch 981, Loss: 0.007804
# Epoch 9, Batch 982, Loss: 0.007774
# Epoch 9, Batch 983, Loss: 0.000768
# Epoch 9, Batch 984, Loss: 0.003050
# Epoch 9, Batch 985, Loss: 0.085635
# Epoch 9, Batch 986, Loss: 0.002540
# Epoch 9, Batch 987, Loss: 0.024285
# Epoch 9, Batch 988, Loss: 0.003462
# Epoch 9, Batch 989, Loss: 0.001270
# Epoch 9, Batch 990, Loss: 0.001866
# Epoch 9, Batch 991, Loss: 0.005396
# Epoch 9, Batch 992, Loss: 0.001623
# Epoch 9, Batch 993, Loss: 0.057372
# Epoch 9, Batch 994, Loss: 0.008069
# Epoch 9, Batch 995, Loss: 0.005376
# Epoch 9, Batch 996, Loss: 0.009957
# Epoch 9, Batch 997, Loss: 0.007856
# Epoch 9, Batch 998, Loss: 0.001863
# Epoch 9, Batch 999, Loss: 0.100437
# Epoch 9, Batch 1000, Loss: 0.003433
# Epoch 9, Batch 1001, Loss: 0.004732
# Epoch 9, Batch 1002, Loss: 0.020368
# Epoch 9, Batch 1003, Loss: 0.012612
# Epoch 9, Batch 1004, Loss: 0.007650
# Epoch 9, Batch 1005, Loss: 0.059272
# Epoch 9, Batch 1006, Loss: 0.000264
# Epoch 9, Batch 1007, Loss: 0.005208
# Epoch 9, Batch 1008, Loss: 0.013330
# Epoch 9, Batch 1009, Loss: 0.023325
# Epoch 9, Batch 1010, Loss: 0.010822
# Epoch 9, Batch 1011, Loss: 0.049396
# Epoch 9, Batch 1012, Loss: 0.003271
# Epoch 9, Batch 1013, Loss: 0.015157
# Epoch 9, Batch 1014, Loss: 0.000783
# Epoch 9, Batch 1015, Loss: 0.007728
# Epoch 9, Batch 1016, Loss: 0.006350
# Epoch 9, Batch 1017, Loss: 0.008470
# Epoch 9, Batch 1018, Loss: 0.018980
# Epoch 9, Batch 1019, Loss: 0.014812
# Epoch 9, Batch 1020, Loss: 0.002589
# Epoch 9, Batch 1021, Loss: 0.009049
# Epoch 9, Batch 1022, Loss: 0.010746
# Epoch 9, Batch 1023, Loss: 0.000735
# Epoch 9, Batch 1024, Loss: 0.017056
# Epoch 9, Batch 1025, Loss: 0.001667
# Epoch 9, Batch 1026, Loss: 0.046639
# Epoch 9, Batch 1027, Loss: 0.003173
# Epoch 9, Batch 1028, Loss: 0.022493
# Epoch 9, Batch 1029, Loss: 0.001521
# Epoch 9, Batch 1030, Loss: 0.030273
# Epoch 9, Batch 1031, Loss: 0.011812
# Epoch 9, Batch 1032, Loss: 0.005298
# Epoch 9, Batch 1033, Loss: 0.000371
# Epoch 9, Batch 1034, Loss: 0.001514
# Epoch 9, Batch 1035, Loss: 0.010729
# Epoch 9, Batch 1036, Loss: 0.005512
# Epoch 9, Batch 1037, Loss: 0.015764
# Epoch 9, Batch 1038, Loss: 0.001822
# Epoch 9, Batch 1039, Loss: 0.001386
# Epoch 9, Batch 1040, Loss: 0.034034
# Epoch 9, Batch 1041, Loss: 0.006691
# Epoch 9, Batch 1042, Loss: 0.014333
# Epoch 9, Batch 1043, Loss: 0.019992
# Epoch 9, Batch 1044, Loss: 0.000970
# Epoch 9, Batch 1045, Loss: 0.003959
# Epoch 9, Batch 1046, Loss: 0.015931
# Epoch 9, Batch 1047, Loss: 0.020954
# Epoch 9, Batch 1048, Loss: 0.006727
# Epoch 9, Batch 1049, Loss: 0.009709
# Epoch 9, Batch 1050, Loss: 0.003659
# Epoch 9, Batch 1051, Loss: 0.034382
# Epoch 9, Batch 1052, Loss: 0.114442
# Epoch 9, Batch 1053, Loss: 0.053554
# Epoch 9, Batch 1054, Loss: 0.022580
# Epoch 9, Batch 1055, Loss: 0.014928
# Epoch 9, Batch 1056, Loss: 0.004643
# Epoch 9, Batch 1057, Loss: 0.041232
# Epoch 9, Batch 1058, Loss: 0.017300
# Epoch 9, Batch 1059, Loss: 0.170250
# Epoch 9, Batch 1060, Loss: 0.011177
# Epoch 9, Batch 1061, Loss: 0.022551
# Epoch 9, Batch 1062, Loss: 0.008288
# Epoch 9, Batch 1063, Loss: 0.010730
# Epoch 9, Batch 1064, Loss: 0.048416
# Epoch 9, Batch 1065, Loss: 0.007805
# Epoch 9, Batch 1066, Loss: 0.013029
# Epoch 9, Batch 1067, Loss: 0.022081
# Epoch 9, Batch 1068, Loss: 0.003012
# Epoch 9, Batch 1069, Loss: 0.002815
# Epoch 9, Batch 1070, Loss: 0.002217
# Epoch 9, Batch 1071, Loss: 0.018345
# Epoch 9, Batch 1072, Loss: 0.003100
# Epoch 9, Batch 1073, Loss: 0.016085
# Epoch 9, Batch 1074, Loss: 0.014013
# Epoch 9, Batch 1075, Loss: 0.003528
# Epoch 9, Batch 1076, Loss: 0.051332
# Epoch 9, Batch 1077, Loss: 0.016809
# Epoch 9, Batch 1078, Loss: 0.001010
# Epoch 9, Batch 1079, Loss: 0.000755
# Epoch 9, Batch 1080, Loss: 0.080554
# Epoch 9, Batch 1081, Loss: 0.013514
# Epoch 9, Batch 1082, Loss: 0.038213
# Epoch 9, Batch 1083, Loss: 0.019490
# Epoch 9, Batch 1084, Loss: 0.003634
# Epoch 9, Batch 1085, Loss: 0.001752
# Epoch 9, Batch 1086, Loss: 0.033929
# Epoch 9, Batch 1087, Loss: 0.000603
# Epoch 9, Batch 1088, Loss: 0.011117
# Epoch 9, Batch 1089, Loss: 0.028337
# Epoch 9, Batch 1090, Loss: 0.053041
# Epoch 9, Batch 1091, Loss: 0.004189
# Epoch 9, Batch 1092, Loss: 0.020485
# Epoch 9, Batch 1093, Loss: 0.008892
# Epoch 9, Batch 1094, Loss: 0.000521
# Epoch 9, Batch 1095, Loss: 0.007854
# Epoch 9, Batch 1096, Loss: 0.005529
# Epoch 9, Batch 1097, Loss: 0.011863
# Epoch 9, Batch 1098, Loss: 0.030180
# Epoch 9, Batch 1099, Loss: 0.003693
# Epoch 9, Batch 1100, Loss: 0.003624
# Epoch 9, Batch 1101, Loss: 0.038550
# Epoch 9, Batch 1102, Loss: 0.001342
# Epoch 9, Batch 1103, Loss: 0.007694
# Epoch 9, Batch 1104, Loss: 0.031083
# Epoch 9, Batch 1105, Loss: 0.008219
# Epoch 9, Batch 1106, Loss: 0.001713
# Epoch 9, Batch 1107, Loss: 0.001916
# Epoch 9, Batch 1108, Loss: 0.002903
# Epoch 9, Batch 1109, Loss: 0.059512
# Epoch 9, Batch 1110, Loss: 0.003802
# Epoch 9, Batch 1111, Loss: 0.021883
# Epoch 9, Batch 1112, Loss: 0.016645
# Epoch 9, Batch 1113, Loss: 0.026473
# Epoch 9, Batch 1114, Loss: 0.007358
# Epoch 9, Batch 1115, Loss: 0.003379
# Epoch 9, Batch 1116, Loss: 0.014448
# Epoch 9, Batch 1117, Loss: 0.003192
# Epoch 9, Batch 1118, Loss: 0.000313
# Epoch 9, Batch 1119, Loss: 0.009526
# Epoch 9, Batch 1120, Loss: 0.005625
# Epoch 9, Batch 1121, Loss: 0.006140
# Epoch 9, Batch 1122, Loss: 0.040981
# Epoch 9, Batch 1123, Loss: 0.001213
# Epoch 9, Batch 1124, Loss: 0.004428
# Epoch 9, Batch 1125, Loss: 0.005158
# Epoch 9, Batch 1126, Loss: 0.109950
# Epoch 9, Batch 1127, Loss: 0.003408
# Epoch 9, Batch 1128, Loss: 0.023621
# Epoch 9, Batch 1129, Loss: 0.027513
# Epoch 9, Batch 1130, Loss: 0.002117
# Epoch 9, Batch 1131, Loss: 0.003225
# Epoch 9, Batch 1132, Loss: 0.045755
# Epoch 9, Batch 1133, Loss: 0.004869
# Epoch 9, Batch 1134, Loss: 0.002636
# Epoch 9, Batch 1135, Loss: 0.017179
# Epoch 9, Batch 1136, Loss: 0.038055
# Epoch 9, Batch 1137, Loss: 0.067225
# Epoch 9, Batch 1138, Loss: 0.011254
# Epoch 9, Batch 1139, Loss: 0.002101
# Epoch 9, Batch 1140, Loss: 0.007016
# Epoch 9, Batch 1141, Loss: 0.009743
# Epoch 9, Batch 1142, Loss: 0.000859
# Epoch 9, Batch 1143, Loss: 0.004744
# Epoch 9, Batch 1144, Loss: 0.004772
# Epoch 9, Batch 1145, Loss: 0.022404
# Epoch 9, Batch 1146, Loss: 0.015155
# Epoch 9, Batch 1147, Loss: 0.011092
# Epoch 9, Batch 1148, Loss: 0.339825
# Epoch 9, Batch 1149, Loss: 0.001454
# Epoch 9, Batch 1150, Loss: 0.016371
# Epoch 9, Batch 1151, Loss: 0.011780
# Epoch 9, Batch 1152, Loss: 0.043963
# Epoch 9, Batch 1153, Loss: 0.005276
# Epoch 9, Batch 1154, Loss: 0.037613
# Epoch 9, Batch 1155, Loss: 0.003452
# Epoch 9, Batch 1156, Loss: 0.006384
# Epoch 9, Batch 1157, Loss: 0.013733
# Epoch 9, Batch 1158, Loss: 0.009679
# Epoch 9, Batch 1159, Loss: 0.009871
# Epoch 9, Batch 1160, Loss: 0.004504
# Epoch 9, Batch 1161, Loss: 0.011818
# Epoch 9, Batch 1162, Loss: 0.010873
# Epoch 9, Batch 1163, Loss: 0.031602
# Epoch 9, Batch 1164, Loss: 0.016288
# Epoch 9, Batch 1165, Loss: 0.023775
# Epoch 9, Batch 1166, Loss: 0.115607
# Epoch 9, Batch 1167, Loss: 0.035471
# Epoch 9, Batch 1168, Loss: 0.015815
# Epoch 9, Batch 1169, Loss: 0.027966
# Epoch 9, Batch 1170, Loss: 0.001981
# Epoch 9, Batch 1171, Loss: 0.018760
# Epoch 9, Batch 1172, Loss: 0.006893
# Epoch 9, Batch 1173, Loss: 0.009235
# Epoch 9, Batch 1174, Loss: 0.005602
# Epoch 9, Batch 1175, Loss: 0.000870
# Epoch 9, Batch 1176, Loss: 0.002104
# Epoch 9, Batch 1177, Loss: 0.004035
# Epoch 9, Batch 1178, Loss: 0.025501
# Epoch 9, Batch 1179, Loss: 0.182876
# Epoch 9, Batch 1180, Loss: 0.011673
# Epoch 9, Batch 1181, Loss: 0.010727
# Epoch 9, Batch 1182, Loss: 0.058588
# Epoch 9, Batch 1183, Loss: 0.046749
# Epoch 9, Batch 1184, Loss: 0.075527
# Epoch 9, Batch 1185, Loss: 0.004843
# Epoch 9, Batch 1186, Loss: 0.007730
# Epoch 9, Batch 1187, Loss: 0.005721
# Epoch 9, Batch 1188, Loss: 0.032032
# Epoch 9, Batch 1189, Loss: 0.000179
# Epoch 9, Batch 1190, Loss: 0.011071
# Epoch 9, Batch 1191, Loss: 0.004144
# Epoch 9, Batch 1192, Loss: 0.007338
# Epoch 9, Batch 1193, Loss: 0.021251
# Epoch 9, Batch 1194, Loss: 0.005175
# Epoch 9, Batch 1195, Loss: 0.008138
# Epoch 9, Batch 1196, Loss: 0.031627
# Epoch 9, Batch 1197, Loss: 0.056093
# Epoch 9, Batch 1198, Loss: 0.005045
# Epoch 9, Batch 1199, Loss: 0.017591
# Epoch 9, Batch 1200, Loss: 0.056826
# Epoch 9, Batch 1201, Loss: 0.070686
# Epoch 9, Batch 1202, Loss: 0.139276
# Epoch 9, Batch 1203, Loss: 0.004902
# Epoch 9, Batch 1204, Loss: 0.137338
# Epoch 9, Batch 1205, Loss: 0.024351
# Epoch 9, Batch 1206, Loss: 0.003224
# Epoch 9, Batch 1207, Loss: 0.001440
# Epoch 9, Batch 1208, Loss: 0.165269
# Epoch 9, Batch 1209, Loss: 0.053682
# Epoch 9, Batch 1210, Loss: 0.072511
# Epoch 9, Batch 1211, Loss: 0.003119
# Epoch 9, Batch 1212, Loss: 0.005208
# Epoch 9, Batch 1213, Loss: 0.017712
# Epoch 9, Batch 1214, Loss: 0.002076
# Epoch 9, Batch 1215, Loss: 0.013987
# Epoch 9, Batch 1216, Loss: 0.033334
# Epoch 9, Batch 1217, Loss: 0.002280
# Epoch 9, Batch 1218, Loss: 0.012690
# Epoch 9, Batch 1219, Loss: 0.046925
# Epoch 9, Batch 1220, Loss: 0.005687
# Epoch 9, Batch 1221, Loss: 0.004348
# Epoch 9, Batch 1222, Loss: 0.008697
# Epoch 9, Batch 1223, Loss: 0.002621
# Epoch 9, Batch 1224, Loss: 0.003625
# Epoch 9, Batch 1225, Loss: 0.001134
# Epoch 9, Batch 1226, Loss: 0.025718
# Epoch 9, Batch 1227, Loss: 0.001614
# Epoch 9, Batch 1228, Loss: 0.096150
# Epoch 9, Batch 1229, Loss: 0.005693
# Epoch 9, Batch 1230, Loss: 0.002062
# Epoch 9, Batch 1231, Loss: 0.005443
# Epoch 9, Batch 1232, Loss: 0.016796
# Epoch 9, Batch 1233, Loss: 0.016115
# Epoch 9, Batch 1234, Loss: 0.001406
# Epoch 9, Batch 1235, Loss: 0.001839
# Epoch 9, Batch 1236, Loss: 0.070600
# Epoch 9, Batch 1237, Loss: 0.018392
# Epoch 9, Batch 1238, Loss: 0.005268
# Epoch 9, Batch 1239, Loss: 0.005286
# Epoch 9, Batch 1240, Loss: 0.039312
# Epoch 9, Batch 1241, Loss: 0.006603
# Epoch 9, Batch 1242, Loss: 0.085370
# Epoch 9, Batch 1243, Loss: 0.006372
# Epoch 9, Batch 1244, Loss: 0.020416
# Epoch 9, Batch 1245, Loss: 0.114981
# Epoch 9, Batch 1246, Loss: 0.012364
# Epoch 9, Batch 1247, Loss: 0.017501
# Epoch 9, Batch 1248, Loss: 0.016119
# Epoch 9, Batch 1249, Loss: 0.003779
# Epoch 9, Batch 1250, Loss: 0.051370
# Epoch 9, Batch 1251, Loss: 0.006526
# Epoch 9, Batch 1252, Loss: 0.003101
# Epoch 9, Batch 1253, Loss: 0.025515
# Epoch 9, Batch 1254, Loss: 0.017000
# Epoch 9, Batch 1255, Loss: 0.010702
# Epoch 9, Batch 1256, Loss: 0.035966
# Epoch 9, Batch 1257, Loss: 0.076566
# Epoch 9, Batch 1258, Loss: 0.057991
# Epoch 9, Batch 1259, Loss: 0.081957
# Epoch 9, Batch 1260, Loss: 0.008527
# Epoch 9, Batch 1261, Loss: 0.101530
# Epoch 9, Batch 1262, Loss: 0.007641
# Epoch 9, Batch 1263, Loss: 0.024237
# Epoch 9, Batch 1264, Loss: 0.017091
# Epoch 9, Batch 1265, Loss: 0.068523
# Epoch 9, Batch 1266, Loss: 0.003651
# Epoch 9, Batch 1267, Loss: 0.009846
# Epoch 9, Batch 1268, Loss: 0.005061
# Epoch 9, Batch 1269, Loss: 0.055925
# Epoch 9, Batch 1270, Loss: 0.015982
# Epoch 9, Batch 1271, Loss: 0.002558
# Epoch 9, Batch 1272, Loss: 0.036472
# Epoch 9, Batch 1273, Loss: 0.006111
# Epoch 9, Batch 1274, Loss: 0.035325
# Epoch 9, Batch 1275, Loss: 0.035666
# Epoch 9, Batch 1276, Loss: 0.002321
# Epoch 9, Batch 1277, Loss: 0.015304
# Epoch 9, Batch 1278, Loss: 0.000344
# Epoch 9, Batch 1279, Loss: 0.029311
# Epoch 9, Batch 1280, Loss: 0.007548
# Epoch 9, Batch 1281, Loss: 0.002812
# Epoch 9, Batch 1282, Loss: 0.000565
# Epoch 9, Batch 1283, Loss: 0.028638
# Epoch 9, Batch 1284, Loss: 0.023600
# Epoch 9, Batch 1285, Loss: 0.045216
# Epoch 9, Batch 1286, Loss: 0.006535
# Epoch 9, Batch 1287, Loss: 0.002039
# Epoch 9, Batch 1288, Loss: 0.001808
# Epoch 9, Batch 1289, Loss: 0.023697
# Epoch 9, Batch 1290, Loss: 0.004224
# Epoch 9, Batch 1291, Loss: 0.111605
# Epoch 9, Batch 1292, Loss: 0.007341
# Epoch 9, Batch 1293, Loss: 0.036595
# Epoch 9, Batch 1294, Loss: 0.004017
# Epoch 9, Batch 1295, Loss: 0.004297
# Epoch 9, Batch 1296, Loss: 0.010994
# Epoch 9, Batch 1297, Loss: 0.006246
# Epoch 9, Batch 1298, Loss: 0.014269
# Epoch 9, Batch 1299, Loss: 0.028469
# Epoch 9, Batch 1300, Loss: 0.001744
# Epoch 9, Batch 1301, Loss: 0.000777
# Epoch 9, Batch 1302, Loss: 0.015618
# Epoch 9, Batch 1303, Loss: 0.014744
# Epoch 9, Batch 1304, Loss: 0.026320
# Epoch 9, Batch 1305, Loss: 0.049100
# Epoch 9, Batch 1306, Loss: 0.132014
# Epoch 9, Batch 1307, Loss: 0.014700
# Epoch 9, Batch 1308, Loss: 0.052309
# Epoch 9, Batch 1309, Loss: 0.001889
# Epoch 9, Batch 1310, Loss: 0.007933
# Epoch 9, Batch 1311, Loss: 0.009830
# Epoch 9, Batch 1312, Loss: 0.006693
# Warning: test set has no labels, skip accuracy evaluation.
# Saved: checkpoints\model_epoch_9.pth

# %%
# 9.1) 训练曲线可视化
epochs_axis = list(range(1, len(epoch_losses) + 1))

plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs_axis, epoch_losses, marker="o")
plt.title("Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True, linestyle="--", alpha=0.4)

plt.subplot(1, 2, 2)
valid_acc = [a for a in epoch_accs if a is not None]
valid_epochs = [i + 1 for i, a in enumerate(epoch_accs) if a is not None]
if valid_acc:
    plt.plot(valid_epochs, valid_acc, marker="o", color="green")
    plt.ylim(0, 1)
plt.title("Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.grid(True, linestyle="--", alpha=0.4)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10) 训练后单图验证与可选模型加载推理
#
# 先做一次单图验证；再演示如何加载保存的权重做推理。

# %%
# 训练后单图验证
single_sample_check(out, test_dataset)

# 可选：加载某个 checkpoint 后再做单图推理
# model2 = MyNetwork()
# model2.load_state_dict(torch.load(os.path.join("checkpoints", "model_epoch_8.pth"), map_location="cpu"))
# single_sample_check(model2, test_dataset)
# Out:
# Single Image Validation
# Image: d:\CZ_WorkSpace\ai学习\深度学习实践\task1\MNIST_kaggle\testSet\img_332.jpg
# Pred Label: 3, Confidence: 0.9998 (no ground-truth label)

# %%
# 11) 加载模型参数并对测试集推理（导出 Kaggle 提交文件）
import pandas as pd
from torch.utils.data import DataLoader

# TODO: 修改为你要加载的权重文件路径
ckpt_path = os.path.join("checkpoints", "model_epoch_8.pth")

infer_model = MyNetwork()
infer_model.load_state_dict(torch.load(ckpt_path, map_location="cpu"))
infer_model.eval()

# 测试集无标签，推理时 batch 处理
infer_loader = DataLoader(test_dataset, batch_size=128, shuffle=False)

pred_records = []
with torch.no_grad():
    for images, file_paths in infer_loader:
        logits = infer_model(images)
        preds = torch.argmax(logits, dim=1).cpu().numpy().tolist()
        for path, pred in zip(file_paths, preds):
            base = os.path.basename(path)
            match = re.search(r"\d+", base)
            if match is None:
                raise ValueError(f"Cannot parse image id from filename: {base}")
            image_id = int(match.group())
            pred_records.append((image_id, pred))

# 按 ImageId 数值升序，符合 Kaggle 提交要求
pred_records.sort(key=lambda x: x[0])
submit_df = pd.DataFrame(pred_records, columns=["ImageId", "Label"])

# 保存为 CSV，方便提交到 Kaggle
submit_path = "kaggle_submit_FCN.csv"
submit_df.to_csv(submit_path, index=False)
print(f"Saved submission file: {submit_path}")
print(submit_df.head())
# Out:
# Saved submission file: kaggle_submit_FCN.csv
#    ImageId  Label
# 0        1      2
# 1        2      0
# 2        3      9
# 3        4      9
# 4        5      3
