# %% [markdown]
# # 任务1_2: 卷积神经网络 (CNN) 版本
#
# 本 Notebook 参考 task1_1.ipynb 的流程，改为 CNN 网络结构。

# %% [markdown]
# ## 1) 安装与启动 Jupyter 内核（VS Code）
#
# 首次使用可在此单元安装依赖；运行后在 VS Code 右上角选择 Python 内核。

# %%
# 如已安装可跳过
# %pip install -U pip
# %pip install ipykernel notebook torch torchvision pillow pandas matplotlib

# 导入 sys 用于查看当前内核的 Python 路径
import sys
# 输出当前解释器路径，确认内核环境
print(sys.executable)
# 输出提示信息，确认单元执行
print("内核已就绪")
# Out:
# d:\anaconda\envs\DL\python.exe
# 内核已就绪

# %%
# 解决 Windows 下 OpenMP 重复加载导致的内核崩溃问题
# 导入 os 用于设置环境变量
import os
# 允许重复加载 OpenMP 库，避免特定环境崩溃
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
# 打印确认信息
print("KMP_DUPLICATE_LIB_OK set")
# Out:
# KMP_DUPLICATE_LIB_OK set

# %% [markdown]
# ## 2) 导入依赖并检查 PyTorch 版本

# %%
# 基础库：路径、正则、随机数
import os
import re
import random
# 深度学习与数据处理相关
import torch
import pandas as pd
import torch.nn as nn
import matplotlib.pyplot as plt
from PIL import Image
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader

# 打印 PyTorch 版本，确认环境
print("torch version:", torch.__version__)
# Out:
# torch version: 2.8.0+cpu

# %% [markdown]
# ## 3) 配置数据路径（基于当前工作目录）
#
# Notebook 中没有 __file__，这里使用当前工作目录并手动拼接数据路径。

# %%
# 若你的 Notebook 不在该目录运行，可手动指定项目根目录
# 这里用当前工作目录的上一级作为默认根目录
project_root = os.path.dirname(os.getcwd())
# 例如：project_root = r"d:/CZ_WorkSpace/ai学习/深度学习实践"

# 拼接训练与测试数据集路径
train_dir = os.path.join(project_root, "MNIST_kaggle", "trainingSet")
test_dir = os.path.join(project_root, "MNIST_kaggle", "testSet")

# 打印路径与是否存在，便于排查数据路径问题
print("cwd:", os.getcwd())
print("project_root:", project_root)
print("train_dir exists:", os.path.exists(train_dir), "train_dir:", train_dir)
print("test_dir exists:", os.path.exists(test_dir), "test_dir:", test_dir)
# Out:
# cwd: d:\CZ_WorkSpace\ai学习\深度学习实践\task1\task1_2
# project_root: d:\CZ_WorkSpace\ai学习\深度学习实践\task1
# train_dir exists: True train_dir: d:\CZ_WorkSpace\ai学习\深度学习实践\task1\MNIST_kaggle\trainingSet
# test_dir exists: True test_dir: d:\CZ_WorkSpace\ai学习\深度学习实践\task1\MNIST_kaggle\testSet

# %% [markdown]
# ## 4) 定义 MyDataset（有标签/无标签双模式）
#
# CNN 输入为 [1, 28, 28]，这里不再展平成 784。

# %%
class MyDataset(Dataset):
    # 初始化数据集，支持有标签/无标签两种模式
    def __init__(self, data_dir, labeled=True):
        # 保存数据目录与标注标记
        self.data_dir = data_dir
        self.labeled = labeled
        # samples 保存 (路径, 标签) 或 路径
        self.samples = []
        # 定义统一的图像预处理流程
        self.transform = transforms.Compose([
            transforms.Grayscale(num_output_channels=1),
            transforms.Resize((28, 28)),
            transforms.ToTensor(),
        ])

        # 如果是训练集，读取子目录作为类别
        if self.labeled:
            # 获取所有类别目录名
            class_names = [d for d in os.listdir(data_dir) if os.path.isdir(os.path.join(data_dir, d))]
            # 按数字顺序排序类别目录
            class_names = sorted(class_names, key=lambda x: int(x) if x.isdigit() else x)
            # 构建类别名到整数标签的映射
            self.class_to_idx = {name: int(name) for name in class_names}
            # 遍历每个类别目录收集样本
            for class_name in class_names:
                class_dir = os.path.join(data_dir, class_name)
                for file_name in os.listdir(class_dir):
                    # 只保留图片文件
                    if file_name.lower().endswith((".jpg", ".jpeg", ".png", ".bmp")):
                        file_path = os.path.join(class_dir, file_name)
                        label = self.class_to_idx[class_name]
                        self.samples.append((file_path, label))
        else:
            # 测试集无标签，仅保存图片路径
            self.class_to_idx = {}
            for file_name in os.listdir(data_dir):
                file_path = os.path.join(data_dir, file_name)
                # 只保留图片文件
                if os.path.isfile(file_path) and file_name.lower().endswith((".jpg", ".jpeg", ".png", ".bmp")):
                    self.samples.append(file_path)

    # 返回样本数量
    def __len__(self):
        return len(self.samples)

    # 获取单个样本
    def __getitem__(self, idx):
        # 根据是否有标签拆包
        if self.labeled:
            file_path, label = self.samples[idx]
        else:
            file_path = self.samples[idx]
            label = None

        # 读取图片并做预处理
        image = Image.open(file_path)
        image = self.transform(image)

        # 训练集返回 (图像张量, 标签)
        if self.labeled:
            return image, torch.tensor(label, dtype=torch.long)
        # 测试集返回 (图像张量, 文件路径)
        return image, file_path

# %% [markdown]
# ## 5) 构建 DataLoader 并检查 batch 形状

# %%
# 构建训练集 Dataset（有标签）
mydataset = MyDataset(data_dir=train_dir, labeled=True)
# 训练 DataLoader：打乱样本，提升训练随机性
mydataset_loader = DataLoader(mydataset, batch_size=64, shuffle=True)

# 构建测试集 Dataset（无标签）
test_dataset = MyDataset(data_dir=test_dir, labeled=False)
# 测试 DataLoader：不打乱，保持文件顺序
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# 打印样本数量，检查数据是否加载成功
print(f"Train samples: {len(mydataset)}")
print(f"Test samples: {len(test_dataset)}")

# 简单查看前两个 batch 的形状与标签示例
for batch_idx, (images, labels) in enumerate(mydataset_loader):
    print(f"Batch {batch_idx}: images={images.shape}, labels={labels.shape}")
    print("Label sample:", labels[:10].tolist())
    if batch_idx == 1:
        break
# Out:
# Train samples: 42000
# Test samples: 28000
# Batch 0: images=torch.Size([64, 1, 28, 28]), labels=torch.Size([64])
# Label sample: [3, 1, 1, 4, 5, 8, 0, 8, 0, 8]
# Batch 1: images=torch.Size([64, 1, 28, 28]), labels=torch.Size([64])
# Label sample: [9, 8, 6, 7, 1, 3, 0, 7, 6, 6]

# %% [markdown]
# ## 6) 定义卷积神经网络 MyCNN
#
# 结构示例：Conv(1->16) -> ReLU -> MaxPool -> Conv(16->32) -> ReLU -> MaxPool -> FC。

# %%
class MyCNN(nn.Module):
    # 初始化 CNN 网络结构
    def __init__(self):
        super(MyCNN, self).__init__()
        # 卷积特征提取部分
        self.features = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(16, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
        )
        # 分类器：展平后接全连接层输出 logits
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(32 * 7 * 7, 128),
            nn.ReLU(),
            nn.Linear(128, 10),
        )

    # 前向传播逻辑
    def forward(self, x):
        # 提取卷积特征
        x = self.features(x)
        # 通过分类器得到最终输出
        x = self.classifier(x)
        return x

# %% [markdown]
# ## 7) 定义评估函数 evaluate 与单样本推理 single_sample_check

# %%
def evaluate(model, data_loader):
    # 若数据集为空或无标签，跳过评估
    if len(data_loader.dataset) == 0 or not data_loader.dataset.labeled:
        print("Warning: test set has no labels, skip accuracy evaluation.")
        return None

    # 切换到评估模式，关闭 dropout/bn 的训练行为
    model.eval()
    correct = 0
    total = 0
    # 评估阶段不需要梯度，节省显存与时间
    with torch.no_grad():
        for images, labels in data_loader:
            # 前向推理得到 logits
            outputs = model(images)
            # 取最大值所在类别作为预测结果
            preds = torch.argmax(outputs, dim=1)
            # 统计预测正确数量
            correct += (preds == labels).sum().item()
            # 统计样本总数
            total += labels.size(0)

    # 恢复训练模式，避免影响后续训练
    model.train()
    if total == 0:
        print("Warning: test set is empty, skip accuracy evaluation.")
        return None
    # 返回准确率
    return correct / total


def single_sample_check(model, dataset):
    # 若测试集为空，直接返回
    if len(dataset) == 0:
        print("Single image validation skipped: test dataset is empty.")
        return

    # 随机抽取一张图片做单样本推理
    sample_idx = random.randint(0, len(dataset) - 1)
    sample = dataset[sample_idx]
    if dataset.labeled:
        # 训练集/有标签模式
        image, label = sample
        image_path, _ = dataset.samples[sample_idx]
    else:
        # 测试集/无标签模式
        image, image_path = sample
        label = None

    # 推理前切换到评估模式
    model.eval()
    with torch.no_grad():
        # 为单张图片增加 batch 维度
        logits = model(image.unsqueeze(0))
        # 计算 softmax 概率用于置信度
        probs = torch.softmax(logits, dim=1)
        # 取最大概率的类别作为预测结果
        pred = torch.argmax(probs, dim=1).item()
        # 取预测类别的置信度
        confidence = probs[0, pred].item()
    # 恢复训练模式
    model.train()

    # 输出推理结果
    print("\nSingle Image Validation")
    print(f"Image: {image_path}")
    if label is not None:
        print(f"True Label: {label.item()}, Pred Label: {pred}, Confidence: {confidence:.4f}")
    else:
        print(f"Pred Label: {pred}, Confidence: {confidence:.4f} (no ground-truth label)")

# %% [markdown]
# ## 8) 定义损失函数与优化器

# %%
# 定义交叉熵损失（输入 logits，目标为类别索引）
loss_fn = nn.CrossEntropyLoss()
# 初始化 CNN 模型
model = MyCNN()
# 定义优化器（Adam）
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# 快速可用性检查：随机输入跑通前向与损失
_ = loss_fn(model(torch.randn(4, 1, 28, 28)), torch.randint(0, 10, (4,)))
print("model check ok")
# Out:
# model check ok

# %% [markdown]
# ## 9) 训练循环（含评估与模型保存）
#
# 模型和提交文件保存到 task1_2 目录下。

# %%
# 训练总轮数
epochs = 10
# 模型参数保存目录（相对当前工作目录）
checkpoint_dir = os.path.join(os.getcwd(), "checkpoints")
# 确保目录存在
os.makedirs(checkpoint_dir, exist_ok=True)

# 记录每个 epoch 的平均 loss
epoch_losses = []
# 记录每个 epoch 的准确率（若无标签则记录 None）
epoch_accs = []

# 开始训练循环
for epoch in range(epochs):
    # 设置为训练模式
    model.train()
    running_loss = 0.0
    sample_count = 0
    # 逐 batch 训练
    for batch_idx, (images, labels) in enumerate(mydataset_loader):
        # 前向推理得到 logits
        output = model(images)
        # 计算当前 batch 的损失
        loss = loss_fn(output, labels)

        # 清空梯度
        optimizer.zero_grad()
        # 反向传播计算梯度
        loss.backward()
        # 更新参数
        optimizer.step()

        # 累计 loss（按样本数加权）
        batch_size = labels.size(0)
        running_loss += loss.item() * batch_size
        sample_count += batch_size

        # 输出当前 batch 的 loss
        print(f"Epoch {epoch}, Batch {batch_idx}, Loss: {loss.item():.6f}")

    # 计算并记录该 epoch 的平均 loss
    epoch_loss = running_loss / max(sample_count, 1)
    epoch_losses.append(epoch_loss)

    # 在测试集上做一次评估（若有标签）
    test_acc = evaluate(model, test_loader)
    if test_acc is not None:
        epoch_accs.append(test_acc)
        print(f"Epoch {epoch}, Test Accuracy: {test_acc * 100:.2f}%")
    else:
        epoch_accs.append(None)

    # 保存该 epoch 的模型参数
    if epoch % 1 == 0:
        ckpt_path = os.path.join(checkpoint_dir, f"model_epoch_{epoch}.pth")
        torch.save(model.state_dict(), ckpt_path)
        print("Saved:", ckpt_path)
# Out:
# Epoch 0, Batch 0, Loss: 2.311666
# Epoch 0, Batch 1, Loss: 2.289992
# Epoch 0, Batch 2, Loss: 2.291528
# Epoch 0, Batch 3, Loss: 2.287369
# Epoch 0, Batch 4, Loss: 2.271430
# Epoch 0, Batch 5, Loss: 2.243545
# Epoch 0, Batch 6, Loss: 2.232274
# Epoch 0, Batch 7, Loss: 2.176629
# Epoch 0, Batch 8, Loss: 2.202188
# Epoch 0, Batch 9, Loss: 2.172542
# Epoch 0, Batch 10, Loss: 2.125464
# Epoch 0, Batch 11, Loss: 2.141774
# Epoch 0, Batch 12, Loss: 2.101068
# Epoch 0, Batch 13, Loss: 2.066507
# Epoch 0, Batch 14, Loss: 2.022452
# Epoch 0, Batch 15, Loss: 2.035747
# Epoch 0, Batch 16, Loss: 2.012767
# Epoch 0, Batch 17, Loss: 1.900483
# Epoch 0, Batch 18, Loss: 1.841856
# Epoch 0, Batch 19, Loss: 1.778278
# Epoch 0, Batch 20, Loss: 1.743826
# Epoch 0, Batch 21, Loss: 1.660724
# Epoch 0, Batch 22, Loss: 1.796239
# Epoch 0, Batch 23, Loss: 1.610721
# Epoch 0, Batch 24, Loss: 1.588114
# Epoch 0, Batch 25, Loss: 1.474738
# Epoch 0, Batch 26, Loss: 1.414637
# Epoch 0, Batch 27, Loss: 1.270301
# Epoch 0, Batch 28, Loss: 1.253030
# Epoch 0, Batch 29, Loss: 1.072118
# Epoch 0, Batch 30, Loss: 1.207163
# Epoch 0, Batch 31, Loss: 1.130479
# Epoch 0, Batch 32, Loss: 1.053632
# Epoch 0, Batch 33, Loss: 0.939510
# Epoch 0, Batch 34, Loss: 0.812877
# Epoch 0, Batch 35, Loss: 0.793774
# Epoch 0, Batch 36, Loss: 0.699753
# Epoch 0, Batch 37, Loss: 0.700773
# Epoch 0, Batch 38, Loss: 0.787831
# Epoch 0, Batch 39, Loss: 0.632717
# Epoch 0, Batch 40, Loss: 0.550531
# Epoch 0, Batch 41, Loss: 0.625582
# Epoch 0, Batch 42, Loss: 0.826634
# Epoch 0, Batch 43, Loss: 0.753599
# Epoch 0, Batch 44, Loss: 0.733933
# Epoch 0, Batch 45, Loss: 0.663054
# Epoch 0, Batch 46, Loss: 0.627225
# Epoch 0, Batch 47, Loss: 0.679663
# Epoch 0, Batch 48, Loss: 0.572941
# Epoch 0, Batch 49, Loss: 0.650817
# Epoch 0, Batch 50, Loss: 0.671236
# Epoch 0, Batch 51, Loss: 0.672550
# Epoch 0, Batch 52, Loss: 0.692844
# Epoch 0, Batch 53, Loss: 0.472365
# Epoch 0, Batch 54, Loss: 0.520148
# Epoch 0, Batch 55, Loss: 0.511190
# Epoch 0, Batch 56, Loss: 0.482700
# Epoch 0, Batch 57, Loss: 0.585913
# Epoch 0, Batch 58, Loss: 0.402199
# Epoch 0, Batch 59, Loss: 0.397201
# Epoch 0, Batch 60, Loss: 0.469084
# Epoch 0, Batch 61, Loss: 0.457895
# Epoch 0, Batch 62, Loss: 0.388496
# Epoch 0, Batch 63, Loss: 0.506171
# Epoch 0, Batch 64, Loss: 0.434842
# Epoch 0, Batch 65, Loss: 0.696341
# Epoch 0, Batch 66, Loss: 0.438749
# Epoch 0, Batch 67, Loss: 0.434275
# Epoch 0, Batch 68, Loss: 0.524095
# Epoch 0, Batch 69, Loss: 0.539971
# Epoch 0, Batch 70, Loss: 0.771149
# Epoch 0, Batch 71, Loss: 0.486657
# Epoch 0, Batch 72, Loss: 0.460756
# Epoch 0, Batch 73, Loss: 0.451968
# Epoch 0, Batch 74, Loss: 0.628531
# Epoch 0, Batch 75, Loss: 0.437396
# Epoch 0, Batch 76, Loss: 0.361053
# Epoch 0, Batch 77, Loss: 0.291127
# Epoch 0, Batch 78, Loss: 0.510258
# Epoch 0, Batch 79, Loss: 0.302544
# Epoch 0, Batch 80, Loss: 0.336086
# Epoch 0, Batch 81, Loss: 0.384063
# Epoch 0, Batch 82, Loss: 0.333072
# Epoch 0, Batch 83, Loss: 0.399706
# Epoch 0, Batch 84, Loss: 0.505070
# Epoch 0, Batch 85, Loss: 0.278432
# Epoch 0, Batch 86, Loss: 0.427556
# Epoch 0, Batch 87, Loss: 0.381651
# Epoch 0, Batch 88, Loss: 0.312157
# Epoch 0, Batch 89, Loss: 0.571518
# Epoch 0, Batch 90, Loss: 0.365831
# Epoch 0, Batch 91, Loss: 0.312376
# Epoch 0, Batch 92, Loss: 0.307632
# Epoch 0, Batch 93, Loss: 0.425940
# Epoch 0, Batch 94, Loss: 0.402056
# Epoch 0, Batch 95, Loss: 0.207536
# Epoch 0, Batch 96, Loss: 0.337978
# Epoch 0, Batch 97, Loss: 0.402042
# Epoch 0, Batch 98, Loss: 0.458983
# Epoch 0, Batch 99, Loss: 0.269191
# Epoch 0, Batch 100, Loss: 0.508851
# Epoch 0, Batch 101, Loss: 0.441013
# Epoch 0, Batch 102, Loss: 0.384208
# Epoch 0, Batch 103, Loss: 0.336333
# Epoch 0, Batch 104, Loss: 0.334020
# Epoch 0, Batch 105, Loss: 0.366983
# Epoch 0, Batch 106, Loss: 0.274687
# Epoch 0, Batch 107, Loss: 0.439366
# Epoch 0, Batch 108, Loss: 0.391646
# Epoch 0, Batch 109, Loss: 0.408501
# Epoch 0, Batch 110, Loss: 0.288001
# Epoch 0, Batch 111, Loss: 0.306386
# Epoch 0, Batch 112, Loss: 0.227784
# Epoch 0, Batch 113, Loss: 0.240349
# Epoch 0, Batch 114, Loss: 0.279462
# Epoch 0, Batch 115, Loss: 0.293749
# Epoch 0, Batch 116, Loss: 0.337809
# Epoch 0, Batch 117, Loss: 0.274708
# Epoch 0, Batch 118, Loss: 0.122175
# Epoch 0, Batch 119, Loss: 0.266155
# Epoch 0, Batch 120, Loss: 0.236922
# Epoch 0, Batch 121, Loss: 0.298736
# Epoch 0, Batch 122, Loss: 0.319006
# Epoch 0, Batch 123, Loss: 0.298839
# Epoch 0, Batch 124, Loss: 0.263106
# Epoch 0, Batch 125, Loss: 0.354537
# Epoch 0, Batch 126, Loss: 0.364014
# Epoch 0, Batch 127, Loss: 0.331039
# Epoch 0, Batch 128, Loss: 0.333236
# Epoch 0, Batch 129, Loss: 0.343131
# Epoch 0, Batch 130, Loss: 0.431412
# Epoch 0, Batch 131, Loss: 0.438140
# Epoch 0, Batch 132, Loss: 0.130823
# Epoch 0, Batch 133, Loss: 0.215293
# Epoch 0, Batch 134, Loss: 0.422856
# Epoch 0, Batch 135, Loss: 0.333141
# Epoch 0, Batch 136, Loss: 0.141577
# Epoch 0, Batch 137, Loss: 0.482565
# Epoch 0, Batch 138, Loss: 0.320894
# Epoch 0, Batch 139, Loss: 0.353221
# Epoch 0, Batch 140, Loss: 0.384498
# Epoch 0, Batch 141, Loss: 0.418274
# Epoch 0, Batch 142, Loss: 0.294978
# Epoch 0, Batch 143, Loss: 0.164708
# Epoch 0, Batch 144, Loss: 0.476187
# Epoch 0, Batch 145, Loss: 0.235837
# Epoch 0, Batch 146, Loss: 0.314347
# Epoch 0, Batch 147, Loss: 0.196215
# Epoch 0, Batch 148, Loss: 0.204354
# Epoch 0, Batch 149, Loss: 0.230348
# Epoch 0, Batch 150, Loss: 0.209219
# Epoch 0, Batch 151, Loss: 0.273239
# Epoch 0, Batch 152, Loss: 0.141672
# Epoch 0, Batch 153, Loss: 0.312868
# Epoch 0, Batch 154, Loss: 0.330115
# Epoch 0, Batch 155, Loss: 0.200405
# Epoch 0, Batch 156, Loss: 0.144716
# Epoch 0, Batch 157, Loss: 0.329703
# Epoch 0, Batch 158, Loss: 0.287567
# Epoch 0, Batch 159, Loss: 0.222424
# Epoch 0, Batch 160, Loss: 0.246020
# Epoch 0, Batch 161, Loss: 0.168888
# Epoch 0, Batch 162, Loss: 0.182267
# Epoch 0, Batch 163, Loss: 0.212097
# Epoch 0, Batch 164, Loss: 0.226054
# Epoch 0, Batch 165, Loss: 0.387114
# Epoch 0, Batch 166, Loss: 0.257433
# Epoch 0, Batch 167, Loss: 0.222798
# Epoch 0, Batch 168, Loss: 0.230296
# Epoch 0, Batch 169, Loss: 0.248684
# Epoch 0, Batch 170, Loss: 0.185684
# Epoch 0, Batch 171, Loss: 0.229192
# Epoch 0, Batch 172, Loss: 0.252050
# Epoch 0, Batch 173, Loss: 0.210523
# Epoch 0, Batch 174, Loss: 0.130805
# Epoch 0, Batch 175, Loss: 0.204166
# Epoch 0, Batch 176, Loss: 0.397947
# Epoch 0, Batch 177, Loss: 0.189809
# Epoch 0, Batch 178, Loss: 0.226887
# Epoch 0, Batch 179, Loss: 0.405793
# Epoch 0, Batch 180, Loss: 0.177942
# Epoch 0, Batch 181, Loss: 0.140596
# Epoch 0, Batch 182, Loss: 0.122879
# Epoch 0, Batch 183, Loss: 0.154822
# Epoch 0, Batch 184, Loss: 0.116061
# Epoch 0, Batch 185, Loss: 0.219868
# Epoch 0, Batch 186, Loss: 0.151977
# Epoch 0, Batch 187, Loss: 0.336794
# Epoch 0, Batch 188, Loss: 0.190028
# Epoch 0, Batch 189, Loss: 0.187700
# Epoch 0, Batch 190, Loss: 0.089725
# Epoch 0, Batch 191, Loss: 0.220499
# Epoch 0, Batch 192, Loss: 0.079524
# Epoch 0, Batch 193, Loss: 0.257957
# Epoch 0, Batch 194, Loss: 0.150379
# Epoch 0, Batch 195, Loss: 0.276516
# Epoch 0, Batch 196, Loss: 0.352011
# Epoch 0, Batch 197, Loss: 0.357997
# Epoch 0, Batch 198, Loss: 0.334312
# Epoch 0, Batch 199, Loss: 0.225386
# Epoch 0, Batch 200, Loss: 0.146576
# Epoch 0, Batch 201, Loss: 0.269797
# Epoch 0, Batch 202, Loss: 0.183239
# Epoch 0, Batch 203, Loss: 0.351242
# Epoch 0, Batch 204, Loss: 0.308853
# Epoch 0, Batch 205, Loss: 0.330991
# Epoch 0, Batch 206, Loss: 0.103655
# Epoch 0, Batch 207, Loss: 0.175357
# Epoch 0, Batch 208, Loss: 0.237280
# Epoch 0, Batch 209, Loss: 0.335017
# Epoch 0, Batch 210, Loss: 0.182417
# Epoch 0, Batch 211, Loss: 0.084968
# Epoch 0, Batch 212, Loss: 0.181508
# Epoch 0, Batch 213, Loss: 0.160410
# Epoch 0, Batch 214, Loss: 0.072117
# Epoch 0, Batch 215, Loss: 0.167643
# Epoch 0, Batch 216, Loss: 0.329656
# Epoch 0, Batch 217, Loss: 0.157256
# Epoch 0, Batch 218, Loss: 0.246598
# Epoch 0, Batch 219, Loss: 0.169702
# Epoch 0, Batch 220, Loss: 0.329316
# Epoch 0, Batch 221, Loss: 0.190980
# Epoch 0, Batch 222, Loss: 0.257576
# Epoch 0, Batch 223, Loss: 0.269359
# Epoch 0, Batch 224, Loss: 0.312564
# Epoch 0, Batch 225, Loss: 0.082435
# Epoch 0, Batch 226, Loss: 0.183906
# Epoch 0, Batch 227, Loss: 0.224347
# Epoch 0, Batch 228, Loss: 0.167904
# Epoch 0, Batch 229, Loss: 0.316372
# Epoch 0, Batch 230, Loss: 0.438388
# Epoch 0, Batch 231, Loss: 0.187131
# Epoch 0, Batch 232, Loss: 0.221880
# Epoch 0, Batch 233, Loss: 0.207757
# Epoch 0, Batch 234, Loss: 0.278108
# Epoch 0, Batch 235, Loss: 0.175040
# Epoch 0, Batch 236, Loss: 0.115489
# Epoch 0, Batch 237, Loss: 0.137996
# Epoch 0, Batch 238, Loss: 0.071049
# Epoch 0, Batch 239, Loss: 0.288141
# Epoch 0, Batch 240, Loss: 0.326715
# Epoch 0, Batch 241, Loss: 0.158691
# Epoch 0, Batch 242, Loss: 0.299609
# Epoch 0, Batch 243, Loss: 0.225979
# Epoch 0, Batch 244, Loss: 0.196228
# Epoch 0, Batch 245, Loss: 0.170441
# Epoch 0, Batch 246, Loss: 0.223091
# Epoch 0, Batch 247, Loss: 0.233565
# Epoch 0, Batch 248, Loss: 0.129397
# Epoch 0, Batch 249, Loss: 0.130311
# Epoch 0, Batch 250, Loss: 0.091817
# Epoch 0, Batch 251, Loss: 0.365431
# Epoch 0, Batch 252, Loss: 0.187337
# Epoch 0, Batch 253, Loss: 0.177623
# Epoch 0, Batch 254, Loss: 0.229429
# Epoch 0, Batch 255, Loss: 0.062468
# Epoch 0, Batch 256, Loss: 0.094223
# Epoch 0, Batch 257, Loss: 0.133591
# Epoch 0, Batch 258, Loss: 0.175541
# Epoch 0, Batch 259, Loss: 0.036969
# Epoch 0, Batch 260, Loss: 0.182403
# Epoch 0, Batch 261, Loss: 0.214286
# Epoch 0, Batch 262, Loss: 0.188512
# Epoch 0, Batch 263, Loss: 0.081489
# Epoch 0, Batch 264, Loss: 0.308377
# Epoch 0, Batch 265, Loss: 0.074615
# Epoch 0, Batch 266, Loss: 0.243144
# Epoch 0, Batch 267, Loss: 0.119767
# Epoch 0, Batch 268, Loss: 0.089411
# Epoch 0, Batch 269, Loss: 0.171855
# Epoch 0, Batch 270, Loss: 0.187316
# Epoch 0, Batch 271, Loss: 0.104254
# Epoch 0, Batch 272, Loss: 0.216636
# Epoch 0, Batch 273, Loss: 0.093397
# Epoch 0, Batch 274, Loss: 0.205771
# Epoch 0, Batch 275, Loss: 0.158791
# Epoch 0, Batch 276, Loss: 0.187403
# Epoch 0, Batch 277, Loss: 0.156412
# Epoch 0, Batch 278, Loss: 0.132043
# Epoch 0, Batch 279, Loss: 0.164457
# Epoch 0, Batch 280, Loss: 0.142654
# Epoch 0, Batch 281, Loss: 0.134787
# Epoch 0, Batch 282, Loss: 0.243199
# Epoch 0, Batch 283, Loss: 0.149117
# Epoch 0, Batch 284, Loss: 0.106250
# Epoch 0, Batch 285, Loss: 0.095089
# Epoch 0, Batch 286, Loss: 0.133932
# Epoch 0, Batch 287, Loss: 0.069984
# Epoch 0, Batch 288, Loss: 0.341110
# Epoch 0, Batch 289, Loss: 0.076172
# Epoch 0, Batch 290, Loss: 0.191805
# Epoch 0, Batch 291, Loss: 0.150485
# Epoch 0, Batch 292, Loss: 0.241647
# Epoch 0, Batch 293, Loss: 0.205343
# Epoch 0, Batch 294, Loss: 0.197487
# Epoch 0, Batch 295, Loss: 0.140693
# Epoch 0, Batch 296, Loss: 0.212335
# Epoch 0, Batch 297, Loss: 0.103102
# Epoch 0, Batch 298, Loss: 0.084383
# Epoch 0, Batch 299, Loss: 0.315925
# Epoch 0, Batch 300, Loss: 0.193861
# Epoch 0, Batch 301, Loss: 0.557728
# Epoch 0, Batch 302, Loss: 0.194430
# Epoch 0, Batch 303, Loss: 0.223790
# Epoch 0, Batch 304, Loss: 0.230843
# Epoch 0, Batch 305, Loss: 0.098938
# Epoch 0, Batch 306, Loss: 0.356350
# Epoch 0, Batch 307, Loss: 0.147101
# Epoch 0, Batch 308, Loss: 0.224637
# Epoch 0, Batch 309, Loss: 0.170317
# Epoch 0, Batch 310, Loss: 0.106410
# Epoch 0, Batch 311, Loss: 0.140460
# Epoch 0, Batch 312, Loss: 0.116475
# Epoch 0, Batch 313, Loss: 0.140182
# Epoch 0, Batch 314, Loss: 0.046311
# Epoch 0, Batch 315, Loss: 0.083793
# Epoch 0, Batch 316, Loss: 0.175472
# Epoch 0, Batch 317, Loss: 0.102421
# Epoch 0, Batch 318, Loss: 0.188244
# Epoch 0, Batch 319, Loss: 0.146655
# Epoch 0, Batch 320, Loss: 0.141949
# Epoch 0, Batch 321, Loss: 0.053991
# Epoch 0, Batch 322, Loss: 0.097028
# Epoch 0, Batch 323, Loss: 0.082558
# Epoch 0, Batch 324, Loss: 0.324204
# Epoch 0, Batch 325, Loss: 0.132695
# Epoch 0, Batch 326, Loss: 0.130492
# Epoch 0, Batch 327, Loss: 0.312892
# Epoch 0, Batch 328, Loss: 0.379003
# Epoch 0, Batch 329, Loss: 0.273915
# Epoch 0, Batch 330, Loss: 0.109051
# Epoch 0, Batch 331, Loss: 0.087625
# Epoch 0, Batch 332, Loss: 0.090366
# Epoch 0, Batch 333, Loss: 0.277149
# Epoch 0, Batch 334, Loss: 0.128515
# Epoch 0, Batch 335, Loss: 0.215503
# Epoch 0, Batch 336, Loss: 0.181866
# Epoch 0, Batch 337, Loss: 0.133328
# Epoch 0, Batch 338, Loss: 0.205153
# Epoch 0, Batch 339, Loss: 0.104210
# Epoch 0, Batch 340, Loss: 0.150118
# Epoch 0, Batch 341, Loss: 0.077807
# Epoch 0, Batch 342, Loss: 0.181273
# Epoch 0, Batch 343, Loss: 0.279897
# Epoch 0, Batch 344, Loss: 0.189528
# Epoch 0, Batch 345, Loss: 0.114659
# Epoch 0, Batch 346, Loss: 0.192515
# Epoch 0, Batch 347, Loss: 0.104806
# Epoch 0, Batch 348, Loss: 0.051997
# Epoch 0, Batch 349, Loss: 0.042495
# Epoch 0, Batch 350, Loss: 0.124218
# Epoch 0, Batch 351, Loss: 0.053587
# Epoch 0, Batch 352, Loss: 0.084076
# Epoch 0, Batch 353, Loss: 0.278904
# Epoch 0, Batch 354, Loss: 0.222609
# Epoch 0, Batch 355, Loss: 0.088846
# Epoch 0, Batch 356, Loss: 0.177895
# Epoch 0, Batch 357, Loss: 0.163696
# Epoch 0, Batch 358, Loss: 0.154558
# Epoch 0, Batch 359, Loss: 0.063117
# Epoch 0, Batch 360, Loss: 0.124308
# Epoch 0, Batch 361, Loss: 0.046396
# Epoch 0, Batch 362, Loss: 0.236022
# Epoch 0, Batch 363, Loss: 0.192477
# Epoch 0, Batch 364, Loss: 0.255980
# Epoch 0, Batch 365, Loss: 0.290758
# Epoch 0, Batch 366, Loss: 0.275583
# Epoch 0, Batch 367, Loss: 0.244084
# Epoch 0, Batch 368, Loss: 0.202157
# Epoch 0, Batch 369, Loss: 0.175725
# Epoch 0, Batch 370, Loss: 0.140220
# Epoch 0, Batch 371, Loss: 0.110454
# Epoch 0, Batch 372, Loss: 0.062151
# Epoch 0, Batch 373, Loss: 0.084414
# Epoch 0, Batch 374, Loss: 0.123146
# Epoch 0, Batch 375, Loss: 0.131931
# Epoch 0, Batch 376, Loss: 0.104525
# Epoch 0, Batch 377, Loss: 0.113957
# Epoch 0, Batch 378, Loss: 0.207348
# Epoch 0, Batch 379, Loss: 0.043280
# Epoch 0, Batch 380, Loss: 0.184899
# Epoch 0, Batch 381, Loss: 0.069032
# Epoch 0, Batch 382, Loss: 0.215473
# Epoch 0, Batch 383, Loss: 0.134289
# Epoch 0, Batch 384, Loss: 0.193196
# Epoch 0, Batch 385, Loss: 0.133791
# Epoch 0, Batch 386, Loss: 0.271596
# Epoch 0, Batch 387, Loss: 0.095506
# Epoch 0, Batch 388, Loss: 0.099626
# Epoch 0, Batch 389, Loss: 0.142407
# Epoch 0, Batch 390, Loss: 0.187721
# Epoch 0, Batch 391, Loss: 0.117734
# Epoch 0, Batch 392, Loss: 0.054284
# Epoch 0, Batch 393, Loss: 0.132814
# Epoch 0, Batch 394, Loss: 0.109405
# Epoch 0, Batch 395, Loss: 0.102320
# Epoch 0, Batch 396, Loss: 0.085057
# Epoch 0, Batch 397, Loss: 0.291658
# Epoch 0, Batch 398, Loss: 0.112957
# Epoch 0, Batch 399, Loss: 0.168746
# Epoch 0, Batch 400, Loss: 0.180446
# Epoch 0, Batch 401, Loss: 0.146719
# Epoch 0, Batch 402, Loss: 0.063670
# Epoch 0, Batch 403, Loss: 0.228245
# Epoch 0, Batch 404, Loss: 0.162390
# Epoch 0, Batch 405, Loss: 0.211349
# Epoch 0, Batch 406, Loss: 0.079044
# Epoch 0, Batch 407, Loss: 0.156139
# Epoch 0, Batch 408, Loss: 0.045936
# Epoch 0, Batch 409, Loss: 0.021478
# Epoch 0, Batch 410, Loss: 0.086136
# Epoch 0, Batch 411, Loss: 0.076906
# Epoch 0, Batch 412, Loss: 0.056958
# Epoch 0, Batch 413, Loss: 0.300430
# Epoch 0, Batch 414, Loss: 0.144004
# Epoch 0, Batch 415, Loss: 0.103795
# Epoch 0, Batch 416, Loss: 0.111234
# Epoch 0, Batch 417, Loss: 0.065773
# Epoch 0, Batch 418, Loss: 0.026166
# Epoch 0, Batch 419, Loss: 0.203954
# Epoch 0, Batch 420, Loss: 0.130883
# Epoch 0, Batch 421, Loss: 0.087080
# Epoch 0, Batch 422, Loss: 0.091844
# Epoch 0, Batch 423, Loss: 0.249341
# Epoch 0, Batch 424, Loss: 0.119727
# Epoch 0, Batch 425, Loss: 0.122162
# Epoch 0, Batch 426, Loss: 0.164730
# Epoch 0, Batch 427, Loss: 0.104682
# Epoch 0, Batch 428, Loss: 0.078192
# Epoch 0, Batch 429, Loss: 0.188363
# Epoch 0, Batch 430, Loss: 0.063570
# Epoch 0, Batch 431, Loss: 0.045778
# Epoch 0, Batch 432, Loss: 0.171518
# Epoch 0, Batch 433, Loss: 0.175289
# Epoch 0, Batch 434, Loss: 0.091797
# Epoch 0, Batch 435, Loss: 0.078372
# Epoch 0, Batch 436, Loss: 0.043999
# Epoch 0, Batch 437, Loss: 0.049459
# Epoch 0, Batch 438, Loss: 0.192656
# Epoch 0, Batch 439, Loss: 0.072404
# Epoch 0, Batch 440, Loss: 0.094649
# Epoch 0, Batch 441, Loss: 0.018996
# Epoch 0, Batch 442, Loss: 0.060678
# Epoch 0, Batch 443, Loss: 0.126357
# Epoch 0, Batch 444, Loss: 0.184188
# Epoch 0, Batch 445, Loss: 0.022601
# Epoch 0, Batch 446, Loss: 0.112077
# Epoch 0, Batch 447, Loss: 0.173509
# Epoch 0, Batch 448, Loss: 0.075639
# Epoch 0, Batch 449, Loss: 0.126456
# Epoch 0, Batch 450, Loss: 0.058670
# Epoch 0, Batch 451, Loss: 0.024233
# Epoch 0, Batch 452, Loss: 0.087454
# Epoch 0, Batch 453, Loss: 0.033827
# Epoch 0, Batch 454, Loss: 0.274603
# Epoch 0, Batch 455, Loss: 0.085633
# Epoch 0, Batch 456, Loss: 0.055964
# Epoch 0, Batch 457, Loss: 0.060561
# Epoch 0, Batch 458, Loss: 0.192399
# Epoch 0, Batch 459, Loss: 0.127804
# Epoch 0, Batch 460, Loss: 0.155782
# Epoch 0, Batch 461, Loss: 0.078730
# Epoch 0, Batch 462, Loss: 0.137398
# Epoch 0, Batch 463, Loss: 0.173513
# Epoch 0, Batch 464, Loss: 0.067705
# Epoch 0, Batch 465, Loss: 0.351623
# Epoch 0, Batch 466, Loss: 0.063859
# Epoch 0, Batch 467, Loss: 0.220204
# Epoch 0, Batch 468, Loss: 0.174988
# Epoch 0, Batch 469, Loss: 0.075703
# Epoch 0, Batch 470, Loss: 0.130182
# Epoch 0, Batch 471, Loss: 0.116705
# Epoch 0, Batch 472, Loss: 0.072563
# Epoch 0, Batch 473, Loss: 0.051445
# Epoch 0, Batch 474, Loss: 0.035006
# Epoch 0, Batch 475, Loss: 0.126470
# Epoch 0, Batch 476, Loss: 0.128707
# Epoch 0, Batch 477, Loss: 0.249321
# Epoch 0, Batch 478, Loss: 0.253951
# Epoch 0, Batch 479, Loss: 0.064524
# Epoch 0, Batch 480, Loss: 0.029936
# Epoch 0, Batch 481, Loss: 0.083860
# Epoch 0, Batch 482, Loss: 0.122407
# Epoch 0, Batch 483, Loss: 0.151095
# Epoch 0, Batch 484, Loss: 0.077988
# Epoch 0, Batch 485, Loss: 0.141688
# Epoch 0, Batch 486, Loss: 0.082978
# Epoch 0, Batch 487, Loss: 0.031314
# Epoch 0, Batch 488, Loss: 0.187364
# Epoch 0, Batch 489, Loss: 0.175525
# Epoch 0, Batch 490, Loss: 0.081676
# Epoch 0, Batch 491, Loss: 0.083400
# Epoch 0, Batch 492, Loss: 0.106614
# Epoch 0, Batch 493, Loss: 0.033807
# Epoch 0, Batch 494, Loss: 0.117642
# Epoch 0, Batch 495, Loss: 0.064134
# Epoch 0, Batch 496, Loss: 0.153218
# Epoch 0, Batch 497, Loss: 0.028998
# Epoch 0, Batch 498, Loss: 0.088325
# Epoch 0, Batch 499, Loss: 0.102818
# Epoch 0, Batch 500, Loss: 0.089010
# Epoch 0, Batch 501, Loss: 0.068195
# Epoch 0, Batch 502, Loss: 0.127907
# Epoch 0, Batch 503, Loss: 0.051939
# Epoch 0, Batch 504, Loss: 0.054819
# Epoch 0, Batch 505, Loss: 0.201840
# Epoch 0, Batch 506, Loss: 0.089083
# Epoch 0, Batch 507, Loss: 0.130525
# Epoch 0, Batch 508, Loss: 0.274147
# Epoch 0, Batch 509, Loss: 0.177918
# Epoch 0, Batch 510, Loss: 0.070885
# Epoch 0, Batch 511, Loss: 0.097811
# Epoch 0, Batch 512, Loss: 0.135492
# Epoch 0, Batch 513, Loss: 0.073232
# Epoch 0, Batch 514, Loss: 0.118330
# Epoch 0, Batch 515, Loss: 0.339233
# Epoch 0, Batch 516, Loss: 0.068118
# Epoch 0, Batch 517, Loss: 0.028867
# Epoch 0, Batch 518, Loss: 0.038204
# Epoch 0, Batch 519, Loss: 0.056068
# Epoch 0, Batch 520, Loss: 0.060737
# Epoch 0, Batch 521, Loss: 0.218626
# Epoch 0, Batch 522, Loss: 0.074819
# Epoch 0, Batch 523, Loss: 0.144356
# Epoch 0, Batch 524, Loss: 0.121243
# Epoch 0, Batch 525, Loss: 0.117699
# Epoch 0, Batch 526, Loss: 0.075389
# Epoch 0, Batch 527, Loss: 0.090001
# Epoch 0, Batch 528, Loss: 0.180375
# Epoch 0, Batch 529, Loss: 0.039365
# Epoch 0, Batch 530, Loss: 0.162242
# Epoch 0, Batch 531, Loss: 0.068584
# Epoch 0, Batch 532, Loss: 0.068079
# Epoch 0, Batch 533, Loss: 0.089105
# Epoch 0, Batch 534, Loss: 0.290918
# Epoch 0, Batch 535, Loss: 0.159507
# Epoch 0, Batch 536, Loss: 0.116511
# Epoch 0, Batch 537, Loss: 0.305071
# Epoch 0, Batch 538, Loss: 0.103120
# Epoch 0, Batch 539, Loss: 0.059238
# Epoch 0, Batch 540, Loss: 0.028898
# Epoch 0, Batch 541, Loss: 0.044847
# Epoch 0, Batch 542, Loss: 0.176528
# Epoch 0, Batch 543, Loss: 0.059914
# Epoch 0, Batch 544, Loss: 0.144550
# Epoch 0, Batch 545, Loss: 0.154075
# Epoch 0, Batch 546, Loss: 0.095731
# Epoch 0, Batch 547, Loss: 0.033219
# Epoch 0, Batch 548, Loss: 0.103296
# Epoch 0, Batch 549, Loss: 0.051549
# Epoch 0, Batch 550, Loss: 0.032502
# Epoch 0, Batch 551, Loss: 0.221010
# Epoch 0, Batch 552, Loss: 0.071032
# Epoch 0, Batch 553, Loss: 0.089523
# Epoch 0, Batch 554, Loss: 0.145917
# Epoch 0, Batch 555, Loss: 0.042676
# Epoch 0, Batch 556, Loss: 0.041689
# Epoch 0, Batch 557, Loss: 0.150380
# Epoch 0, Batch 558, Loss: 0.093339
# Epoch 0, Batch 559, Loss: 0.057266
# Epoch 0, Batch 560, Loss: 0.041113
# Epoch 0, Batch 561, Loss: 0.080130
# Epoch 0, Batch 562, Loss: 0.053974
# Epoch 0, Batch 563, Loss: 0.034379
# Epoch 0, Batch 564, Loss: 0.125377
# Epoch 0, Batch 565, Loss: 0.175257
# Epoch 0, Batch 566, Loss: 0.060321
# Epoch 0, Batch 567, Loss: 0.034033
# Epoch 0, Batch 568, Loss: 0.101110
# Epoch 0, Batch 569, Loss: 0.238312
# Epoch 0, Batch 570, Loss: 0.036097
# Epoch 0, Batch 571, Loss: 0.111720
# Epoch 0, Batch 572, Loss: 0.147970
# Epoch 0, Batch 573, Loss: 0.137303
# Epoch 0, Batch 574, Loss: 0.160746
# Epoch 0, Batch 575, Loss: 0.157746
# Epoch 0, Batch 576, Loss: 0.086705
# Epoch 0, Batch 577, Loss: 0.064621
# Epoch 0, Batch 578, Loss: 0.204263
# Epoch 0, Batch 579, Loss: 0.109769
# Epoch 0, Batch 580, Loss: 0.024132
# Epoch 0, Batch 581, Loss: 0.101107
# Epoch 0, Batch 582, Loss: 0.021509
# Epoch 0, Batch 583, Loss: 0.066636
# Epoch 0, Batch 584, Loss: 0.083437
# Epoch 0, Batch 585, Loss: 0.138538
# Epoch 0, Batch 586, Loss: 0.051909
# Epoch 0, Batch 587, Loss: 0.126039
# Epoch 0, Batch 588, Loss: 0.105483
# Epoch 0, Batch 589, Loss: 0.115404
# Epoch 0, Batch 590, Loss: 0.035180
# Epoch 0, Batch 591, Loss: 0.018683
# Epoch 0, Batch 592, Loss: 0.135397
# Epoch 0, Batch 593, Loss: 0.138744
# Epoch 0, Batch 594, Loss: 0.102303
# Epoch 0, Batch 595, Loss: 0.103852
# Epoch 0, Batch 596, Loss: 0.238735
# Epoch 0, Batch 597, Loss: 0.084930
# Epoch 0, Batch 598, Loss: 0.042061
# Epoch 0, Batch 599, Loss: 0.062915
# Epoch 0, Batch 600, Loss: 0.036171
# Epoch 0, Batch 601, Loss: 0.152154
# Epoch 0, Batch 602, Loss: 0.200537
# Epoch 0, Batch 603, Loss: 0.104304
# Epoch 0, Batch 604, Loss: 0.099749
# Epoch 0, Batch 605, Loss: 0.025911
# Epoch 0, Batch 606, Loss: 0.043459
# Epoch 0, Batch 607, Loss: 0.114854
# Epoch 0, Batch 608, Loss: 0.160680
# Epoch 0, Batch 609, Loss: 0.064858
# Epoch 0, Batch 610, Loss: 0.094270
# Epoch 0, Batch 611, Loss: 0.113049
# Epoch 0, Batch 612, Loss: 0.067767
# Epoch 0, Batch 613, Loss: 0.014927
# Epoch 0, Batch 614, Loss: 0.073424
# Epoch 0, Batch 615, Loss: 0.191827
# Epoch 0, Batch 616, Loss: 0.111398
# Epoch 0, Batch 617, Loss: 0.065616
# Epoch 0, Batch 618, Loss: 0.130143
# Epoch 0, Batch 619, Loss: 0.058859
# Epoch 0, Batch 620, Loss: 0.084769
# Epoch 0, Batch 621, Loss: 0.043628
# Epoch 0, Batch 622, Loss: 0.172038
# Epoch 0, Batch 623, Loss: 0.096580
# Epoch 0, Batch 624, Loss: 0.194510
# Epoch 0, Batch 625, Loss: 0.153573
# Epoch 0, Batch 626, Loss: 0.081441
# Epoch 0, Batch 627, Loss: 0.135475
# Epoch 0, Batch 628, Loss: 0.033754
# Epoch 0, Batch 629, Loss: 0.199064
# Epoch 0, Batch 630, Loss: 0.201245
# Epoch 0, Batch 631, Loss: 0.017678
# Epoch 0, Batch 632, Loss: 0.084045
# Epoch 0, Batch 633, Loss: 0.047148
# Epoch 0, Batch 634, Loss: 0.055524
# Epoch 0, Batch 635, Loss: 0.024730
# Epoch 0, Batch 636, Loss: 0.071115
# Epoch 0, Batch 637, Loss: 0.129708
# Epoch 0, Batch 638, Loss: 0.082311
# Epoch 0, Batch 639, Loss: 0.081914
# Epoch 0, Batch 640, Loss: 0.093687
# Epoch 0, Batch 641, Loss: 0.137630
# Epoch 0, Batch 642, Loss: 0.045881
# Epoch 0, Batch 643, Loss: 0.101800
# Epoch 0, Batch 644, Loss: 0.053179
# Epoch 0, Batch 645, Loss: 0.089776
# Epoch 0, Batch 646, Loss: 0.022180
# Epoch 0, Batch 647, Loss: 0.016196
# Epoch 0, Batch 648, Loss: 0.217454
# Epoch 0, Batch 649, Loss: 0.054446
# Epoch 0, Batch 650, Loss: 0.032016
# Epoch 0, Batch 651, Loss: 0.058028
# Epoch 0, Batch 652, Loss: 0.246067
# Epoch 0, Batch 653, Loss: 0.057045
# Epoch 0, Batch 654, Loss: 0.155525
# Epoch 0, Batch 655, Loss: 0.134328
# Epoch 0, Batch 656, Loss: 0.231327
# Warning: test set has no labels, skip accuracy evaluation.
# Saved: d:\CZ_WorkSpace\ai学习\深度学习实践\task1\task1_2\checkpoints\model_epoch_0.pth
# Epoch 1, Batch 0, Loss: 0.046158
# Epoch 1, Batch 1, Loss: 0.050335
# Epoch 1, Batch 2, Loss: 0.059556
# Epoch 1, Batch 3, Loss: 0.069882
# Epoch 1, Batch 4, Loss: 0.075448
# Epoch 1, Batch 5, Loss: 0.148639
# Epoch 1, Batch 6, Loss: 0.152364
# Epoch 1, Batch 7, Loss: 0.107552
# Epoch 1, Batch 8, Loss: 0.097491
# Epoch 1, Batch 9, Loss: 0.178097
# Epoch 1, Batch 10, Loss: 0.036325
# Epoch 1, Batch 11, Loss: 0.116489
# Epoch 1, Batch 12, Loss: 0.054489
# Epoch 1, Batch 13, Loss: 0.022892
# Epoch 1, Batch 14, Loss: 0.042863
# Epoch 1, Batch 15, Loss: 0.057749
# Epoch 1, Batch 16, Loss: 0.064910
# Epoch 1, Batch 17, Loss: 0.034258
# Epoch 1, Batch 18, Loss: 0.104262
# Epoch 1, Batch 19, Loss: 0.074727
# Epoch 1, Batch 20, Loss: 0.174470
# Epoch 1, Batch 21, Loss: 0.056026
# Epoch 1, Batch 22, Loss: 0.083032
# Epoch 1, Batch 23, Loss: 0.074631
# Epoch 1, Batch 24, Loss: 0.089176
# Epoch 1, Batch 25, Loss: 0.035551
# Epoch 1, Batch 26, Loss: 0.038759
# Epoch 1, Batch 27, Loss: 0.039252
# Epoch 1, Batch 28, Loss: 0.033852
# Epoch 1, Batch 29, Loss: 0.067592
# Epoch 1, Batch 30, Loss: 0.032457
# Epoch 1, Batch 31, Loss: 0.102954
# Epoch 1, Batch 32, Loss: 0.105027
# Epoch 1, Batch 33, Loss: 0.176638
# Epoch 1, Batch 34, Loss: 0.117989
# Epoch 1, Batch 35, Loss: 0.095920
# Epoch 1, Batch 36, Loss: 0.126437
# Epoch 1, Batch 37, Loss: 0.076692
# Epoch 1, Batch 38, Loss: 0.041376
# Epoch 1, Batch 39, Loss: 0.044642
# Epoch 1, Batch 40, Loss: 0.050810
# Epoch 1, Batch 41, Loss: 0.110547
# Epoch 1, Batch 42, Loss: 0.110509
# Epoch 1, Batch 43, Loss: 0.042871
# Epoch 1, Batch 44, Loss: 0.044411
# Epoch 1, Batch 45, Loss: 0.023236
# Epoch 1, Batch 46, Loss: 0.055733
# Epoch 1, Batch 47, Loss: 0.051041
# Epoch 1, Batch 48, Loss: 0.124957
# Epoch 1, Batch 49, Loss: 0.060446
# Epoch 1, Batch 50, Loss: 0.158699
# Epoch 1, Batch 51, Loss: 0.097530
# Epoch 1, Batch 52, Loss: 0.052929
# Epoch 1, Batch 53, Loss: 0.247773
# Epoch 1, Batch 54, Loss: 0.178540
# Epoch 1, Batch 55, Loss: 0.019569
# Epoch 1, Batch 56, Loss: 0.050921
# Epoch 1, Batch 57, Loss: 0.209533
# Epoch 1, Batch 58, Loss: 0.036942
# Epoch 1, Batch 59, Loss: 0.144902
# Epoch 1, Batch 60, Loss: 0.093566
# Epoch 1, Batch 61, Loss: 0.025038
# Epoch 1, Batch 62, Loss: 0.155373
# Epoch 1, Batch 63, Loss: 0.063514
# Epoch 1, Batch 64, Loss: 0.110108
# Epoch 1, Batch 65, Loss: 0.122819
# Epoch 1, Batch 66, Loss: 0.061528
# Epoch 1, Batch 67, Loss: 0.191443
# Epoch 1, Batch 68, Loss: 0.149973
# Epoch 1, Batch 69, Loss: 0.035485
# Epoch 1, Batch 70, Loss: 0.048374
# Epoch 1, Batch 71, Loss: 0.153186
# Epoch 1, Batch 72, Loss: 0.038318
# Epoch 1, Batch 73, Loss: 0.052609
# Epoch 1, Batch 74, Loss: 0.073146
# Epoch 1, Batch 75, Loss: 0.137951
# Epoch 1, Batch 76, Loss: 0.031707
# Epoch 1, Batch 77, Loss: 0.044833
# Epoch 1, Batch 78, Loss: 0.107254
# Epoch 1, Batch 79, Loss: 0.119656
# Epoch 1, Batch 80, Loss: 0.303076
# Epoch 1, Batch 81, Loss: 0.060556
# Epoch 1, Batch 82, Loss: 0.094244
# Epoch 1, Batch 83, Loss: 0.053516
# Epoch 1, Batch 84, Loss: 0.031440
# Epoch 1, Batch 85, Loss: 0.031803
# Epoch 1, Batch 86, Loss: 0.062830
# Epoch 1, Batch 87, Loss: 0.079877
# Epoch 1, Batch 88, Loss: 0.108224
# Epoch 1, Batch 89, Loss: 0.067229
# Epoch 1, Batch 90, Loss: 0.052727
# Epoch 1, Batch 91, Loss: 0.166491
# Epoch 1, Batch 92, Loss: 0.048725
# Epoch 1, Batch 93, Loss: 0.126055
# Epoch 1, Batch 94, Loss: 0.133477
# Epoch 1, Batch 95, Loss: 0.055511
# Epoch 1, Batch 96, Loss: 0.066457
# Epoch 1, Batch 97, Loss: 0.145350
# Epoch 1, Batch 98, Loss: 0.034515
# Epoch 1, Batch 99, Loss: 0.123942
# Epoch 1, Batch 100, Loss: 0.139402
# Epoch 1, Batch 101, Loss: 0.048670
# Epoch 1, Batch 102, Loss: 0.048400
# Epoch 1, Batch 103, Loss: 0.095500
# Epoch 1, Batch 104, Loss: 0.213552
# Epoch 1, Batch 105, Loss: 0.184496
# Epoch 1, Batch 106, Loss: 0.038404
# Epoch 1, Batch 107, Loss: 0.074120
# Epoch 1, Batch 108, Loss: 0.032672
# Epoch 1, Batch 109, Loss: 0.024399
# Epoch 1, Batch 110, Loss: 0.152360
# Epoch 1, Batch 111, Loss: 0.132897
# Epoch 1, Batch 112, Loss: 0.029546
# Epoch 1, Batch 113, Loss: 0.074137
# Epoch 1, Batch 114, Loss: 0.088053
# Epoch 1, Batch 115, Loss: 0.032064
# Epoch 1, Batch 116, Loss: 0.029848
# Epoch 1, Batch 117, Loss: 0.123801
# Epoch 1, Batch 118, Loss: 0.133475
# Epoch 1, Batch 119, Loss: 0.043283
# Epoch 1, Batch 120, Loss: 0.145029
# Epoch 1, Batch 121, Loss: 0.160069
# Epoch 1, Batch 122, Loss: 0.075574
# Epoch 1, Batch 123, Loss: 0.077803
# Epoch 1, Batch 124, Loss: 0.044880
# Epoch 1, Batch 125, Loss: 0.092033
# Epoch 1, Batch 126, Loss: 0.115878
# Epoch 1, Batch 127, Loss: 0.053656
# Epoch 1, Batch 128, Loss: 0.121007
# Epoch 1, Batch 129, Loss: 0.144663
# Epoch 1, Batch 130, Loss: 0.106938
# Epoch 1, Batch 131, Loss: 0.126850
# Epoch 1, Batch 132, Loss: 0.065341
# Epoch 1, Batch 133, Loss: 0.045526
# Epoch 1, Batch 134, Loss: 0.061938
# Epoch 1, Batch 135, Loss: 0.052337
# Epoch 1, Batch 136, Loss: 0.137139
# Epoch 1, Batch 137, Loss: 0.078560
# Epoch 1, Batch 138, Loss: 0.090138
# Epoch 1, Batch 139, Loss: 0.174640
# Epoch 1, Batch 140, Loss: 0.057263
# Epoch 1, Batch 141, Loss: 0.015216
# Epoch 1, Batch 142, Loss: 0.024989
# Epoch 1, Batch 143, Loss: 0.030724
# Epoch 1, Batch 144, Loss: 0.025363
# Epoch 1, Batch 145, Loss: 0.046184
# Epoch 1, Batch 146, Loss: 0.016717
# Epoch 1, Batch 147, Loss: 0.090629
# Epoch 1, Batch 148, Loss: 0.009892
# Epoch 1, Batch 149, Loss: 0.331241
# Epoch 1, Batch 150, Loss: 0.143652
# Epoch 1, Batch 151, Loss: 0.083052
# Epoch 1, Batch 152, Loss: 0.043751
# Epoch 1, Batch 153, Loss: 0.019888
# Epoch 1, Batch 154, Loss: 0.080422
# Epoch 1, Batch 155, Loss: 0.056290
# Epoch 1, Batch 156, Loss: 0.042351
# Epoch 1, Batch 157, Loss: 0.084000
# Epoch 1, Batch 158, Loss: 0.080026
# Epoch 1, Batch 159, Loss: 0.051578
# Epoch 1, Batch 160, Loss: 0.036637
# Epoch 1, Batch 161, Loss: 0.108367
# Epoch 1, Batch 162, Loss: 0.080539
# Epoch 1, Batch 163, Loss: 0.025119
# Epoch 1, Batch 164, Loss: 0.099368
# Epoch 1, Batch 165, Loss: 0.081116
# Epoch 1, Batch 166, Loss: 0.100280
# Epoch 1, Batch 167, Loss: 0.096006
# Epoch 1, Batch 168, Loss: 0.059954
# Epoch 1, Batch 169, Loss: 0.046886
# Epoch 1, Batch 170, Loss: 0.035982
# Epoch 1, Batch 171, Loss: 0.043856
# Epoch 1, Batch 172, Loss: 0.081948
# Epoch 1, Batch 173, Loss: 0.101237
# Epoch 1, Batch 174, Loss: 0.056159
# Epoch 1, Batch 175, Loss: 0.108147
# Epoch 1, Batch 176, Loss: 0.032936
# Epoch 1, Batch 177, Loss: 0.070829
# Epoch 1, Batch 178, Loss: 0.119277
# Epoch 1, Batch 179, Loss: 0.143371
# Epoch 1, Batch 180, Loss: 0.012034
# Epoch 1, Batch 181, Loss: 0.086070
# Epoch 1, Batch 182, Loss: 0.033588
# Epoch 1, Batch 183, Loss: 0.018108
# Epoch 1, Batch 184, Loss: 0.095615
# Epoch 1, Batch 185, Loss: 0.112856
# Epoch 1, Batch 186, Loss: 0.020877
# Epoch 1, Batch 187, Loss: 0.081696
# Epoch 1, Batch 188, Loss: 0.060756
# Epoch 1, Batch 189, Loss: 0.049998
# Epoch 1, Batch 190, Loss: 0.100068
# Epoch 1, Batch 191, Loss: 0.251601
# Epoch 1, Batch 192, Loss: 0.024187
# Epoch 1, Batch 193, Loss: 0.231024
# Epoch 1, Batch 194, Loss: 0.190356
# Epoch 1, Batch 195, Loss: 0.036736
# Epoch 1, Batch 196, Loss: 0.179917
# Epoch 1, Batch 197, Loss: 0.134420
# Epoch 1, Batch 198, Loss: 0.056399
# Epoch 1, Batch 199, Loss: 0.041280
# Epoch 1, Batch 200, Loss: 0.110332
# Epoch 1, Batch 201, Loss: 0.032198
# Epoch 1, Batch 202, Loss: 0.069663
# Epoch 1, Batch 203, Loss: 0.091811
# Epoch 1, Batch 204, Loss: 0.102594
# Epoch 1, Batch 205, Loss: 0.093905
# Epoch 1, Batch 206, Loss: 0.142251
# Epoch 1, Batch 207, Loss: 0.067712
# Epoch 1, Batch 208, Loss: 0.110496
# Epoch 1, Batch 209, Loss: 0.063521
# Epoch 1, Batch 210, Loss: 0.036749
# Epoch 1, Batch 211, Loss: 0.065777
# Epoch 1, Batch 212, Loss: 0.080740
# Epoch 1, Batch 213, Loss: 0.102682
# Epoch 1, Batch 214, Loss: 0.073628
# Epoch 1, Batch 215, Loss: 0.101110
# Epoch 1, Batch 216, Loss: 0.053361
# Epoch 1, Batch 217, Loss: 0.035528
# Epoch 1, Batch 218, Loss: 0.064404
# Epoch 1, Batch 219, Loss: 0.027821
# Epoch 1, Batch 220, Loss: 0.055295
# Epoch 1, Batch 221, Loss: 0.041190
# Epoch 1, Batch 222, Loss: 0.134394
# Epoch 1, Batch 223, Loss: 0.067204
# Epoch 1, Batch 224, Loss: 0.026978
# Epoch 1, Batch 225, Loss: 0.053141
# Epoch 1, Batch 226, Loss: 0.030307
# Epoch 1, Batch 227, Loss: 0.141375
# Epoch 1, Batch 228, Loss: 0.031230
# Epoch 1, Batch 229, Loss: 0.070811
# Epoch 1, Batch 230, Loss: 0.073166
# Epoch 1, Batch 231, Loss: 0.021425
# Epoch 1, Batch 232, Loss: 0.019440
# Epoch 1, Batch 233, Loss: 0.089692
# Epoch 1, Batch 234, Loss: 0.086482
# Epoch 1, Batch 235, Loss: 0.056511
# Epoch 1, Batch 236, Loss: 0.018063
# Epoch 1, Batch 237, Loss: 0.133623
# Epoch 1, Batch 238, Loss: 0.125432
# Epoch 1, Batch 239, Loss: 0.103124
# Epoch 1, Batch 240, Loss: 0.125374
# Epoch 1, Batch 241, Loss: 0.029652
# Epoch 1, Batch 242, Loss: 0.069994
# Epoch 1, Batch 243, Loss: 0.059440
# Epoch 1, Batch 244, Loss: 0.038397
# Epoch 1, Batch 245, Loss: 0.089683
# Epoch 1, Batch 246, Loss: 0.082662
# Epoch 1, Batch 247, Loss: 0.060587
# Epoch 1, Batch 248, Loss: 0.085368
# Epoch 1, Batch 249, Loss: 0.031008
# Epoch 1, Batch 250, Loss: 0.061071
# Epoch 1, Batch 251, Loss: 0.146819
# Epoch 1, Batch 252, Loss: 0.064729
# Epoch 1, Batch 253, Loss: 0.143492
# Epoch 1, Batch 254, Loss: 0.056244
# Epoch 1, Batch 255, Loss: 0.049933
# Epoch 1, Batch 256, Loss: 0.019713
# Epoch 1, Batch 257, Loss: 0.119687
# Epoch 1, Batch 258, Loss: 0.083390
# Epoch 1, Batch 259, Loss: 0.105735
# Epoch 1, Batch 260, Loss: 0.074543
# Epoch 1, Batch 261, Loss: 0.021910
# Epoch 1, Batch 262, Loss: 0.013579
# Epoch 1, Batch 263, Loss: 0.065277
# Epoch 1, Batch 264, Loss: 0.105832
# Epoch 1, Batch 265, Loss: 0.130452
# Epoch 1, Batch 266, Loss: 0.040754
# Epoch 1, Batch 267, Loss: 0.067042
# Epoch 1, Batch 268, Loss: 0.042668
# Epoch 1, Batch 269, Loss: 0.023391
# Epoch 1, Batch 270, Loss: 0.139380
# Epoch 1, Batch 271, Loss: 0.033108
# Epoch 1, Batch 272, Loss: 0.082094
# Epoch 1, Batch 273, Loss: 0.123378
# Epoch 1, Batch 274, Loss: 0.022279
# Epoch 1, Batch 275, Loss: 0.036547
# Epoch 1, Batch 276, Loss: 0.041269
# Epoch 1, Batch 277, Loss: 0.015338
# Epoch 1, Batch 278, Loss: 0.017834
# Epoch 1, Batch 279, Loss: 0.125179
# Epoch 1, Batch 280, Loss: 0.034345
# Epoch 1, Batch 281, Loss: 0.044871
# Epoch 1, Batch 282, Loss: 0.052897
# Epoch 1, Batch 283, Loss: 0.093977
# Epoch 1, Batch 284, Loss: 0.064263
# Epoch 1, Batch 285, Loss: 0.058919
# Epoch 1, Batch 286, Loss: 0.056894
# Epoch 1, Batch 287, Loss: 0.071836
# Epoch 1, Batch 288, Loss: 0.032263
# Epoch 1, Batch 289, Loss: 0.030472
# Epoch 1, Batch 290, Loss: 0.110714
# Epoch 1, Batch 291, Loss: 0.147616
# Epoch 1, Batch 292, Loss: 0.019117
# Epoch 1, Batch 293, Loss: 0.170600
# Epoch 1, Batch 294, Loss: 0.164649
# Epoch 1, Batch 295, Loss: 0.123048
# Epoch 1, Batch 296, Loss: 0.054413
# Epoch 1, Batch 297, Loss: 0.046448
# Epoch 1, Batch 298, Loss: 0.014943
# Epoch 1, Batch 299, Loss: 0.029949
# Epoch 1, Batch 300, Loss: 0.013836
# Epoch 1, Batch 301, Loss: 0.069361
# Epoch 1, Batch 302, Loss: 0.042459
# Epoch 1, Batch 303, Loss: 0.195801
# Epoch 1, Batch 304, Loss: 0.006947
# Epoch 1, Batch 305, Loss: 0.010426
# Epoch 1, Batch 306, Loss: 0.068595
# Epoch 1, Batch 307, Loss: 0.104609
# Epoch 1, Batch 308, Loss: 0.023491
# Epoch 1, Batch 309, Loss: 0.139145
# Epoch 1, Batch 310, Loss: 0.090893
# Epoch 1, Batch 311, Loss: 0.099427
# Epoch 1, Batch 312, Loss: 0.175789
# Epoch 1, Batch 313, Loss: 0.107584
# Epoch 1, Batch 314, Loss: 0.193064
# Epoch 1, Batch 315, Loss: 0.093033
# Epoch 1, Batch 316, Loss: 0.018402
# Epoch 1, Batch 317, Loss: 0.049850
# Epoch 1, Batch 318, Loss: 0.012468
# Epoch 1, Batch 319, Loss: 0.132026
# Epoch 1, Batch 320, Loss: 0.057200
# Epoch 1, Batch 321, Loss: 0.083913
# Epoch 1, Batch 322, Loss: 0.041241
# Epoch 1, Batch 323, Loss: 0.049942
# Epoch 1, Batch 324, Loss: 0.055139
# Epoch 1, Batch 325, Loss: 0.102166
# Epoch 1, Batch 326, Loss: 0.048842
# Epoch 1, Batch 327, Loss: 0.082469
# Epoch 1, Batch 328, Loss: 0.089167
# Epoch 1, Batch 329, Loss: 0.065998
# Epoch 1, Batch 330, Loss: 0.012203
# Epoch 1, Batch 331, Loss: 0.109407
# Epoch 1, Batch 332, Loss: 0.083140
# Epoch 1, Batch 333, Loss: 0.061641
# Epoch 1, Batch 334, Loss: 0.014028
# Epoch 1, Batch 335, Loss: 0.036877
# Epoch 1, Batch 336, Loss: 0.017296
# Epoch 1, Batch 337, Loss: 0.021577
# Epoch 1, Batch 338, Loss: 0.041056
# Epoch 1, Batch 339, Loss: 0.077446
# Epoch 1, Batch 340, Loss: 0.161072
# Epoch 1, Batch 341, Loss: 0.068678
# Epoch 1, Batch 342, Loss: 0.062959
# Epoch 1, Batch 343, Loss: 0.041890
# Epoch 1, Batch 344, Loss: 0.004131
# Epoch 1, Batch 345, Loss: 0.073243
# Epoch 1, Batch 346, Loss: 0.066722
# Epoch 1, Batch 347, Loss: 0.258497
# Epoch 1, Batch 348, Loss: 0.142162
# Epoch 1, Batch 349, Loss: 0.058583
# Epoch 1, Batch 350, Loss: 0.069047
# Epoch 1, Batch 351, Loss: 0.076757
# Epoch 1, Batch 352, Loss: 0.061484
# Epoch 1, Batch 353, Loss: 0.178753
# Epoch 1, Batch 354, Loss: 0.043213
# Epoch 1, Batch 355, Loss: 0.068683
# Epoch 1, Batch 356, Loss: 0.076197
# Epoch 1, Batch 357, Loss: 0.266002
# Epoch 1, Batch 358, Loss: 0.079241
# Epoch 1, Batch 359, Loss: 0.043005
# Epoch 1, Batch 360, Loss: 0.103074
# Epoch 1, Batch 361, Loss: 0.019468
# Epoch 1, Batch 362, Loss: 0.022870
# Epoch 1, Batch 363, Loss: 0.053926
# Epoch 1, Batch 364, Loss: 0.041692
# Epoch 1, Batch 365, Loss: 0.068606
# Epoch 1, Batch 366, Loss: 0.020446
# Epoch 1, Batch 367, Loss: 0.022802
# Epoch 1, Batch 368, Loss: 0.081062
# Epoch 1, Batch 369, Loss: 0.031569
# Epoch 1, Batch 370, Loss: 0.033338
# Epoch 1, Batch 371, Loss: 0.098270
# Epoch 1, Batch 372, Loss: 0.042673
# Epoch 1, Batch 373, Loss: 0.065460
# Epoch 1, Batch 374, Loss: 0.006145
# Epoch 1, Batch 375, Loss: 0.049016
# Epoch 1, Batch 376, Loss: 0.017337
# Epoch 1, Batch 377, Loss: 0.011442
# Epoch 1, Batch 378, Loss: 0.065040
# Epoch 1, Batch 379, Loss: 0.075841
# Epoch 1, Batch 380, Loss: 0.073966
# Epoch 1, Batch 381, Loss: 0.051719
# Epoch 1, Batch 382, Loss: 0.084534
# Epoch 1, Batch 383, Loss: 0.081326
# Epoch 1, Batch 384, Loss: 0.042524
# Epoch 1, Batch 385, Loss: 0.013841
# Epoch 1, Batch 386, Loss: 0.041753
# Epoch 1, Batch 387, Loss: 0.077655
# Epoch 1, Batch 388, Loss: 0.011215
# Epoch 1, Batch 389, Loss: 0.021915
# Epoch 1, Batch 390, Loss: 0.114394
# Epoch 1, Batch 391, Loss: 0.006568
# Epoch 1, Batch 392, Loss: 0.083477
# Epoch 1, Batch 393, Loss: 0.011346
# Epoch 1, Batch 394, Loss: 0.036044
# Epoch 1, Batch 395, Loss: 0.044232
# Epoch 1, Batch 396, Loss: 0.026647
# Epoch 1, Batch 397, Loss: 0.043714
# Epoch 1, Batch 398, Loss: 0.165399
# Epoch 1, Batch 399, Loss: 0.053550
# Epoch 1, Batch 400, Loss: 0.162121
# Epoch 1, Batch 401, Loss: 0.020968
# Epoch 1, Batch 402, Loss: 0.086734
# Epoch 1, Batch 403, Loss: 0.055446
# Epoch 1, Batch 404, Loss: 0.008960
# Epoch 1, Batch 405, Loss: 0.115901
# Epoch 1, Batch 406, Loss: 0.115591
# Epoch 1, Batch 407, Loss: 0.019330
# Epoch 1, Batch 408, Loss: 0.065885
# Epoch 1, Batch 409, Loss: 0.011440
# Epoch 1, Batch 410, Loss: 0.006076
# Epoch 1, Batch 411, Loss: 0.008378
# Epoch 1, Batch 412, Loss: 0.014874
# Epoch 1, Batch 413, Loss: 0.024298
# Epoch 1, Batch 414, Loss: 0.046114
# Epoch 1, Batch 415, Loss: 0.027292
# Epoch 1, Batch 416, Loss: 0.016942
# Epoch 1, Batch 417, Loss: 0.214716
# Epoch 1, Batch 418, Loss: 0.049068
# Epoch 1, Batch 419, Loss: 0.087020
# Epoch 1, Batch 420, Loss: 0.096923
# Epoch 1, Batch 421, Loss: 0.107638
# Epoch 1, Batch 422, Loss: 0.099345
# Epoch 1, Batch 423, Loss: 0.098722
# Epoch 1, Batch 424, Loss: 0.132844
# Epoch 1, Batch 425, Loss: 0.088515
# Epoch 1, Batch 426, Loss: 0.064937
# Epoch 1, Batch 427, Loss: 0.143912
# Epoch 1, Batch 428, Loss: 0.025441
# Epoch 1, Batch 429, Loss: 0.055517
# Epoch 1, Batch 430, Loss: 0.009214
# Epoch 1, Batch 431, Loss: 0.016778
# Epoch 1, Batch 432, Loss: 0.065643
# Epoch 1, Batch 433, Loss: 0.148663
# Epoch 1, Batch 434, Loss: 0.022378
# Epoch 1, Batch 435, Loss: 0.124574
# Epoch 1, Batch 436, Loss: 0.090902
# Epoch 1, Batch 437, Loss: 0.114261
# Epoch 1, Batch 438, Loss: 0.133688
# Epoch 1, Batch 439, Loss: 0.059333
# Epoch 1, Batch 440, Loss: 0.115608
# Epoch 1, Batch 441, Loss: 0.144963
# Epoch 1, Batch 442, Loss: 0.036888
# Epoch 1, Batch 443, Loss: 0.190920
# Epoch 1, Batch 444, Loss: 0.034365
# Epoch 1, Batch 445, Loss: 0.106120
# Epoch 1, Batch 446, Loss: 0.083707
# Epoch 1, Batch 447, Loss: 0.009053
# Epoch 1, Batch 448, Loss: 0.053246
# Epoch 1, Batch 449, Loss: 0.119892
# Epoch 1, Batch 450, Loss: 0.014210
# Epoch 1, Batch 451, Loss: 0.008828
# Epoch 1, Batch 452, Loss: 0.026619
# Epoch 1, Batch 453, Loss: 0.055552
# Epoch 1, Batch 454, Loss: 0.075505
# Epoch 1, Batch 455, Loss: 0.104936
# Epoch 1, Batch 456, Loss: 0.027463
# Epoch 1, Batch 457, Loss: 0.110400
# Epoch 1, Batch 458, Loss: 0.077400
# Epoch 1, Batch 459, Loss: 0.087893
# Epoch 1, Batch 460, Loss: 0.170871
# Epoch 1, Batch 461, Loss: 0.013795
# Epoch 1, Batch 462, Loss: 0.042302
# Epoch 1, Batch 463, Loss: 0.052363
# Epoch 1, Batch 464, Loss: 0.047318
# Epoch 1, Batch 465, Loss: 0.170250
# Epoch 1, Batch 466, Loss: 0.137700
# Epoch 1, Batch 467, Loss: 0.029250
# Epoch 1, Batch 468, Loss: 0.204979
# Epoch 1, Batch 469, Loss: 0.079952
# Epoch 1, Batch 470, Loss: 0.102091
# Epoch 1, Batch 471, Loss: 0.031821
# Epoch 1, Batch 472, Loss: 0.016322
# Epoch 1, Batch 473, Loss: 0.049026
# Epoch 1, Batch 474, Loss: 0.029110
# Epoch 1, Batch 475, Loss: 0.046204
# Epoch 1, Batch 476, Loss: 0.054099
# Epoch 1, Batch 477, Loss: 0.013704
# Epoch 1, Batch 478, Loss: 0.027499
# Epoch 1, Batch 479, Loss: 0.060929
# Epoch 1, Batch 480, Loss: 0.084812
# Epoch 1, Batch 481, Loss: 0.025304
# Epoch 1, Batch 482, Loss: 0.074236
# Epoch 1, Batch 483, Loss: 0.095380
# Epoch 1, Batch 484, Loss: 0.067443
# Epoch 1, Batch 485, Loss: 0.024532
# Epoch 1, Batch 486, Loss: 0.068559
# Epoch 1, Batch 487, Loss: 0.028417
# Epoch 1, Batch 488, Loss: 0.040733
# Epoch 1, Batch 489, Loss: 0.086742
# Epoch 1, Batch 490, Loss: 0.051388
# Epoch 1, Batch 491, Loss: 0.106450
# Epoch 1, Batch 492, Loss: 0.036315
# Epoch 1, Batch 493, Loss: 0.009421
# Epoch 1, Batch 494, Loss: 0.101453
# Epoch 1, Batch 495, Loss: 0.120118
# Epoch 1, Batch 496, Loss: 0.048861
# Epoch 1, Batch 497, Loss: 0.057942
# Epoch 1, Batch 498, Loss: 0.021510
# Epoch 1, Batch 499, Loss: 0.078869
# Epoch 1, Batch 500, Loss: 0.020566
# Epoch 1, Batch 501, Loss: 0.048920
# Epoch 1, Batch 502, Loss: 0.063582
# Epoch 1, Batch 503, Loss: 0.056053
# Epoch 1, Batch 504, Loss: 0.145308
# Epoch 1, Batch 505, Loss: 0.028416
# Epoch 1, Batch 506, Loss: 0.092062
# Epoch 1, Batch 507, Loss: 0.031553
# Epoch 1, Batch 508, Loss: 0.086582
# Epoch 1, Batch 509, Loss: 0.015147
# Epoch 1, Batch 510, Loss: 0.010711
# Epoch 1, Batch 511, Loss: 0.023355
# Epoch 1, Batch 512, Loss: 0.017291
# Epoch 1, Batch 513, Loss: 0.052636
# Epoch 1, Batch 514, Loss: 0.102927
# Epoch 1, Batch 515, Loss: 0.050384
# Epoch 1, Batch 516, Loss: 0.042856
# Epoch 1, Batch 517, Loss: 0.056034
# Epoch 1, Batch 518, Loss: 0.036900
# Epoch 1, Batch 519, Loss: 0.025065
# Epoch 1, Batch 520, Loss: 0.034805
# Epoch 1, Batch 521, Loss: 0.007465
# Epoch 1, Batch 522, Loss: 0.086825
# Epoch 1, Batch 523, Loss: 0.252053
# Epoch 1, Batch 524, Loss: 0.129402
# Epoch 1, Batch 525, Loss: 0.061607
# Epoch 1, Batch 526, Loss: 0.088495
# Epoch 1, Batch 527, Loss: 0.071123
# Epoch 1, Batch 528, Loss: 0.132381
# Epoch 1, Batch 529, Loss: 0.117199
# Epoch 1, Batch 530, Loss: 0.083864
# Epoch 1, Batch 531, Loss: 0.116588
# Epoch 1, Batch 532, Loss: 0.060065
# Epoch 1, Batch 533, Loss: 0.039650
# Epoch 1, Batch 534, Loss: 0.022108
# Epoch 1, Batch 535, Loss: 0.196580
# Epoch 1, Batch 536, Loss: 0.016491
# Epoch 1, Batch 537, Loss: 0.019461
# Epoch 1, Batch 538, Loss: 0.092574
# Epoch 1, Batch 539, Loss: 0.098295
# Epoch 1, Batch 540, Loss: 0.062068
# Epoch 1, Batch 541, Loss: 0.025246
# Epoch 1, Batch 542, Loss: 0.044308
# Epoch 1, Batch 543, Loss: 0.039998
# Epoch 1, Batch 544, Loss: 0.053131
# Epoch 1, Batch 545, Loss: 0.079544
# Epoch 1, Batch 546, Loss: 0.022694
# Epoch 1, Batch 547, Loss: 0.023018
# Epoch 1, Batch 548, Loss: 0.155716
# Epoch 1, Batch 549, Loss: 0.107789
# Epoch 1, Batch 550, Loss: 0.084147
# Epoch 1, Batch 551, Loss: 0.045456
# Epoch 1, Batch 552, Loss: 0.146135
# Epoch 1, Batch 553, Loss: 0.019782
# Epoch 1, Batch 554, Loss: 0.159171
# Epoch 1, Batch 555, Loss: 0.032291
# Epoch 1, Batch 556, Loss: 0.086250
# Epoch 1, Batch 557, Loss: 0.073365
# Epoch 1, Batch 558, Loss: 0.043349
# Epoch 1, Batch 559, Loss: 0.079875
# Epoch 1, Batch 560, Loss: 0.223040
# Epoch 1, Batch 561, Loss: 0.056833
# Epoch 1, Batch 562, Loss: 0.062919
# Epoch 1, Batch 563, Loss: 0.096372
# Epoch 1, Batch 564, Loss: 0.040337
# Epoch 1, Batch 565, Loss: 0.112791
# Epoch 1, Batch 566, Loss: 0.022012
# Epoch 1, Batch 567, Loss: 0.053838
# Epoch 1, Batch 568, Loss: 0.137573
# Epoch 1, Batch 569, Loss: 0.118233
# Epoch 1, Batch 570, Loss: 0.106503
# Epoch 1, Batch 571, Loss: 0.046205
# Epoch 1, Batch 572, Loss: 0.076291
# Epoch 1, Batch 573, Loss: 0.030589
# Epoch 1, Batch 574, Loss: 0.055347
# Epoch 1, Batch 575, Loss: 0.097928
# Epoch 1, Batch 576, Loss: 0.017427
# Epoch 1, Batch 577, Loss: 0.080978
# Epoch 1, Batch 578, Loss: 0.055268
# Epoch 1, Batch 579, Loss: 0.024994
# Epoch 1, Batch 580, Loss: 0.066772
# Epoch 1, Batch 581, Loss: 0.040933
# Epoch 1, Batch 582, Loss: 0.016647
# Epoch 1, Batch 583, Loss: 0.038342
# Epoch 1, Batch 584, Loss: 0.046414
# Epoch 1, Batch 585, Loss: 0.058582
# Epoch 1, Batch 586, Loss: 0.055060
# Epoch 1, Batch 587, Loss: 0.051325
# Epoch 1, Batch 588, Loss: 0.167832
# Epoch 1, Batch 589, Loss: 0.094488
# Epoch 1, Batch 590, Loss: 0.040087
# Epoch 1, Batch 591, Loss: 0.038587
# Epoch 1, Batch 592, Loss: 0.107198
# Epoch 1, Batch 593, Loss: 0.177346
# Epoch 1, Batch 594, Loss: 0.050685
# Epoch 1, Batch 595, Loss: 0.047248
# Epoch 1, Batch 596, Loss: 0.051497
# Epoch 1, Batch 597, Loss: 0.093116
# Epoch 1, Batch 598, Loss: 0.023390
# Epoch 1, Batch 599, Loss: 0.020604
# Epoch 1, Batch 600, Loss: 0.112711
# Epoch 1, Batch 601, Loss: 0.009493
# Epoch 1, Batch 602, Loss: 0.052196
# Epoch 1, Batch 603, Loss: 0.366075
# Epoch 1, Batch 604, Loss: 0.014073
# Epoch 1, Batch 605, Loss: 0.045700
# Epoch 1, Batch 606, Loss: 0.010380
# Epoch 1, Batch 607, Loss: 0.106252
# Epoch 1, Batch 608, Loss: 0.059008
# Epoch 1, Batch 609, Loss: 0.074979
# Epoch 1, Batch 610, Loss: 0.053510
# Epoch 1, Batch 611, Loss: 0.032610
# Epoch 1, Batch 612, Loss: 0.126524
# Epoch 1, Batch 613, Loss: 0.119655
# Epoch 1, Batch 614, Loss: 0.087207
# Epoch 1, Batch 615, Loss: 0.066347
# Epoch 1, Batch 616, Loss: 0.095405
# Epoch 1, Batch 617, Loss: 0.011398
# Epoch 1, Batch 618, Loss: 0.030075
# Epoch 1, Batch 619, Loss: 0.017661
# Epoch 1, Batch 620, Loss: 0.075679
# Epoch 1, Batch 621, Loss: 0.036761
# Epoch 1, Batch 622, Loss: 0.116910
# Epoch 1, Batch 623, Loss: 0.057818
# Epoch 1, Batch 624, Loss: 0.027532
# Epoch 1, Batch 625, Loss: 0.030309
# Epoch 1, Batch 626, Loss: 0.031350
# Epoch 1, Batch 627, Loss: 0.155344
# Epoch 1, Batch 628, Loss: 0.073871
# Epoch 1, Batch 629, Loss: 0.063644
# Epoch 1, Batch 630, Loss: 0.095203
# Epoch 1, Batch 631, Loss: 0.064019
# Epoch 1, Batch 632, Loss: 0.042882
# Epoch 1, Batch 633, Loss: 0.070895
# Epoch 1, Batch 634, Loss: 0.116273
# Epoch 1, Batch 635, Loss: 0.135942
# Epoch 1, Batch 636, Loss: 0.023100
# Epoch 1, Batch 637, Loss: 0.035273
# Epoch 1, Batch 638, Loss: 0.041373
# Epoch 1, Batch 639, Loss: 0.244862
# Epoch 1, Batch 640, Loss: 0.119122
# Epoch 1, Batch 641, Loss: 0.041850
# Epoch 1, Batch 642, Loss: 0.154022
# Epoch 1, Batch 643, Loss: 0.141328
# Epoch 1, Batch 644, Loss: 0.032396
# Epoch 1, Batch 645, Loss: 0.067123
# Epoch 1, Batch 646, Loss: 0.041724
# Epoch 1, Batch 647, Loss: 0.074610
# Epoch 1, Batch 648, Loss: 0.034367
# Epoch 1, Batch 649, Loss: 0.179930
# Epoch 1, Batch 650, Loss: 0.159645
# Epoch 1, Batch 651, Loss: 0.081436
# Epoch 1, Batch 652, Loss: 0.010223
# Epoch 1, Batch 653, Loss: 0.015918
# Epoch 1, Batch 654, Loss: 0.068459
# Epoch 1, Batch 655, Loss: 0.113322
# Epoch 1, Batch 656, Loss: 0.230696
# Warning: test set has no labels, skip accuracy evaluation.
# Saved: d:\CZ_WorkSpace\ai学习\深度学习实践\task1\task1_2\checkpoints\model_epoch_1.pth
# Epoch 2, Batch 0, Loss: 0.065981
# Epoch 2, Batch 1, Loss: 0.005215
# Epoch 2, Batch 2, Loss: 0.016370
# Epoch 2, Batch 3, Loss: 0.022808
# Epoch 2, Batch 4, Loss: 0.024032
# Epoch 2, Batch 5, Loss: 0.049622
# Epoch 2, Batch 6, Loss: 0.028631
# Epoch 2, Batch 7, Loss: 0.008377
# Epoch 2, Batch 8, Loss: 0.035489
# Epoch 2, Batch 9, Loss: 0.130085
# Epoch 2, Batch 10, Loss: 0.030672
# Epoch 2, Batch 11, Loss: 0.139164
# Epoch 2, Batch 12, Loss: 0.067593
# Epoch 2, Batch 13, Loss: 0.053588
# Epoch 2, Batch 14, Loss: 0.029231
# Epoch 2, Batch 15, Loss: 0.115461
# Epoch 2, Batch 16, Loss: 0.025984
# Epoch 2, Batch 17, Loss: 0.117270
# Epoch 2, Batch 18, Loss: 0.033238
# Epoch 2, Batch 19, Loss: 0.061735
# Epoch 2, Batch 20, Loss: 0.109173
# Epoch 2, Batch 21, Loss: 0.077645
# Epoch 2, Batch 22, Loss: 0.023529
# Epoch 2, Batch 23, Loss: 0.088397
# Epoch 2, Batch 24, Loss: 0.020259
# Epoch 2, Batch 25, Loss: 0.049423
# Epoch 2, Batch 26, Loss: 0.012288
# Epoch 2, Batch 27, Loss: 0.035037
# Epoch 2, Batch 28, Loss: 0.081828
# Epoch 2, Batch 29, Loss: 0.028964
# Epoch 2, Batch 30, Loss: 0.137376
# Epoch 2, Batch 31, Loss: 0.019618
# Epoch 2, Batch 32, Loss: 0.120673
# Epoch 2, Batch 33, Loss: 0.138801
# Epoch 2, Batch 34, Loss: 0.059551
# Epoch 2, Batch 35, Loss: 0.019282
# Epoch 2, Batch 36, Loss: 0.011113
# Epoch 2, Batch 37, Loss: 0.039727
# Epoch 2, Batch 38, Loss: 0.140414
# Epoch 2, Batch 39, Loss: 0.097501
# Epoch 2, Batch 40, Loss: 0.057852
# Epoch 2, Batch 41, Loss: 0.066647
# Epoch 2, Batch 42, Loss: 0.068506
# Epoch 2, Batch 43, Loss: 0.175841
# Epoch 2, Batch 44, Loss: 0.092706
# Epoch 2, Batch 45, Loss: 0.029429
# Epoch 2, Batch 46, Loss: 0.026761
# Epoch 2, Batch 47, Loss: 0.029941
# Epoch 2, Batch 48, Loss: 0.061185
# Epoch 2, Batch 49, Loss: 0.098390
# Epoch 2, Batch 50, Loss: 0.036354
# Epoch 2, Batch 51, Loss: 0.006988
# Epoch 2, Batch 52, Loss: 0.026232
# Epoch 2, Batch 53, Loss: 0.010535
# Epoch 2, Batch 54, Loss: 0.068382
# Epoch 2, Batch 55, Loss: 0.036578
# Epoch 2, Batch 56, Loss: 0.039368
# ...
# Epoch 9, Batch 204, Loss: 0.006381
# Epoch 9, Batch 205, Loss: 0.023709
# Epoch 9, Batch 206, Loss: 0.005678
# Epoch 9, Batch 207, Loss: 0.003725
# Epoch 9, Batch 208, Loss: 0.011144
# Epoch 9, Batch 209, Loss: 0.001445
# Epoch 9, Batch 210, Loss: 0.000831
# Epoch 9, Batch 211, Loss: 0.023060
# Epoch 9, Batch 212, Loss: 0.001288
# Epoch 9, Batch 213, Loss: 0.019702
# Epoch 9, Batch 214, Loss: 0.011720
# Epoch 9, Batch 215, Loss: 0.001416
# Epoch 9, Batch 216, Loss: 0.024237
# Epoch 9, Batch 217, Loss: 0.001101
# Epoch 9, Batch 218, Loss: 0.001062
# Epoch 9, Batch 219, Loss: 0.024154
# Epoch 9, Batch 220, Loss: 0.003038
# Epoch 9, Batch 221, Loss: 0.000096
# Epoch 9, Batch 222, Loss: 0.013386
# Epoch 9, Batch 223, Loss: 0.000639
# Epoch 9, Batch 224, Loss: 0.035190
# Epoch 9, Batch 225, Loss: 0.004464
# Epoch 9, Batch 226, Loss: 0.000186
# Epoch 9, Batch 227, Loss: 0.009271
# Epoch 9, Batch 228, Loss: 0.001935
# Epoch 9, Batch 229, Loss: 0.009037
# Epoch 9, Batch 230, Loss: 0.002396
# Epoch 9, Batch 231, Loss: 0.002719
# Epoch 9, Batch 232, Loss: 0.001048
# Epoch 9, Batch 233, Loss: 0.002424
# Epoch 9, Batch 234, Loss: 0.004084
# Epoch 9, Batch 235, Loss: 0.015980
# Epoch 9, Batch 236, Loss: 0.011949
# Epoch 9, Batch 237, Loss: 0.001083
# Epoch 9, Batch 238, Loss: 0.005339
# Epoch 9, Batch 239, Loss: 0.025445
# Epoch 9, Batch 240, Loss: 0.000189
# Epoch 9, Batch 241, Loss: 0.000158
# Epoch 9, Batch 242, Loss: 0.000607
# Epoch 9, Batch 243, Loss: 0.007860
# Epoch 9, Batch 244, Loss: 0.023945
# Epoch 9, Batch 245, Loss: 0.001329
# Epoch 9, Batch 246, Loss: 0.000549
# Epoch 9, Batch 247, Loss: 0.023376
# Epoch 9, Batch 248, Loss: 0.009160
# Epoch 9, Batch 249, Loss: 0.015793
# Epoch 9, Batch 250, Loss: 0.000542
# Epoch 9, Batch 251, Loss: 0.000960
# Epoch 9, Batch 252, Loss: 0.004941
# Epoch 9, Batch 253, Loss: 0.001611
# Epoch 9, Batch 254, Loss: 0.000175
# Epoch 9, Batch 255, Loss: 0.002038
# Epoch 9, Batch 256, Loss: 0.000973
# Epoch 9, Batch 257, Loss: 0.003057
# Epoch 9, Batch 258, Loss: 0.000787
# Epoch 9, Batch 259, Loss: 0.006074
# Epoch 9, Batch 260, Loss: 0.020167
# Epoch 9, Batch 261, Loss: 0.001647
# Epoch 9, Batch 262, Loss: 0.001655
# Epoch 9, Batch 263, Loss: 0.007327
# Epoch 9, Batch 264, Loss: 0.001352
# Epoch 9, Batch 265, Loss: 0.019499
# Epoch 9, Batch 266, Loss: 0.006371
# Epoch 9, Batch 267, Loss: 0.084663
# Epoch 9, Batch 268, Loss: 0.000739
# Epoch 9, Batch 269, Loss: 0.002071
# Epoch 9, Batch 270, Loss: 0.003344
# Epoch 9, Batch 271, Loss: 0.000944
# Epoch 9, Batch 272, Loss: 0.004843
# Epoch 9, Batch 273, Loss: 0.004476
# Epoch 9, Batch 274, Loss: 0.045639
# Epoch 9, Batch 275, Loss: 0.011234
# Epoch 9, Batch 276, Loss: 0.015242
# Epoch 9, Batch 277, Loss: 0.016739
# Epoch 9, Batch 278, Loss: 0.008229
# Epoch 9, Batch 279, Loss: 0.003929
# Epoch 9, Batch 280, Loss: 0.001721
# Epoch 9, Batch 281, Loss: 0.002168
# Epoch 9, Batch 282, Loss: 0.000834
# Epoch 9, Batch 283, Loss: 0.003993
# Epoch 9, Batch 284, Loss: 0.000077
# Epoch 9, Batch 285, Loss: 0.086808
# Epoch 9, Batch 286, Loss: 0.029714
# Epoch 9, Batch 287, Loss: 0.012919
# Epoch 9, Batch 288, Loss: 0.004311
# Epoch 9, Batch 289, Loss: 0.014618
# Epoch 9, Batch 290, Loss: 0.016979
# Epoch 9, Batch 291, Loss: 0.001275
# Epoch 9, Batch 292, Loss: 0.001414
# Epoch 9, Batch 293, Loss: 0.006477
# Epoch 9, Batch 294, Loss: 0.002861
# Epoch 9, Batch 295, Loss: 0.001212
# Epoch 9, Batch 296, Loss: 0.010779
# Epoch 9, Batch 297, Loss: 0.007230
# Epoch 9, Batch 298, Loss: 0.006495
# Epoch 9, Batch 299, Loss: 0.017470
# Epoch 9, Batch 300, Loss: 0.005504
# Epoch 9, Batch 301, Loss: 0.013264
# Epoch 9, Batch 302, Loss: 0.000236
# Epoch 9, Batch 303, Loss: 0.002024
# Epoch 9, Batch 304, Loss: 0.001785
# Epoch 9, Batch 305, Loss: 0.000637
# Epoch 9, Batch 306, Loss: 0.013909
# Epoch 9, Batch 307, Loss: 0.030628
# Epoch 9, Batch 308, Loss: 0.002151
# Epoch 9, Batch 309, Loss: 0.000461
# Epoch 9, Batch 310, Loss: 0.000120
# Epoch 9, Batch 311, Loss: 0.001224
# Epoch 9, Batch 312, Loss: 0.000897
# Epoch 9, Batch 313, Loss: 0.002350
# Epoch 9, Batch 314, Loss: 0.004584
# Epoch 9, Batch 315, Loss: 0.036687
# Epoch 9, Batch 316, Loss: 0.005834
# Epoch 9, Batch 317, Loss: 0.016038
# Epoch 9, Batch 318, Loss: 0.003491
# Epoch 9, Batch 319, Loss: 0.030451
# Epoch 9, Batch 320, Loss: 0.012598
# Epoch 9, Batch 321, Loss: 0.001339
# Epoch 9, Batch 322, Loss: 0.000838
# Epoch 9, Batch 323, Loss: 0.008229
# Epoch 9, Batch 324, Loss: 0.002134
# Epoch 9, Batch 325, Loss: 0.000784
# Epoch 9, Batch 326, Loss: 0.020584
# Epoch 9, Batch 327, Loss: 0.041003
# Epoch 9, Batch 328, Loss: 0.000608
# Epoch 9, Batch 329, Loss: 0.018307
# Epoch 9, Batch 330, Loss: 0.002268
# Epoch 9, Batch 331, Loss: 0.041909
# Epoch 9, Batch 332, Loss: 0.005169
# Epoch 9, Batch 333, Loss: 0.045966
# Epoch 9, Batch 334, Loss: 0.014703
# Epoch 9, Batch 335, Loss: 0.002775
# Epoch 9, Batch 336, Loss: 0.001318
# Epoch 9, Batch 337, Loss: 0.000316
# Epoch 9, Batch 338, Loss: 0.000521
# Epoch 9, Batch 339, Loss: 0.011579
# Epoch 9, Batch 340, Loss: 0.005648
# Epoch 9, Batch 341, Loss: 0.002585
# Epoch 9, Batch 342, Loss: 0.000102
# Epoch 9, Batch 343, Loss: 0.018517
# Epoch 9, Batch 344, Loss: 0.007295
# Epoch 9, Batch 345, Loss: 0.014185
# Epoch 9, Batch 346, Loss: 0.001487
# Epoch 9, Batch 347, Loss: 0.040024
# Epoch 9, Batch 348, Loss: 0.002936
# Epoch 9, Batch 349, Loss: 0.001577
# Epoch 9, Batch 350, Loss: 0.003756
# Epoch 9, Batch 351, Loss: 0.001008
# Epoch 9, Batch 352, Loss: 0.000134
# Epoch 9, Batch 353, Loss: 0.000676
# Epoch 9, Batch 354, Loss: 0.009840
# Epoch 9, Batch 355, Loss: 0.000297
# Epoch 9, Batch 356, Loss: 0.015330
# Epoch 9, Batch 357, Loss: 0.010817
# Epoch 9, Batch 358, Loss: 0.000259
# Epoch 9, Batch 359, Loss: 0.041205
# Epoch 9, Batch 360, Loss: 0.001748
# Epoch 9, Batch 361, Loss: 0.062218
# Epoch 9, Batch 362, Loss: 0.000713
# Epoch 9, Batch 363, Loss: 0.001844
# Epoch 9, Batch 364, Loss: 0.003362
# Epoch 9, Batch 365, Loss: 0.012195
# Epoch 9, Batch 366, Loss: 0.030855
# Epoch 9, Batch 367, Loss: 0.001163
# Epoch 9, Batch 368, Loss: 0.000151
# Epoch 9, Batch 369, Loss: 0.000801
# Epoch 9, Batch 370, Loss: 0.004332
# Epoch 9, Batch 371, Loss: 0.031281
# Epoch 9, Batch 372, Loss: 0.002054
# Epoch 9, Batch 373, Loss: 0.000263
# Epoch 9, Batch 374, Loss: 0.002107
# Epoch 9, Batch 375, Loss: 0.000547
# Epoch 9, Batch 376, Loss: 0.000567
# Epoch 9, Batch 377, Loss: 0.003309
# Epoch 9, Batch 378, Loss: 0.000906
# Epoch 9, Batch 379, Loss: 0.001345
# Epoch 9, Batch 380, Loss: 0.005957
# Epoch 9, Batch 381, Loss: 0.007902
# Epoch 9, Batch 382, Loss: 0.000454
# Epoch 9, Batch 383, Loss: 0.001794
# Epoch 9, Batch 384, Loss: 0.001263
# Epoch 9, Batch 385, Loss: 0.001173
# Epoch 9, Batch 386, Loss: 0.000158
# Epoch 9, Batch 387, Loss: 0.001407
# Epoch 9, Batch 388, Loss: 0.046396
# Epoch 9, Batch 389, Loss: 0.000819
# Epoch 9, Batch 390, Loss: 0.010693
# Epoch 9, Batch 391, Loss: 0.005516
# Epoch 9, Batch 392, Loss: 0.000673
# Epoch 9, Batch 393, Loss: 0.003363
# Epoch 9, Batch 394, Loss: 0.024157
# Epoch 9, Batch 395, Loss: 0.000440
# Epoch 9, Batch 396, Loss: 0.000957
# Epoch 9, Batch 397, Loss: 0.004691
# Epoch 9, Batch 398, Loss: 0.002724
# Epoch 9, Batch 399, Loss: 0.009193
# Epoch 9, Batch 400, Loss: 0.004657
# Epoch 9, Batch 401, Loss: 0.002804
# Epoch 9, Batch 402, Loss: 0.001402
# Epoch 9, Batch 403, Loss: 0.032093
# Epoch 9, Batch 404, Loss: 0.026004
# Epoch 9, Batch 405, Loss: 0.012110
# Epoch 9, Batch 406, Loss: 0.054284
# Epoch 9, Batch 407, Loss: 0.000450
# Epoch 9, Batch 408, Loss: 0.016759
# Epoch 9, Batch 409, Loss: 0.011753
# Epoch 9, Batch 410, Loss: 0.001260
# Epoch 9, Batch 411, Loss: 0.000616
# Epoch 9, Batch 412, Loss: 0.000210
# Epoch 9, Batch 413, Loss: 0.009098
# Epoch 9, Batch 414, Loss: 0.026441
# Epoch 9, Batch 415, Loss: 0.038256
# Epoch 9, Batch 416, Loss: 0.003647
# Epoch 9, Batch 417, Loss: 0.023060
# Epoch 9, Batch 418, Loss: 0.006355
# Epoch 9, Batch 419, Loss: 0.000407
# Epoch 9, Batch 420, Loss: 0.002189
# Epoch 9, Batch 421, Loss: 0.002449
# Epoch 9, Batch 422, Loss: 0.004914
# Epoch 9, Batch 423, Loss: 0.005849
# Epoch 9, Batch 424, Loss: 0.016816
# Epoch 9, Batch 425, Loss: 0.041750
# Epoch 9, Batch 426, Loss: 0.006325
# Epoch 9, Batch 427, Loss: 0.000236
# Epoch 9, Batch 428, Loss: 0.040349
# Epoch 9, Batch 429, Loss: 0.010934
# Epoch 9, Batch 430, Loss: 0.130058
# Epoch 9, Batch 431, Loss: 0.008448
# Epoch 9, Batch 432, Loss: 0.000940
# Epoch 9, Batch 433, Loss: 0.001698
# Epoch 9, Batch 434, Loss: 0.002111
# Epoch 9, Batch 435, Loss: 0.001781
# Epoch 9, Batch 436, Loss: 0.002849
# Epoch 9, Batch 437, Loss: 0.003887
# Epoch 9, Batch 438, Loss: 0.078500
# Epoch 9, Batch 439, Loss: 0.001650
# Epoch 9, Batch 440, Loss: 0.004097
# Epoch 9, Batch 441, Loss: 0.004014
# Epoch 9, Batch 442, Loss: 0.000217
# Epoch 9, Batch 443, Loss: 0.015761
# Epoch 9, Batch 444, Loss: 0.040198
# Epoch 9, Batch 445, Loss: 0.025764
# Epoch 9, Batch 446, Loss: 0.010362
# Epoch 9, Batch 447, Loss: 0.092548
# Epoch 9, Batch 448, Loss: 0.002770
# Epoch 9, Batch 449, Loss: 0.003757
# Epoch 9, Batch 450, Loss: 0.002636
# Epoch 9, Batch 451, Loss: 0.002133
# Epoch 9, Batch 452, Loss: 0.000819
# Epoch 9, Batch 453, Loss: 0.009125
# Epoch 9, Batch 454, Loss: 0.001124
# Epoch 9, Batch 455, Loss: 0.001594
# Epoch 9, Batch 456, Loss: 0.003579
# Epoch 9, Batch 457, Loss: 0.005903
# Epoch 9, Batch 458, Loss: 0.080413
# Epoch 9, Batch 459, Loss: 0.002667
# Epoch 9, Batch 460, Loss: 0.005202
# Epoch 9, Batch 461, Loss: 0.016216
# Epoch 9, Batch 462, Loss: 0.006812
# Epoch 9, Batch 463, Loss: 0.011753
# Epoch 9, Batch 464, Loss: 0.025639
# Epoch 9, Batch 465, Loss: 0.000321
# Epoch 9, Batch 466, Loss: 0.000427
# Epoch 9, Batch 467, Loss: 0.051227
# Epoch 9, Batch 468, Loss: 0.008733
# Epoch 9, Batch 469, Loss: 0.002788
# Epoch 9, Batch 470, Loss: 0.002377
# Epoch 9, Batch 471, Loss: 0.004071
# Epoch 9, Batch 472, Loss: 0.006875
# Epoch 9, Batch 473, Loss: 0.009205
# Epoch 9, Batch 474, Loss: 0.011285
# Epoch 9, Batch 475, Loss: 0.003116
# Epoch 9, Batch 476, Loss: 0.013973
# Epoch 9, Batch 477, Loss: 0.033154
# Epoch 9, Batch 478, Loss: 0.000152
# Epoch 9, Batch 479, Loss: 0.000596
# Epoch 9, Batch 480, Loss: 0.002131
# Epoch 9, Batch 481, Loss: 0.000425
# Epoch 9, Batch 482, Loss: 0.009587
# Epoch 9, Batch 483, Loss: 0.017023
# Epoch 9, Batch 484, Loss: 0.000069
# Epoch 9, Batch 485, Loss: 0.002283
# Epoch 9, Batch 486, Loss: 0.008002
# Epoch 9, Batch 487, Loss: 0.001533
# Epoch 9, Batch 488, Loss: 0.000548
# Epoch 9, Batch 489, Loss: 0.001401
# Epoch 9, Batch 490, Loss: 0.002678
# Epoch 9, Batch 491, Loss: 0.002974
# Epoch 9, Batch 492, Loss: 0.020451
# Epoch 9, Batch 493, Loss: 0.000611
# Epoch 9, Batch 494, Loss: 0.033091
# Epoch 9, Batch 495, Loss: 0.011850
# Epoch 9, Batch 496, Loss: 0.001316
# Epoch 9, Batch 497, Loss: 0.001005
# Epoch 9, Batch 498, Loss: 0.000209
# Epoch 9, Batch 499, Loss: 0.006749
# Epoch 9, Batch 500, Loss: 0.000595
# Epoch 9, Batch 501, Loss: 0.009590
# Epoch 9, Batch 502, Loss: 0.000735
# Epoch 9, Batch 503, Loss: 0.001897
# Epoch 9, Batch 504, Loss: 0.014794
# Epoch 9, Batch 505, Loss: 0.001793
# Epoch 9, Batch 506, Loss: 0.007226
# Epoch 9, Batch 507, Loss: 0.002315
# Epoch 9, Batch 508, Loss: 0.002730
# Epoch 9, Batch 509, Loss: 0.002789
# Epoch 9, Batch 510, Loss: 0.000347
# Epoch 9, Batch 511, Loss: 0.028806
# Epoch 9, Batch 512, Loss: 0.000815
# Epoch 9, Batch 513, Loss: 0.002146
# Epoch 9, Batch 514, Loss: 0.062778
# Epoch 9, Batch 515, Loss: 0.003330
# Epoch 9, Batch 516, Loss: 0.000906
# Epoch 9, Batch 517, Loss: 0.000727
# Epoch 9, Batch 518, Loss: 0.001136
# Epoch 9, Batch 519, Loss: 0.025073
# Epoch 9, Batch 520, Loss: 0.002727
# Epoch 9, Batch 521, Loss: 0.001096
# Epoch 9, Batch 522, Loss: 0.008840
# Epoch 9, Batch 523, Loss: 0.095201
# Epoch 9, Batch 524, Loss: 0.003553
# Epoch 9, Batch 525, Loss: 0.002650
# Epoch 9, Batch 526, Loss: 0.025326
# Epoch 9, Batch 527, Loss: 0.012827
# Epoch 9, Batch 528, Loss: 0.000371
# Epoch 9, Batch 529, Loss: 0.003512
# Epoch 9, Batch 530, Loss: 0.000972
# Epoch 9, Batch 531, Loss: 0.001535
# Epoch 9, Batch 532, Loss: 0.003584
# Epoch 9, Batch 533, Loss: 0.000457
# Epoch 9, Batch 534, Loss: 0.003660
# Epoch 9, Batch 535, Loss: 0.005307
# Epoch 9, Batch 536, Loss: 0.001227
# Epoch 9, Batch 537, Loss: 0.000941
# Epoch 9, Batch 538, Loss: 0.000751
# Epoch 9, Batch 539, Loss: 0.006440
# Epoch 9, Batch 540, Loss: 0.002123
# Epoch 9, Batch 541, Loss: 0.007265
# Epoch 9, Batch 542, Loss: 0.019834
# Epoch 9, Batch 543, Loss: 0.000301
# Epoch 9, Batch 544, Loss: 0.014561
# Epoch 9, Batch 545, Loss: 0.000661
# Epoch 9, Batch 546, Loss: 0.023464
# Epoch 9, Batch 547, Loss: 0.003331
# Epoch 9, Batch 548, Loss: 0.003083
# Epoch 9, Batch 549, Loss: 0.023413
# Epoch 9, Batch 550, Loss: 0.001696
# Epoch 9, Batch 551, Loss: 0.069009
# Epoch 9, Batch 552, Loss: 0.000795
# Epoch 9, Batch 553, Loss: 0.010376
# Epoch 9, Batch 554, Loss: 0.069849
# Epoch 9, Batch 555, Loss: 0.000153
# Epoch 9, Batch 556, Loss: 0.000353
# Epoch 9, Batch 557, Loss: 0.007758
# Epoch 9, Batch 558, Loss: 0.002193
# Epoch 9, Batch 559, Loss: 0.003842
# Epoch 9, Batch 560, Loss: 0.000069
# Epoch 9, Batch 561, Loss: 0.015406
# Epoch 9, Batch 562, Loss: 0.002145
# Epoch 9, Batch 563, Loss: 0.000838
# Epoch 9, Batch 564, Loss: 0.003577
# Epoch 9, Batch 565, Loss: 0.001326
# Epoch 9, Batch 566, Loss: 0.000154
# Epoch 9, Batch 567, Loss: 0.001275
# Epoch 9, Batch 568, Loss: 0.008961
# Epoch 9, Batch 569, Loss: 0.000068
# Epoch 9, Batch 570, Loss: 0.000141
# Epoch 9, Batch 571, Loss: 0.002270
# Epoch 9, Batch 572, Loss: 0.000776
# Epoch 9, Batch 573, Loss: 0.076602
# Epoch 9, Batch 574, Loss: 0.003601
# Epoch 9, Batch 575, Loss: 0.009904
# Epoch 9, Batch 576, Loss: 0.004165
# Epoch 9, Batch 577, Loss: 0.015382
# Epoch 9, Batch 578, Loss: 0.015102
# Epoch 9, Batch 579, Loss: 0.000467
# Epoch 9, Batch 580, Loss: 0.007433
# Epoch 9, Batch 581, Loss: 0.000743
# Epoch 9, Batch 582, Loss: 0.002452
# Epoch 9, Batch 583, Loss: 0.002415
# Epoch 9, Batch 584, Loss: 0.000121
# Epoch 9, Batch 585, Loss: 0.004186
# Epoch 9, Batch 586, Loss: 0.000088
# Epoch 9, Batch 587, Loss: 0.070839
# Epoch 9, Batch 588, Loss: 0.003834
# Epoch 9, Batch 589, Loss: 0.018571
# Epoch 9, Batch 590, Loss: 0.000419
# Epoch 9, Batch 591, Loss: 0.002751
# Epoch 9, Batch 592, Loss: 0.000703
# Epoch 9, Batch 593, Loss: 0.003000
# Epoch 9, Batch 594, Loss: 0.002451
# Epoch 9, Batch 595, Loss: 0.001179
# Epoch 9, Batch 596, Loss: 0.001092
# Epoch 9, Batch 597, Loss: 0.002261
# Epoch 9, Batch 598, Loss: 0.006666
# Epoch 9, Batch 599, Loss: 0.042524
# Epoch 9, Batch 600, Loss: 0.018333
# Epoch 9, Batch 601, Loss: 0.000341
# Epoch 9, Batch 602, Loss: 0.030810
# Epoch 9, Batch 603, Loss: 0.010168
# Epoch 9, Batch 604, Loss: 0.007869
# Epoch 9, Batch 605, Loss: 0.001664
# Epoch 9, Batch 606, Loss: 0.046165
# Epoch 9, Batch 607, Loss: 0.009889
# Epoch 9, Batch 608, Loss: 0.000457
# Epoch 9, Batch 609, Loss: 0.038844
# Epoch 9, Batch 610, Loss: 0.001570
# Epoch 9, Batch 611, Loss: 0.000682
# Epoch 9, Batch 612, Loss: 0.002435
# Epoch 9, Batch 613, Loss: 0.007798
# Epoch 9, Batch 614, Loss: 0.003531
# Epoch 9, Batch 615, Loss: 0.001419
# Epoch 9, Batch 616, Loss: 0.018264
# Epoch 9, Batch 617, Loss: 0.006980
# Epoch 9, Batch 618, Loss: 0.000333
# Epoch 9, Batch 619, Loss: 0.014212
# Epoch 9, Batch 620, Loss: 0.013221
# Epoch 9, Batch 621, Loss: 0.006771
# Epoch 9, Batch 622, Loss: 0.002504
# Epoch 9, Batch 623, Loss: 0.009977
# Epoch 9, Batch 624, Loss: 0.000882
# Epoch 9, Batch 625, Loss: 0.010388
# Epoch 9, Batch 626, Loss: 0.003298
# Epoch 9, Batch 627, Loss: 0.000047
# Epoch 9, Batch 628, Loss: 0.002227
# Epoch 9, Batch 629, Loss: 0.041379
# Epoch 9, Batch 630, Loss: 0.006575
# Epoch 9, Batch 631, Loss: 0.006082
# Epoch 9, Batch 632, Loss: 0.008424
# Epoch 9, Batch 633, Loss: 0.068707
# Epoch 9, Batch 634, Loss: 0.001735
# Epoch 9, Batch 635, Loss: 0.004796
# Epoch 9, Batch 636, Loss: 0.016398
# Epoch 9, Batch 637, Loss: 0.000249
# Epoch 9, Batch 638, Loss: 0.008134
# Epoch 9, Batch 639, Loss: 0.015250
# Epoch 9, Batch 640, Loss: 0.000197
# Epoch 9, Batch 641, Loss: 0.006502
# Epoch 9, Batch 642, Loss: 0.000391
# Epoch 9, Batch 643, Loss: 0.000082
# Epoch 9, Batch 644, Loss: 0.001492
# Epoch 9, Batch 645, Loss: 0.057679
# Epoch 9, Batch 646, Loss: 0.015941
# Epoch 9, Batch 647, Loss: 0.008870
# Epoch 9, Batch 648, Loss: 0.002334
# Epoch 9, Batch 649, Loss: 0.083218
# Epoch 9, Batch 650, Loss: 0.011640
# Epoch 9, Batch 651, Loss: 0.043461
# Epoch 9, Batch 652, Loss: 0.002006
# Epoch 9, Batch 653, Loss: 0.052586
# Epoch 9, Batch 654, Loss: 0.001826
# Epoch 9, Batch 655, Loss: 0.006875
# Epoch 9, Batch 656, Loss: 0.001066
# Warning: test set has no labels, skip accuracy evaluation.
# Saved: d:\CZ_WorkSpace\ai学习\深度学习实践\task1\task1_2\checkpoints\model_epoch_9.pth

# %%
# 9.1) 训练曲线可视化
# 构造 epoch 轴
epochs_axis = list(range(1, len(epoch_losses) + 1))

# 创建画布
plt.figure(figsize=(10, 4))
# 左图：训练损失
plt.subplot(1, 2, 1)
plt.plot(epochs_axis, epoch_losses, marker="o")
plt.title("Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True, linestyle="--", alpha=0.4)

# 右图：验证准确率（若有）
#plt.subplot(1, 2, 2)
valid_acc = [a for a in epoch_accs if a is not None]
valid_epochs = [i + 1 for i, a in enumerate(epoch_accs) if a is not None]
if valid_acc:
    plt.plot(valid_epochs, valid_acc, marker="o", color="green")
    plt.ylim(0, 1)
plt.title("Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.grid(True, linestyle="--", alpha=0.4)

# 调整布局并显示
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10) 训练后单图验证与可选模型加载推理

# %%
# 训练后随机抽样做一次单图验证
single_sample_check(model, test_dataset)

# 可选：加载某个 checkpoint 后再做单图推理
# model2 = MyCNN()
# model2.load_state_dict(torch.load(os.path.join(checkpoint_dir, "model_epoch_8.pth"), map_location="cpu"))
# single_sample_check(model2, test_dataset)
# Out:
# Single Image Validation
# Image: d:\CZ_WorkSpace\ai学习\深度学习实践\task1\MNIST_kaggle\testSet\img_7064.jpg
# Pred Label: 7, Confidence: 0.6555 (no ground-truth label)

# %%
# 11) 加载模型参数并对测试集推理（导出 Kaggle 提交文件）
# 引入 DataLoader 以便批量推理
from torch.utils.data import DataLoader

# TODO: 修改为你要加载的权重文件路径
ckpt_path = os.path.join(checkpoint_dir, "model_epoch_8.pth")

# 初始化模型并加载权重
infer_model = MyCNN()
infer_model.load_state_dict(torch.load(ckpt_path, map_location="cpu"))
infer_model.eval()

# 构建推理 DataLoader（无标签）
infer_loader = DataLoader(test_dataset, batch_size=128, shuffle=False)
pred_records = []
with torch.no_grad():
    for images, file_paths in infer_loader:
        # 前向推理得到 logits
        logits = infer_model(images)
        # 取最大值所在类别作为预测结果
        preds = torch.argmax(logits, dim=1).cpu().numpy().tolist()
        for path, pred in zip(file_paths, preds):
            # 从文件名中解析 ImageId
            base = os.path.basename(path)
            match = re.search(r"\d+", base)
            if match is None:
                raise ValueError(f"Cannot parse image id from filename: {base}")
            image_id = int(match.group())
            pred_records.append((image_id, pred))

# 按 ImageId 升序排序，符合 Kaggle 提交格式
pred_records.sort(key=lambda x: x[0])
submit_df = pd.DataFrame(pred_records, columns=["ImageId", "Label"])

# 保存提交文件到当前工作目录
submit_path = os.path.join(os.getcwd(), "kaggle_submit.csv")
submit_df.to_csv(submit_path, index=False)
print(f"Saved submission file: {submit_path}")
print(submit_df.head())
# Out:
# Saved submission file: d:\CZ_WorkSpace\ai学习\深度学习实践\task1\task1_2\kaggle_submit.csv
#    ImageId  Label
# 0        1      2
# 1        2      0
# 2        3      9
# 3        4      9
# 4        5      3
